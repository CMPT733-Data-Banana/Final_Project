# %%
import pandas as pd

# %%
df_1=pd.read_csv("bc_rest_open.csv")

# %%
category_list_client=pd.DataFrame()

# %%
category_list_client['categories']=df_1.categories

# %%
from re import split

# %%
# from itertools import groupby


# results = {value: len(list(sorted(freq))) for value, freq in groupby(sorted(df_1.name))}
# results

# %%
# import pprint
# pp = pprint.PrettyPrinter(depth=4)
# pp.pprint(results)

# %%
# rest2=df_1[df_1['name']=='De Dutch']

# %%
# rest2

# %%
# rest2_cat=rest2['categories']
# rest2_cat

# %%
# rest2_comp=df_1[df_1.categories.isin(rest2.categories)]

# %%
# rest2_comp

# %%
# rest2_comp.sort_values('stars',ascending=False)

# %%
# rest2_comp_filter=rest2_comp[rest2_comp['stars'] >= 4.0]

# %%
# rest2_comp_filter=rest2_comp_filter[rest2_comp_filter['review_count'] >= 100]

# %%
# rest2_comp_filter

# %%
# rest2_comp_filter = rest2_comp_filter[rest2_comp_filter['name'].str.contains("De Dutch")== False]
# rest2_coords=rest2_comp_filter[['business_id','name','stars','latitude','longitude']]

# %%
# rest2_coords

# %%
# rest2_og_coords=rest2[['business_id','name','stars','latitude','longitude']]

# %%
# rest2_og_coords

# %%
# rest2_og_coords.to_csv('rest2og.csv')

# %%
# rest2_coords.to_csv('rest2.csv')

# %%
rest1=df_1[df_1.name=='Mucho Burrito']

#rest1

# %%
rest1_comp=df_1[df_1.categories.isin(rest1.categories)]

rest1_comp
# Out:
#                  business_id                             name  \
# 116   bWmgiuAxZC60YoE1IgMiHg                   Tacofino Oasis
# 509   oAv2XW5i-w3A-pESAu1Abw                    Mucho Burrito
# 693   fm6crzNySAjkHGGbsOz_fg                          Quesada
# 1185  wtyCB3iRPHSXNxmtZsg89A                    Tacofino Ocho
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria
# 1437  FTcqO7j-A6Z3NVEs_Or6-g     Charlie's Mexican Restaurant
# 1451  LiEz1GBLKwYBW7n4H9YxzQ                    Mucho Burrito
# 1955  VCzzjdi1FU7gPOQsSReSXw                          Don Oso
# 2083  Nrmsdtg10pyX2Qm2nZcVSg                     Best Burrito
# 2514  w-WIdtND5jGIiiYoFjhtmg                        La Casita
# 2535  rr3fgRYPxcXt0pACSaAjew                         Tacofino
# 2755  aqchZyKeC32rmPX5I2DYYw                    Mucho Burrito
# 2816  jEhTKvmL7RM-7j_ipovizg     La Taqueria Pinche Taco Shop
# 3400  P3XAouZt4PXHRurzfirJxw                 Rosarito Burrito
# ...

# %%
rest1_comp.sort_values('stars',ascending=False)
# Out:
#                  business_id                             name  \
# 4296  XDWS4Rayi52jrN0z0ibG4Q                 Mi Casa Mexicana
# 4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos
# 3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina
# 116   bWmgiuAxZC60YoE1IgMiHg                   Tacofino Oasis
# 2755  aqchZyKeC32rmPX5I2DYYw                    Mucho Burrito
# 4453  k7AMSxc3qWaSychj1EpLTg                       La Cantina
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria
# 4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón
# 4446  t2ssQUXsQILshsn6IJa00Q             Ole Ole Mexican Deli
# 4149  bUyJ7AHN-dXCewS0NVw7jQ                       Lucky Taco
# 3725  9v0Iz8rR1-CK3GumfuSwgw                    Mucho Burrito
# 2816  jEhTKvmL7RM-7j_ipovizg     La Taqueria Pinche Taco Shop
# 2535  rr3fgRYPxcXt0pACSaAjew                         Tacofino
# 1955  VCzzjdi1FU7gPOQsSReSXw                          Don Oso
# ...

# %%
rest1_comp_filter=rest1_comp[rest1_comp['stars'] >= 4.0]
rest1_comp_filter
# Out:
#                  business_id                             name  \
# 116   bWmgiuAxZC60YoE1IgMiHg                   Tacofino Oasis
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria
# 2755  aqchZyKeC32rmPX5I2DYYw                    Mucho Burrito
# 3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina
# 4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón
# 4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos
# 4296  XDWS4Rayi52jrN0z0ibG4Q                 Mi Casa Mexicana
# 4453  k7AMSxc3qWaSychj1EpLTg                       La Cantina
#
#                           address       city state postal_code   latitude  \
# 116             122-1050 W Pender  Vancouver    BC         V6E  49.286801
# 1299        1622 Commercial Drive  Vancouver    BC     V5L 3Y4  49.270090
# 2755            7113 120th Street      Delta    BC     V4E 2A9  49.131666
# 3746        1049 Granville Street  Vancouver    BC     V6Z 1L4  49.278828
# ...

# %%
rest1_comp_filter=rest1_comp_filter[rest1_comp_filter['review_count'] >= 100]
rest1_comp_filter
# Out:
#                  business_id                             name  \
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria
# 3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina
# 4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón
# 4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos
#
#                           address       city state postal_code   latitude  \
# 1299        1622 Commercial Drive  Vancouver    BC     V5L 3Y4  49.270090
# 3746        1049 Granville Street  Vancouver    BC     V6Z 1L4  49.278828
# 4085  701 Kingsway Street, Unit 5  Vancouver    BC     V5T 3K6  49.256904
# 4089           1187 Denman Street  Vancouver    BC     V6G 2N1  49.287774
#
#        longitude  stars  review_count  is_open  \
# 1299 -123.069500    4.0           242        1
# 3746 -123.124044    4.5           356        1
# 4085 -123.089246    4.0           581        1
# 4089 -123.141263    4.5           101        1
#
# ...

# %%
rest1_comp_filter = rest1_comp_filter[rest1_comp_filter['name'].str.contains("Mucho Burrito")== False]
rest1_coords=rest1_comp_filter[['business_id','name','stars','latitude','longitude']]

# %%
rest1_coords
# Out:
#                  business_id                             name  stars  \
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria    4.0
# 3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina    4.5
# 4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón    4.0
# 4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos    4.5
#
#        latitude   longitude
# 1299  49.270090 -123.069500
# 3746  49.278828 -123.124044
# 4085  49.256904 -123.089246
# 4089  49.287774 -123.141263

# %%
rest1_og_coords=rest1[['business_id','name','stars','latitude','longitude']]

# %%
rest1_og_coords
# Out:
#                  business_id           name  stars   latitude   longitude
# 509   oAv2XW5i-w3A-pESAu1Abw  Mucho Burrito    3.0  49.278722 -123.128947
# 1451  LiEz1GBLKwYBW7n4H9YxzQ  Mucho Burrito    3.0  49.198046 -122.979105
# 2755  aqchZyKeC32rmPX5I2DYYw  Mucho Burrito    4.0  49.131666 -122.892143
# 3725  9v0Iz8rR1-CK3GumfuSwgw  Mucho Burrito    3.5  49.178843 -122.844991

# %%
rest1_og_coords.to_csv('rest1og.csv')

# %%
rest1_coords.to_csv('rest1.csv')

# %%
# results

# %%
#rest4 is here

# %%
rest4=df_1[df_1['name']=='Toshi Sushi']
rest4
# Out:
#                  business_id         name               address       city  \
# 2720  cD-yIXTipTTN336R5c_MMg  Toshi Sushi  181 East 16th Avenue  Vancouver
#
#      state postal_code   latitude   longitude  stars  review_count  is_open  \
# 2720    BC     V5T 4R2  49.256699 -123.101936    4.0           410        1
#
#                                              attributes  \
# 2720  {'RestaurantsAttire': "u'casual'", 'Restaurant...
#
#                              categories  \
# 2720  Sushi Bars, Restaurants, Japanese
#
#                                                   hours
# 2720  {'Tuesday': '16:0-20:0', 'Wednesday': '16:0-20...

# %%
# rest6=df_1[df_1['name']=='Main Kabab Hut']

# rest6

# %%
rest4.categories
# Out:
# 2720    Sushi Bars, Restaurants, Japanese
# Name: categories, dtype: object

# %%
rest4_comp = df_1[df_1['categories'].str.contains('Sushi')]

rest4_comp
# Out:
#                  business_id                         name  \
# 7     XqaO85CV9Km7m_aQ3iIpRA             Cactus Club Cafe
# 16    7lRIEq5_tBBR1T9d_vTDvQ                  Yoko Sushi
# 17    mvCO6pRpfMB0_1GLlwgZRw             Sushi California
# 22    rDLPdfI6TOsQlTf6AQaCTA    Akari Japanese Restaurant
# 32    _aGG6e3dWYrKyFNpdK_vpA  Sushi Maki Japanese Cuisine
# ...                      ...                          ...
# 4671  vnOhpYbHv7PZXD1iwKytXg               Everyday Sushi
# 4682  tm7wfsNwucLsDhXnknmyCw          Aero Inn Sushi Cafe
# 4686  wF5gy4a0pBAA5QTQ_ceOWQ               Hanamori Sushi
# 4718  HRmLSZKvoER_UhqObL5zng                     Tomokazu
# 4725  jrW5mnMLDp2BeGZh8A6VFg                  Sushi Ninja
#
#                        address       city state postal_code   latitude  \
# 7      1666-6551 Number 3 Road   Richmond    BC     V6Y 2B6  49.166831
# 16          1001 Austin Avenue  Coquitlam    BC     V3K 3N9  49.249298
# ...

# %%
rest4_comp_filter=rest4_comp[rest4_comp['stars'] >= 4]
rest4_comp_filter
# Out:
#                  business_id                       name  \
# 16    7lRIEq5_tBBR1T9d_vTDvQ                Yoko Sushi
# 22    rDLPdfI6TOsQlTf6AQaCTA  Akari Japanese Restaurant
# 84    t6eEIUaZK97tEejpDNa4cw                Sushi Karis
# 160   jrVEB7FPeD7zeLdYfmnwVg   Kuma Japanese Restaurant
# 166   szPJyzsly0a5ZkehLAV1fA                  Pokérrito
# ...                      ...                        ...
# 4625  uZGQy70xpYkUzQxTpKoXaA        Yui Japanese Bistro
# 4631  S6QRnCQVpEqQRyszrF51bw           Ajisai Sushi Bar
# 4641  CjQMcgDgX_RdpSNby266oA            Tsuki Sushi Bar
# 4652  6k1omPa3O3Kl7lSjXfCxvA             Octopus Garden
# 4686  wF5gy4a0pBAA5QTQ_ceOWQ             Hanamori Sushi
#
#                         address       city state postal_code   latitude  \
# 16           1001 Austin Avenue  Coquitlam    BC     V3K 3N9  49.249298
# 22              7261 120 Street      Delta    BC     V4C 6P5  49.134883
# 84            504 Nelson Street  Coquitlam    BC     V3J 7R4  49.249346
# ...

# %%
rest4_comp_filter=rest4_comp_filter[rest4_comp_filter['review_count'] >= 100]
rest4_comp_filter
# Out:
#                  business_id                             name  \
# 166   szPJyzsly0a5ZkehLAV1fA                        Pokérrito
# 307   G3jAGk0OUS_hkrsD4ERevA            Sushimoto Enterprises
# 369   9UThLJTuOQPLcDCLx5BVqw                    Sushi By Yuji
# 376   j7VmHg9M-eWZuDw-p4AIaA         Seto Japanese Restaurant
# 455   irdrKokOvuxP_atEjtzkQA                 Green Leaf Sushi
# 500   NBiBIk83cYjWnFS8QTJWyg                      Kaide Sushi
# 665   gpTJqlxw4_bI_7K_R_Fw4w            Fujiya Japanese Foods
# 991   iMtUsHOqitE6Aau59K_XRg                        Sushi Jin
# 1136  e30bAA7PQfbbvZOc5LLuvA                  Kimbap Cheonguk
# 1355  UqqkI-YNmfpng4BKj8kxcg  Sushi Hachi Japanese Restaurant
# 1450  FmD4x9ClmSzSLKOTV7jfXw  Hitoe Sushi Japanese Restaurant
# 1531  o5YLdmUogknjtDzUBv5Smw                        Tom Sushi
# 1541  pJNRkDPA_2wLv_0Bj6fzww                 Sushi K Kamizato
# 1724  Cw-_dU8r4A_Z9nsCIigibA            Tatsu Japanese Bistro
# ...

# %%
rest4
# Out:
#                  business_id         name               address       city  \
# 2720  cD-yIXTipTTN336R5c_MMg  Toshi Sushi  181 East 16th Avenue  Vancouver
#
#      state postal_code   latitude   longitude  stars  review_count  is_open  \
# 2720    BC     V5T 4R2  49.256699 -123.101936    4.0           410        1
#
#                                              attributes  \
# 2720  {'RestaurantsAttire': "u'casual'", 'Restaurant...
#
#                              categories  \
# 2720  Sushi Bars, Restaurants, Japanese
#
#                                                   hours
# 2720  {'Tuesday': '16:0-20:0', 'Wednesday': '16:0-20...

# %%
rest4_comp_filter = rest4_comp_filter[rest4_comp_filter['name'].str.contains("Toshi Sushi")== False]
rest4_coords=rest4_comp_filter[['business_id','name','stars','latitude','longitude']]

# %%
rest4_coords
# Out:
#                  business_id                             name  stars  \
# 166   szPJyzsly0a5ZkehLAV1fA                        Pokérrito    4.0
# 307   G3jAGk0OUS_hkrsD4ERevA            Sushimoto Enterprises    4.0
# 369   9UThLJTuOQPLcDCLx5BVqw                    Sushi By Yuji    4.0
# 376   j7VmHg9M-eWZuDw-p4AIaA         Seto Japanese Restaurant    4.0
# 455   irdrKokOvuxP_atEjtzkQA                 Green Leaf Sushi    4.0
# 500   NBiBIk83cYjWnFS8QTJWyg                      Kaide Sushi    4.5
# 665   gpTJqlxw4_bI_7K_R_Fw4w            Fujiya Japanese Foods    4.0
# 991   iMtUsHOqitE6Aau59K_XRg                        Sushi Jin    4.5
# 1136  e30bAA7PQfbbvZOc5LLuvA                  Kimbap Cheonguk    4.5
# 1355  UqqkI-YNmfpng4BKj8kxcg  Sushi Hachi Japanese Restaurant    4.5
# 1450  FmD4x9ClmSzSLKOTV7jfXw  Hitoe Sushi Japanese Restaurant    4.0
# 1531  o5YLdmUogknjtDzUBv5Smw                        Tom Sushi    5.0
# 1541  pJNRkDPA_2wLv_0Bj6fzww                 Sushi K Kamizato    4.0
# ...

# %%
rest4_coords.to_csv('rest4.csv')

# %%
rest4_og_coords=rest4[['business_id','name','stars','latitude','longitude']]

# %%
rest4_og_coords.to_csv('rest4og.csv')

# %%
#rest3 starts here

# %%
# rest3=df_1[df_1['name']=='Cactus Club Cafe']

# %%
# rest3

# %%
# rest3_comp = df_1[df_1['categories'].str.contains('Nightlife','Cocktail')]

# rest3_comp

# %%
# rest3_comp_filter=rest3_comp[rest3_comp['stars'] >= 4]
# rest3_comp_filter

# %%
# rest3_comp_filter=rest3_comp_filter[rest3_comp_filter['review_count'] >= 100]
# rest3_comp_filter

# %%
# rest3_comp_filter = rest3_comp_filter[rest3_comp_filter['name'].str.contains("Cactus Club Cafe")== False]
# rest3_coords=rest3_comp_filter[['business_id','name','stars','latitude','longitude']]

# %%
# rest3_coords

# %%
# rest3_coords.to_csv('rest3.csv')

# %%
# rest3_og_coords=rest3[['business_id','name','stars','latitude','longitude']]

# %%
# rest3_og_coords.to_csv('rest3og.csv')

# %%
#rest 5 starts here

# %%
rest5=df_1[df_1['name']=='Sula Indian Restaurant']

# %%
# rest5

# %%
rest5_comp=df_1[df_1['categories'].str.contains('Indian')]

# %%
# rest5_comp

# %%
rest5_comp_filter=rest5_comp[rest5_comp['stars'] >= 4.0]

# %%
rest5_comp_filter=rest5_comp_filter[rest5_comp_filter['review_count'] >= 100]

# %%
len(rest5_comp_filter)
# Out:
# 24

# %%
rest5_comp_filter = rest5_comp_filter[rest5_comp_filter['name'].str.contains("Sula Indian Restaurant")== False]
rest5_coords=rest5_comp_filter[['business_id','name','stars','latitude','longitude']]

# %%
rest5_coords=rest5_coords.sort_values('stars',ascending=False)

# %%
rest5_coords
# Out:
#                  business_id                                           name  \
# 2130  pJge_LJ3NV8iQtrERe6AyQ                            Indian Roti Kitchen
# 510   usO5eH44mmub9p_pH95OkQ                          Delhi 6 Indian Bistro
# 3521  jOZ6AKjTuOWZ7tUabuZq9A                              Mirchi Restaurant
# 681   uuQse7YxCrnedtJh9gKgpg                       Indian Fusion Restaurant
# 1338  cp6Bq3-VcearblmgKK1rBQ                                    Dosa Corner
# 1649  R47URO-i0MvfgKvD3sINow                  Lazzez's Grill Indian Cuisine
# 108   _Ief3C6t-930SBuwvVuDAQ                            Tasty Indian Bistro
# 2807  9R4vBq3BUYom9geOTiFs0w                                   East Is East
# 3983  dR3UkEvdjJ5fAec0ScMQvg                                   Salam Bombay
# 3588  ytp2-sO-na8NyLK9I2QX2g  Green Lettuce Indian Style Chinese Restaurant
# 3511  m1SJ6Nn7i-gKZETlf8AoOw                           Indian Bombay Bistro
# ...

# %%
rest5_coords.to_csv('rest5.csv')

# %%
rest5_og_coords=rest5[['business_id','name','stars','latitude','longitude']]

# %%
rest5_og_coords.to_csv('rest5og.csv')

# %%
#folium part starts here

# %%
# !pip3 install folium
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
#read all the files
import pandas as pd

# %%
mb1 = pd.read_csv("rest1og.csv")
mb1
# Out:
#    Unnamed: 0             business_id           name  stars   latitude  \
# 0         509  oAv2XW5i-w3A-pESAu1Abw  Mucho Burrito    3.0  49.278722
# 1        1451  LiEz1GBLKwYBW7n4H9YxzQ  Mucho Burrito    3.0  49.198046
# 2        2755  aqchZyKeC32rmPX5I2DYYw  Mucho Burrito    4.0  49.131666
# 3        3725  9v0Iz8rR1-CK3GumfuSwgw  Mucho Burrito    3.5  49.178843
#
#     longitude
# 0 -123.128947
# 1 -122.979105
# 2 -122.892143
# 3 -122.844991

# %%
mbc1 = pd.read_csv("rest1.csv")
mbc1
# Out:
#    Unnamed: 0             business_id                             name  stars  \
# 0        1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria    4.0
# 1        3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina    4.5
# 2        4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón    4.0
# 3        4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos    4.5
#
#     latitude   longitude
# 0  49.270090 -123.069500
# 1  49.278828 -123.124044
# 2  49.256904 -123.089246
# 3  49.287774 -123.141263

# %%
# mb2 = pd.read_csv("rest2og.csv")
# mb2

# %%
# mbc2 = pd.read_csv("rest2.csv")
# mbc2

# %%
# mb3 = pd.read_csv("rest3og.csv")
# mb3

# %%
# mbc3 = pd.read_csv("rest3.csv")
# mbc3

# %%
mb4 = pd.read_csv("rest4og.csv")
mb4
# Out:
#    Unnamed: 0             business_id         name  stars   latitude  \
# 0        2720  cD-yIXTipTTN336R5c_MMg  Toshi Sushi    4.0  49.256699
#
#     longitude
# 0 -123.101936

# %%
mbc4 = pd.read_csv("rest4.csv")
mbc4
# Out:
#     Unnamed: 0             business_id                             name  \
# 0          166  szPJyzsly0a5ZkehLAV1fA                        Pokérrito
# 1          307  G3jAGk0OUS_hkrsD4ERevA            Sushimoto Enterprises
# 2          369  9UThLJTuOQPLcDCLx5BVqw                    Sushi By Yuji
# 3          376  j7VmHg9M-eWZuDw-p4AIaA         Seto Japanese Restaurant
# 4          455  irdrKokOvuxP_atEjtzkQA                 Green Leaf Sushi
# 5          500  NBiBIk83cYjWnFS8QTJWyg                      Kaide Sushi
# 6          665  gpTJqlxw4_bI_7K_R_Fw4w            Fujiya Japanese Foods
# 7          991  iMtUsHOqitE6Aau59K_XRg                        Sushi Jin
# 8         1136  e30bAA7PQfbbvZOc5LLuvA                  Kimbap Cheonguk
# 9         1355  UqqkI-YNmfpng4BKj8kxcg  Sushi Hachi Japanese Restaurant
# 10        1450  FmD4x9ClmSzSLKOTV7jfXw  Hitoe Sushi Japanese Restaurant
# 11        1531  o5YLdmUogknjtDzUBv5Smw                        Tom Sushi
# ...

# %%
mb5 = pd.read_csv("rest5og.csv")
mb5
# Out:
#    Unnamed: 0             business_id                    name  stars  \
# 0        1619  l0cLT4c59zu0H8MVwp7vqA  Sula Indian Restaurant    4.0
#
#     latitude   longitude
# 0  49.274434 -123.069188

# %%
mbc5 = pd.read_csv("rest5.csv")
mbc5
# Out:
#     Unnamed: 0             business_id  \
# 0         2130  pJge_LJ3NV8iQtrERe6AyQ
# 1          510  usO5eH44mmub9p_pH95OkQ
# 2         3521  jOZ6AKjTuOWZ7tUabuZq9A
# 3          681  uuQse7YxCrnedtJh9gKgpg
# 4         1338  cp6Bq3-VcearblmgKK1rBQ
# 5         1649  R47URO-i0MvfgKvD3sINow
# 6          108  _Ief3C6t-930SBuwvVuDAQ
# 7         2807  9R4vBq3BUYom9geOTiFs0w
# 8         3983  dR3UkEvdjJ5fAec0ScMQvg
# 9         3588  ytp2-sO-na8NyLK9I2QX2g
# 10        3511  m1SJ6Nn7i-gKZETlf8AoOw
# 11        3434  xzxi_8_UnznXPOr1p5Fl_A
# 12        3421  18aIKschS0rNDNr0sXWtww
# 13        2907  BdsPT4VZtbJeozhrcgk4XA
# 14          93  VCiopspKLHelqobEsSeNxw
# 15        2597  UwQyc3prSQp3pnvdSSmlaQ
# 16        2391  afIFneEf68Td1m3QCCzy0g
# 17        2129  mKp5lyy0GTV0hGNEkuwuQQ
# 18        1164  eqpBdNm-UtMIsodfxLU7MA
# 19         630  l3Uni57g7J1N7WvAKEzbMg
# 20         437  raZ-NDBs9S1j9fPONh4fWw
# 21         119  QxNVmWT2UXjbJrYuOqlCMQ
# 22        4148  Z97LdaraBqS6lMlgt89IiA
#
# ...

# %%
import folium

# %%
#!pip3 install geopandas

# %%
import geopandas as gpd

# %%
p = folium.Map(location=[49.285006, -123.118050], zoom_start=10, control_scale=True)
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# gdf = gpd.GeoDataFrame(
#     mbc1, geometry=gpd.points_from_xy(mbc1.longitude, mbc1.latitude))

# %%
# gdf.crs = "EPSG:4326"

# %%
# points_gjson = folium.features.GeoJson(gdf, name="Compettitors for Mucho Buritto")
# points_gjson.add_to(p)

# folium.LayerControl().add_to(p)

# %%
# gdf2 = gpd.GeoDataFrame(
#     mb1, geometry=gpd.points_from_xy(mb1.longitude, mb1.latitude))

# %%
# gdf2.crs = "EPSG:4326"

# %%
r1fg = folium.FeatureGroup(name='Mucho Buritto',overlay=True)
r1cfg = folium.FeatureGroup(name='Mucho Buritto Compititors',overlay=True)

# r2fg = folium.FeatureGroup(name='De Dutch',overlay=True)
# r2cfg = folium.FeatureGroup(name='De Dutch Compititors',overlay=True)

# r3fg = folium.FeatureGroup(name='Cactus Club Cafe',overlay=True)
# r3cfg = folium.FeatureGroup(name='Cactus Club Cafe Compititors',overlay=True)

r4fg = folium.FeatureGroup(name='Toshi Sushi',overlay=True)
r4cfg = folium.FeatureGroup(name='Toshi Sushi Compititors',overlay=True)

r5fg = folium.FeatureGroup(name='SULA Indian Restaurant',overlay=True)
r5cfg = folium.FeatureGroup(name='SULA Indian Restaurant Compititors',overlay=True)


r1fg.add_to(p)
r1cfg.add_to(p)

# r2fg.add_to(p)
# r2cfg.add_to(p)


# r3fg.add_to(p)
# r3cfg.add_to(p)

r4fg.add_to(p)
r4cfg.add_to(p)

r5fg.add_to(p)
r5cfg.add_to(p)

# %%
folium.LayerControl(collapsed= False).add_to(p)

#p

# %%
for index, row in mb1.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'lightgreen',icon='glass')
                 ).add_to(r1fg)


a = mbc1['latitude'].to_list()
b = mbc1['longitude'].to_list()
points = []

c = mb1['latitude'].to_list()
d = mb1['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc1.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'darkred', icon = 'star')
                 ).add_to(r1cfg)

# %%
# for index, row in mb2.iterrows():
#     folium.Marker([row['latitude'], row['longitude']], 
#                   popup=row[['name','stars']],
#                   icon=folium.Icon(color = 'darkblue',icon='glass')
#                  ).add_to(r2fg)


# a = mbc2['latitude'].to_list()
# b = mbc2['longitude'].to_list()
# points = []

# c = mb2['latitude'].to_list()
# d = mb2['longitude'].to_list()
# pointsc = []

# for i in range(len(a)):
#     points.append([a[i], b[i]])
    
# for i in range(len(c)):
#     pointsc.append([c[i], d[i]])

# for index, row in mbc2.iterrows():
        
#     iframe = folium.IFrame(width=200, height=200)
#     popup = folium.Popup(iframe, max_width=2650)
#     folium.Marker([row['latitude'], row['longitude']], 
#                   popup=row[['name','stars']],
#                   icon=folium.Icon(color = 'beige', icon = 'star')
#                  ).add_to(r2cfg)

# %%
# for index, row in mb3.iterrows():
#     folium.Marker([row['latitude'], row['longitude']], 
#                   popup=row[['name','stars']],
#                   icon=folium.Icon(color = 'pink',icon='glass')
#                  ).add_to(r3fg)


# a = mbc3['latitude'].to_list()
# b = mbc3['longitude'].to_list()
# points = []

# c = mb3['latitude'].to_list()
# d = mb3['longitude'].to_list()
# pointsc = []

# for i in range(len(a)):
#     points.append([a[i], b[i]])
    
# for i in range(len(c)):
#     pointsc.append([c[i], d[i]])

# for index, row in mbc3.iterrows():
        
#     iframe = folium.IFrame(width=200, height=200)
#     popup = folium.Popup(iframe, max_width=2650)
#     folium.Marker([row['latitude'], row['longitude']], 
#                   popup=row[['name','stars']],
#                   icon=folium.Icon(color = 'lightblue', icon = 'star')
#                  ).add_to(r3cfg)

# %%
for index, row in mb4.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'biege',icon='glass')
                 ).add_to(r4fg)


a = mbc4['latitude'].to_list()
b = mbc4['longitude'].to_list()
points = []

c = mb4['latitude'].to_list()
d = mb4['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc4.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'purple', icon = 'star')
                 ).add_to(r4cfg)
# Out:
# /var/folders/5d/yhcn6m7d2pn9ytcsv1j2890w0000gn/T/ipykernel_2933/1242786004.py:4: UserWarning: color argument of Icon should be one of: {'darkgreen', 'red', 'cadetblue', 'lightgray', 'darkpurple', 'darkred', 'blue', 'darkblue', 'green', 'lightred', 'lightblue', 'gray', 'purple', 'pink', 'white', 'beige', 'orange', 'black', 'lightgreen'}.
#   icon=folium.Icon(color = 'biege',icon='glass')

# %%
for index, row in mb5.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'cadetblue',icon='glass')
                 ).add_to(r5fg)


a = mbc5['latitude'].to_list()
b = mbc5['longitude'].to_list()
points = []

c = mb5['latitude'].to_list()
d = mb5['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc5.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'lightgray', icon = 'star')
                 ).add_to(r5cfg)

# %%
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
outfp = "rest_base_map.html"
p.save(outfp)

# %%
# folium.Marker(mbc1, icon=folium.Icon(color='cadetblue',icon = 'fa-industry', prefix='fa')).add_to(gdf1)

# folium.Marker(mb1,icon=folium.Icon(color='cadetblue',icon = 'fa-industry', prefix='fa')).add_to(gdf2)
# p.add_child(gdf1)
# p.add_child(gdf2)

# %%
# points_gjson2 = folium.features.GeoJson(gdf2, name="Mucho Buritto")
# folium.LayerControl().add_to(p)


# points_gjson2.add_to(p)


# folium.LayerControl().add_to(p)

# %%
p

# %%
# # Create a Map instance

# # Add points to the map instance
# points_gjson.add_to(p)

# # Alternative syntax for adding points to the map instance
# #m.add_child(points_gjson)


# #Show map
# p

# %%
# folium.LayerControl().add_to(p)
# p.add_child(points_gjson)

# #Show map
# p

# %%
q = folium.Map(location=[49.285006, -123.118050], zoom_start=12, control_scale=True)

# %%
r1fg = folium.FeatureGroup(name='Mucho Buritto',overlay=True)
r1cfg = folium.FeatureGroup(name='Mucho Buritto Competitors',overlay=True)

# %%
r1fg.add_to(q)
r1cfg.add_to(q)

# %%
for index, row in mb1.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  tooltip='Reviews:'+str(row['stars'])+'\n'+'Name'+':'+ str(row['name']),
                  icon=folium.Icon(color = 'pink',icon='glass')
                 ).add_to(r1fg)


a = mbc1['latitude'].to_list()
b = mbc1['longitude'].to_list()
points = []

c = mb1['latitude'].to_list()
d = mb1['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc1.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
                  icon=folium.Icon(color = 'darkpurple', icon = 'star')
                 ).add_to(r1cfg)

# %%
folium.LayerControl(collapsed= False).add_to(q)

# %%
q
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
outfp = "Mucho Buritto wide map.html"
q.save(outfp)

# %%
#mexican rest ends here

# %%
# r = folium.Map(location=[49.285006, -123.118050], zoom_start=12, control_scale=True)

# %%
# r2fg = folium.FeatureGroup(name='De Dutch',overlay=True)
# r2cfg = folium.FeatureGroup(name='De Dutch Competitors',overlay=True)

# r2fg.add_to(r)
# r2cfg.add_to(r)

# %%
# for index, row in mb2.iterrows():
#     folium.Marker([row['latitude'], row['longitude']], 
#                   tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
#                   icon=folium.Icon(color = 'pink',icon='glass')
#                  ).add_to(r2fg)


# a = mbc2['latitude'].to_list()
# b = mbc2['longitude'].to_list()
# points = []

# c = mb2['latitude'].to_list()
# d = mb2['longitude'].to_list()
# pointsc = []

# for i in range(len(a)):
#     points.append([a[i], b[i]])
    
# for i in range(len(c)):
#     pointsc.append([c[i], d[i]])

# for index, row in mbc2.iterrows():
        
#     iframe = folium.IFrame(width=200, height=200)
#     popup = folium.Popup(iframe, max_width=2650)
#     folium.Marker([row['latitude'], row['longitude']], 
#                   tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
#                   icon=folium.Icon(color = 'darkpurple', icon = 'star')
#                  ).add_to(r2cfg)

# %%
# folium.LayerControl().add_to(r)

# %%
# r

# %%
# outfp = "canadian_rest.html"
# r.save(outfp)

# %%
# s = folium.Map(location=[49.285006, -123.118050], zoom_start=10, control_scale=True)

# %%
# r3fg = folium.FeatureGroup(name='Cactus Club Cafe',overlay=True)
# r3cfg = folium.FeatureGroup(name='Cactus Club Cafe Competitors',overlay=True)


# r3fg.add_to(s)
# r3cfg.add_to(s)

# %%
# for index, row in mb3.iterrows():
#     folium.Marker([row['latitude'], row['longitude']], 
#                   tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
#                   icon=folium.Icon(color = 'pink',icon='glass')
#                  ).add_to(r3fg)


# a = mbc3['latitude'].to_list()
# b = mbc3['longitude'].to_list()
# points = []

# c = mb3['latitude'].to_list()
# d = mb3['longitude'].to_list()
# pointsc = []

# for i in range(len(a)):
#     points.append([a[i], b[i]])
    
# for i in range(len(c)):
#     pointsc.append([c[i], d[i]])

# for index, row in mbc3.iterrows():
        
#     iframe = folium.IFrame(width=200, height=200)
#     popup = folium.Popup(iframe, max_width=2650)
#     folium.Marker([row['latitude'], row['longitude']], 
#                   tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
#                   icon=folium.Icon(color = 'darkpurple', icon = 'star')
#                  ).add_to(r3cfg)

# %%
# folium.LayerControl().add_to(s)
# s

# %%
# outfp = "nightlife_rest.html"
# s.save(outfp)

# %%
t = folium.Map(location=[49.285006, -123.118050], zoom_start=12, control_scale=True)

# %%
r4fg = folium.FeatureGroup(name='Toshi Sushi',overlay=True)
r4cfg = folium.FeatureGroup(name='Toshi Sushi Competitors',overlay=True)


r4fg.add_to(t)
r4cfg.add_to(t)

# %%
for index, row in mb4.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
                  icon=folium.Icon(color = 'pink',icon='glass')
                 ).add_to(r4fg)


a = mbc4['latitude'].to_list()
b = mbc4['longitude'].to_list()
points = []

c = mb4['latitude'].to_list()
d = mb4['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc4.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
                  icon=folium.Icon(color = 'darkpurple', icon = 'star')
                 ).add_to(r4cfg)

# %%
folium.LayerControl(collapsed= False).add_to(t)
t
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
outfp = "Toshi Sushi Wide.html"
t.save(outfp)

# %%
u = folium.Map(location=[49.285006, -123.118050], zoom_start=12, control_scale=True)

# %%
r5fg = folium.FeatureGroup(name='SULA Indian Restaurant',overlay=True)
r5cfg = folium.FeatureGroup(name='SULA Indian Restaurant Competitors',overlay=True)

r5fg.add_to(u)
r5cfg.add_to(u)

# %%
for index, row in mb5.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
                  icon=folium.Icon(color = 'pink',icon='glass')
                 ).add_to(r5fg)


a = mbc5['latitude'].to_list()
b = mbc5['longitude'].to_list()
points = []

c = mb5['latitude'].to_list()
d = mb5['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc5.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  tooltip='Reviews:'+str(row['stars'])+'\t'+'Name'+':'+ str(row['name']),
                  icon=folium.Icon(color = 'darkpurple', icon = 'star')
                 ).add_to(r5cfg)

# %%
mbc5['latitude']
mbc5['longitude']
# Out:
# 0    -123.115355
# 1    -123.144968
# 2    -123.140140
# 3    -123.072428
# 4    -123.090829
# 5    -122.804792
# 6    -122.890501
# 7    -123.172693
# 8    -123.121840
# 9    -123.065938
# 10   -122.932603
# 11   -122.890066
# 12   -123.133735
# 13   -123.020050
# 14   -123.076325
# 15   -123.123969
# 16   -123.041712
# 17   -123.101476
# 18   -123.125714
# 19   -123.076990
# 20   -123.114788
# 21   -123.169557
# 22   -123.130517
# Name: longitude, dtype: float64

# %%
mbc5['latitude']
# Out:
# 0     49.259024
# 1     49.265235
# 2     49.213541
# 3     49.327987
# 4     49.209751
# 5     49.277355
# 6     49.154520
# 7     49.264389
# 8     49.284023
# 9     49.245795
# 10    49.223157
# 11    49.139607
# 12    49.282163
# 13    49.254436
# 14    49.250466
# 15    49.274317
# 16    49.236280
# 17    49.245353
# 18    49.284819
# 19    49.251000
# 20    49.257537
# 21    49.263968
# 22    49.263478
# Name: latitude, dtype: float64

# %%
folium.LayerControl(collapsed= False).add_to(u)
u
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
outfp = "Sula indian wide map.html"
u.save(outfp)

# %%
# u.write_html('newer.html')

# %%
# outfp = "indian_rest.html"
# u.save(outfp)

# %%
# df_1['name'].max()

# %%
# from sklearn.cluster import DBSCAN
# import matplotlib.pyplot as plt
# import numpy as np

# %%
# coords = burioto_comp[['latitude', 'longitude']].values

# %%
# kms_per_radian = 6371.0088
# epsilon = 1 / kms_per_radian
# db = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree', metric='haversine')

# %%
# labels = db.fit_predict(np.radians(coords))

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True

# %%
# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = labels == k

    xy = coords[class_member_mask & core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=14,
    )

    xy = coords[class_member_mask & ~core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=6,
    )

plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()

# %%
df1_name

# %%
locations_A2=df1_name[['latitude','longitude','name','stars']]
locations_A2

# %%
locations_A2.to_csv('locationwithmeta.csv')

# %%
locations_B2=burioto_comp[['latitude','longitude','name','stars']]

locations_B2

# %%
locations_B2.to_csv('compwithmeta.csv')

# %%
locations_A=df1_name[['latitude','longitude','name']]
locations_B=pd.DataFrame(coords)

# %%
locations_A=locations_A.reset_index()

# %%
df_1.loc[509:,].head(1)

# %%
df_1.loc[1451:,].head(1)

# %%
df_1.loc[2755:,].head(1)

# %%
df_1.loc[3725:,].head(1)

# %%
locations_A

# %%
locations_A.drop(columns='index')

# %%
locations_B

# %%
import pandas as pd
import numpy as np
import sklearn.neighbors
# Create two dataframes with city names and lat-long in degrees

# %%
locations_A

# %%
locations_B.iloc[:, 0]

# %%
locations_A[['lat_radians_A','long_radians_A']] = (
    np.radians(locations_A.loc[:,['latitude','longitude']])
)

# %%
# add columns with radians for latitude and longitude

locations_B[['lat_radians_B','long_radians_B']] = (
    np.radians(locations_B.iloc[:,[0,1]])
)

# %%
locations_B

# %%
dist = sklearn.neighbors.DistanceMetric.get_metric('haversine')
dist_matrix = (dist.pairwise
    (locations_A[['lat_radians_A','long_radians_A']],
     locations_B[['lat_radians_B','long_radians_B']])*3959
)
# Note that 3959 is the radius of the earth in miles
df_dist_matrix = (
    pd.DataFrame(dist_matrix)
)

# %%
# Unpivot this dataframe from wide format to long format.
# When you unpivot, the data in the pivot table becomes a
# column named 'value'. Rename this column to 'miles' for clarity.
df_dist_long = (
    pd.melt(df_dist_matrix.reset_index())
)
df_dist_long = df_dist_long.rename(columns={'value':'miles'})

# %%
df_dist_long

# %%
locations_A

# %%
locations_A.to_csv('mucho_burrito.csv', encoding='utf-8')

# %%
locations_B.to_csv('mucho_burrito_comp.csv', encoding='utf-8')

# %%
pip install folium

# %%
listb1=locations_B.iloc[:,0]
listb2=locations_B.iloc[:,1]

# %%
listb3=pd.concat(listb1,listb2)
listb3

# %%
import folium
m=folium.Map(listb1,listb2)
m

# %%
category_list_client_exploded['categories']=df_1['categories'].str.split(',')

# %%
category_list_client_exploded

# %%
# # initializing the data and an empty list
# flat_list = []

# # iterating over the data
# for item in category_list_client_exploded:
#     # appending elements to the flat_list
#     flat_list += item

# # printing the resultantn flat_list
# print(flat_list)

# %%
competitor_common_categories_df = pd.DataFrame(columns = ['index', 'nr_common_categories', 'list_common_categories'])

competitor_common_categories_df

# %%
cuisines_list = ['Mexican', 'American', 'Italian', 'Indian', 
            'Chinese', 'Mediterranean', 'Pizza', 'Bars']
cusines['cuisines']=pd.DataFrame(cuisines_list)

# %%
cusines

# %%
common_cuisnes=category_list_client_exploded[category_list_client_exploded.isin(cusines)]
common_cuisnes

# %%
cusines

# %%
common_cuisnes2=df_1[df_1['categories'].isin(cusines['cuisines'])]
common_cuisnes2

# %%
pd.Series(list(set(s1).intersection(set(s2))))

# %%
common_cuisnes = (list(set(category_list_client_exploded["categories"])).intersection(set(cusines["cuisines"])))
df_subset = category_list_client_exploded[category_list_client_exploded["categories"].isin(common_users) & cusines["cuisines"].isin(common_users)]

# %%
category_list_client_exploded

# %%
# def get_cuisine(x,y):
#     for cuisine in y:
#         if cuisine in x:
#             print (cuisine)
#             return cuisine
#     else:
#         return 'other'
# get_cuisine(category_list_client_exploded,cuisines)

# %%
# for index, row in category_list_client_exploded.iteritems():
#          print(index,row)

# %%
# category_list_client

# %%
# cuisines = ['mexican', 'american', 'italian', 'indian', 
#             'chinese', 'mediterranean', 'pizza', 'bar']

# %%
###########follium to show clusters of all restaurants

# df_1

# %%
# import folium

# %%
# import pandas as pd

# %%
# latitude =49.285006

# longitude = -123.118050

# map_BC = folium.Map(location=[latitude, longitude], zoom_start=10)

# map_BC

# %%
# rests = df_1[['business_id', 'latitude','longitude','name','stars','city']]

# rests.head()

# %%
# new_rest=rests[['latitude','longitude']]

# %%
# number_of_occurences = pd.DataFrame(rests['stars'].value_counts())
# number_of_occurences.reset_index(inplace=True)
# number_of_occurences.columns = ['stars', 'Count']
# number_of_occurences.head()

# %%
/

# %%
# import matplotlib.pyplot as plt

# %%
# distortions = []

# K = range(1,20)
# for k in K:
#     kmean = KMeans(n_clusters=k, random_state=0, n_init = 50, max_iter = 500)
#     kmean.fit(new_rest)
#     distortions.append(kmean.inertia_)

# %%
# plt.figure(figsize=(10,5))
# plt.plot(K, distortions, 'bx-')
# plt.xlabel('k')
# plt.ylabel('Distortion')
# plt.title('The Elbow Method')
# plt.show()

# %%
# # run k-means clustering
# kmeans = KMeans(n_clusters=4, random_state=0).fit(new_rest)

# new_rest['cluster'] = kmeans.labels_
# new_rest.head()

# %%
# number_of_occurences = number_of_occurences.merge(rests.drop_duplicates())

# number_of_occurences = number_of_occurences.merge(new_rest)

# number_of_occurences.head()

# %%
# data4=number_of_occurences[number_of_occurences['stars']>=4]
# data4

# %%
# rest5_comp_filter=rest5_comp[rest5_comp['stars'] >= 4.0]

# %%
########occc

# %%
# occ = folium.Map(location=[49.285006, -123.118050], zoom_start=10, control_scale=True)

# %%
# r4_fg = folium.FeatureGroup(name='Rest4',overlay=True)
# # r4cfg = folium.FeatureGroup(name='Toshi Sushi Competitors',overlay=True)


# r4_fg.add_to(occ)
# #r4cfg.add_to(t)

# %%
data4[['latitude','longitude']]

# %%
# from folium.plugins import MarkerCluster

# %%
# n_mean = data4['Count'].mean()
# mc = MarkerCluster()

# # for lat, lng, number, city, state in zip(data4['latitude'],
# #                                          data4['longitude'],
# #                                          data4['Count'],
# #                                          data4['stars'],
# #                                          data4['city']):
   

# #           folium.Circle(data4[lat,lng],radius=number/n_mean*5,   color='Red', fill=True, fill_color='blue',
# #              ).add_to(r4_fg)
    
    
    
# mc = MarkerCluster(data4[['latitude','longitude']],radius=number/n_mean*5,   color='Red', fill=True, fill_color='blue',
#              overlay=True,control=True)

# mc.add_to(occ)


# #         folium.vector_layers.CircleMarker(
# #             [lat, lng],
# #             radius=number/n_mean*5, # define how big you want the circle markers to be
# #             color='yellow',
# #             fill=True,
# #             fill_color='blue',
# #             fill_opacity=0.6
# #         )
    

# occ.add_to(occ)

# %%
# folium.LayerControl().add_to(occ)

# %%
# occ

# %%
# occurences = folium.map.FeatureGroup()
# n_mean = data4['Count'].mean()

# for lat, lng, number, city, state in zip(data4['latitude'],
#                                          data4['longitude'],
#                                          data4['Count'],
#                                          data4['stars'],
#                                          data4['city'],):
#     occurences.add_child(
#         folium.vector_layers.CircleMarker(
#             [lat, lng],
#             radius=number/n_mean*5, # define how big you want the circle markers to be
#             color='yellow',
#             fill=True,
#             fill_color='blue',
#             fill_opacity=0.6,
#             tooltip = str(number)+','+ str(city)
#         )
#     )

# map_BC.add_child(occurences)

# %%
# outfp = "4starrest.html"
# map_BC.save(outfp)

# %%
# occurences = folium.map.FeatureGroup()
# n_mean = number_of_occurences['Count'].mean()

# for lat, lng, number, city, state in zip(number_of_occurences['latitude'],
#                                          number_of_occurences['longitude'],
#                                          number_of_occurences['Count'],
#                                          number_of_occurences['stars'],
#                                          number_of_occurences['city'],):
#     occurences.add_child(
#         folium.vector_layers.CircleMarker(
#             [lat, lng],
#             radius=number/n_mean*5, # define how big you want the circle markers to be
#             color='yellow',
#             fill=True,
#             fill_color='blue',
#             fill_opacity=0.6,
#             tooltip = str(number)+','+ str(city)
#         )
#     )

# map_BC.add_child(occurences)

# %%
# import folium

# %%
# latitude =49.285006

# longitude = -123.118050

# %%
# map_BC = folium.Map(location=[latitude, longitude], zoom_start=10)

# %%
# new_fbg=folium.FeatureGroup(name='Rest4',overlay=True)
# new_fbg.add_to(map_BC)

# %%
# n_mean = number_of_occurences['Count'].mean()

# for lat, lng, number, city, state in zip(data4['latitude'],
#                                          data4['longitude'],
#                                          data4['Count'],
#                                          data4['stars'],
#                                          data4['city'],):
#     occurences.add_child(
#         folium.vector_layers.CircleMarker(
#             [lat, lng],
#             radius=number/n_mean*5, # define how big you want the circle markers to be
#             color='yellow',
#             fill=True,
#             fill_color='blue',
#             fill_opacity=0.6,
#             tooltip = str(number)+','+ str(city)
#         )
#     )

# map_BC.add_child(new_fbg)
