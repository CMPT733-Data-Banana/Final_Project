# %%
import pandas as pd

# %%
from wordcloud import STOPWORDS
import nltk

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
stop_list= list(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /Users/Anan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_closed = pd.read_csv("reviews_closed.csv")

# %%
df_open = pd.read_csv("reviews_open.csv")

# %%
df_open
# Out:
#                    business_id                 date                 user_id  \
# 0       KXCXaF5qimmtKKqnPc_LQA  2018-03-03 23:45:25  JHXQEayrDHOWGexs0dCviA
# 1       jMz_y_-cWMfiZF7Q5snE6Q  2016-01-30 02:39:22  vFnYYmtVwcMGyyGesNImVQ
# 2       M4jkJHewQXZvDV34Tuon8g  2014-08-10 20:40:15  M20pTzUOo2yD5Cuh5shjSA
# 3       VPqWLp9kMiZEbctCebIZUA  2018-09-25 03:22:50  IMfkbLVt_GJfD7zJ9T4fcw
# 4       lq0rcFfgZJfzo9UD8bjDuA  2012-08-15 03:50:41  MGUSVcw0yu7tHwy334MFfQ
# ...                        ...                  ...                     ...
# 328930  JUilvuzRUKgi9yd7HCcPOg  2020-10-07 20:40:26  sRNw6HmUbJQpxv5dD-Fr_w
# 328931  2hqpc3ztTxMR-pgrHOC4uA  2020-10-04 19:30:47  fwRgIT36EabrYl86gtBD2g
# 328932  TrwJFKTV88_WFBEZnFZvzw  2020-11-22 07:52:59  0EubEKPAIwJkEDo1U8-oZw
# 328933  VhcQ07Smvo2PRdQ7CYaMpA  2021-01-01 19:48:56  n6Ihd5cyjWGOIiTVHn7gqw
# 328934  vXTo69v2bGEyuBdT0X1hrw  2010-01-30 07:53:00  _6up_KUwL5RsuWtK8fQxXg
#
#                      review_id  \
# ...

# %%
print(stop_list)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
from wordcloud import WordCloud as wc

wordcloud_object = wc(background_color="white",stopwords = stop_list, 
                      min_font_size = 5, contour_width=3,width=600, height=400,
                      colormap='rainbow').generate(','.join(list(df_closed.text.values)))
wordcloud_object.to_file("Closed_reviews.png")
wordcloud_object.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1A41ACCD90>

# %%
from wordcloud import WordCloud as wc

wordcloud_object = wc(background_color="white",stopwords = stop_list, 
                      min_font_size = 5, contour_width=3,width=600, height=400,
                      colormap='rainbow').generate(','.join(list(df_open.text.values)))

wordcloud_object.to_file("Open_reviews.png")
wordcloud_object.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1A1EFE5210>

# %%
from wordcloud import WordCloud as wc

# %%
df_open['ratings'] = ''
df_open.loc[df_open.stars >=4, 'ratings'] = 'positive'
df_open.loc[df_open.stars ==3, 'ratings'] = 'neutral'
df_open.loc[df_open.stars <3, 'ratings'] = 'negative'

# %%
from wordcloud import WordCloud as wc

wordcloud_object = wc(background_color="white",stopwords = stop_list, 
                      min_font_size = 5, contour_width=3,width=600, height=400,
                      colormap='rainbow').generate(','.join(list(df_open[df_open.ratings=="negative"].text.values)))

wordcloud_object.to_file("Negative_reviews.png")
wordcloud_object.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1A4C140710>

# %%
from wordcloud import WordCloud as wc

wordcloud_object = wc(background_color="white",stopwords = stop_list, 
                      min_font_size = 5, contour_width=3,width=600, height=400,
                      colormap='rainbow').generate(','.join(list(df_open[df_open.ratings=="positive"].text.values)))

wordcloud_object.to_file("Positive_reviews.png")
wordcloud_object.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1A3CB6FF10>
