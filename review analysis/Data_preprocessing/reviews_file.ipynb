# %%
review_df=pd.read_csv("review.csv", encoding='utf-8',error_bad_lines=False, engine="python")

# %%
review_df.head()
# Out:
#               business_id                 date                 user_id  \
# 0  buF9druCkbuXLX526sGELQ  2014-10-11 03:34:02  ak0TdVmGKo4pwqdJSTLwWw
# 1  RA4V8pr014UyUbDvI-LW2A  2015-07-03 20:38:25  YoVfDbnISlW0f7abNQACIg
# 2  _sS2LBIGNT5NQb6PD1Vtjw  2013-05-28 20:38:06  eC5evKn1TWDyHCyQAwguUw
# 3  0AzLzHfOJgL7ROwhdww2ew  2010-01-08 02:29:15  SFQ1jcnGguO0LYWnbbftAA
# 4  8zehGz9jnxPqXtOc7KaJxA  2011-07-28 18:05:01  0kA0PAJ8QFMeveQWHFqz2A
#
#                 review_id                                               text  \
# 0  lWC-xP3rd6obsecCYsGZRg  Apparently Prides Osteria had a rough summer a...
# 1  8bFej1QE5LXp4O05qjGqXA  This store is pretty good. Not as great as Wal...
# 2  NDhkzczKjLshODbqDoNLSg  I called WVM on the recommendation of a couple...
# 3  T5fAqjjFooT4V0OeZyuk1w  I've stayed at many Marriott and Renaissance M...
# 4  sjm_uUcQVxab_EeLCqsYLg  The food is always great here. The service fro...
#
#    funny  cool  useful  stars
# 0      1     1       3    4.0
# ...

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8635403 entries, 0 to 8635402
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   business_id  object
#  1   date         object
#  2   user_id      object
#  3   review_id    object
#  4   text         object
#  5   funny        int64
#  6   cool         int64
#  7   useful       int64
#  8   stars        float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 592.9+ MB

# %%
df = pd.read_csv("bc_rest.csv")

# %%
df.head()
# Out:
#               business_id                         name  \
# 0  D4JtQNTI4X3KcbzacDJsMw          Bob Likes Thai Food
# 1  QciD6FbNklaJvUbLExD4Nw                         ARGO
# 2  Xi2GGNzOiUS8r6WCFvu-fw               Kerala Kitchen
# 3  NoPXKdIwRzflOW-5exFAqA  1st Avenue Seafood by Pocha
# 4  jfDfHzAq6iKkRnzzZ4n1nQ  Let's Roll Custom Sushi Bar
#
#                          address       city state postal_code   latitude  \
# 0                   3755 Main St  Vancouver    BC         V5V  49.251342
# 1      3790 Canada Way, Unit 108    Burnaby    BC     V5G 1G4  49.254436
# 2           103- 9386 120 Street     Surrey    BC     V3V 4B9  49.173723
# 3               901 Lougheed Hwy  Coquitlam    BC     V3K 3T3  49.237547
# 4  1184 Denman Street, Suite 104  Vancouver    BC     V6G 2M9  49.286360
#
#     longitude  stars  review_count  is_open  \
# 0 -123.101333    3.5           169        1
# 1 -123.020050    4.0            76        1
# 2 -122.889641    4.0             9        1
# ...

# %%
df_open = df[df.is_open == 1]

# %%
df_closed = df[df.is_open == 0]

# %%
new_df=review_df[review_df.business_id.isin(df.business_id)]

# %%
new_df.head()
# Out:
#                business_id                 date                 user_id  \
# 16  6Hm2FmfLcU_M91TrZI5htA  2014-02-05 21:09:05  bUHweiErUJ36WGeNrPmEbA
# 17  KXCXaF5qimmtKKqnPc_LQA  2018-03-03 23:45:25  JHXQEayrDHOWGexs0dCviA
# 22  jMz_y_-cWMfiZF7Q5snE6Q  2016-01-30 02:39:22  vFnYYmtVwcMGyyGesNImVQ
# 40  M4jkJHewQXZvDV34Tuon8g  2014-08-10 20:40:15  M20pTzUOo2yD5Cuh5shjSA
# 47  VPqWLp9kMiZEbctCebIZUA  2018-09-25 03:22:50  IMfkbLVt_GJfD7zJ9T4fcw
#
#                  review_id                                               text  \
# 16  LBJJWJ0uNlIybMfPnQGS0A  I loved everything about this place. I've only...
# 17  ucFOnqgaV40oQ2YNyz5ddQ  Great coffee and pastries. Baristas are excell...
# 22  1OsubwE6zKNU1fkBGxOFrQ  Ordered the original tonkotsu base ramen and a...
# 40  KeyNH8Jj05BZGtqjgCFnTg  Had the worst experience there today when I tr...
# 47  P320Yt8vFD3yjI34hq-umg  Overall is good, is worth the line up I don't ...
#
#     funny  cool  useful  stars
# 16      3     3       5    5.0
# ...

# %%
new_df_open=review_df[review_df.business_id.isin(df_open.business_id)]

# %%
new_df_closed=review_df[review_df.business_id.isin(df_closed.business_id)]

# %%
new_df_closed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97871 entries, 16 to 8635120
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  97871 non-null  object
#  1   date         97871 non-null  object
#  2   user_id      97871 non-null  object
#  3   review_id    97871 non-null  object
#  4   text         97871 non-null  object
#  5   funny        97871 non-null  int64
#  6   cool         97871 non-null  int64
#  7   useful       97871 non-null  int64
#  8   stars        97871 non-null  float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 7.5+ MB

# %%
new_df.to_csv('reviews_open_close.csv', index=False, header=True)

# %%
new_df_open.to_csv('reviews_open.csv', index=False, header=True)

# %%
new_df_closed.to_csv('reviews_closed.csv', index=False, header=True)
