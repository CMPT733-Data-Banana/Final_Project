# %%
# !pip3 install pandas

# %%
# !pip3 install Ipython
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: Ipython in /usr/local/lib/python3.9/site-packages (8.1.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/site-packages (from Ipython) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.9/site-packages (from Ipython) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/site-packages (from Ipython) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/site-packages (from Ipython) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/site-packages (from Ipython) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/site-packages (from Ipython) (0.1.3)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/site-packages (from Ipython) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.9/site-packages (from Ipython) (2.11.2)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.9/site-packages (from Ipython) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/site-packages (from Ipython) (0.18.1)
# Requirement already satisfied: appnope in /usr/local/lib/python3.9/site-packages (from Ipython) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/site-packages (from Ipython) (3.0.28)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/site-packages (from jedi>=0.16->Ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/site-packages (from pexpect>4.3->Ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython) (0.2.5)
# Requirement already satisfied: executing in /usr/local/lib/python3.9/site-packages (from stack-data->Ipython) (0.8.2)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.9/site-packages (from stack-data->Ipython) (0.2.2)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.9/site-packages (from stack-data->Ipython) (2.0.5)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from asttokens->stack-data->Ipython) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import requests as r
import pandas as pd
import numpy as np
import csv
import json
#import Ipython
from itertools import product
#from Ipython import display
#import matplotlib.pyplot as plt

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50
# 200

# %%
data_dict3 = response.json()

# %%
cols=['id','alias','name','image_url','is_closed','url','review_count','categories','rating','coordinates','transactions','price','location','phone','display_phone','distance']

# %%
data_dict3
# Out:
# {'businesses': [{'id': 'GmEeIcJ9vR04kxzYgPMEgg',
#    'alias': 'guu-with-garlic-vancouver-2',
#    'name': 'Guu with Garlic',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nmwRtlU1ZrNBXkDcG1klYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guu-with-garlic-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 943,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.290249, 'longitude': -123.1338142},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1698 Robson Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6G 1C7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1698 Robson Street',
#      'Vancouver, BC V6G 1C7',
#      'Canada']},
#    'phone': '+16046858678',
#    'display_phone': '+1 604-685-8678',
#    'distance': 3257.0203971774486},
#   {'id': 'wHTXCWVsx2PYPT21JV-HeQ',
#    'alias': 'lupo-vancouver',
#    'name': 'Lupo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v4PWKNJ_REK2R2D3oYh8Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lupo-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 405,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.27823, 'longitude': -123.1174},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '869 Hamilton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 2R7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['869 Hamilton Street',
#      'Vancouver, BC V6B 2R7',
#      'Canada']},
#    'phone': '+16045692535',
#    'display_phone': '+1 604-569-2535',
#    'distance': 1660.4638556190805},
#   {'id': 'azoKlaqB7hdfMs_1zr9uBw',
#    'alias': 'the-keefer-bar-vancouver',
#    'name': 'The Keefer Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nSlzQsJJo1uVjFF5DmnBdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-keefer-bar-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 260,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2794866783565,
#     'longitude': -123.101473627377},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '135 Keefer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6A 1X3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['135 Keefer Street',
#      'Vancouver, BC V6A 1X3',
#      'Canada']},
#    'phone': '+16046881961',
#    'display_phone': '+1 604-688-1961',
#    'distance': 2096.174539433314},
#   {'id': 'DVZFAIbu5dfJAiwz_P-vFQ',
#    'alias': 'cafe-d-lite-express-richmond',
#    'name': "Cafe D'Lite Express",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pSvqLYcKYaeU4iio2fAKDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-d-lite-express-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 51,
#    'categories': [{'alias': 'singaporean', 'title': 'Singaporean'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.18408, 'longitude': -123.13404},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4151 Hazelbridge Way',
#     'address2': 'Suite 2220',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 4J7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4151 Hazelbridge Way',
#      'Suite 2220',
#      'Richmond, BC V6X 4J7',
#      'Canada']},
#    'phone': '+16042956603',
#    'display_phone': '+1 604-295-6603',
#    'distance': 8892.260494275426},
#   {'id': '2fO8UIOhMOwNTwtJng1WSg',
#    'alias': 'mangia-cucina-and-bar-vancouver',
#    'name': 'Mangia Cucina & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0qg91D8hY_FTI3yrhBAhjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mangia-cucina-and-bar-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 63,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.26542712485377,
#     'longitude': -123.10690661226711},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2211 Manitoba St',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 3A3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2211 Manitoba St',
#      'Vancouver, BC V5Y 3A3',
#      'Canada']},
#    'phone': '+16046205445',
#    'display_phone': '+1 604-620-5445',
#    'distance': 717.2314303985685},
#   {'id': 'S9qq5lPxLLNdlw8oTdaBDA',
#    'alias': 'mdg-ma-dang-goul-vancouver',
#    'name': 'MDG Ma Dang Goul',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s6HwxVGTBnKcKTV528QAzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mdg-ma-dang-goul-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 162,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2907499, 'longitude': -123.1368076},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '847 Denman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6G 2L7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['847 Denman Street',
#      'Vancouver, BC V6G 2L7',
#      'Canada']},
#    'phone': '+16046883585',
#    'display_phone': '+1 604-688-3585',
#    'distance': 3412.3570511803096},
#   {'id': '-E1kVYGDwyijG06SaCmvuQ',
#    'alias': 'the-vancouver-fish-company-vancouver-3',
#    'name': 'The Vancouver Fish Company',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I91z2CmXV-l9CoHC8x_PIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-vancouver-fish-company-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 218,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2706337, 'longitude': -123.13633},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1517 Anderson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6H',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1517 Anderson St', 'Vancouver, BC V6H', 'Canada']},
#    'phone': '+16045593474',
#    'display_phone': '+1 604-559-3474',
#    'distance': 1686.1501919638226},
#   {'id': 'tau2mchY6M7lGyLHgBbA8A',
#    'alias': 'rodneys-oyster-house-vancouver-3',
#    'name': "Rodney's Oyster House",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jTND654e5TEpxdqBRy4inQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rodneys-oyster-house-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 242,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2831349, 'longitude': -123.1030172},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '52 Powell Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6A 1E7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['52 Powell Street',
#      'Vancouver, BC V6A 1E7',
#      'Canada']},
#    'phone': '+16046852005',
#    'display_phone': '+1 604-685-2005',
#    'distance': 2406.9732229519427},
#   {'id': '_FNETIpl9zRXbDE1itXoUw',
#    'alias': 'pinpin-restaurant-vancouver',
#    'name': 'Pinpin Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p6_KL_8F3hEk2uEo9oFV9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinpin-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 115,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.22895, 'longitude': -123.09107},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6113 Fraser Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5W 2Z9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['6113 Fraser Street',
#      'Vancouver, BC V5W 2Z9',
#      'Canada']},
#    'phone': '+16043223086',
#    'display_phone': '+1 604-322-3086',
#    'distance': 4232.83440655229},
#   {'id': 'gV9lrbWr1CE1Jl0E58UO2g',
#    'alias': 'minami-vancouver',
#    'name': 'Minami',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D-UEnSvBAabTEimiqb96Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minami-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 682,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2752733, 'longitude': -123.1207029},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1118 Mainland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 2T9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1118 Mainland Street',
#      'Vancouver, BC V6B 2T9',
#      'Canada']},
#    'phone': '+16046858080',
#    'display_phone': '+1 604-685-8080',
#    'distance': 1373.6689932219708},
#   {'id': 'ieuUpA1eswgXDAfxp8B42A',
#    'alias': 'la-mezcaleria-vancouver',
#    'name': 'La Mezcaleria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HiB7iAkWxh4EbGeaCi2QVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-mezcaleria-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 266,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2702237, 'longitude': -123.0694136},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1622 Commercial Drive',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5L 3Y4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1622 Commercial Drive',
#      'Vancouver, BC V5L 3Y4',
#      'Canada']},
#    'phone': '+16045598226',
#    'display_phone': '+1 604-559-8226',
#    'distance': 3489.9433581823273},
#   {'id': 'PPAT6YnBJaJ0B3TpaPN-VQ',
#    'alias': 'haraheri-vancouver',
#    'name': 'Haraheri',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8LpM4W9ZA4joBZx0z2FqKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haraheri-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 248,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2800601, 'longitude': -123.1252654},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '888 Nelson St',
#     'address2': 'm101',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6Z 2H2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['888 Nelson St',
#      'm101',
#      'Vancouver, BC V6Z 2H2',
#      'Canada']},
#    'phone': '+16048990855',
#    'display_phone': '+1 604-899-0855',
#    'distance': 1977.9613198672282},
#   {'id': 'iPlWTqPac_B9qpS0Y_AhcQ',
#    'alias': 'tandoori-palace-vancouver',
#    'name': 'Tandoori Palace',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qGm2sV51eQCgpyFoL-3LIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tandoori-palace-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 109,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'pakistani', 'title': 'Pakistani'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2717682, 'longitude': -123.0697249},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1439 Commercial Drive',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5L 3X8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1439 Commercial Drive',
#      'Vancouver, BC V5L 3X8',
#      'Canada']},
#    'phone': '+16042548452',
#    'display_phone': '+1 604-254-8452',
#    'distance': 3481.4413341329023},
#   {'id': 'IApa8s-StZo2QcXOyu35tg',
#    'alias': 'little-minhs-burnaby-2',
#    'name': "Little Minh's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AXJ_m7j0xSySIFPAtrZoQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-minhs-burnaby-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 108,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.1990675, 'longitude': -122.9799962},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '7533 Market Crossing',
#     'address2': None,
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5J 0A3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['7533 Market Crossing',
#      'Burnaby, BC V5J 0A3',
#      'Canada']},
#    'phone': '+17789286668',
#    'display_phone': '+1 778-928-6668',
#    'distance': 12332.13369700441},
#   {'id': '0d9r36yJ2Zg9ggcOaAZmQA',
#    'alias': 'the-sandbar-seafood-restaurant-vancouver-2',
#    'name': 'The Sandbar Seafood Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BM_2TrXZp8wZvU2-XHZ4wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-sandbar-seafood-restaurant-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 650,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.27165, 'longitude': -123.134376},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1535 Johnston Street',
#     'address2': 'Ste 102',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6H 3R9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1535 Johnston Street',
#      'Ste 102',
#      'Vancouver, BC V6H 3R9',
#      'Canada']},
#    'phone': '+16046699030',
#    'display_phone': '+1 604-669-9030',
#    'distance': 1612.7184384978793},
#   {'id': 'BJ_B0Ov1z4U8F8mURQlgvQ',
#    'alias': 'afghan-chopan-bakery-and-diner-richmond-2',
#    'name': 'Afghan Chopan Bakery & Diner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SiR5QLZnDJWXDM6Uyb0aUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/afghan-chopan-bakery-and-diner-richmond-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 14,
#    'categories': [{'alias': 'afghani', 'title': 'Afghan'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.1700051, 'longitude': -123.1331254},
#    'transactions': [],
#    'location': {'address1': '8260 Westminster Highway',
#     'address2': '',
#     'address3': None,
#     'city': 'Richmond',
#     'zip_code': 'V6X',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['8260 Westminster Highway',
#      'Richmond, BC V6X',
#      'Canada']},
#    'phone': '+16042736505',
#    'display_phone': '+1 604-273-6505',
#    'distance': 10473.967226341218},
#   {'id': 'gt1BSfVFvzI-qHdJ3LUZug',
#    'alias': 'blue-water-cafe-vancouver',
#    'name': 'Blue Water Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IEYJnzoc9gOV6iDaTr6a3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-water-cafe-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 942,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2761945, 'longitude': -123.1209935},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1095 Hamilton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 5T4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1095 Hamilton St',
#      'Vancouver, BC V6B 5T4',
#      'Canada']},
#    'phone': '+16046888078',
#    'display_phone': '+1 604-688-8078',
#    'distance': 1482.328162797273},
#   {'id': 'NWyAvEo2rDZg-1wU4GwJZQ',
#    'alias': 'coast-restaurant-vancouver',
#    'name': 'Coast Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iuuUwfTXE6o4fuFqYB4s9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coast-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 555,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.284914, 'longitude': -123.1234737},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1054 Alberni Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1A3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1054 Alberni Street',
#      'Vancouver, BC V6E 1A3',
#      'Canada']},
#    'phone': '+16046855010',
#    'display_phone': '+1 604-685-5010',
#    'distance': 2429.4059777899956},
#   {'id': 'UwQyc3prSQp3pnvdSSmlaQ',
#    'alias': 'tasty-indian-bistro-vancouver',
#    'name': 'Tasty Indian Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/92v7Yvq3e3aMspodtI8L2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-indian-bistro-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 163,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2744011, 'longitude': -123.1236818},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1261 Hamilton Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V6B 6K3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1261 Hamilton Street',
#      'Vancouver, BC V6B 6K3',
#      'Canada']},
#    'phone': '+16044233300',
#    'display_phone': '+1 604-423-3300',
#    'distance': 1349.9260113837895},
#   {'id': '_3TI4d58nH8xip1V1u---w',
#    'alias': 'the-naam-vancouver-2',
#    'name': 'The Naam',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HFeIq1PBaRKum4JFqZMJbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-naam-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 575,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2683459, 'longitude': -123.1670621},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2724 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6K 1R1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2724 W 4th Avenue',
#      'Vancouver, BC V6K 1R1',
#      'Canada']},
#    'phone': '+16047387151',
#    'display_phone': '+1 604-738-7151',
#    'distance': 3731.46174697045},
#   {'id': 'l184Y1d3oAa5_Al4YIaRjQ',
#    'alias': 'anh-and-chi-vancouver',
#    'name': 'Anh and Chi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hZIqpqBLJ2ttxvPCTjDvEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anh-and-chi-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 527,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2550314422938,
#     'longitude': -123.100882202153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3388 Main Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 3M7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3388 Main Street',
#      'Vancouver, BC V5V 3M7',
#      'Canada']},
#    'phone': '+16048788883',
#    'display_phone': '+1 604-878-8883',
#    'distance': 1442.4854753127547},
#   {'id': 'rbgjXYiutRMsKCOrzkm5aw',
#    'alias': 'oyster-express-vancouver',
#    'name': 'Oyster Express',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/N7CuaWvy6kwfAFUGiHrGnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oyster-express-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 160,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2792784082144,
#     'longitude': -123.097397130932},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '296 Keefer Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6A 1X5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['296 Keefer Street',
#      'Vancouver, BC V6A 1X5',
#      'Canada']},
#    'phone': '+16046843300',
#    'display_phone': '+1 604-684-3300',
#    'distance': 2243.1236846595466},
#   {'id': 'as2xQt48ltKKDUQbMCBrMw',
#    'alias': 'shizen-ya-vancouver-13',
#    'name': 'Shizen Ya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/d2hPY0p4s7mhBqf_qncXRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shizen-ya-vancouver-13?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 556,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2808844, 'longitude': -123.1246278},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '965 Hornby Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V6Z 1V3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['965 Hornby Street',
#      'Vancouver, BC V6Z 1V3',
#      'Canada']},
#    'phone': '+16045680013',
#    'display_phone': '+1 604-568-0013',
#    'distance': 2050.432447968474},
#   {'id': '2UAmjQgLdVFqmPRvrDA2PA',
#    'alias': 'gyoza-bar-vancouver-2',
#    'name': 'Gyoza Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fpxjPkxxCm9OyIzZmf9qig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gyoza-bar-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 319,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2841553, 'longitude': -123.1143602},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '622 W Pender Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 1V8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['622 W Pender Street',
#      'Vancouver, BC V6B 1V8',
#      'Canada']},
#    'phone': '+16043365563',
#    'display_phone': '+1 604-336-5563',
#    'distance': 2325.3864352914093},
#   {'id': 'zJFR6pBdPsuqBve9pmtg0Q',
#    'alias': 'sprezzatura-vancouver-2',
#    'name': 'Sprezzatura',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KVS7-TfLCz3JqHPDNPFU2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sprezzatura-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 44,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2613547, 'longitude': -123.0978287},
#    'transactions': [],
#    'location': {'address1': '265 Kingsway',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 3J5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['265 Kingsway', 'Vancouver, BC V5T 3J5', 'Canada']},
#    'phone': '+16048766333',
#    'display_phone': '+1 604-876-6333',
#    'distance': 1372.2120329292823},
#   {'id': 'ztP4E-dCMEOZRT9XYLDNzw',
#    'alias': 'maenam-vancouver',
#    'name': 'Maenam',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B_8peVH2ZFQ6ceAP-37YRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maenam-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 361,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26787, 'longitude': -123.1488979},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1938 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1938 W 4th Avenue',
#      'Vancouver, BC V6J 1M5',
#      'Canada']},
#    'phone': '+16047305579',
#    'display_phone': '+1 604-730-5579',
#    'distance': 2425.042090447681},
#   {'id': 'mfgRqzZPPthaSaGGfOf2bw',
#    'alias': 'po-kong-vegetarian-restaurant-vancouver',
#    'name': 'Po Kong Vegetarian Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QdXk3ONqPDk2eHIfRswUIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/po-kong-vegetarian-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 126,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.25047, 'longitude': -123.07746},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1334 Kingsway Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 3E4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1334 Kingsway Avenue',
#      'Vancouver, BC V5V 3E4',
#      'Canada']},
#    'phone': '+16048763088',
#    'display_phone': '+1 604-876-3088',
#    'distance': 3154.5783349981307},
#   {'id': '7MTK1nzefMtcsz8eM2XYdg',
#    'alias': 'cactus-club-cafe-vancouver-7',
#    'name': 'Cactus Club Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tIcHDyRRzXbcvAvbjRB24g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cactus-club-cafe-vancouver-7?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 279,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.28689653721021, 'longitude': -123.14273036},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1790 Beach Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1V3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1790 Beach Avenue',
#      'Vancouver, BC V6E 1V3',
#      'Canada']},
#    'phone': '+16046812582',
#    'display_phone': '+1 604-681-2582',
#    'distance': 3254.891560570041},
#   {'id': '7mRvm9gLTXVzkMZgJ1kQzw',
#    'alias': 'madras-spice-vancouver',
#    'name': 'Madras Spice',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7vSsEwqvL15ah8Tdrv3-0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madras-spice-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 53,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2278432, 'longitude': -123.0904916},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6260 Fraser Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5W 3A1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['6260 Fraser Street',
#      'Vancouver, BC V5W 3A1',
#      'Canada']},
#    'phone': '+16043256555',
#    'display_phone': '+1 604-325-6555',
#    'distance': 4365.944183146833},
#   {'id': 'bExSibVFQPQdq3-xGyIEqw',
#    'alias': 'sal-y-limón-vancouver-2',
#    'name': 'Sal y Limón',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-pddKkqU-rw4u-ZcNeWQHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sal-y-lim%C3%B3n-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 594,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2569043786921,
#     'longitude': -123.08924632997},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '701 Kingsway Street',
#     'address2': 'Unit 5',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 3K6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['701 Kingsway Street',
#      'Unit 5',
#      'Vancouver, BC V5T 3K6',
#      'Canada']},
#    'phone': '+16046774247',
#    'display_phone': '+1 604-677-4247',
#    'distance': 2082.216366141734},
#   {'id': 'XZWw32Kq-fWw3NSxLkZDvg',
#    'alias': 'kintaro-ramen-vancouver',
#    'name': 'Kintaro Ramen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1A2TqctUoIA-y-a4l-0YJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kintaro-ramen-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 794,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2916373, 'longitude': -123.135091},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '788 Denman Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6G 2L5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['788 Denman Street',
#      'Vancouver, BC V6G 2L5',
#      'Canada']},
#    'phone': '+16046827568',
#    'display_phone': '+1 604-682-7568',
#    'distance': 3437.5526972769967},
#   {'id': 't1Q-DxnxjDy-u92bgGoYZQ',
#    'alias': 'the-keg-steakhouse-bar-burnaby-3',
#    'name': 'The Keg Steakhouse + Bar - Burnaby',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X2CWD7xjIGXsyfRH4vXp6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-keg-steakhouse-bar-burnaby-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 200,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2596278, 'longitude': -123.0019108},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '4510 Still Creek Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5C 0B5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4510 Still Creek Ave',
#      'Burnaby, BC V5C 0B5',
#      'Canada']},
#    'phone': '+16042944626',
#    'display_phone': '+1 604-294-4626',
#    'distance': 8305.408712809369},
#   {'id': 'K4FoQUln-Rvoy4gGVbHZIQ',
#    'alias': 'blvd-bistro-north-vancouver',
#    'name': 'Blvd Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/h1fwsC0_qg1mmaA42xLlRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blvd-bistro-north-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 175,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.3121844712081,
#     'longitude': -123.056914508343},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '636 Queensbury Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'North Vancouver',
#     'zip_code': 'V7L 3V6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['636 Queensbury Avenue',
#      'North Vancouver, BC V7L 3V6',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6933.865631031646},
#   {'id': 'AEOyRbQtYD3bmX1qJWvt4g',
#    'alias': 'peaceful-restaurant-vancouver',
#    'name': 'Peaceful Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8wFBWB7fzzVQlFycVnsSgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peaceful-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 588,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.263147, 'longitude': -123.116143},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '110-532 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['110-532 W Broadway',
#      'Vancouver, BC V5Z 1E9',
#      'Canada']},
#    'phone': '+16048799878',
#    'display_phone': '+1 604-879-9878',
#    'distance': 15.772340755351154},
#   {'id': 'LXW8pRE_VLi8gnW94s-GFg',
#    'alias': 'meet-in-gastown-vancouver',
#    'name': 'MeeT in Gastown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y1uiybAKG6xo_dw54TGS4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meet-in-gastown-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 430,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2833175986916,
#     'longitude': -123.104960943409},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '12 Water Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 1A5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['12 Water Street', 'Vancouver, BC V6B 1A5', 'Canada']},
#    'phone': '+16046961111',
#    'display_phone': '+1 604-696-1111',
#    'distance': 2373.447280516688},
#   {'id': 'gHIBoDXCL5VJyvX10thtsQ',
#    'alias': 'italia-bella-bar-and-grill-vancouver-2',
#    'name': 'Italia Bella Bar & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L2skXj2Urr3bp2RCroyZZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italia-bella-bar-and-grill-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 36,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26171, 'longitude': -123.09812},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '215 Kingsway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 3J5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['215 Kingsway', 'Vancouver, BC V5T 3J5', 'Canada']},
#    'phone': '+16047084400',
#    'display_phone': '+1 604-708-4400',
#    'distance': 1325.3969368679461},
#   {'id': 'JgSGpSMHbGecAXs_o1rE_g',
#    'alias': 'dinesty-dumpling-house-vancouver',
#    'name': 'Dinesty Dumpling House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VvhIRty9gwuHk5AxvjttWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dinesty-dumpling-house-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 808,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'dumplings', 'title': 'Dumplings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2908176, 'longitude': -123.1343912},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1719 Robson Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6G 1C8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1719 Robson Street',
#      'Vancouver, BC V6G 1C8',
#      'Canada']},
#    'phone': '+16046697769',
#    'display_phone': '+1 604-669-7769',
#    'distance': 3333.75059839881},
#   {'id': 'S6QRnCQVpEqQRyszrF51bw',
#    'alias': 'ajisai-sushi-bar-vancouver',
#    'name': 'Ajisai Sushi Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kMtiTuXmuoGMEjxhwsDn1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ajisai-sushi-bar-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 388,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.233870067400616,
#     'longitude': -123.15368540804255},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2081 West 42nd Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6M 3V3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2081 West 42nd Avenue',
#      'Vancouver, BC V6M 3V3',
#      'Canada']},
#    'phone': '+16042661428',
#    'display_phone': '+1 604-266-1428',
#    'distance': 4252.757427669955},
#   {'id': 'X5Esday1Wyl8EUrRL0c0zg',
#    'alias': 'yujis-from-japan-vancouver',
#    'name': "Yuji's From Japan",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QCWPT_ik5CEXOi1tnsqMWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yujis-from-japan-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 46,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2678978, 'longitude': -123.1857435},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2083 Alma Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6R 4N6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2083 Alma Street',
#      'Vancouver, BC V6R 4N6',
#      'Canada']},
#    'phone': '+16044284688',
#    'display_phone': '+1 604-428-4688',
#    'distance': 5070.304415080263},
#   {'id': 'vnKoBdTuh2lsUKASMwQYbA',
#    'alias': 'chongqing-vancouver-3',
#    'name': 'ChongQing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jn99Vkgi4Gj3gxQAdWs29A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chongqing-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 367,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.286526424773,
#     'longitude': -123.128171776697},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1260 Robson Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1C1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1260 Robson Street',
#      'Vancouver, BC V6E 1C1',
#      'Canada']},
#    'phone': '+16045680303',
#    'display_phone': '+1 604-568-0303',
#    'distance': 2726.4920907303717},
#   {'id': 'r-UGAU1-PsZ6HNZW237O-Q',
#    'alias': 'salt-tasting-room-vancouver',
#    'name': 'Salt Tasting Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uaLW7DPQE79UoLN5GJEWvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salt-tasting-room-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 489,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2833019455415,
#     'longitude': -123.106055259705},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '45 Blood Alley Square',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V6B 1A4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['45 Blood Alley Square',
#      'Vancouver, BC V6B 1A4',
#      'Canada']},
#    'phone': '+16046331912',
#    'display_phone': '+1 604-633-1912',
#    'distance': 2345.640596716483},
#   {'id': 's0sSli9r2FcJzjHGtlhDUg',
#    'alias': 'dang-anh-cafe-vancouver',
#    'name': 'Dang Anh Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sG4LDoir2wnrT1Z4jxqZIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dang-anh-cafe-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 77,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2376581, 'longitude': -123.0652216},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5186 Victoria Drive',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5P 3V3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['5186 Victoria Drive',
#      'Vancouver, BC V5P 3V3',
#      'Canada']},
#    'phone': '+17783797977',
#    'display_phone': '+1 778-379-7977',
#    'distance': 4678.886729754821},
#   {'id': 'RECT6A2mn5DHVVMQ_gO_2A',
#    'alias': 'mamas-fish-and-chips-food-truck-vancouver',
#    'name': "Mama's Fish & Chips Food Truck",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aCdwwS823zQitf0FaKe8mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamas-fish-and-chips-food-truck-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 8,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': None, 'longitude': None},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': '',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['Vancouver, BC', 'Canada']},
#    'phone': '+16048974240',
#    'display_phone': '+1 604-897-4240',
#    'distance': 2187.4801620233316},
#   {'id': '8IUK_KGorRQ4yfa5h6ANcQ',
#    'alias': 'western-lake-chinese-seafood-restaurant-vancouver',
#    'name': 'Western Lake Chinese Seafood Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ICCU429pf1TanAnOlGGt2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/western-lake-chinese-seafood-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 386,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.23937, 'longitude': -123.06577},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4989 Victoria Drive',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5P 3T7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4989 Victoria Drive',
#      'Vancouver, BC V5P 3T7',
#      'Canada']},
#    'phone': '+16043216862',
#    'display_phone': '+1 604-321-6862',
#    'distance': 4538.9339264597365},
#   {'id': 'RqtEy936GDBb0ddesDqKQg',
#    'alias': 'breakfast-table-vancouver',
#    'name': 'Breakfast Table',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OYMx7U7xvI7GMK9CY_J3IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/breakfast-table-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 226,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2586084, 'longitude': -123.13855},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3014 Granville Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6H 1H6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3014 Granville Street',
#      'Vancouver, BC V6H 1H6',
#      'Canada']},
#    'phone': '+16048051900',
#    'display_phone': '+1 604-805-1900',
#    'distance': 1700.27293789745},
#   {'id': 'pj3EecjmDf-xnwXyfVbZmw',
#    'alias': 'burgoo-bistro-north-vancouver',
#    'name': 'Burgoo Bistro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qscHtqwj0iN8UltGUJ4TJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burgoo-bistro-north-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 233,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.31054, 'longitude': -123.0802329},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3 Lonsdale Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'North Vancouver',
#     'zip_code': 'V7M 2E4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3 Lonsdale Ave',
#      'North Vancouver, BC V7M 2E4',
#      'Canada']},
#    'phone': '+16049040933',
#    'display_phone': '+1 604-904-0933',
#    'distance': 5880.19202847227},
#   {'id': 'qO03dJ4hU0sb5I1eBSEVkA',
#    'alias': 'dynasty-seafood-restaurant-vancouver',
#    'name': 'Dynasty Seafood Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5PeLja9OpEkB5zh-96QjrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dynasty-seafood-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 242,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2635999, 'longitude': -123.12138},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '777 W Broadway',
#     'address2': 'Ste 108',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 4J7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['777 W Broadway',
#      'Ste 108',
#      'Vancouver, BC V5Z 4J7',
#      'Canada']},
#    'phone': '+16048768388',
#    'display_phone': '+1 604-876-8388',
#    'distance': 373.45202244322445},
#   {'id': 'kK4imiJdmPKJBgQXoQ_VTg',
#    'alias': 'teahouse-in-stanley-park-vancouver-2',
#    'name': 'Teahouse in Stanley Park',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oraL02vtbrp-CQ6ZLVKVuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teahouse-in-stanley-park-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 401,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.3012529987012,
#     'longitude': -123.157079257071},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '7501 Stanley Park Drive',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V6G 1Z4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['7501 Stanley Park Drive',
#      'Vancouver, BC V6G 1Z4',
#      'Canada']},
#    'phone': '+16046693281',
#    'display_phone': '+1 604-669-3281',
#    'distance': 5158.658847272449},
#   {'id': 'l0cLT4c59zu0H8MVwp7vqA',
#    'alias': 'sula-indian-restaurant-vancouver',
#    'name': 'Sula Indian Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V0luL70-25C6ecEOogmyJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sula-indian-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 211,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2745279, 'longitude': -123.0693263},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1128 Commercial Drive',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5L 2N1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1128 Commercial Drive',
#      'Vancouver, BC V5L 2N1',
#      'Canada']},
#    'phone': '+16042151130',
#    'display_phone': '+1 604-215-1130',
#    'distance': 3631.3164817857755},
#   {'id': 'vLbjVhNd73054UVdvOeg7Q',
#    'alias': 'haidilao-richmond-2',
#    'name': 'Haidilao',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1yp8KpH6sCukurgjRGx3mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haidilao-richmond-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 153,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.17043, 'longitude': -123.13633},
#    'transactions': [],
#    'location': {'address1': '5890 No. 3 Road',
#     'address2': 'Suite 200',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6Y 0C2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['5890 No. 3 Road',
#      'Suite 200',
#      'Richmond, BC V6Y 0C2',
#      'Canada']},
#    'phone': '+16043706665',
#    'display_phone': '+1 604-370-6665',
#    'distance': 10379.332622469245}],
#  'total': 129,
#  'region': {'center': {'longitude': -123.11622619628906,
#    'latitude': 49.26327804232932}}}

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 51}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=51
# 200

# %%
data_dict4 = response.json()
data_dict4
# Out:
# {'businesses': [{'id': '_4R46MNkwx9MeOyt0YfNxA',
#    'alias': 'chambar-vancouver',
#    'name': 'Chambar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fSzNu6lZuyOz65t229txpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chambar-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 1403,
#    'categories': [{'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2801460007961,
#     'longitude': -123.109925328073},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '568 Beatty Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 2L3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['568 Beatty Street',
#      'Vancouver, BC V6B 2L3',
#      'Canada']},
#    'phone': '+16048797119',
#    'display_phone': '+1 604-879-7119',
#    'distance': 1930.5337011764295},
#   {'id': 'yjrJxldzYf6v1mtr8sFwkg',
#    'alias': 'kobe-japanese-steakhouse-vancouver-5',
#    'name': 'Kobe Japanese Steakhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/svXIi0kpjKpobKsplUPkKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kobe-japanese-steakhouse-vancouver-5?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 220,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2844963362851,
#     'longitude': -123.122744097068},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1042 Alberni Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1A3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1042 Alberni Street',
#      'Vancouver, BC V6E 1A3',
#      'Canada']},
#    'phone': '+16046842451',
#    'display_phone': '+1 604-684-2451',
#    'distance': 2406.2830360806443},
#   {'id': 'WWfntt6UzgdwhSl3y1t5fg',
#    'alias': 'la-cigale-french-bistro-vancouver',
#    'name': 'La Cigale French Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2x8PKjg2p8XNUroVnp20Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cigale-french-bistro-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 148,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2683296, 'longitude': -123.1494293},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1961 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1961 W 4th Avenue',
#      'Vancouver, BC V6J 1M7',
#      'Canada']},
#    'phone': '+16047320004',
#    'display_phone': '+1 604-732-0004',
#    'distance': 2473.974349851787},
#   {'id': 'Mfdo3zuB2P0xFQ40DLPaEQ',
#    'alias': 'la-quercia-vancouver',
#    'name': 'La Quercia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I9P2TWGMkI6SV0ezXSIkdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-quercia-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 195,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2687649, 'longitude': -123.1853601},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '3689 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6R 1P2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3689 W 4th Avenue',
#      'Vancouver, BC V6R 1P2',
#      'Canada']},
#    'phone': '+16046761007',
#    'display_phone': '+1 604-676-1007',
#    'distance': 5056.173177817841},
#   {'id': 'vLbjVhNd73054UVdvOeg7Q',
#    'alias': 'haidilao-richmond-2',
#    'name': 'Haidilao',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1yp8KpH6sCukurgjRGx3mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haidilao-richmond-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 153,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.17043, 'longitude': -123.13633},
#    'transactions': [],
#    'location': {'address1': '5890 No. 3 Road',
#     'address2': 'Suite 200',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6Y 0C2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['5890 No. 3 Road',
#      'Suite 200',
#      'Richmond, BC V6Y 0C2',
#      'Canada']},
#    'phone': '+16043706665',
#    'display_phone': '+1 604-370-6665',
#    'distance': 10379.332622469245},
#   {'id': 'kOOX1tsU0nbg0MbLXTLL6A',
#    'alias': 'meet-on-main-vancouver',
#    'name': 'MeeT on Main',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JKhhmdujy0da-tBw2L3A5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meet-on-main-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 438,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2467145032391,
#     'longitude': -123.100830778711},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4288 Main Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 3P9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4288 Main Street',
#      'Vancouver, BC V5V 3P9',
#      'Canada']},
#    'phone': '+16046961010',
#    'display_phone': '+1 604-696-1010',
#    'distance': 2154.2052891107187},
#   {'id': 'iLeNiouZRJ0xNGNY8SrJLQ',
#    'alias': 'sai-woo-vancouver',
#    'name': 'Sai Woo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/frA3LwlwxsKF189hR2uTmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sai-woo-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 151,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.28015, 'longitude': -123.10099},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '158 East Pender Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6A 1T3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['158 East Pender Street',
#      'Vancouver, BC V6A 1T3',
#      'Canada']},
#    'phone': '+16045681117',
#    'display_phone': '+1 604-568-1117',
#    'distance': 2187.374620798791},
#   {'id': 'DkKH_q0_vdWSWZwFhPFLZw',
#    'alias': 'tavola-vancouver',
#    'name': 'Tavola',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NAU0gCQXm9zZjD91bAZKig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavola-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 344,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2918164, 'longitude': -123.1357186},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1829 Robson Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6G 3E4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1829 Robson Street',
#      'Vancouver, BC V6G 3E4',
#      'Canada']},
#    'phone': '+16046064680',
#    'display_phone': '+1 604-606-4680',
#    'distance': 3485.9718228476213},
#   {'id': 'D4JtQNTI4X3KcbzacDJsMw',
#    'alias': 'bob-likes-thai-food-vancouver',
#    'name': 'Bob Likes Thai Food',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t-IVn2ERRJ82c_BMfhF0YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bob-likes-thai-food-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 179,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.25134, 'longitude': -123.10133},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3755 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3755 Main St', 'Vancouver, BC V5V', 'Canada']},
#    'phone': '+16045688538',
#    'display_phone': '+1 604-568-8538',
#    'distance': 1713.3045355603335},
#   {'id': 'RIb01mB9pEJ3yeebyHb4XA',
#    'alias': 'cioppinos-mediterranean-grill-vancouver-3',
#    'name': "Cioppino's Mediterranean Grill",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/go1C_5bwz6HBS3Tfwm_kXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cioppinos-mediterranean-grill-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 165,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.275522, 'longitude': -123.121794},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1133 Hamilton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 5P6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1133 Hamilton Street',
#      'Vancouver, BC V6B 5P6',
#      'Canada']},
#    'phone': '+16046887466',
#    'display_phone': '+1 604-688-7466',
#    'distance': 1420.1333416798086},
#   {'id': 'sjfuYW6x3BTgAg_w0NSpRg',
#    'alias': 'the-golden-joy-vancouver',
#    'name': 'The Golden Joy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZvJcCr3_T_xEBlRBMNMCWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-golden-joy-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 4,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2468667, 'longitude': -123.0899815},
#    'transactions': [],
#    'location': {'address1': '4288 Fraser St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 4E8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4288 Fraser St', 'Vancouver, BC V5V 4E8', 'Canada']},
#    'phone': '+16048720720',
#    'display_phone': '+1 604-872-0720',
#    'distance': 2642.3894831777216},
#   {'id': 'g-WSOodoG-L81DFYWM0FMQ',
#    'alias': 'italian-kitchen-vancouver',
#    'name': 'Italian Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qBMme9w14ReRa93WAE3_SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italian-kitchen-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 584,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2825685, 'longitude': -123.1236112},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '860 Burrard St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6Z 1X9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['860 Burrard St', 'Vancouver, BC V6Z 1X9', 'Canada']},
#    'phone': '+16046872858',
#    'display_phone': '+1 604-687-2858',
#    'distance': 2210.900234072475},
#   {'id': '7Tne8P5zyMpJKfpjQg2P-g',
#    'alias': 'l-abattoir-vancouver',
#    'name': "L'Abattoir",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GS-SN8Til4uuOabhDJ3eGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-abattoir-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 535,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2831869855333,
#     'longitude': -123.104450140894},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '217 Carrall Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 2J1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['217 Carrall Street',
#      'Vancouver, BC V6B 2J1',
#      'Canada']},
#    'phone': '+16045681701',
#    'display_phone': '+1 604-568-1701',
#    'distance': 2372.9069417590035},
#   {'id': 'wf6nzrwNG86Np8PrAr9E4A',
#    'alias': 'kirin-seafood-restaurant-vancouver-2',
#    'name': 'Kirin Seafood Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_CDCb0eozhCIiezEsZa0vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kirin-seafood-restaurant-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 431,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2861292, 'longitude': -123.1253806},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1172 Alberni Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 3Z3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1172 Alberni Street',
#      'Vancouver, BC V6E 3Z3',
#      'Canada']},
#    'phone': '+16046828833',
#    'display_phone': '+1 604-682-8833',
#    'distance': 2645.0665437059956},
#   {'id': 'pRSQYWdlzbeAWUbBuo4lhg',
#    'alias': 'yuans-garden-restaurant-richmond',
#    'name': "Yuan's Garden Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C-BPacL7BHzDWAo6p9Z7ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuans-garden-restaurant-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 130,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.178503, 'longitude': -123.134908},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '101 - 8077 Alexandra Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 3A6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['101 - 8077 Alexandra Road',
#      'Richmond, BC V6X 3A6',
#      'Canada']},
#    'phone': '+17782976098',
#    'display_phone': '+1 778-297-6098',
#    'distance': 9500.03129578177},
#   {'id': 'NN19pPLwqETuATMNlUNb_Q',
#    'alias': 'new-town-bakery-and-restaurant-vancouver-2',
#    'name': 'New Town Bakery & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p9Xg-kVQ8mT5IvQaN93DJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-town-bakery-and-restaurant-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 325,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.280153, 'longitude': -123.101201},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '148 Pender Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6A 1T3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['148 Pender Street E',
#      'Vancouver, BC V6A 1T3',
#      'Canada']},
#    'phone': '+16046811828',
#    'display_phone': '+1 604-681-1828',
#    'distance': 2185.3814528432613},
#   {'id': 'bl3_oJaZIQc-L3ZLgSzEtg',
#    'alias': 'moxies-vancouver',
#    'name': 'Moxies',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ddKXADOUdUVEsAgGElGQsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxies-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 94,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 49.2790041, 'longitude': -123.1131403},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '180 W Georgia St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 4P4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['180 W Georgia St',
#      'Vancouver, BC V6B 4P4',
#      'Canada']},
#    'phone': '+16046848434',
#    'display_phone': '+1 604-684-8434',
#    'distance': 1762.9304558182166},
#   {'id': 'uTLMc2oGsWzITyKULF1lRA',
#    'alias': 'vijs-railway-express-vancouver',
#    'name': "Vij's Railway Express",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4vDsb0VMBbULRR2fsrbY3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vijs-railway-express-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 70,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2858582, 'longitude': -123.1221924},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1075 W Georgia Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 0B6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1075 W Georgia Street',
#      'Vancouver, BC V6E 0B6',
#      'Canada']},
#    'phone': '+16046393335',
#    'display_phone': '+1 604-639-3335',
#    'distance': 2538.461056569528},
#   {'id': '4WBtUrKNyfuyth71On3ApA',
#    'alias': 'trattoria-kitchen-vancouver',
#    'name': 'Trattoria Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/50GY0c1UwWtRPamQIM7H2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-kitchen-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 291,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2674716476322,
#     'longitude': -123.146645910264},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1850 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1850 W 4th Avenue',
#      'Vancouver, BC V6J 1M3',
#      'Canada']},
#    'phone': '+16047321441',
#    'display_phone': '+1 604-732-1441',
#    'distance': 2255.999407401689},
#   {'id': 'AcEBuSwoXHdtobr-LiRRQg',
#    'alias': 'bellagio-cafe-vancouver-3',
#    'name': 'Bellagio Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JrX-t7goEsVuB2PAhCQBXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellagio-cafe-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 203,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2829785794205,
#     'longitude': -123.121498532105},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '773 Hornby Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6Z 1S2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['773 Hornby Street',
#      'Vancouver, BC V6Z 1S2',
#      'Canada']},
#    'phone': '+16044081281',
#    'display_phone': '+1 604-408-1281',
#    'distance': 2223.7416634010174},
#   {'id': 'dnybLydYkgR1LdUr5Q0DIw',
#    'alias': 'antons-pasta-bar-burnaby-2',
#    'name': "Anton's Pasta Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3gARvMA7jHYJNYs4Vls8cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antons-pasta-bar-burnaby-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 427,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.28072, 'longitude': -123.00984},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4260 Hastings Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5C 2J6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4260 Hastings Street',
#      'Burnaby, BC V5C 2J6',
#      'Canada']},
#    'phone': '+16042996636',
#    'display_phone': '+1 604-299-6636',
#    'distance': 7962.504148466183},
#   {'id': 'IZazp-g5qBGEUaPkOB-F3w',
#    'alias': 'anatolias-gate-restaurant-burnaby',
#    'name': "Anatolia's Gate Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CkEl8qG0myI0P9xqoJxCTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anatolias-gate-restaurant-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 131,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2183151, 'longitude': -122.9579254},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7084 Kingsway',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5E 1E7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['7084 Kingsway', 'Burnaby, BC V5E 1E7', 'Canada']},
#    'phone': '+16045252519',
#    'display_phone': '+1 604-525-2519',
#    'distance': 12506.523663451335},
#   {'id': '4jM6Mvylg6eKUCh6HOdlKg',
#    'alias': 'samurai-japanese-restaurant-vancouver',
#    'name': 'Samurai Japanese Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6cq2GTW1yGushBORjJN3Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-japanese-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 271,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2805525, 'longitude': -123.1314877},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1108 Davie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1N1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1108 Davie Street',
#      'Vancouver, BC V6E 1N1',
#      'Canada']},
#    'phone': '+16046090078',
#    'display_phone': '+1 604-609-0078',
#    'distance': 2217.1087297889912},
#   {'id': 'VZGdyz_NTAouzOqRT9QD_g',
#    'alias': 'ebisu-on-robson-vancouver',
#    'name': 'Ebisu On Robson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XnrrB8nPnvo70RQSxkjggg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ebisu-on-robson-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 257,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2858604, 'longitude': -123.1274591},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '827 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 3Y4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['827 Bute Street', 'Vancouver, BC V6E 3Y4', 'Canada']},
#    'phone': '+16046898266',
#    'display_phone': '+1 604-689-8266',
#    'distance': 2639.965258212162},
#   {'id': 'UAcbpL0tF-URY0yKlLw6ow',
#    'alias': 'sun-sui-wah-seafood-restaurant-vancouver-2',
#    'name': 'Sun Sui Wah Seafood Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SlhVR-v2ygyA913tZofcdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sun-sui-wah-seafood-restaurant-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 500,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.25053, 'longitude': -123.1006},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3888 Main Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 3N9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3888 Main Street',
#      'Vancouver, BC V5V 3N9',
#      'Canada']},
#    'phone': '+16048728822',
#    'display_phone': '+1 604-872-8822',
#    'distance': 1821.6773498589075},
#   {'id': 'yg2s2EA9Lnepuz36N7n_0g',
#    'alias': 'yaletown-brewing-company-vancouver',
#    'name': 'Yaletown Brewing Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C5A3MXj6UrWyTkbeJfEeMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yaletown-brewing-company-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 424,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2755483, 'longitude': -123.120817},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1111 Mainland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 2T9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1111 Mainland Street',
#      'Vancouver, BC V6B 2T9',
#      'Canada']},
#    'phone': '+16046812739',
#    'display_phone': '+1 604-681-2739',
#    'distance': 1415.7366483144174},
#   {'id': 'LpkjUSkqfYa_8AOyYF7gRQ',
#    'alias': 'indian-oven-restaurant-vancouver',
#    'name': 'Indian Oven Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xetpTRU11klUv91ugnn7Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indian-oven-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 144,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2678849, 'longitude': -123.1506642},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2006 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2006 W 4th Avenue',
#      'Vancouver, BC V6J 1M9',
#      'Canada']},
#    'phone': '+16047305069',
#    'display_phone': '+1 604-730-5069',
#    'distance': 2550.8073210487382},
#   {'id': 'oT8WhLz_LP-2GPZa4vPzjw',
#    'alias': 'grand-villa-casino-hotel-and-conference-centre-burnaby',
#    'name': 'Grand Villa Casino Hotel & Conference Centre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Jy72m0ycuCh3sSy3F2bokQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-villa-casino-hotel-and-conference-centre-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 62,
#    'categories': [{'alias': 'casinos', 'title': 'Casinos'},
#     {'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.256686763017626, 'longitude': -123.0074197},
#    'transactions': [],
#    'location': {'address1': '4331 Dominion Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5G 1C7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4331 Dominion Street',
#      'Burnaby, BC V5G 1C7',
#      'Canada']},
#    'phone': '+16044362211',
#    'display_phone': '+1 604-436-2211',
#    'distance': 7929.900074749667},
#   {'id': 'BdsPT4VZtbJeozhrcgk4XA',
#    'alias': 'agra-tandoori-restaurant-burnaby',
#    'name': 'Agra Tandoori Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/91BLbyPsE0d2VLqHntJTxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/agra-tandoori-restaurant-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 156,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.25443, 'longitude': -123.02066},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3790 Canada Way',
#     'address2': '110',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5G 1G4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3790 Canada Way',
#      '110',
#      'Burnaby, BC V5G 1G4',
#      'Canada']},
#    'phone': '+16044301600',
#    'display_phone': '+1 604-430-1600',
#    'distance': 7048.440562040471},
#   {'id': 'k50eFm74cJtUOEIScrDCMQ',
#    'alias': 'bibo-pizzeria-con-cucina-vancouver',
#    'name': 'Bibo Pizzeria con Cucina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_CFBw_6e5mAqyjZJi_NAtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibo-pizzeria-con-cucina-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 121,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2682628, 'longitude': -123.1465315},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1835 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1835 W 4th Avenue',
#      'Vancouver, BC V6J 1M4',
#      'Canada']},
#    'phone': '+16045686177',
#    'display_phone': '+1 604-568-6177',
#    'distance': 2267.7432254623677},
#   {'id': '2w2JBXIUgGzaMLXkmpXAtg',
#    'alias': 'maxs-restaurant-vancouver-3',
#    'name': "Max's Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BH0hNRNFWerG3qJGfefB5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maxs-restaurant-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 194,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 49.232045, 'longitude': -123.027391},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3546 Kingsway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5R 5L7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3546 Kingsway', 'Vancouver, BC V5R 5L7', 'Canada']},
#    'phone': '+16044353505',
#    'display_phone': '+1 604-435-3505',
#    'distance': 7324.044360437476},
#   {'id': '9GFCY3QeVkX2fIbOnT0i1g',
#    'alias': 'el-furniture-warehouse-hastings-vancouver-2',
#    'name': 'El Furniture Warehouse - Hastings',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WkBxB25Liqa3rVs9wmOXcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-furniture-warehouse-hastings-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 144,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.28219, 'longitude': -123.10861},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '156 W. Hastings St.',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 1GB',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['156 W. Hastings St.',
#      'Vancouver, BC V6B 1GB',
#      'Canada']},
#    'phone': '+16045581560',
#    'display_phone': '+1 604-558-1560',
#    'distance': 2160.8333551823375},
#   {'id': 'CX-NLp9SM3V2ooO9RIOhYg',
#    'alias': 'yolks-vancouver-3',
#    'name': 'Yolks',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rQIV54arDLzHEJTI3Bl20w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yolks-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 403,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.281081, 'longitude': -123.072931},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1598 E Hastings Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5L 1S5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1598 E Hastings Street',
#      'Vancouver, BC V5L 1S5',
#      'Canada']},
#    'phone': '+16045599655',
#    'display_phone': '+1 604-559-9655',
#    'distance': 3712.8612526540005},
#   {'id': '7f4AH7Isc9yirRcMQMaaXg',
#    'alias': 'dae-ji-cutlet-house-vancouver-2',
#    'name': 'Dae-Ji Cutlet House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OxbsDrZaTJe8TDhRLABN1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dae-ji-cutlet-house-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 60,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2826395, 'longitude': -123.1146671},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '519 Dunsmuir Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 1Y4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['519 Dunsmuir Street',
#      'Vancouver, BC V6B 1Y4',
#      'Canada']},
#    'phone': '+16046771636',
#    'display_phone': '+1 604-677-1636',
#    'distance': 2157.9525703426716},
#   {'id': 'Ev0LaR5V7wNr6qUK_olJAg',
#    'alias': 'broken-rice-vietnamese-restaurant-burnaby',
#    'name': 'Broken Rice Vietnamese Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ULQgKztUnX4KJoZjbpbbAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/broken-rice-vietnamese-restaurant-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 156,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2808832078838,
#     'longitude': -123.014717570458},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4088 Hastings Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5C 2J3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4088 Hastings Street',
#      'Burnaby, BC V5C 2J3',
#      'Canada']},
#    'phone': '+16045583838',
#    'display_phone': '+1 604-558-3838',
#    'distance': 7620.292966626185},
#   {'id': 'NIhqNI90BS7IkUSj9FjnJw',
#    'alias': 'samsoonie-noodle-and-rice-richmond',
#    'name': 'Samsoonie Noodle & Rice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UF6Wl-WKy9n-9usbHqpD_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samsoonie-noodle-and-rice-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 119,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.1707688466573,
#     'longitude': -123.133460687081},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '140-8211 Westminster Highway',
#     'address2': 'Suite 140',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 1A7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['140-8211 Westminster Highway',
#      'Suite 140',
#      'Richmond, BC V6X 1A7',
#      'Canada']},
#    'phone': '+17782977798',
#    'display_phone': '+1 778-297-7798',
#    'distance': 10362.426416877091},
#   {'id': 'FThw9d9asDhGfYSt0N4UoA',
#    'alias': 'tour-de-feast-north-vancouver-2',
#    'name': 'Tour De Feast',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/abrfg89nUEeeF9j2Q48tkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tour-de-feast-north-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 275,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.3074, 'longitude': -123.03223},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '319 Mountain Highway',
#     'address2': '',
#     'address3': '',
#     'city': 'North Vancouver',
#     'zip_code': 'V7J 2K7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['319 Mountain Highway',
#      'North Vancouver, BC V7J 2K7',
#      'Canada']},
#    'phone': '+16049801811',
#    'display_phone': '+1 604-980-1811',
#    'distance': 7824.114275537122},
#   {'id': 'T1MLjfYhYlK0pM4AFK0GUg',
#    'alias': 'lin-chinese-cuisine-and-tea-house-vancouver',
#    'name': 'Lin Chinese Cuisine And Tea House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EeBo4ZjynYrKqXVSnlXppA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lin-chinese-cuisine-and-tea-house-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 216,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.263677, 'longitude': -123.1395952},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1537 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1W6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1537 W Broadway', 'Vancouver, BC V6J 1W6', 'Canada']},
#    'phone': '+16047339696',
#    'display_phone': '+1 604-733-9696',
#    'distance': 1696.3209674276466},
#   {'id': 'Th8vr2RP68E43TfFOV_ohQ',
#    'alias': 'olive-and-anchor-west-vancouver',
#    'name': 'Olive & Anchor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SV1Wc4WGKO5pZtpYW0XZLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olive-and-anchor-west-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 181,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.3744299, 'longitude': -123.27492},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6418 Bay Street',
#     'address2': '',
#     'address3': '',
#     'city': 'West Vancouver',
#     'zip_code': 'V7W 2H1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['6418 Bay Street',
#      'West Vancouver, BC V7W 2H1',
#      'Canada']},
#    'phone': '+16049218848',
#    'display_phone': '+1 604-921-8848',
#    'distance': 16896.090121900157},
#   {'id': '2a3szzbszzWYvVBuqjNSKw',
#    'alias': 'veras-burger-shack-vancouver-4',
#    'name': "Vera's Burger Shack",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y_kPL5yexdW7f1PNfVHtBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/veras-burger-shack-vancouver-4?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 125,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'poutineries', 'title': 'Poutineries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.279515, 'longitude': -123.13008},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1030 Davie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1N2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1030 Davie Street',
#      'Vancouver, BC V6E 1N2',
#      'Canada']},
#    'phone': '+16048938372',
#    'display_phone': '+1 604-893-8372',
#    'distance': 2066.3916260161345},
#   {'id': 'A2bK8SMYMQfNs3WgICHZyw',
#    'alias': 'joey-bentall-one-vancouver-4',
#    'name': 'JOEY Bentall One',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RSaqkN6FNhqwWPM3s0TSSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joey-bentall-one-vancouver-4?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 198,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2864205554373,
#     'longitude': -123.118409514427},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '507 Burrard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V7X 8A8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['507 Burrard Street',
#      'Vancouver, BC V7X 8A8',
#      'Canada']},
#    'phone': '+16049155639',
#    'display_phone': '+1 604-915-5639',
#    'distance': 2578.197278816364},
#   {'id': 'O5nsEejA12DdMwRk0BKvKQ',
#    'alias': 'cheungs-chiu-chow-restaurant-richmond',
#    'name': "Cheung's Chiu Chow Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PmduXSE0RtnfqP7WmZXicA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cheungs-chiu-chow-restaurant-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 9,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 49.1787, 'longitude': -123.129832},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8391 Alexandra Rodd',
#     'address2': 'Suite 2150',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 1C3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['8391 Alexandra Rodd',
#      'Suite 2150',
#      'Richmond, BC V6X 1C3',
#      'Canada']},
#    'phone': '+17788988428',
#    'display_phone': '+1 778-898-8428',
#    'distance': 9456.407581139845},
#   {'id': 'cLVwhzVhNdF-5sM56p3ODQ',
#    'alias': 'richmond-ninkazu-sushi-richmond-2',
#    'name': 'Richmond Ninkazu Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0BB1FH4qSMlBsxez5lbMNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/richmond-ninkazu-sushi-richmond-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 157,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.18728, 'longitude': -123.1286},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8388 Capstan Way',
#     'address2': 'Ste 1488',
#     'address3': 'Union Square Shopping Centre',
#     'city': 'Richmond',
#     'zip_code': 'V6X 4A7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['8388 Capstan Way',
#      'Ste 1488',
#      'Union Square Shopping Centre',
#      'Richmond, BC V6X 4A7',
#      'Canada']},
#    'phone': '+16042077799',
#    'display_phone': '+1 604-207-7799',
#    'distance': 8463.284853587511},
#   {'id': 'ZHbiidBB8LVmh_hQQbRjig',
#    'alias': 'thai-son-restaurant-vancouver',
#    'name': 'Thai Son Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z9GVLlDHDdmSx842CCLtZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-son-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 102,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2628812, 'longitude': -123.0967428},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '373 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 1W6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['373 E Broadway', 'Vancouver, BC V5T 1W6', 'Canada']},
#    'phone': '+16048756436',
#    'display_phone': '+1 604-875-6436',
#    'distance': 1412.9811300137158},
#   {'id': 'xvxGpiNcqAcG1-eZ1I94Gw',
#    'alias': 'river-rock-casino-resort-richmond',
#    'name': 'River Rock Casino Resort',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/azXKmbGLnrML_jBX_dBB3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/river-rock-casino-resort-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 209,
#    'categories': [{'alias': 'casinos', 'title': 'Casinos'},
#     {'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.195004, 'longitude': -123.128031},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8811 River Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 3P8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['8811 River Road', 'Richmond, BC V6X 3P8', 'Canada']},
#    'phone': '+16042478900',
#    'display_phone': '+1 604-247-8900',
#    'distance': 7639.959242302945},
#   {'id': 'ThXa_yrZagsACaj-GKpt0w',
#    'alias': 'tomahawk-barbeque-north-vancouver',
#    'name': 'Tomahawk Barbeque',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vM5R6SrTTZ2qEOb1kGAFAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomahawk-barbeque-north-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 208,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.32276, 'longitude': -123.11297},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1550 Philip Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'North Vancouver',
#     'zip_code': 'V7P 2V8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1550 Philip Avenue',
#      'North Vancouver, BC V7P 2V8',
#      'Canada']},
#    'phone': '+16049882612',
#    'display_phone': '+1 604-988-2612',
#    'distance': 6617.798452750326},
#   {'id': 'dg330bwIZ0mzo3Rddt1lOQ',
#    'alias': 'downtown-sushi-bar-japanese-restaurant-vancouver',
#    'name': 'Downtown Sushi Bar Japanese Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KwvQMNueZnfUlArfbFMqmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/downtown-sushi-bar-japanese-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 106,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 49.2820468, 'longitude': -123.133499},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1205 Davie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1N4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1205 Davie Street',
#      'Vancouver, BC V6E 1N4',
#      'Canada']},
#    'phone': '+16046892833',
#    'display_phone': '+1 604-689-2833',
#    'distance': 2425.822370047313},
#   {'id': 'hpV0nNy9TmdgurcrEzTwRA',
#    'alias': 'moxies-richmond',
#    'name': 'Moxies',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YGqVzMC2sV7dZmiGi_oyTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxies-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 212,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.187373, 'longitude': -123.110501},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10251 St Edwards Drive',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 2M9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['10251 St Edwards Drive',
#      'Richmond, BC V6X 2M9',
#      'Canada']},
#    'phone': '+16042761180',
#    'display_phone': '+1 604-276-1180',
#    'distance': 8450.480166647738},
#   {'id': 'Dasi6G7bPTMv4k0hPp5MVA',
#    'alias': 'sushi-garden-burnaby',
#    'name': 'Sushi Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NItEZk-w3xIB--T1EmrrLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-garden-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 237,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2666107, 'longitude': -123.0093272},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4269 Lougheed Highway',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5C 3Y6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4269 Lougheed Highway',
#      'Burnaby, BC V5C 3Y6',
#      'Canada']},
#    'phone': '+16042940104',
#    'display_phone': '+1 604-294-0104',
#    'distance': 7778.754884319326},
#   {'id': '4KRfgc6Dwh32tsTN3oGCXw',
#    'alias': 'joyeaux-cafe-and-restaurant-vancouver',
#    'name': 'Joyeaux Cafe & Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y3CLoiR65mpQX-DMqfidoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joyeaux-cafe-and-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 208,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.28477337898, 'longitude': -123.116895498202},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '551 Howe Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6C 2C2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['551 Howe Street', 'Vancouver, BC V6C 2C2', 'Canada']},
#    'phone': '+16046819168',
#    'display_phone': '+1 604-681-9168',
#    'distance': 2390.6628974466516}],
#  'total': 129,
#  'region': {'center': {'longitude': -123.11622619628906,
#    'latitude': 49.26327804232932}}}

# %%
with open('data51bc.json', 'w') as fp:
    json.dump(data_dict4, fp)

# %%
data_dict4
# Out:
# {'businesses': [{'id': 'DkKH_q0_vdWSWZwFhPFLZw',
#    'alias': 'tavola-vancouver',
#    'name': 'Tavola',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NAU0gCQXm9zZjD91bAZKig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavola-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 344,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2918164, 'longitude': -123.1357186},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1829 Robson Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6G 3E4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1829 Robson Street',
#      'Vancouver, BC V6G 3E4',
#      'Canada']},
#    'phone': '+16046064680',
#    'display_phone': '+1 604-606-4680',
#    'distance': 3485.9718228476213},
#   {'id': 'kOOX1tsU0nbg0MbLXTLL6A',
#    'alias': 'meet-on-main-vancouver',
#    'name': 'MeeT on Main',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JKhhmdujy0da-tBw2L3A5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meet-on-main-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 438,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2467145032391,
#     'longitude': -123.100830778711},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4288 Main Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 3P9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4288 Main Street',
#      'Vancouver, BC V5V 3P9',
#      'Canada']},
#    'phone': '+16046961010',
#    'display_phone': '+1 604-696-1010',
#    'distance': 2154.2052891107187},
#   {'id': '_4R46MNkwx9MeOyt0YfNxA',
#    'alias': 'chambar-vancouver',
#    'name': 'Chambar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fSzNu6lZuyOz65t229txpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chambar-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 1403,
#    'categories': [{'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2801460007961,
#     'longitude': -123.109925328073},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '568 Beatty Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 2L3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['568 Beatty Street',
#      'Vancouver, BC V6B 2L3',
#      'Canada']},
#    'phone': '+16048797119',
#    'display_phone': '+1 604-879-7119',
#    'distance': 1930.5337011764295},
#   {'id': 'yjrJxldzYf6v1mtr8sFwkg',
#    'alias': 'kobe-japanese-steakhouse-vancouver-5',
#    'name': 'Kobe Japanese Steakhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/svXIi0kpjKpobKsplUPkKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kobe-japanese-steakhouse-vancouver-5?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 220,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2844963362851,
#     'longitude': -123.122744097068},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1042 Alberni Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1A3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1042 Alberni Street',
#      'Vancouver, BC V6E 1A3',
#      'Canada']},
#    'phone': '+16046842451',
#    'display_phone': '+1 604-684-2451',
#    'distance': 2406.2830360806443},
#   {'id': 'g-WSOodoG-L81DFYWM0FMQ',
#    'alias': 'italian-kitchen-vancouver',
#    'name': 'Italian Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qBMme9w14ReRa93WAE3_SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italian-kitchen-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 584,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2825685, 'longitude': -123.1236112},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '860 Burrard St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6Z 1X9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['860 Burrard St', 'Vancouver, BC V6Z 1X9', 'Canada']},
#    'phone': '+16046872858',
#    'display_phone': '+1 604-687-2858',
#    'distance': 2210.900234072475},
#   {'id': 'Mfdo3zuB2P0xFQ40DLPaEQ',
#    'alias': 'la-quercia-vancouver',
#    'name': 'La Quercia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I9P2TWGMkI6SV0ezXSIkdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-quercia-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 195,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2687649, 'longitude': -123.1853601},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '3689 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6R 1P2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3689 W 4th Avenue',
#      'Vancouver, BC V6R 1P2',
#      'Canada']},
#    'phone': '+16046761007',
#    'display_phone': '+1 604-676-1007',
#    'distance': 5056.173177817841},
#   {'id': 'sjfuYW6x3BTgAg_w0NSpRg',
#    'alias': 'the-golden-joy-vancouver',
#    'name': 'The Golden Joy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZvJcCr3_T_xEBlRBMNMCWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-golden-joy-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 4,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2468667, 'longitude': -123.0899815},
#    'transactions': [],
#    'location': {'address1': '4288 Fraser St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 4E8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4288 Fraser St', 'Vancouver, BC V5V 4E8', 'Canada']},
#    'phone': '+16048720720',
#    'display_phone': '+1 604-872-0720',
#    'distance': 2642.3894831777216},
#   {'id': 'D4JtQNTI4X3KcbzacDJsMw',
#    'alias': 'bob-likes-thai-food-vancouver',
#    'name': 'Bob Likes Thai Food',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t-IVn2ERRJ82c_BMfhF0YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bob-likes-thai-food-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 179,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.25134, 'longitude': -123.10133},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3755 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3755 Main St', 'Vancouver, BC V5V', 'Canada']},
#    'phone': '+16045688538',
#    'display_phone': '+1 604-568-8538',
#    'distance': 1713.3045355603335},
#   {'id': 'iLeNiouZRJ0xNGNY8SrJLQ',
#    'alias': 'sai-woo-vancouver',
#    'name': 'Sai Woo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/frA3LwlwxsKF189hR2uTmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sai-woo-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 151,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.28015, 'longitude': -123.10099},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '158 East Pender Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6A 1T3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['158 East Pender Street',
#      'Vancouver, BC V6A 1T3',
#      'Canada']},
#    'phone': '+16045681117',
#    'display_phone': '+1 604-568-1117',
#    'distance': 2187.374620798791},
#   {'id': 'NN19pPLwqETuATMNlUNb_Q',
#    'alias': 'new-town-bakery-and-restaurant-vancouver-2',
#    'name': 'New Town Bakery & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p9Xg-kVQ8mT5IvQaN93DJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-town-bakery-and-restaurant-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 325,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.280153, 'longitude': -123.101201},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '148 Pender Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6A 1T3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['148 Pender Street E',
#      'Vancouver, BC V6A 1T3',
#      'Canada']},
#    'phone': '+16046811828',
#    'display_phone': '+1 604-681-1828',
#    'distance': 2185.3814528432613},
#   {'id': 'WWfntt6UzgdwhSl3y1t5fg',
#    'alias': 'la-cigale-french-bistro-vancouver',
#    'name': 'La Cigale French Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2x8PKjg2p8XNUroVnp20Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cigale-french-bistro-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 148,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2683296, 'longitude': -123.1494293},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1961 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1961 W 4th Avenue',
#      'Vancouver, BC V6J 1M7',
#      'Canada']},
#    'phone': '+16047320004',
#    'display_phone': '+1 604-732-0004',
#    'distance': 2473.974349851787},
#   {'id': 'KfXBoMeZBC22VHL4GRt-8g',
#    'alias': 'john-3-16-malaysian-delights-richmond-3',
#    'name': 'John 3:16 Malaysian Delights',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2pS1chfToHp9M3LXX8eGfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/john-3-16-malaysian-delights-richmond-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 174,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.1641317, 'longitude': -123.1362195},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6832 & 6838 No.3 Road',
#     'address2': '',
#     'address3': None,
#     'city': 'Richmond',
#     'zip_code': 'V6Y 2C4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['6832 & 6838 No.3 Road',
#      'Richmond, BC V6Y 2C4',
#      'Canada']},
#    'phone': '+16042148181',
#    'display_phone': '+1 604-214-8181',
#    'distance': 11119.798038180701},
#   {'id': 'uTLMc2oGsWzITyKULF1lRA',
#    'alias': 'vijs-railway-express-vancouver',
#    'name': "Vij's Railway Express",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4vDsb0VMBbULRR2fsrbY3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vijs-railway-express-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 70,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2858582, 'longitude': -123.1221924},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1075 W Georgia Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 0B6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1075 W Georgia Street',
#      'Vancouver, BC V6E 0B6',
#      'Canada']},
#    'phone': '+16046393335',
#    'display_phone': '+1 604-639-3335',
#    'distance': 2538.461056569528},
#   {'id': 'bl3_oJaZIQc-L3ZLgSzEtg',
#    'alias': 'moxies-vancouver',
#    'name': 'Moxies',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ddKXADOUdUVEsAgGElGQsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxies-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 94,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 49.2790041, 'longitude': -123.1131403},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '180 W Georgia St',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 4P4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['180 W Georgia St',
#      'Vancouver, BC V6B 4P4',
#      'Canada']},
#    'phone': '+16046848434',
#    'display_phone': '+1 604-684-8434',
#    'distance': 1762.9304558182166},
#   {'id': '4WBtUrKNyfuyth71On3ApA',
#    'alias': 'trattoria-kitchen-vancouver',
#    'name': 'Trattoria Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/50GY0c1UwWtRPamQIM7H2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-kitchen-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 291,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2674716476322,
#     'longitude': -123.146645910264},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1850 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1850 W 4th Avenue',
#      'Vancouver, BC V6J 1M3',
#      'Canada']},
#    'phone': '+16047321441',
#    'display_phone': '+1 604-732-1441',
#    'distance': 2255.999407401689},
#   {'id': 'wf6nzrwNG86Np8PrAr9E4A',
#    'alias': 'kirin-seafood-restaurant-vancouver-2',
#    'name': 'Kirin Seafood Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_CDCb0eozhCIiezEsZa0vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kirin-seafood-restaurant-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 431,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2861292, 'longitude': -123.1253806},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1172 Alberni Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 3Z3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1172 Alberni Street',
#      'Vancouver, BC V6E 3Z3',
#      'Canada']},
#    'phone': '+16046828833',
#    'display_phone': '+1 604-682-8833',
#    'distance': 2645.0665437059956},
#   {'id': 'AcEBuSwoXHdtobr-LiRRQg',
#    'alias': 'bellagio-cafe-vancouver-3',
#    'name': 'Bellagio Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JrX-t7goEsVuB2PAhCQBXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bellagio-cafe-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 203,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2829785794205,
#     'longitude': -123.121498532105},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '773 Hornby Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6Z 1S2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['773 Hornby Street',
#      'Vancouver, BC V6Z 1S2',
#      'Canada']},
#    'phone': '+16044081281',
#    'display_phone': '+1 604-408-1281',
#    'distance': 2223.7416634010174},
#   {'id': 'dnybLydYkgR1LdUr5Q0DIw',
#    'alias': 'antons-pasta-bar-burnaby-2',
#    'name': "Anton's Pasta Bar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3gARvMA7jHYJNYs4Vls8cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antons-pasta-bar-burnaby-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 427,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.28072, 'longitude': -123.00984},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4260 Hastings Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5C 2J6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4260 Hastings Street',
#      'Burnaby, BC V5C 2J6',
#      'Canada']},
#    'phone': '+16042996636',
#    'display_phone': '+1 604-299-6636',
#    'distance': 7962.504148466183},
#   {'id': 'IZazp-g5qBGEUaPkOB-F3w',
#    'alias': 'anatolias-gate-restaurant-burnaby',
#    'name': "Anatolia's Gate Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CkEl8qG0myI0P9xqoJxCTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anatolias-gate-restaurant-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 131,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2183151, 'longitude': -122.9579254},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7084 Kingsway',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5E 1E7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['7084 Kingsway', 'Burnaby, BC V5E 1E7', 'Canada']},
#    'phone': '+16045252519',
#    'display_phone': '+1 604-525-2519',
#    'distance': 12506.523663451335},
#   {'id': '4jM6Mvylg6eKUCh6HOdlKg',
#    'alias': 'samurai-japanese-restaurant-vancouver',
#    'name': 'Samurai Japanese Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6cq2GTW1yGushBORjJN3Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-japanese-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 271,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2805525, 'longitude': -123.1314877},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1108 Davie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1N1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1108 Davie Street',
#      'Vancouver, BC V6E 1N1',
#      'Canada']},
#    'phone': '+16046090078',
#    'display_phone': '+1 604-609-0078',
#    'distance': 2217.1087297889912},
#   {'id': 'VZGdyz_NTAouzOqRT9QD_g',
#    'alias': 'ebisu-on-robson-vancouver',
#    'name': 'Ebisu On Robson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XnrrB8nPnvo70RQSxkjggg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ebisu-on-robson-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 257,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2858604, 'longitude': -123.1274591},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '827 Bute Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 3Y4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['827 Bute Street', 'Vancouver, BC V6E 3Y4', 'Canada']},
#    'phone': '+16046898266',
#    'display_phone': '+1 604-689-8266',
#    'distance': 2639.965258212162},
#   {'id': 'pRSQYWdlzbeAWUbBuo4lhg',
#    'alias': 'yuans-garden-restaurant-richmond',
#    'name': "Yuan's Garden Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C-BPacL7BHzDWAo6p9Z7ZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuans-garden-restaurant-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 130,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.178503, 'longitude': -123.134908},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '101 - 8077 Alexandra Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 3A6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['101 - 8077 Alexandra Road',
#      'Richmond, BC V6X 3A6',
#      'Canada']},
#    'phone': '+17782976098',
#    'display_phone': '+1 778-297-6098',
#    'distance': 9500.03129578177},
#   {'id': 'LpkjUSkqfYa_8AOyYF7gRQ',
#    'alias': 'indian-oven-restaurant-vancouver',
#    'name': 'Indian Oven Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xetpTRU11klUv91ugnn7Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indian-oven-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 144,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2678849, 'longitude': -123.1506642},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2006 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2006 W 4th Avenue',
#      'Vancouver, BC V6J 1M9',
#      'Canada']},
#    'phone': '+16047305069',
#    'display_phone': '+1 604-730-5069',
#    'distance': 2550.8073210487382},
#   {'id': '7Tne8P5zyMpJKfpjQg2P-g',
#    'alias': 'l-abattoir-vancouver',
#    'name': "L'Abattoir",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GS-SN8Til4uuOabhDJ3eGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-abattoir-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 535,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2831869855333,
#     'longitude': -123.104450140894},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '217 Carrall Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 2J1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['217 Carrall Street',
#      'Vancouver, BC V6B 2J1',
#      'Canada']},
#    'phone': '+16045681701',
#    'display_phone': '+1 604-568-1701',
#    'distance': 2372.9069417590035},
#   {'id': 'yg2s2EA9Lnepuz36N7n_0g',
#    'alias': 'yaletown-brewing-company-vancouver',
#    'name': 'Yaletown Brewing Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C5A3MXj6UrWyTkbeJfEeMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yaletown-brewing-company-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 424,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2755483, 'longitude': -123.120817},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1111 Mainland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 2T9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1111 Mainland Street',
#      'Vancouver, BC V6B 2T9',
#      'Canada']},
#    'phone': '+16046812739',
#    'display_phone': '+1 604-681-2739',
#    'distance': 1415.7366483144174},
#   {'id': 'RIb01mB9pEJ3yeebyHb4XA',
#    'alias': 'cioppinos-mediterranean-grill-vancouver-3',
#    'name': "Cioppino's Mediterranean Grill",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/go1C_5bwz6HBS3Tfwm_kXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cioppinos-mediterranean-grill-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 165,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.275522, 'longitude': -123.121794},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1133 Hamilton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 5P6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1133 Hamilton Street',
#      'Vancouver, BC V6B 5P6',
#      'Canada']},
#    'phone': '+16046887466',
#    'display_phone': '+1 604-688-7466',
#    'distance': 1420.1333416798086},
#   {'id': 'BdsPT4VZtbJeozhrcgk4XA',
#    'alias': 'agra-tandoori-restaurant-burnaby',
#    'name': 'Agra Tandoori Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/91BLbyPsE0d2VLqHntJTxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/agra-tandoori-restaurant-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 156,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.25443, 'longitude': -123.02066},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3790 Canada Way',
#     'address2': '110',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5G 1G4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3790 Canada Way',
#      '110',
#      'Burnaby, BC V5G 1G4',
#      'Canada']},
#    'phone': '+16044301600',
#    'display_phone': '+1 604-430-1600',
#    'distance': 7048.440562040471},
#   {'id': 'oT8WhLz_LP-2GPZa4vPzjw',
#    'alias': 'grand-villa-casino-hotel-and-conference-centre-burnaby',
#    'name': 'Grand Villa Casino Hotel & Conference Centre',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Jy72m0ycuCh3sSy3F2bokQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-villa-casino-hotel-and-conference-centre-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 62,
#    'categories': [{'alias': 'casinos', 'title': 'Casinos'},
#     {'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.256686763017626, 'longitude': -123.0074197},
#    'transactions': [],
#    'location': {'address1': '4331 Dominion Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5G 1C7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4331 Dominion Street',
#      'Burnaby, BC V5G 1C7',
#      'Canada']},
#    'phone': '+16044362211',
#    'display_phone': '+1 604-436-2211',
#    'distance': 7929.900074749667},
#   {'id': '9GFCY3QeVkX2fIbOnT0i1g',
#    'alias': 'el-furniture-warehouse-hastings-vancouver-2',
#    'name': 'El Furniture Warehouse - Hastings',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WkBxB25Liqa3rVs9wmOXcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-furniture-warehouse-hastings-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 144,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.28219, 'longitude': -123.10861},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '156 W. Hastings St.',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 1GB',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['156 W. Hastings St.',
#      'Vancouver, BC V6B 1GB',
#      'Canada']},
#    'phone': '+16045581560',
#    'display_phone': '+1 604-558-1560',
#    'distance': 2160.8333551823375},
#   {'id': '2w2JBXIUgGzaMLXkmpXAtg',
#    'alias': 'maxs-restaurant-vancouver-3',
#    'name': "Max's Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BH0hNRNFWerG3qJGfefB5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maxs-restaurant-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 194,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 49.232045, 'longitude': -123.027391},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3546 Kingsway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5R 5L7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3546 Kingsway', 'Vancouver, BC V5R 5L7', 'Canada']},
#    'phone': '+16044353505',
#    'display_phone': '+1 604-435-3505',
#    'distance': 7324.044360437476},
#   {'id': 'k50eFm74cJtUOEIScrDCMQ',
#    'alias': 'bibo-pizzeria-con-cucina-vancouver',
#    'name': 'Bibo Pizzeria con Cucina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_CFBw_6e5mAqyjZJi_NAtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibo-pizzeria-con-cucina-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 121,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2682628, 'longitude': -123.1465315},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1835 W 4th Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1M4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1835 W 4th Avenue',
#      'Vancouver, BC V6J 1M4',
#      'Canada']},
#    'phone': '+16045686177',
#    'display_phone': '+1 604-568-6177',
#    'distance': 2267.7432254623677},
#   {'id': 'CX-NLp9SM3V2ooO9RIOhYg',
#    'alias': 'yolks-vancouver-3',
#    'name': 'Yolks',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rQIV54arDLzHEJTI3Bl20w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yolks-vancouver-3?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 403,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.281081, 'longitude': -123.072931},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1598 E Hastings Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5L 1S5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1598 E Hastings Street',
#      'Vancouver, BC V5L 1S5',
#      'Canada']},
#    'phone': '+16045599655',
#    'display_phone': '+1 604-559-9655',
#    'distance': 3712.8612526540005},
#   {'id': 'NIhqNI90BS7IkUSj9FjnJw',
#    'alias': 'samsoonie-noodle-and-rice-richmond',
#    'name': 'Samsoonie Noodle & Rice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UF6Wl-WKy9n-9usbHqpD_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samsoonie-noodle-and-rice-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 119,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.1707688466573,
#     'longitude': -123.133460687081},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '140-8211 Westminster Highway',
#     'address2': 'Suite 140',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 1A7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['140-8211 Westminster Highway',
#      'Suite 140',
#      'Richmond, BC V6X 1A7',
#      'Canada']},
#    'phone': '+17782977798',
#    'display_phone': '+1 778-297-7798',
#    'distance': 10362.426416877091},
#   {'id': 'Ev0LaR5V7wNr6qUK_olJAg',
#    'alias': 'broken-rice-vietnamese-restaurant-burnaby',
#    'name': 'Broken Rice Vietnamese Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ULQgKztUnX4KJoZjbpbbAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/broken-rice-vietnamese-restaurant-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 156,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2808832078838,
#     'longitude': -123.014717570458},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4088 Hastings Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5C 2J3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4088 Hastings Street',
#      'Burnaby, BC V5C 2J3',
#      'Canada']},
#    'phone': '+16045583838',
#    'display_phone': '+1 604-558-3838',
#    'distance': 7620.292966626185},
#   {'id': '7f4AH7Isc9yirRcMQMaaXg',
#    'alias': 'dae-ji-cutlet-house-vancouver-2',
#    'name': 'Dae-Ji Cutlet House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OxbsDrZaTJe8TDhRLABN1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dae-ji-cutlet-house-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 60,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2826395, 'longitude': -123.1146671},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '519 Dunsmuir Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6B 1Y4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['519 Dunsmuir Street',
#      'Vancouver, BC V6B 1Y4',
#      'Canada']},
#    'phone': '+16046771636',
#    'display_phone': '+1 604-677-1636',
#    'distance': 2157.9525703426716},
#   {'id': 'FThw9d9asDhGfYSt0N4UoA',
#    'alias': 'tour-de-feast-north-vancouver-2',
#    'name': 'Tour De Feast',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/abrfg89nUEeeF9j2Q48tkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tour-de-feast-north-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 275,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.3074, 'longitude': -123.03223},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '319 Mountain Highway',
#     'address2': '',
#     'address3': '',
#     'city': 'North Vancouver',
#     'zip_code': 'V7J 2K7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['319 Mountain Highway',
#      'North Vancouver, BC V7J 2K7',
#      'Canada']},
#    'phone': '+16049801811',
#    'display_phone': '+1 604-980-1811',
#    'distance': 7824.114275537122},
#   {'id': 'UAcbpL0tF-URY0yKlLw6ow',
#    'alias': 'sun-sui-wah-seafood-restaurant-vancouver-2',
#    'name': 'Sun Sui Wah Seafood Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SlhVR-v2ygyA913tZofcdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sun-sui-wah-seafood-restaurant-vancouver-2?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 500,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.25053, 'longitude': -123.1006},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3888 Main Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 3N9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3888 Main Street',
#      'Vancouver, BC V5V 3N9',
#      'Canada']},
#    'phone': '+16048728822',
#    'display_phone': '+1 604-872-8822',
#    'distance': 1821.6773498589075},
#   {'id': 'Th8vr2RP68E43TfFOV_ohQ',
#    'alias': 'olive-and-anchor-west-vancouver',
#    'name': 'Olive & Anchor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SV1Wc4WGKO5pZtpYW0XZLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olive-and-anchor-west-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 181,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.3744299, 'longitude': -123.27492},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6418 Bay Street',
#     'address2': '',
#     'address3': '',
#     'city': 'West Vancouver',
#     'zip_code': 'V7W 2H1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['6418 Bay Street',
#      'West Vancouver, BC V7W 2H1',
#      'Canada']},
#    'phone': '+16049218848',
#    'display_phone': '+1 604-921-8848',
#    'distance': 16896.090121900157},
#   {'id': '2a3szzbszzWYvVBuqjNSKw',
#    'alias': 'veras-burger-shack-vancouver-4',
#    'name': "Vera's Burger Shack",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y_kPL5yexdW7f1PNfVHtBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/veras-burger-shack-vancouver-4?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 125,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'poutineries', 'title': 'Poutineries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.279515, 'longitude': -123.13008},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1030 Davie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1N2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1030 Davie Street',
#      'Vancouver, BC V6E 1N2',
#      'Canada']},
#    'phone': '+16048938372',
#    'display_phone': '+1 604-893-8372',
#    'distance': 2066.3916260161345},
#   {'id': 'T1MLjfYhYlK0pM4AFK0GUg',
#    'alias': 'lin-chinese-cuisine-and-tea-house-vancouver',
#    'name': 'Lin Chinese Cuisine And Tea House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EeBo4ZjynYrKqXVSnlXppA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lin-chinese-cuisine-and-tea-house-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 216,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.263677, 'longitude': -123.1395952},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1537 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6J 1W6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1537 W Broadway', 'Vancouver, BC V6J 1W6', 'Canada']},
#    'phone': '+16047339696',
#    'display_phone': '+1 604-733-9696',
#    'distance': 1696.3209674276466},
#   {'id': 'A2bK8SMYMQfNs3WgICHZyw',
#    'alias': 'joey-bentall-one-vancouver-4',
#    'name': 'JOEY Bentall One',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RSaqkN6FNhqwWPM3s0TSSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joey-bentall-one-vancouver-4?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 198,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2864205554373,
#     'longitude': -123.118409514427},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '507 Burrard Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V7X 8A8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['507 Burrard Street',
#      'Vancouver, BC V7X 8A8',
#      'Canada']},
#    'phone': '+16049155639',
#    'display_phone': '+1 604-915-5639',
#    'distance': 2578.197278816364},
#   {'id': 'O5nsEejA12DdMwRk0BKvKQ',
#    'alias': 'cheungs-chiu-chow-restaurant-richmond',
#    'name': "Cheung's Chiu Chow Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PmduXSE0RtnfqP7WmZXicA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cheungs-chiu-chow-restaurant-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 9,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 49.1787, 'longitude': -123.129832},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8391 Alexandra Rodd',
#     'address2': 'Suite 2150',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 1C3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['8391 Alexandra Rodd',
#      'Suite 2150',
#      'Richmond, BC V6X 1C3',
#      'Canada']},
#    'phone': '+17788988428',
#    'display_phone': '+1 778-898-8428',
#    'distance': 9456.407581139845},
#   {'id': 'ZHbiidBB8LVmh_hQQbRjig',
#    'alias': 'thai-son-restaurant-vancouver',
#    'name': 'Thai Son Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z9GVLlDHDdmSx842CCLtZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-son-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 102,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2628812, 'longitude': -123.0967428},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '373 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 1W6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['373 E Broadway', 'Vancouver, BC V5T 1W6', 'Canada']},
#    'phone': '+16048756436',
#    'display_phone': '+1 604-875-6436',
#    'distance': 1412.9811300137158},
#   {'id': 'dg330bwIZ0mzo3Rddt1lOQ',
#    'alias': 'downtown-sushi-bar-japanese-restaurant-vancouver',
#    'name': 'Downtown Sushi Bar Japanese Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KwvQMNueZnfUlArfbFMqmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/downtown-sushi-bar-japanese-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 106,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 49.2820468, 'longitude': -123.133499},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1205 Davie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6E 1N4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1205 Davie Street',
#      'Vancouver, BC V6E 1N4',
#      'Canada']},
#    'phone': '+16046892833',
#    'display_phone': '+1 604-689-2833',
#    'distance': 2425.822370047313},
#   {'id': 'xvxGpiNcqAcG1-eZ1I94Gw',
#    'alias': 'river-rock-casino-resort-richmond',
#    'name': 'River Rock Casino Resort',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/azXKmbGLnrML_jBX_dBB3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/river-rock-casino-resort-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 209,
#    'categories': [{'alias': 'casinos', 'title': 'Casinos'},
#     {'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.195004, 'longitude': -123.128031},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8811 River Road',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 3P8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['8811 River Road', 'Richmond, BC V6X 3P8', 'Canada']},
#    'phone': '+16042478900',
#    'display_phone': '+1 604-247-8900',
#    'distance': 7639.959242302945},
#   {'id': 'ThXa_yrZagsACaj-GKpt0w',
#    'alias': 'tomahawk-barbeque-north-vancouver',
#    'name': 'Tomahawk Barbeque',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vM5R6SrTTZ2qEOb1kGAFAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomahawk-barbeque-north-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 208,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.32276, 'longitude': -123.11297},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1550 Philip Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'North Vancouver',
#     'zip_code': 'V7P 2V8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1550 Philip Avenue',
#      'North Vancouver, BC V7P 2V8',
#      'Canada']},
#    'phone': '+16049882612',
#    'display_phone': '+1 604-988-2612',
#    'distance': 6617.798452750326},
#   {'id': 'Dasi6G7bPTMv4k0hPp5MVA',
#    'alias': 'sushi-garden-burnaby',
#    'name': 'Sushi Garden',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NItEZk-w3xIB--T1EmrrLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-garden-burnaby?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 237,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2666107, 'longitude': -123.0093272},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4269 Lougheed Highway',
#     'address2': '',
#     'address3': '',
#     'city': 'Burnaby',
#     'zip_code': 'V5C 3Y6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['4269 Lougheed Highway',
#      'Burnaby, BC V5C 3Y6',
#      'Canada']},
#    'phone': '+16042940104',
#    'display_phone': '+1 604-294-0104',
#    'distance': 7778.754884319326},
#   {'id': 'hpV0nNy9TmdgurcrEzTwRA',
#    'alias': 'moxies-richmond',
#    'name': 'Moxies',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YGqVzMC2sV7dZmiGi_oyTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moxies-richmond?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 212,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.187373, 'longitude': -123.110501},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '10251 St Edwards Drive',
#     'address2': '',
#     'address3': '',
#     'city': 'Richmond',
#     'zip_code': 'V6X 2M9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['10251 St Edwards Drive',
#      'Richmond, BC V6X 2M9',
#      'Canada']},
#    'phone': '+16042761180',
#    'display_phone': '+1 604-276-1180',
#    'distance': 8450.480166647738},
#   {'id': '4KRfgc6Dwh32tsTN3oGCXw',
#    'alias': 'joyeaux-cafe-and-restaurant-vancouver',
#    'name': 'Joyeaux Cafe & Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y3CLoiR65mpQX-DMqfidoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joyeaux-cafe-and-restaurant-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 208,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.28477337898, 'longitude': -123.116895498202},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '551 Howe Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6C 2C2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['551 Howe Street', 'Vancouver, BC V6C 2C2', 'Canada']},
#    'phone': '+16046819168',
#    'display_phone': '+1 604-681-9168',
#    'distance': 2390.6628974466516},
#   {'id': '5BNRsSDddMgeba1UQ2aX5g',
#    'alias': 'olympia-pizza-vancouver',
#    'name': 'Olympia Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vbFKFi-6UZwzWV_HjmWiPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olympia-pizza-vancouver?adjust_creative=3lSARo23b8cgF8Buuq49iA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=3lSARo23b8cgF8Buuq49iA',
#    'review_count': 78,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.26447, 'longitude': -123.17617},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3205 Broadway W',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V6K 2H5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3205 Broadway W', 'Vancouver, BC V6K 2H5', 'Canada']},
#    'phone': '+16047325334',
#    'display_phone': '+1 604-732-5334',
#    'distance': 4343.574463920568}],
#  'total': 129,
#  'region': {'center': {'longitude': -123.11622619628906,
#    'latitude': 49.26327804232932}}}

# %%
with open('data51bc.json', 'w') as fp:
    json.dump(data_dict4, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 101}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=101
# 200

# %%
data_dict5 = response.json()

# %%
with open('data101bc.json', 'w') as fp:
    json.dump(data_dict5, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 151}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=151
# 200

# %%
data_dict6 = response.json()

# %%
with open('data151bc.json', 'w') as fp:
    json.dump(data_dict6, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 201}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=201
# 200

# %%
data_dict7 = response.json()

# %%
with open('data201bc.json', 'w') as fp:
    json.dump(data_dict7, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 251}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code

# %%
data_dict8 = response.json()

# %%
with open('data251bc.json', 'w') as fp:
    json.dump(data_dict8, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 301}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=301
# 200

# %%
data_dict9 = response.json()

# %%
with open('data301bc.json', 'w') as fp:
    json.dump(data_dict9, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 351}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=351
# 200

# %%
data_dict10 = response.json()

# %%
with open('data351bc.json', 'w') as fp:
    json.dump(data_dict10, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 401}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=401
# 200

# %%
data_dict11 = response.json()

# %%
with open('data401bc.json', 'w') as fp:
    json.dump(data_dict11, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 451}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=451
# 200

# %%
data_dict12 = response.json()

# %%
with open('data401bc.json', 'w') as fp:
    json.dump(data_dict12, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 451}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)

# %%
data_dict12 = response.json()

# %%
with open('data401bc.json', 'w') as fp:
    json.dump(data_dict12, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 501}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=501
# 200

# %%
data_dict13 = response.json()

# %%
with open('data501bc.json', 'w') as fp:
    json.dump(data_dict12, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 551}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=551
# 200

# %%
data_dict14 = response.json()

# %%
data_dict14
# Out:
# {'businesses': [],
#  'total': 129,
#  'region': {'center': {'longitude': -123.11622619628906,
#    'latitude': 49.26327804232932}}}

# %%
with open('data551bc.json', 'w') as fp:
    json.dump(data_dict14, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 601}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=601
# 200

# %%
data_dict16 = response.json()

# %%
with open('data601bc.json', 'w') as fp:
    json.dump(data_dict16, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 651}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=651
# 200

# %%
data_dict17 = response.json()

# %%
data_dict17
# Out:
# {'businesses': [],
#  'total': 129,
#  'region': {'center': {'longitude': -123.11622619628906,
#    'latitude': 49.26327804232932}}}

# %%
with open('data651bc.json', 'w') as fp:
    json.dump(data_dict17, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 701}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=701
# 200

# %%
data_dict18 = response.json()

# %%
with open('data701bc.json', 'w') as fp:
    json.dump(data_dict18, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 701}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)

# %%
data_dict18 = response.json()

# %%
data_dict18
# Out:
# {'businesses': [],
#  'total': 129,
#  'region': {'center': {'longitude': -123.11622619628906,
#    'latitude': 49.26327804232932}}}

# %%
with open('data701bc.json', 'w') as fp:
    json.dump(data_dict18, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 751}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=751
# 200

# %%
data_dict19 = response.json()

# %%
data_dict19
# Out:
# {'businesses': [],
#  'total': 129,
#  'region': {'center': {'longitude': -123.11622619628906,
#    'latitude': 49.26327804232932}}}

# %%
with open('data751bc.json', 'w') as fp:
    json.dump(data_dict19, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 801}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=751
# 200

# %%
data_dict21 = response.json()

# %%
with open('data801bc.json', 'w') as fp:
    json.dump(data_dict19, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 851}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=801
# 200

# %%
data_dict22 = response.json()

# %%
with open('data851bc.json', 'w') as fp:
    json.dump(data_dict22, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 901}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=901
# 200

# %%
data_dict23 = response.json()

# %%
data_dict23
# Out:
# {'businesses': [],
#  'total': 129,
#  'region': {'center': {'longitude': -123.11622619628906,
#    'latitude': 49.26327804232932}}}

# %%
with open('data851bc.json', 'w') as fp:
    json.dump(data_dict23, fp)

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'Vancouver, British Columbia',
          'limit': 50,
          'offset': 951}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/search?term=restuarent&location=Vancouver%2C+British+Columbia&limit=50&offset=951
# 400

# %%
data_dict24 = response.json()

# %%
with open('data901bc.json', 'w') as fp:
    json.dump(data_dict24, fp)

# %%
import pandas as pd

# %%
df1=pd.read_csv("combined.csv")

# %%
len(df1)
# Out:
# 261

# %%
#data cleaning

# %%
import pandas as pd

# %%
df1=pd.read_csv("combined.csv")

# %%
len(df1)
# Out:
# 231

# %%
df1.head()
# Out:
#            businesses__id             businesses__alias     businesses__name  \
# 0  GmEeIcJ9vR04kxzYgPMEgg   guu-with-garlic-vancouver-2      Guu with Garlic
# 1                     NaN                           NaN                  NaN
# 2  wHTXCWVsx2PYPT21JV-HeQ                lupo-vancouver                 Lupo
# 3  azoKlaqB7hdfMs_1zr9uBw      the-keefer-bar-vancouver       The Keefer Bar
# 4  DVZFAIbu5dfJAiwz_P-vFQ  cafe-d-lite-express-richmond  Cafe D'Lite Express
#
#                                businesses__image_url businesses__is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/nmwRtl...                 FALSE
# 1                                                NaN                   NaN
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/v4PWKN...                 FALSE
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/nSlzQs...                 FALSE
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/pSvqLY...                 FALSE
#
#                                      businesses__url businesses__review_count  \
# 0  https://www.yelp.com/biz/guu-with-garlic-vanco...                      943
# 1                                                NaN                      NaN
# 2  https://www.yelp.com/biz/lupo-vancouver?adjust...                      405
# 3  https://www.yelp.com/biz/the-keefer-bar-vancou...                      260
# 4  https://www.yelp.com/biz/cafe-d-lite-express-r...                       51
#
#   businesses__categories__alias businesses__categories__title  \
# 0                      japanese                      Japanese
# 1                         tapas                    Tapas Bars
# 2                       italian                       Italian
# 3                       lounges                       Lounges
# 4                   singaporean                   Singaporean
#
#   businesses__rating  ... businesses__location__display_address__001  \
# 0                4.5  ...                         1698 Robson Street
# 1                NaN  ...                                        NaN
# 2                4.5  ...                        869 Hamilton Street
# 3                4.0  ...                          135 Keefer Street
# 4                3.5  ...                       4151 Hazelbridge Way
#
#   businesses__location__display_address__002  \
# 0                      Vancouver, BC V6G 1C7
# 1                                        NaN
# 2                      Vancouver, BC V6B 2R7
# 3                      Vancouver, BC V6A 1X3
# 4                                 Suite 2220
#
#   businesses__location__display_address__003  \
# 0                                     Canada
# 1                                        NaN
# 2                                     Canada
# 3                                     Canada
# 4                       Richmond, BC V6X 4J7
#
#   businesses__location__display_address__004 businesses__phone  \
# 0                                        NaN       16046858678
# 1                                        NaN               NaN
# 2                                        NaN       16045692535
# 3                                        NaN       16046881961
# 4                                     Canada       16042956603
#
#   businesses__display_phone businesses__distance total  \
# 0           +1 604-685-8678   3257.0203971774500   129
# 1                       NaN                  NaN   NaN
# 2           +1 604-569-2535   1660.4638556190800   NaN
# 3           +1 604-688-1961    2096.174539433310   NaN
# 4           +1 604-295-6603    8892.260494275430   NaN
#
#   region__center__longitude region__center__latitude
# 0       -123.11622619628900        49.26327804232930
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
# [5 rows x 31 columns]

# %%
df1.rename(columns={"categories/0/alias": "category_alias", "categories/0/title": "Category_2: Title"})
# Out:
#              businesses__id             businesses__alias  \
# 0    GmEeIcJ9vR04kxzYgPMEgg   guu-with-garlic-vancouver-2
# 1                       NaN                           NaN
# 2    wHTXCWVsx2PYPT21JV-HeQ                lupo-vancouver
# 3    azoKlaqB7hdfMs_1zr9uBw      the-keefer-bar-vancouver
# 4    DVZFAIbu5dfJAiwz_P-vFQ  cafe-d-lite-express-richmond
# ..                      ...                           ...
# 226  mzREMIknfmagJugibXrCsQ        pho-tien-thanh-toronto
# 227  vh1tPEaPioD78QmoqnWXpw          sukho-thai-toronto-2
# 228  twirfhS-LvbQjAoZjoxWOQ            sushi-karu-toronto
# 229                     NaN                           NaN
# 230  ERnG-1q3igX3VSgm5uLZ6A       pizza-e-pazzi-toronto-4
#
#         businesses__name                              businesses__image_url  \
# 0        Guu with Garlic  https://s3-media1.fl.yelpcdn.com/bphoto/nmwRtl...
# 1                    NaN                                                NaN
# 2                   Lupo  https://s3-media2.fl.yelpcdn.com/bphoto/v4PWKN...
# 3         The Keefer Bar  https://s3-media1.fl.yelpcdn.com/bphoto/nSlzQs...
# 4    Cafe D'Lite Express  https://s3-media1.fl.yelpcdn.com/bphoto/pSvqLY...
# ..                   ...                                                ...
# 226       Pho Tien Thanh  https://s3-media2.fl.yelpcdn.com/bphoto/qAtzA8...
# 227           Sukho Thai  https://s3-media3.fl.yelpcdn.com/bphoto/PIozRU...
# 228           Sushi Karu  https://s3-media2.fl.yelpcdn.com/bphoto/9gblT2...
# 229                  NaN                                                NaN
# 230        Pizza e Pazzi  https://s3-media3.fl.yelpcdn.com/bphoto/PN91kZ...
#
#     businesses__is_closed                                    businesses__url  \
# 0                   FALSE  https://www.yelp.com/biz/guu-with-garlic-vanco...
# 1                     NaN                                                NaN
# 2                   FALSE  https://www.yelp.com/biz/lupo-vancouver?adjust...
# 3                   FALSE  https://www.yelp.com/biz/the-keefer-bar-vancou...
# 4                   FALSE  https://www.yelp.com/biz/cafe-d-lite-express-r...
# ..                    ...                                                ...
# 226                 FALSE  https://www.yelp.com/biz/pho-tien-thanh-toront...
# 227                 FALSE  https://www.yelp.com/biz/sukho-thai-toronto-2?...
# 228                 FALSE  https://www.yelp.com/biz/sushi-karu-toronto?ad...
# 229                   NaN                                                NaN
# 230                 FALSE  https://www.yelp.com/biz/pizza-e-pazzi-toronto...
#
#     businesses__review_count businesses__categories__alias  \
# 0                        943                      japanese
# 1                        NaN                         tapas
# 2                        405                       italian
# 3                        260                       lounges
# 4                         51                   singaporean
# ..                       ...                           ...
# 226                      411                    vietnamese
# 227                      503                          thai
# 228                       14                      japanese
# 229                      NaN                        korean
# 230                       81                         pizza
#
#     businesses__categories__title businesses__rating  ...  \
# 0                        Japanese                4.5  ...
# 1                      Tapas Bars                NaN  ...
# 2                         Italian                4.5  ...
# 3                         Lounges                4.0  ...
# 4                     Singaporean                3.5  ...
# ..                            ...                ...  ...
# 226                    Vietnamese                4.0  ...
# 227                          Thai                3.5  ...
# 228                      Japanese                4.5  ...
# 229                        Korean                NaN  ...
# 230                         Pizza                4.0  ...
#
#     businesses__location__display_address__001  \
# 0                           1698 Robson Street
# 1                                          NaN
# 2                          869 Hamilton Street
# 3                            135 Keefer Street
# 4                         4151 Hazelbridge Way
# ..                                         ...
# 226                        57 Ossington Avenue
# 227                     52 Wellington Street E
# 228                         378 Oakwood Avenue
# 229                                        NaN
# 230                     1182 St Clair Avenue W
#
#     businesses__location__display_address__002  \
# 0                        Vancouver, BC V6G 1C7
# 1                                          NaN
# 2                        Vancouver, BC V6B 2R7
# 3                        Vancouver, BC V6A 1X3
# 4                                   Suite 2220
# ..                                         ...
# 226                        Toronto, ON M6J 2Y9
# 227                        Toronto, ON M5E 1C9
# 228                        Toronto, ON M6E 2W3
# 229                                        NaN
# 230                        Toronto, ON M6E 1B4
#
#     businesses__location__display_address__003  \
# 0                                       Canada
# 1                                          NaN
# 2                                       Canada
# 3                                       Canada
# 4                         Richmond, BC V6X 4J7
# ..                                         ...
# 226                                     Canada
# 227                                     Canada
# 228                                     Canada
# 229                                        NaN
# 230                                     Canada
#
#     businesses__location__display_address__004 businesses__phone  \
# 0                                          NaN       16046858678
# 1                                          NaN               NaN
# 2                                          NaN       16045692535
# 3                                          NaN       16046881961
# 4                                       Canada       16042956603
# ..                                         ...               ...
# 226                                        NaN       14165886997
# 227                                        NaN       16473514612
# 228                                        NaN       16473525278
# 229                                        NaN               NaN
# 230                                        NaN       14166519999
#
#     businesses__display_phone businesses__distance total  \
# 0             +1 604-685-8678   3257.0203971774500   129
# 1                         NaN                  NaN   NaN
# 2             +1 604-569-2535   1660.4638556190800   NaN
# 3             +1 604-688-1961    2096.174539433310   NaN
# 4             +1 604-295-6603    8892.260494275430   NaN
# ..                        ...                  ...   ...
# 226           +1 416-588-6997    3659.700985727960   NaN
# 227           +1 647-351-4612   3374.2002323377700   NaN
# 228           +1 647-352-5278   3709.1563756653500   NaN
# 229                       NaN                  NaN   NaN
# 230           +1 416-651-9999   3806.5360890933600   NaN
#
#     region__center__longitude region__center__latitude
# 0         -123.11622619628900        49.26327804232930
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ..                        ...                      ...
# 226                       NaN                      NaN
# 227                       NaN                      NaN
# 228                       NaN                      NaN
# 229                       NaN                      NaN
# 230                       NaN                      NaN
#
# [231 rows x 31 columns]

# %%
df1.columns
# Out:
# Index(['businesses__id', 'businesses__alias', 'businesses__name',
#        'businesses__image_url', 'businesses__is_closed', 'businesses__url',
#        'businesses__review_count', 'businesses__categories__alias',
#        'businesses__categories__title', 'businesses__rating',
#        'businesses__coordinates__latitude',
#        'businesses__coordinates__longitude', 'businesses__transactions__-',
#        'businesses__price', 'businesses__location__address1',
#        'businesses__location__address2', 'businesses__location__address3',
#        'businesses__location__city', 'businesses__location__zip_code',
#        'businesses__location__country', 'businesses__location__state',
#        'businesses__location__display_address__001',
#        'businesses__location__display_address__002',
#        'businesses__location__display_address__003',
#        'businesses__location__display_address__004', 'businesses__phone',
#        'businesses__display_phone', 'businesses__distance', 'total',
#        'region__center__longitude', 'region__center__latitude'],
#       dtype='object')

# %%
df1.to_csv('outcombined.csv', sep='\t', encoding='utf-8')

# %%
#extraction for bc

# %%
import requests as r
import json

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search

# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_key)}
search_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term': 'restuarent', 
          'location': 'British Columbia, Canada',
          'limit': 50,
          'offset': 701}

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
data_dictBC = response.json()

# %%
with open('datadictbc.json', 'w') as fp:
    json.dump(data_dictBC, fp)

# %%
import csv

# %%
#**Convert the JSON string to a dictionary*
#data_dict4
c = csv.writer(open('data50bcnew.csv', 'a'), lineterminator ='\n')

for biz in data_dict4:

    c.writerow([biz['businesses__categories__title']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 5>()
#       3 c = csv.writer(open('data50bcnew.csv', 'a'), lineterminator ='\n')
#       5 for biz in data_dict4:
# ----> 7     c.writerow([biz['businesses__categories__title']])
#
# TypeError: string indices must be integers

# %%
import pandas as pd
business_json_path = 'data50bc.json'
df_b = pd.read_json(business_json_path, lines=True)

# %%
df_b
# Out:
#                                           businesses  total  \
# 0  [{'id': 'GmEeIcJ9vR04kxzYgPMEgg', 'alias': 'gu...    129
#
#                                               region
# 0  {'center': {'longitude': -123.11622619628906, ...

# %%
# Using the yelp business search API: https://www.yelp.com/developers/documentation/v3/business_search
#usinfg new endpoint
# headers contain the api key.
headers = {'Authorization': 'Bearer {}'.format(api_keys)}
search_api_url = 'https://api.yelp.com/v3/businesses/{id}'

# %%
response = r.get(search_api_url, headers=headers, params=params, timeout=5)

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.yelp.com/v3/businesses/%7Bid%7D?location=Vancouver%2C+BC&limit=50
# 400

# %%
data_need = response.json()

# %%
with open('dneed.json', 'w') as fp:
    json.dump(data_need, fp)

# %%
import pandas as pd
business_json_path = 'dneed.json'
df_b = pd.read_json(business_json_path, lines=True)
