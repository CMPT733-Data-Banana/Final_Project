# %%
#pip install haversine
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import pandas as pd
import folium.plugins as plugins

# %%
att = pd.read_csv('attributes.csv')

# %%
mb4 = pd.read_csv("rest4og.csv")
# mb4

# %%
mbc4 = pd.read_csv("rest4.csv")
# mbc4

# %%
mb2 = pd.read_csv("rest2og.csv")
mb2
# Out:
#    Unnamed: 0             business_id      name  stars  latitude   longitude
# 0         809  BJ-mZ93qfDZJE45gPksFAA  De Dutch    3.5  49.29003 -123.116896

# %%
mbc2 = pd.read_csv("rest2.csv")
mbc2
# Out:
#     Unnamed: 0             business_id                                 name  \
# 0          148  VPqWLp9kMiZEbctCebIZUA                          Medina Cafe
# 1          259  iHr346j7FGUY4JQoeEKXMA                         Harvest Deli
# 2          286  BqOSfSmwWDZzjYzIrBhyNw                            Catch 122
# 3          372  NensKn1MSVU_rm-1Y6WlFA                        Marulilu Cafe
# 4          563  VMTKdTICNrTQdzbgzIbH3Q             Rocky Mountain Flatbread
# 5          607  L4jCuG3S-6kY0FVAyjiLNQ                         Nero Waffles
# 6          687  FFVXF_4OnzTlWITF2IH5SQ                           Maizal RMF
# 7          734  RqtEy936GDBb0ddesDqKQg                      Breakfast Table
# 8          788  icnhQBqyrQ2joCRtV_OORw              Nero Belgian Waffle Bar
# 9          853  7Tne8P5zyMpJKfpjQg2P-g                           L'Abattoir
# 10         980  U5qYTzxrA2uhKLtD-3PX5g                  Neverland Tea Salon
# ...

# %%
mb1 = pd.read_csv("rest1og.csv")
mb1
# Out:
#    Unnamed: 0             business_id           name  stars   latitude  \
# 0         509  oAv2XW5i-w3A-pESAu1Abw  Mucho Burrito    3.0  49.278722
# 1        1451  LiEz1GBLKwYBW7n4H9YxzQ  Mucho Burrito    3.0  49.198046
# 2        2755  aqchZyKeC32rmPX5I2DYYw  Mucho Burrito    4.0  49.131666
# 3        3725  9v0Iz8rR1-CK3GumfuSwgw  Mucho Burrito    3.5  49.178843
#
#     longitude
# 0 -123.128947
# 1 -122.979105
# 2 -122.892143
# 3 -122.844991

# %%
mbc1 = pd.read_csv("rest1.csv")
mbc1
# Out:
#    Unnamed: 0             business_id                             name  stars  \
# 0        1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria    4.0
# 1        3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina    4.5
# 2        4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón    4.0
# 3        4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos    4.5
#
#     latitude   longitude
# 0  49.270090 -123.069500
# 1  49.278828 -123.124044
# 2  49.256904 -123.089246
# 3  49.287774 -123.141263

# %%
mb5 = pd.read_csv("rest5og.csv")
mb5
# Out:
#    Unnamed: 0             business_id                    name  stars  \
# 0        1619  l0cLT4c59zu0H8MVwp7vqA  Sula Indian Restaurant    4.0
#
#     latitude   longitude
# 0  49.274434 -123.069188

# %%
mbc5 = pd.read_csv("rest5.csv")
mbc5
# Out:
#     Unnamed: 0             business_id  \
# 0         2130  pJge_LJ3NV8iQtrERe6AyQ
# 1          510  usO5eH44mmub9p_pH95OkQ
# 2         3521  jOZ6AKjTuOWZ7tUabuZq9A
# 3          681  uuQse7YxCrnedtJh9gKgpg
# 4         1338  cp6Bq3-VcearblmgKK1rBQ
# 5         1649  R47URO-i0MvfgKvD3sINow
# 6          108  _Ief3C6t-930SBuwvVuDAQ
# 7         2807  9R4vBq3BUYom9geOTiFs0w
# 8         3983  dR3UkEvdjJ5fAec0ScMQvg
# 9         3588  ytp2-sO-na8NyLK9I2QX2g
# 10        3511  m1SJ6Nn7i-gKZETlf8AoOw
# 11        3434  xzxi_8_UnznXPOr1p5Fl_A
# 12        3421  18aIKschS0rNDNr0sXWtww
# 13        2907  BdsPT4VZtbJeozhrcgk4XA
# 14          93  VCiopspKLHelqobEsSeNxw
# 15        2597  UwQyc3prSQp3pnvdSSmlaQ
# 16        2391  afIFneEf68Td1m3QCCzy0g
# 17        2129  mKp5lyy0GTV0hGNEkuwuQQ
# 18        1164  eqpBdNm-UtMIsodfxLU7MA
# 19         630  l3Uni57g7J1N7WvAKEzbMg
# 20         437  raZ-NDBs9S1j9fPONh4fWw
# 21         119  QxNVmWT2UXjbJrYuOqlCMQ
# 22        4148  Z97LdaraBqS6lMlgt89IiA
#
# ...

# %%
mb3 = pd.read_csv("rest3og.csv")
mbc3 = pd.read_csv("rest3.csv")
mbc3
# Out:
#    Unnamed: 0             business_id               name  stars   latitude  \
# 0         413  bvlNPKcLDnbhrOo7h92z2g            Raglans    4.0  49.310917
# 1        2547  ewOSIjs3hrMcdYsFcoi1Pg  Arms Reach Bistro    4.0  49.326874
# 2        3938  pj3EecjmDf-xnwXyfVbZmw      Burgoo Bistro    4.0  49.310696
# 3        4078  GvaZyy_5B_QjnaEqZV2Z6Q    Smoke and Bones    4.0  49.323576
#
#     longitude
# 0 -123.079996
# 1 -122.949363
# 2 -123.080335
# 3 -123.101946

# %%
mb3
# Out:
#    Unnamed: 0             business_id              name  stars   latitude  \
# 0         724  sMGcNtd1iNi5IZk2sNhXLQ  Cactus Club Cafe    4.5  49.322767
#
#     longitude
# 0 -123.107459

# %%
#clenaing atttributes for yes/no
if [att['attributes.RestaurantsDelivery'] == ('True')]:
    att['attributes.RestaurantsDelivery'] = 'Yes'

# %%
if [att['attributes.RestaurantsDelivery'] == ('False')]:
    att['attributes.RestaurantsDelivery'] = 'No'

# %%
latitude_list = mbc4['latitude'].astype(float)

# %%
longitude_list = mbc4['longitude'].astype(float)

# %%
dist = []
from haversine import haversine
for i in range(len(latitude_list)):
    disty = haversine((latitude_list[i], longitude_list[i]),
                      (49.25669, -123.101936),
                      unit='km')
    dist.append(disty)

# %%
len(dist)
# Out:
# 40

# %%
mbc4.head()
# Out:
#    Unnamed: 0             business_id                      name  stars  \
# 0         166  szPJyzsly0a5ZkehLAV1fA                 Pokérrito    4.0
# 1         307  G3jAGk0OUS_hkrsD4ERevA     Sushimoto Enterprises    4.0
# 2         369  9UThLJTuOQPLcDCLx5BVqw             Sushi By Yuji    4.0
# 3         376  j7VmHg9M-eWZuDw-p4AIaA  Seto Japanese Restaurant    4.0
# 4         455  irdrKokOvuxP_atEjtzkQA          Green Leaf Sushi    4.0
#
#     latitude   longitude
# 0  49.282642 -123.115118
# 1  49.264259 -122.981803
# 2  49.242483 -123.059835
# 3  49.177587 -123.129710
# 4  49.264268 -123.180100

# %%
mbc4['dists'] = dist

# %%
mbc4.head(2)
# Out:
#    Unnamed: 0             business_id                   name  stars  \
# 0         166  szPJyzsly0a5ZkehLAV1fA              Pokérrito    4.0
# 1         307  G3jAGk0OUS_hkrsD4ERevA  Sushimoto Enterprises    4.0
#
#     latitude   longitude     dists
# 0  49.282642 -123.115118  3.040075
# 1  49.264259 -122.981803  8.758373

# %%
mbc4_filter = mbc4[mbc4['dists'] < 5]

# %%
mb4_att = att[att['business_id'].isin(mb4['business_id'])]

# mb4_att_df

# %%
merged_source_mb4 = pd.merge(mb4_att, mb4, on='business_id')

# %%
merged_source_mb4 = merged_source_mb4
merged_source_mb4
# Out:
#               business_id  attributes.RestaurantsTakeOut  \
# 0  cD-yIXTipTTN336R5c_MMg                           True
#
#    attributes.GoodForKids postal_code                         categories  \
# 0                    True     V5T 4R2  Sushi Bars, Restaurants, Japanese
#
#    attributes.RestaurantsPriceRange2 attributes.WiFi  \
# 0                                  2              no
#
#   attributes.RestaurantsDelivery  stars_x  Unnamed: 0         name  stars_y  \
# 0                             No      4.0        2720  Toshi Sushi      4.0
#
#     latitude   longitude
# 0  49.256699 -123.101936

# %%
mbc4_att_df = att[att['business_id'].isin(mbc4['business_id'])]

# mbc4_att_df.head(2)

# %%
merged_mb4 = pd.merge(mbc4_att_df, mbc4_filter, on='business_id')

# %%
# merged_mb4.head(2)

# %%
merged_mb4 = merged_mb4.drop(columns=['postal_code', 'categories', 'stars_x'])

# %%
# merged_mb4

# %%
merged_mb4_filtered = merged_mb4[
    merged_mb4['attributes.RestaurantsPriceRange2'] == 2]

# %%
merged_mb4_filtered = merged_mb4_filtered.sort_values(by='dists')

# %%
merged_mb4_filtered_1km = merged_mb4_filtered[
    merged_mb4_filtered['dists'] <= 1]

# %%
merged_mb4_filtered_2km = merged_mb4_filtered[
    merged_mb4_filtered['dists'] <= 2]

# %%
merged_mb4_filtered_3km = merged_mb4_filtered[
    merged_mb4_filtered['dists'] <= 3]

# %%
att_filtered = att

# %%
att_df = att[['business_id', 'attributes.RestaurantsPriceRange2']]

# %%
mbc4['dists'] = dist

# %%
mbc4filtered = mbc4[mbc4['dists'] < 5]

# %%
q = folium.Map(location=[49.285006, -123.118050],
               tiles='OpenStreetMap',
               zoom_start=12)

r = plugins.MiniMap(toggle_display=True)

# %%
r41fg = folium.FeatureGroup(
    name='Toshi Sushi and its competiton in 1km radius', overlay=True)

r42fg = folium.FeatureGroup(
    name='Toshi Sushi and its competiton in 2km radius', overlay=True)

r43fg = folium.FeatureGroup(
    name='Toshi Sushi and its competiton in 3km radius', overlay=True)

r4fg = folium.FeatureGroup(name='Toshi Sushi and its competiton in 5km radius',
                           overlay=True)

r41fg.add_to(q)

r42fg.add_to(q)

r43fg.add_to(q)

r4fg.add_to(q)

# %%
#layer for 1
for index, row in merged_source_mb4.iterrows():
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews: ' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkgreen', icon='glass')).add_to(r41fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=1000,
                  label='1KM Radius',
                  color='cadetblue').add_to(r41fg)

a = merged_mb4_filtered_1km['latitude'].to_list()
b = merged_mb4_filtered_1km['longitude'].to_list()
points = []

c = merged_source_mb4['latitude'].to_list()
d = merged_source_mb4['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb4_filtered_1km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip='Reviews: ' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(r41fg)

# %%
# folium.LayerControl().add_to(q)

# %%
#layer 2
for index, row in merged_source_mb4.iterrows():
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkgreen', icon='glass')).add_to(r42fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=2000,
                  label='5KM Radius',
                  color='cadetblue').add_to(r42fg)

a = merged_mb4_filtered_2km['latitude'].to_list()
b = merged_mb4_filtered_2km['longitude'].to_list()
points = []

c = merged_source_mb4['latitude'].to_list()
d = merged_source_mb4['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb4_filtered_2km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(r42fg)

# %%
#layer for 3

for index, row in merged_source_mb4.iterrows():
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkgreen', icon='glass')).add_to(r43fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=3000,
                  label='5KM Radius',
                  color='cadetblue').add_to(r43fg)

a = merged_mb4_filtered_3km['latitude'].to_list()
b = merged_mb4_filtered_3km['longitude'].to_list()
points = []

c = merged_source_mb4['latitude'].to_list()
d = merged_source_mb4['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb4_filtered_3km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(r43fg)

# %%
#layer for 5
for index, row in merged_source_mb4.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' +
                  ':' + str(row['name']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(r4fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=5000,
                  label='5KM Radius',
                  color='cadetblue').add_to(r4fg)

a = mbc4filtered['latitude'].to_list()
b = mbc4filtered['longitude'].to_list()
points = []

c = mb4['latitude'].to_list()
d = mb4['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc4filtered.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews: ' + str(row['stars']) + '\t' + ' Name' +
                  ':' + str(row['name']),
                  icon=folium.Icon(color='darkred', icon='glass')).add_to(r4fg)

# %%
folium.LayerControl(collapsed=False).add_to(q)

# %%
print(
    'This map shows the resturants and their competitors where each marker indicates geocoordinates.'
)
print(
    'On 5km Radius, you can see name and ratings of resturants, further drilling down the radius helps you see common attributes between resturants and their competition.'
)
q
# Out:
# This map shows the resturants and their competitors where each marker indicates geocoordinates.
# On 5km Radius, you can see name and ratings of resturants, further drilling down the radius helps you see common attributes between resturants and their competition.
# ...

# %%
q.save("Toshi Sushi Radius map.html")

# %%
##rest1z
latitude_list1a = mb1['latitude'].astype(float)

# %%
longitude_list1a = mb1['longitude'].astype(float)

# %%
latitude_list1b = mbc1['latitude'].astype(float)
latitude_list1b
# Out:
# 0    49.270090
# 1    49.278828
# 2    49.256904
# 3    49.287774
# Name: latitude, dtype: float64

# %%
longitude_list1b = mbc1['longitude'].astype(float)

# %%
dist = []
from haversine import haversine
for i in range(len(latitude_list1b)):
    disty = haversine((latitude_list1b[i], longitude_list1b[i]),
                      (latitude_list1a[i], longitude_list1a[i]),
                      unit='km')
    dist.append(disty)

# %%
mbc1['dists'] = dist

# %%
mbc1_filter = mbc1[mbc1['dists'] < 5]

# %%
mb1_att = att[att['business_id'].isin(mb1['business_id'])]

# %%
merged_source_mb1 = pd.merge(mb1_att, mb1, on='business_id')
mbc1_att_df = att[att['business_id'].isin(mbc1['business_id'])]

merged_mb1 = pd.merge(mbc1_att_df, mbc1_filter, on='business_id')

# %%
mb1_att.head(1)
# Out:
#                 business_id  attributes.RestaurantsTakeOut  \
# 324  oAv2XW5i-w3A-pESAu1Abw                           True
#
#      attributes.GoodForKids postal_code                       categories  \
# 324                    True     V6Z 1B7  Fast Food, Mexican, Restaurants
#
#      attributes.RestaurantsPriceRange2 attributes.WiFi  \
# 324                                  1            free
#
#     attributes.RestaurantsDelivery  stars
# 324                             No    3.0

# %%
merged_mb1 = merged_mb1.drop(columns=['postal_code', 'categories', 'stars_x'])

# %%
merged_mb1_filtered = merged_mb1[
    merged_mb1['attributes.RestaurantsPriceRange2'] == 2]

# %%
merged_mb1_filtered = merged_mb1_filtered.sort_values(by='dists')

# %%
merged_mb1_filtered = merged_mb1[
    merged_mb1['attributes.RestaurantsPriceRange2'] == 2]

merged_mb1_filtered = merged_mb1_filtered.sort_values(by='dists')

merged_mb1_filtered_1km = merged_mb1_filtered[
    merged_mb1_filtered['dists'] <= 1]

merged_mb1_filtered_1km

merged_mb1_filtered_2km = merged_mb1_filtered[
    merged_mb1_filtered['dists'] <= 2]

merged_mb1_filtered_2km

merged_mb1_filtered_3km = merged_mb1_filtered[
    merged_mb1_filtered['dists'] <= 3]

merged_mb1_filtered_3km

##groupbypiece
# merged_mb4.groupby('attributes.RestaurantsPriceRange2').apply(lambda x: x.sort_values('attributes.RestaurantsPriceRange2'))
# Out:
# Empty DataFrame
# Columns: [business_id, attributes.RestaurantsTakeOut, attributes.GoodForKids, attributes.RestaurantsPriceRange2, attributes.WiFi, attributes.RestaurantsDelivery, Unnamed: 0, name, stars_y, latitude, longitude, dists]
# Index: []

# %%
merged_mb1_filtered_1km
# Out:
# Empty DataFrame
# Columns: [business_id, attributes.RestaurantsTakeOut, attributes.GoodForKids, attributes.RestaurantsPriceRange2, attributes.WiFi, attributes.RestaurantsDelivery, Unnamed: 0, name, stars_y, latitude, longitude, dists]
# Index: []

# %%
map1 = folium.Map(location=[49.285006, -123.118050],
                  tiles='OpenStreetMap',
                  zoom_start=12)

m = plugins.MiniMap(toggle_display=True)

# %%
m1fg = folium.FeatureGroup(
    name='Mucho Burrito and its competiton in 5km radius', overlay=True)
m11fg = folium.FeatureGroup(
    name='Mucho Burrito and its competiton in 1km radius', overlay=True)
m12fg = folium.FeatureGroup(
    name='Mucho Burrito and its competiton in 2km radius', overlay=True)

m13fg = folium.FeatureGroup(
    name='Mucho Burrito and its competiton in 3km radius', overlay=True)

# %%
m1fg.add_to(map1)
m11fg.add_to(map1)
m12fg.add_to(map1)
m13fg.add_to(map1)

# %%
#layer for 5

for index, row in merged_source_mb1.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' +
                  ':' + str(row['name']) + ' Wifi:' +
                  str(row['attributes.WiFi']) + ' Price Range:2' + '$' +
                  ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m1fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=5000,
                  label='5KM Radius',
                  color='cadetblue').add_to(m1fg)

a = merged_mb1_filtered['latitude'].to_list()
b = merged_mb1_filtered['longitude'].to_list()
points = []

c = merged_source_mb1['latitude'].to_list()
d = merged_source_mb1['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb1_filtered.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m1fg)

# %%
#layer for 1

for index, row in merged_source_mb1.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' +
                  ':' + str(row['name']) + ' Wifi:' +
                  str(row['attributes.WiFi']) + ' Price Range:2' + '$' +
                  ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m11fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=1000,
                  label='1KM Radius',
                  color='cadetblue').add_to(m11fg)

a = merged_mb1_filtered_1km['latitude'].to_list()
b = merged_mb1_filtered_1km['longitude'].to_list()
points = []

c = merged_source_mb1['latitude'].to_list()
d = merged_source_mb1['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb1_filtered_1km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m11fg)

# %%
#layer for 2

for index, row in merged_source_mb1.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' +
                  ':' + str(row['name']) + ' Wifi:' +
                  str(row['attributes.WiFi']) + ' Price Range:2' + '$' +
                  ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m12fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=2000,
                  label='2KM Radius',
                  color='cadetblue').add_to(m12fg)

a = merged_mb1_filtered_2km['latitude'].to_list()
b = merged_mb1_filtered_2km['longitude'].to_list()
points = []

c = merged_source_mb1['latitude'].to_list()
d = merged_source_mb1['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb1_filtered_2km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m12fg)

# %%
#layer for 3

for index, row in merged_source_mb1.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' +
                  ':' + str(row['name']) + ' Wifi:' +
                  str(row['attributes.WiFi']) + ' Price Range:2' + '$' +
                  ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m13fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=3000,
                  label='3KM Radius',
                  color='cadetblue').add_to(m13fg)

a = merged_mb1_filtered_3km['latitude'].to_list()
b = merged_mb1_filtered_3km['longitude'].to_list()
points = []

c = merged_source_mb1['latitude'].to_list()
d = merged_source_mb1['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb1_filtered_3km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m13fg)

# %%
folium.LayerControl(collapsed=False).add_to(map1)

# %%
print(
    'This map shows the resturants and their competitors where each marker indicates geocoordinates'
)
print(
    'On 5km Radius, you can see name and ratings of resturants, further drilling down the radius helps you see common attributes between resturants and their competition'
)
map1
# Out:
# This map shows the resturants and their competitors where each marker indicates geocoordinates
# On 5km Radius, you can see name and ratings of resturants, further drilling down the radius helps you see common attributes between resturants and their competition
# ...

# %%
map1.save("Mucho Burrito radius map.html")

# %%
latitude_list2b = mbc2['latitude'].astype(float)

longitude_list2b = mbc2['longitude'].astype(float)

# %%
latitude_list2a = mb2['latitude'].astype(float)

longitude_list2a = mb2['longitude'].astype(float)

# %%
dist2 = []

for i in range(len(latitude_list2b)):
    disty = haversine((latitude_list2b[i], longitude_list2b[i]),
                      (latitude_list2a, longitude_list2a),
                      unit='km')
    dist2.append(disty)

# %%
dist2
# Out:
# [1.066104034556812,
#  4.903478715405829,
#  1.1072480853394628,
#  2.9745305620382836,
#  4.839504612831765,
#  1.357617085776694,
#  3.5265674564519967,
#  3.834009514569042,
#  1.236428707333577,
#  1.180611754271983,
#  5.015786251729106,
#  3.1073409349287844,
#  3.0040807493051833,
#  3.201093563425723,
#  1.85091568222676,
#  4.752045288967118,
#  1.2313256493405669,
#  6.5596728404353275,
#  1.2207596517107355,
#  3.0191824431792766,
#  1.180394372279842,
#  4.783370213781005,
#  0.4806927337049315,
#  0.21701167225680484,
#  3.3404814830599685,
#  3.619039532839328,
#  4.176190586101055,
#  1.4004776026816486,
#  1.7231490279180695,
#  1.3061797619760187,
#  1.4840734214066722,
#  0.9338872042754593,
#  4.313495772959554,
#  0.8910075268330505,
#  3.341489987332555,
#  0.9435694480995765,
#  3.772002971323468,
#  1.2097858046317196,
#  0.8526794469853523,
#  1.544762763972298,
#  1.253690978583521,
#  4.476533019805594,
#  4.4964889135348525,
#  1.310682542317735,
# ...

# %%
mbc2['dists'] = dist2

mbc2_filtered = mbc2[mbc2['dists'] < 5]

mb2_att = att[att['business_id'].isin(mb2['business_id'])]

merged_source_m2 = pd.merge(mb2_att, mb2, on='business_id')

mbc2_att_df = att[att['business_id'].isin(mbc2['business_id'])]

# mbc4_att_df.head(2)

merged_mb2 = pd.merge(mbc2_att_df, mbc2_filtered, on='business_id')

# merged_mb4.head(2)

merged_mb2 = merged_mb2.drop(columns=['postal_code', 'categories', 'stars_x'])

# merged_mb4

merged_mb2_filtered = merged_mb2[
    merged_mb2['attributes.RestaurantsPriceRange2'] == 2]

merged_mb2_filtered = merged_mb2_filtered.sort_values(by='dists')

merged_mb2_filtered_1km = merged_mb2_filtered[
    merged_mb2_filtered['dists'] <= 1]

# merged_mb4_filtered_1km

merged_mb2_filtered_2km = merged_mb2_filtered[
    merged_mb2_filtered['dists'] <= 2]

# merged_mb4_filtered_2km

merged_mb2_filtered_3km = merged_mb2_filtered[
    merged_mb2_filtered['dists'] <= 3]

# merged_mb4_filtered_3km

# %%
#FOR DE DUTCH
map2 = folium.Map(location=[49.285006, -123.118050],
                  tiles='OpenStreetMap',
                  zoom_start=12)

m2 = plugins.MiniMap(toggle_display=True)

m2fg = folium.FeatureGroup(
    name='De Dutch Restaurant and its competiton in 1km radius', overlay=True)
m22fg = folium.FeatureGroup(
    name='De Dutch Restaurant and its competiton in 2km radius', overlay=True)

m23fg = folium.FeatureGroup(
    name='De Dutch Restaurant and its competiton in 3km radius', overlay=True)

m25fg = folium.FeatureGroup(
    name='De Dutch Restaurant and its competiton in 5km radius', overlay=True)

m2fg.add_to(map2)
m22fg.add_to(map2)

m23fg.add_to(map2)

m25fg.add_to(map2)

# %%
#layer for 5
for index, row in merged_source_m2.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' +
                  ':' + str(row['name']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m25fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=5000,
                  label='5KM Radius',
                  color='cadetblue').add_to(m25fg)

a = merged_mb2_filtered['latitude'].to_list()
b = merged_mb2_filtered['longitude'].to_list()
points = []

c = mb3['latitude'].to_list()
d = mb3['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb2_filtered.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews: ' + str(row['stars_y']) + '\t' + 'Name ' +
                  ':' + str(row['name']),
                  icon=folium.Icon(color='darkred',
                                   icon='glass')).add_to(m25fg)

# %%
#layer for 1

for index, row in merged_source_m2.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' +
                  ':' + str(row['name']) + ' Wifi:' +
                  str(row['attributes.WiFi']) + ' Price Range:2' + '$' +
                  ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m2fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=1000,
                  label='1KM Radius',
                  color='cadetblue').add_to(m2fg)

a = merged_mb1_filtered_1km['latitude'].to_list()
b = merged_mb1_filtered_1km['longitude'].to_list()
points = []

c = merged_source_m2['latitude'].to_list()
d = merged_source_m2['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb2_filtered_1km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m2fg)

# %%
#layer for 2

for index, row in merged_source_m2.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' +
                  ':' + str(row['name']) + ' Wifi:' +
                  str(row['attributes.WiFi']) + ' Price Range:2' + '$' +
                  ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m22fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=2000,
                  label='1KM Radius',
                  color='cadetblue').add_to(m22fg)

a = merged_mb1_filtered_1km['latitude'].to_list()
b = merged_mb1_filtered_1km['longitude'].to_list()
points = []

c = merged_source_m2['latitude'].to_list()
d = merged_source_m2['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb2_filtered_1km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m22fg)

# %%
#layer for 3

for index, row in merged_source_m2.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' +
                  ':' + str(row['name']) + ' Wifi:' +
                  str(row['attributes.WiFi']) + ' Price Range:2' + '$' +
                  ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m23fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=3000,
                  label='1KM Radius',
                  color='cadetblue').add_to(m23fg)

a = merged_mb1_filtered_1km['latitude'].to_list()
b = merged_mb1_filtered_1km['longitude'].to_list()
points = []

c = merged_source_m2['latitude'].to_list()
d = merged_source_m2['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb2_filtered_1km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + ' Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m23fg)

# %%
folium.LayerControl(collapsed=False).add_to(map2)

# %%
print(
    'This map shows the resturants and their competitors where each marker indicates geocoordinates.'
)
print(
    'On 5km Radius, you can see name and ratings of resturants, further drilling down the radius helps you see common attributes between resturants and their competition.'
)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map2.save("De Dutch radius map.html")

# %%
#cactus clubs comp

# %%
mbc3
# Out:
#    Unnamed: 0             business_id               name  stars   latitude  \
# 0         413  bvlNPKcLDnbhrOo7h92z2g            Raglans    4.0  49.310917
# 1        2547  ewOSIjs3hrMcdYsFcoi1Pg  Arms Reach Bistro    4.0  49.326874
# 2        3938  pj3EecjmDf-xnwXyfVbZmw      Burgoo Bistro    4.0  49.310696
# 3        4078  GvaZyy_5B_QjnaEqZV2Z6Q    Smoke and Bones    4.0  49.323576
#
#     longitude
# 0 -123.079996
# 1 -122.949363
# 2 -123.080335
# 3 -123.101946

# %%
mb3
# Out:
#    Unnamed: 0             business_id              name  stars   latitude  \
# 0         724  sMGcNtd1iNi5IZk2sNhXLQ  Cactus Club Cafe    4.5  49.322767
#
#     longitude
# 0 -123.107459

# %%
latitude_list3b = mbc3['latitude'].astype(float)

longitude_list3b = mbc3['longitude'].astype(float)
latitude_list3a = mb3['latitude'].astype(float)
longitude_list3a = mb3['longitude'].astype(float)
dist3 = []
for i in range(len(latitude_list3b)):
    disty = haversine((latitude_list3b[i], longitude_list3b[i]),
                      (latitude_list3a, longitude_list3a),
                      unit='km')
    dist3.append(disty)

mbc3['dists'] = dist3

mbc3.head(2)

mbc3_filter = mbc3[mbc3['dists'] <= 5]

mb3_att = att[att['business_id'].isin(mb3['business_id'])]

# mb4_att_df

merged_source_mb3 = pd.merge(mb3_att, mb3, on='business_id')

mbc3_att_df = att[att['business_id'].isin(mbc3['business_id'])]

# mbc4_att_df.head(2)

merged_mb3 = pd.merge(mbc3_att_df, mbc3_filter, on='business_id')

# merged_mb4.head(2)

merged_mb3 = merged_mb3.drop(columns=['postal_code', 'categories', 'stars_x'])

# merged_mb4

merged_mb3_filtered = merged_mb3[
    merged_mb3['attributes.RestaurantsPriceRange2'] == 2]

merged_mb3_filtered = merged_mb3_filtered.sort_values(by='dists')

merged_mb3_filtered_1km = merged_mb3_filtered[
    merged_mb3_filtered['dists'] <= 1]

# merged_mb4_filtered_1km

merged_mb3_filtered_2km = merged_mb3_filtered[
    merged_mb3_filtered['dists'] <= 2]

# merged_mb4_filtered_2km

merged_mb3_filtered_3km = merged_mb3_filtered[
    merged_mb3_filtered['dists'] <= 3]

# merged_mb4_filtered_3km

att_filtered = att

att_df = att[['business_id', 'attributes.RestaurantsPriceRange2']]

# att_df

mbc3['dists'] = dist

mbc3filtered = mbc3[mbc3['dists'] < 5]

# %%
dist3
# Out:
# [2.3872539730623847,
#  11.466905384242075,
#  2.3806054919850235,
#  0.40957114396877586]

# %%
merged_mb3
# Out:
#               business_id  attributes.RestaurantsTakeOut  \
# 0  bvlNPKcLDnbhrOo7h92z2g                          False
# 1  pj3EecjmDf-xnwXyfVbZmw                           True
# 2  GvaZyy_5B_QjnaEqZV2Z6Q                           True
#
#    attributes.GoodForKids  attributes.RestaurantsPriceRange2 attributes.WiFi  \
# 0                    True                                  2              no
# 1                    True                                  2              no
# 2                    True                                  3            free
#
#   attributes.RestaurantsDelivery  Unnamed: 0             name  stars_y  \
# 0                             No         413          Raglans      4.0
# 1                             No        3938    Burgoo Bistro      4.0
# 2                             No        4078  Smoke and Bones      4.0
#
#     latitude   longitude     dists
# 0  49.310917 -123.079996  2.387254
# 1  49.310696 -123.080335  2.380605
# ...

# %%
merged_mb3_filtered
# Out:
#               business_id  attributes.RestaurantsTakeOut  \
# 1  pj3EecjmDf-xnwXyfVbZmw                           True
# 0  bvlNPKcLDnbhrOo7h92z2g                          False
#
#    attributes.GoodForKids  attributes.RestaurantsPriceRange2 attributes.WiFi  \
# 1                    True                                  2              no
# 0                    True                                  2              no
#
#   attributes.RestaurantsDelivery  Unnamed: 0           name  stars_y  \
# 1                             No        3938  Burgoo Bistro      4.0
# 0                             No         413        Raglans      4.0
#
#     latitude   longitude     dists
# 1  49.310696 -123.080335  2.380605
# 0  49.310917 -123.079996  2.387254

# %%
mbc3_filter
# Out:
#    Unnamed: 0             business_id             name  stars   latitude  \
# 0         413  bvlNPKcLDnbhrOo7h92z2g          Raglans    4.0  49.310917
# 2        3938  pj3EecjmDf-xnwXyfVbZmw    Burgoo Bistro    4.0  49.310696
# 3        4078  GvaZyy_5B_QjnaEqZV2Z6Q  Smoke and Bones    4.0  49.323576
#
#     longitude     dists
# 0 -123.079996  2.387254
# 2 -123.080335  2.380605
# 3 -123.101946  0.409571

# %%
merged_mb3_filtered_3km
# Out:
#               business_id  attributes.RestaurantsTakeOut  \
# 1  pj3EecjmDf-xnwXyfVbZmw                           True
# 0  bvlNPKcLDnbhrOo7h92z2g                          False
#
#    attributes.GoodForKids  attributes.RestaurantsPriceRange2 attributes.WiFi  \
# 1                    True                                  2              no
# 0                    True                                  2              no
#
#   attributes.RestaurantsDelivery  Unnamed: 0           name  stars_y  \
# 1                             No        3938  Burgoo Bistro      4.0
# 0                             No         413        Raglans      4.0
#
#     latitude   longitude     dists
# 1  49.310696 -123.080335  2.380605
# 0  49.310917 -123.079996  2.387254

# %%
merged_mb3_filtered_2km
# Out:
# Empty DataFrame
# Columns: [business_id, attributes.RestaurantsTakeOut, attributes.GoodForKids, attributes.RestaurantsPriceRange2, attributes.WiFi, attributes.RestaurantsDelivery, Unnamed: 0, name, stars_y, latitude, longitude, dists]
# Index: []

# %%
merged_mb3_filtered_1km
# Out:
# Empty DataFrame
# Columns: [business_id, attributes.RestaurantsTakeOut, attributes.GoodForKids, attributes.RestaurantsPriceRange2, attributes.WiFi, attributes.RestaurantsDelivery, Unnamed: 0, name, stars_y, latitude, longitude, dists]
# Index: []

# %%
#FOR cactus

map3 = folium.Map(location=[49.285006, -123.118050],
                  tiles='OpenStreetMap',
                  zoom_start=10)

m3 = plugins.MiniMap(toggle_display=True)

m3fg = folium.FeatureGroup(
    name='Cactus Club Cafe and its competiton in 1km radius', overlay=True)
m32fg = folium.FeatureGroup(
    name='Cactus Club Cafe and its competiton in 2km radius', overlay=True)

m33fg = folium.FeatureGroup(
    name='Cactus Club Cafe and its competiton in 3km radius', overlay=True)

m35fg = folium.FeatureGroup(
    name='Cactus Club Cafe and its competiton in 5km radius', overlay=True)

m3fg.add_to(map3)
m32fg.add_to(map3)

m33fg.add_to(map3)

m35fg.add_to(map3)

# %%
#layer for 1

for index, row in merged_source_mb3.iterrows():
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkgreen', icon='glass')).add_to(m3fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=1000,
                  label='1KM Radius',
                  color='cadetblue').add_to(m3fg)

a = merged_mb3_filtered_1km['latitude'].to_list()
b = merged_mb3_filtered_1km['longitude'].to_list()
points = []

c = merged_source_mb3['latitude'].to_list()
d = merged_source_mb3['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb3_filtered_1km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m3fg)

# %%
#layer for 2

for index, row in merged_source_mb3.iterrows():
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkgreen', icon='glass')).add_to(m32fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=2000,
                  label='2KM Radius',
                  color='cadetblue').add_to(m32fg)

a = merged_mb3_filtered_2km['latitude'].to_list()
b = merged_mb3_filtered_2km['longitude'].to_list()
points = []

c = merged_source_mb3['latitude'].to_list()
d = merged_source_mb3['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb3_filtered_2km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m32fg)

# %%
#layer for 3

for index, row in merged_source_mb3.iterrows():
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery:' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkgreen', icon='glass')).add_to(m33fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=3000,
                  label='3KM Radius',
                  color='cadetblue').add_to(m33fg)

a = merged_mb3_filtered_3km['latitude'].to_list()
b = merged_mb3_filtered_3km['longitude'].to_list()
points = []

c = merged_source_mb3['latitude'].to_list()
d = merged_source_mb3['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb3_filtered_3km.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        [row['latitude'], row['longitude']],
        tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' + ':' +
        str(row['name']) + ' Wifi:' + str(row['attributes.WiFi']) +
        ' Price Range:' + str(row['attributes.RestaurantsPriceRange2']) + '$' +
        ' Delivery' + ':' + str(row['attributes.RestaurantsDelivery']),
        icon=folium.Icon(color='darkred', icon='glass')).add_to(m33fg)

# %%
merged_mb3_filtered_3km
# Out:
#               business_id  attributes.RestaurantsTakeOut  \
# 1  pj3EecjmDf-xnwXyfVbZmw                           True
# 0  bvlNPKcLDnbhrOo7h92z2g                          False
#
#    attributes.GoodForKids  attributes.RestaurantsPriceRange2 attributes.WiFi  \
# 1                    True                                  2              no
# 0                    True                                  2              no
#
#   attributes.RestaurantsDelivery  Unnamed: 0           name  stars_y  \
# 1                             No        3938  Burgoo Bistro      4.0
# 0                             No         413        Raglans      4.0
#
#     latitude   longitude     dists
# 1  49.310696 -123.080335  2.380605
# 0  49.310917 -123.079996  2.387254

# %%
merged_mb3_filtered_3km['dists'][
    0] = merged_mb3_filtered_3km['dists'][0] + 0.10
# Out:
# /var/folders/5d/yhcn6m7d2pn9ytcsv1j2890w0000gn/T/ipykernel_32837/1323542320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_mb3_filtered_3km['dists'][0]=merged_mb3_filtered_3km['dists'][0]+0.10

# %%
merged_mb3_filtered_3km['dists'][0]
# Out:
# 2.487253973062385

# %%
#layer for 5
for index, row in merged_source_mb3.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews:' + str(row['stars_y']) + '\t' + 'Name' +
                  ':' + str(row['name']),
                  icon=folium.Icon(color='darkgreen',
                                   icon='glass')).add_to(m35fg)
    folium.Circle([row['latitude'], row['longitude']],
                  radius=5000,
                  label='5KM Radius',
                  color='cadetblue').add_to(m35fg)

a = merged_mb3_filtered['latitude'].to_list()
b = merged_mb3_filtered['longitude'].to_list()
points = []

c = merged_source_mb3['latitude'].to_list()
d = merged_source_mb3['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])

for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in merged_mb3_filtered.iterrows():

    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']],
                  tooltip=' Reviews: ' + str(row['stars_y']) + '\t' + 'Name ' +
                  ':' + str(row['name']),
                  icon=folium.Icon(color='darkred',
                                   icon='glass')).add_to(m35fg)

# %%
folium.LayerControl(collapsed=False).add_to(map3)

# %%
print(
    'This map shows the resturants and their competitors where each marker indicates geocoordinates.'
)
print(
    'On 5km Radius, you can see name and ratings of resturants, further drilling down the radius helps you see common attributes between resturants and their competition.'
)
map3
# Out:
# This map shows the resturants and their competitors where each marker indicates geocoordinates.
# On 5km Radius, you can see name and ratings of resturants, further drilling down the radius helps you see common attributes between resturants and their competition.
# ...

# %%
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map3.save("Cactus Club radius map.html")
