# %%
# !ls
# Out:
# A6 2.ipynb                   data401bc.json
# A6code.ipynb                 data50.json
# A9-2.ipynb                   data501bc.json
# AnacondaProjects             data50bc.json
# Applications                 data50bcnew.csv
# Bokeh.ipynb                  data51.json
# Created-in-GitHub            data51bc.json
# Desktop                      data551bc.json
# Documents                    data601bc.json
# Downloads                    data651bc.json
# FIBA.ipynb                   data701bc.json
# LastOpenedFiles.xml          data751bc.json
# Library                      data801bc.json
# List                         data851bc.json
# MacKeeper Backups            data_cleaning.ipynb
# Movies                       data_extraction.ipynb
# Music                        datadictbc.json
# Pictures                     dneed.json
# Public                       git
# PycharmProjects              hadoop-3.2.2
# RESUME                       lalonde.csv
# Untitled.ipynb               locationwithmeta.csv
# Untitled1.ipynb              log-review-boxplot.png
# Untitled2.ipynb              log-review-count-boxplot.png
# Untitled3.ipynb              miniconda3
# Untitled4.ipynb              mucho_burrito.csv
# a6test.ipynb                 mucho_burrito_comp.csv
# bc_rest.csv                  myFile.csv
# bc_rest_open.csv             outcombined.csv
# city_data.csv                r programming.R
# combined.csv                 r programming3.R
# comp_analysis.ipynb          rest1.csv
# compwithmeta.csv             rest2.csv
# data.json                    spark-3.1.2-bin-hadoop3.2
# data100.json                 ssh
# data101bc.json               test_restraurent.csv
# data151bc.json               up.log
# data201bc.json               van_rest.csv
# data251bc.json               x86-id.log
# data301bc.json               x86-ip.log
# data351bc.json

# %%
import pandas as pd

# %%
df_1=pd.read_csv("bc_rest_open.csv")

# %%
category_list_client=pd.DataFrame()

# %%
category_list_client['categories']=df_1.categories

# %%
category_list_client
# Out:
#                                              categories
# 0                                     Restaurants, Thai
# 1     Food Delivery Services, Food, Restaurants, Med...
# 2                                   Indian, Restaurants
# 3                                    Restaurants, Pizza
# 4                Food, Coffee & Tea, Restaurants, Cafes
# ...                                                 ...
# 4725                            Restaurants, Sushi Bars
# 4726                                 Pizza, Restaurants
# 4727                     Chinese, Japanese, Restaurants
# 4728                                 Pizza, Restaurants
# 4729  Coffee Roasteries, Breakfast & Brunch, Food, C...
#
# [4730 rows x 1 columns]

# %%
from re import split

# %%
df_1
# Out:
#                  business_id                 name  \
# 0     D4JtQNTI4X3KcbzacDJsMw  Bob Likes Thai Food
# 1     QciD6FbNklaJvUbLExD4Nw                 ARGO
# 2     Xi2GGNzOiUS8r6WCFvu-fw       Kerala Kitchen
# 3     OfA_4cHgvlknHMcn0qNs2w       Little Caesars
# 4     r-hWf-bd9im5rj_l2MeofQ       Take Five Café
# ...                      ...                  ...
# 4725  jrW5mnMLDp2BeGZh8A6VFg          Sushi Ninja
# 4726  WtoWJAOmLbordZcE-yY_SQ       Megabite Davie
# 4727  6SxKXdMTcQ9xLKg7X3A5yg       Teppan Kitchen
# 4728  qYn6CQIhtPadf7dqyxnCbg        Pizza Factory
# 4729  dplKdpONowTjlPZvq0wSRw       Elysian Coffee
#
#                               address       city state postal_code   latitude  \
# 0                        3755 Main St  Vancouver    BC         V5V  49.251342
# 1           3790 Canada Way, Unit 108    Burnaby    BC     V5G 1G4  49.254436
# 2                103- 9386 120 Street     Surrey    BC     V3V 4B9  49.173723
# 3                    7010 Kerr Street  Vancouver    BC         V5S  49.219532
# 4            102-609 Granville Street  Vancouver    BC     V7Y 1H4  49.283532
# ...                               ...        ...   ...         ...        ...
# 4725               1861 Commercial Dr  Vancouver    BC     V5N 4A6  49.267992
# 4726                    1112 Davie St  Vancouver    BC     V6E 1N1  49.280569
# 4727  4151 Hazelbridge Way, Unit 3250   Richmond    BC     V6X 4J7  49.184112
# 4728                  7898 6th Street    Burnaby    BC     V3N 3N3  49.219277
# 4729   1100 Burrard Street, Suite 102  Vancouver    BC     V6Z 1Y9  49.279845
#
#        longitude  stars  review_count  is_open  \
# 0    -123.101333    3.5           169        1
# 1    -123.020050    4.0            76        1
# 2    -122.889641    4.0             9        1
# 3    -123.040893    1.0             9        1
# 4    -123.117107    4.0            17        1
# ...          ...    ...           ...      ...
# 4725 -123.069849    3.5            10        1
# 4726 -123.131762    3.0            30        1
# 4727 -123.133543    3.5            32        1
# 4728 -122.927318    2.0             5        1
# 4729 -123.127654    4.0            53        1
#
#                                              attributes  \
# 0     {'GoodForKids': 'True', 'Alcohol': "u'none'", ...
# 1     {'WheelchairAccessible': 'False', 'Restaurants...
# 2     {'BusinessParking': "{'garage': False, 'street...
# 3     {'GoodForKids': 'True', 'RestaurantsReservatio...
# 4     {'BikeParking': 'True', 'WiFi': "'free'", 'Res...
# ...                                                 ...
# 4725  {'RestaurantsDelivery': 'True', 'HasTV': 'True...
# 4726  {'BusinessParking': "{'garage': False, 'street...
# 4727  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 4728  {'RestaurantsReservations': 'False', 'Restaura...
# 4729  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
#
#                                              categories  \
# 0                                     Restaurants, Thai
# 1     Food Delivery Services, Food, Restaurants, Med...
# 2                                   Indian, Restaurants
# 3                                    Restaurants, Pizza
# 4                Food, Coffee & Tea, Restaurants, Cafes
# ...                                                 ...
# 4725                            Restaurants, Sushi Bars
# 4726                                 Pizza, Restaurants
# 4727                     Chinese, Japanese, Restaurants
# 4728                                 Pizza, Restaurants
# 4729  Coffee Roasteries, Breakfast & Brunch, Food, C...
#
#                                                   hours
# 0     {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...
# 1     {'Monday': '0:0-0:0', 'Tuesday': '11:30-21:0',...
# 2     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 3     {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 4                                                   NaN
# ...                                                 ...
# 4725  {'Wednesday': '11:30-21:30', 'Thursday': '11:3...
# 4726  {'Monday': '11:0-1:0', 'Tuesday': '11:0-1:0', ...
# 4727  {'Monday': '11:0-19:0', 'Tuesday': '11:0-19:0'...
# 4728                                                NaN
# 4729  {'Monday': '7:0-18:0', 'Tuesday': '7:0-18:0', ...
#
# [4730 rows x 14 columns]

# %%
df_1.name
# Out:
# 0       Bob Likes Thai Food
# 1                      ARGO
# 2            Kerala Kitchen
# 3            Little Caesars
# 4            Take Five Café
#                ...
# 4725            Sushi Ninja
# 4726         Megabite Davie
# 4727         Teppan Kitchen
# 4728          Pizza Factory
# 4729         Elysian Coffee
# Name: name, Length: 4730, dtype: object

# %%
from itertools import groupby


results = {value: len(list(sorted(freq))) for value, freq in groupby(sorted(df_1.name))}
results
# Out:
# {'0755 Lounge': 1,
#  '131 Water Kitchen & Bar': 1,
#  '1931 Gallery Bistro': 1,
#  '24 Train Express': 1,
#  '3 Quarters Full': 1,
#  "4 Brothers' Pizza": 1,
#  '4 Stones Vegetarian Cuisine': 1,
#  '41 Noodle & Rice Pot House': 1,
#  '49th Parallel Coffee': 2,
#  '5 Spice Vietnamese Cuisine': 1,
#  "50's Burgers": 1,
#  '54th Ave Cafe Restaurant': 1,
#  '6 Degrees Eatery': 1,
#  '604 Dental At Main 41': 1,
#  '6th Ave Bread & Deli': 1,
#  '7 Days Coffee': 1,
#  '7-Eleven': 1,
#  '75 West Coast Grill': 1,
#  '777 Pizza & Donair': 1,
#  '8 at Doneras': 1,
#  '88 PalPal Noodle House': 1,
#  '888 Caffe Express': 1,
#  '99 BBQ House': 1,
#  'A & W Restaurants': 1,
#  'A Bread Affair': 1,
#  'A La Mode': 1,
#  'A Taste of India Restaurant': 1,
#  'A Taste of Punjab': 1,
#  'A Taste of Vietnam': 1,
#  'A&W': 42,
#  'AAA Restaurant': 1,
#  'ABODE Restaurant & Coffee Bar': 1,
#  'AFURI ramen + dumpling': 1,
#  'AKD Kitchen': 1,
#  'ARC Restaurant': 1,
#  'ARGO': 1,
#  'ARISU Authentic Korean BBQ': 1,
#  'ASA Sushi': 1,
#  'Abc Country Restaurant': 1,
#  'Abdul BBQ & Shawarma': 1,
#  'Aberdeen Square Food Court': 1,
#  'Absinthe Bistro': 1,
#  'Abyssinia Ethiopian Restaurant': 1,
#  'Acqua Restaurant + Bar': 1,
#  'Active Body Burnaby': 1,
#  "Adam's Crepes": 1,
#  'Addis Cafe Ethiopian Restaurant': 1,
#  'Adelitas': 1,
#  'Adonia Tea House': 1,
#  'Aero Inn Sushi Cafe': 1,
#  'Afghan Bakery & Fast Food': 1,
#  'Afghan Chopan Bakery & Diner': 1,
#  'Afghan Chopan Restaurant': 2,
#  'Afghan Horsemen Restaurant': 1,
#  'Afghan Turkish Cuisine': 1,
#  'Afra Bakery & Market': 1,
#  'Aggarwal Sweets': 1,
#  'Agora Cafe': 1,
#  'Agra Indian Sweets And Restaurant': 1,
#  'Agra Tandoori Restaurant': 2,
#  'Agro Roasters': 1,
#  'Aji Hana': 1,
#  'Ajisai Sushi Bar': 1,
#  'Ajishou Japanese Cuisine': 1,
#  'Ajiya Sushi Bar': 1,
#  'Ajs Brooklyn Pizza Joint': 1,
#  'Ajuker Fried Chicken': 1,
#  'Akari Japanese Restaurant': 1,
#  'Akasaka Japanese Restaurant': 1,
#  'Akash Chat House & Restaurant': 1,
#  "Akbar's Own Dining Lounge": 1,
#  'Akebono Japanese Food & Sushi': 1,
#  'Akira Sushi': 1,
#  'Al Basha': 2,
#  'Al Basha Restaurant': 1,
#  'Al Porto': 1,
#  'Al-Salam Halal Meat': 1,
#  'Al-Watan Tandoori': 1,
#  'Aladdin Cafe': 1,
#  'Alberello Pizzeria': 1,
#  'Alenka European Foods': 1,
#  'Aleph Eatery': 1,
#  'AliBaba Capilano Cafe': 1,
#  'Alibi Room': 1,
#  'Aling Ening Restaurant': 1,
#  'All About Pho': 1,
#  'All Day Café': 1,
#  'All India Sweets & Restaurant': 1,
#  'Alley BBQ Restaurant': 1,
#  'Alma Mater Society of UBC': 1,
#  'Altitudes Bistro': 1,
#  'Altmaerker German Sausage House And Deli': 1,
#  'Alvin Garden': 1,
#  'Amato Gelato Cafe': 1,
#  "Amay's House": 1,
#  'Amelia Restaurant': 1,
#  'Amigo Pancake House Restaurant': 1,
#  'Amorosa Pasta House': 1,
#  'An Pho': 1,
#  'Ananda Bhavan': 1,
#  'Anar Persian Cuisine': 1,
#  'Anatoli Souvlaki': 1,
#  'Anatolia Express': 1,
#  "Anatolia's Gate Restaurant": 1,
#  'Ancora Waterfront Dining and Patio': 1,
#  'Ancora Waterfront Dining and Patio - Ambleside': 1,
#  'Andamiro Korean Bistro': 1,
#  'Andreas Restaurant': 1,
#  'Angel Cafe': 1,
#  "Angelina's": 1,
#  'Angus T': 1,
#  'Anh and Chi': 1,
#  "Anita's Kitchen": 1,
#  'AnnaLena': 1,
#  "Anny's Dairy Bar": 1,
#  "Anton's Pasta Bar": 1,
#  'Aperture Coffee Bar': 2,
#  "Aphrodite's Organic  Pie Shop": 1,
#  "Aphrodite's Organic Cafe": 1,
#  'Apna Bhaia Sweet Shop': 1,
#  'Apna Chaat House': 1,
#  'Apollo Pizza': 1,
#  'Apollonia Greek Restaurant': 1,
#  'Applause Japanese Restaurant': 1,
#  'Argo Café': 1,
#  'Aria Kabab': 1,
#  'Arike Restaurant': 1,
#  'Arirang Korean Restaurant': 1,
#  'Arms Reach Bistro': 1,
#  'Aroma Restaurant & Bar': 1,
#  'Aroy Thai': 1,
#  'Arriva Ristorante': 1,
#  'Artisan Eats Cafe & Fine Foods': 1,
#  'Artisan Sake Maker': 1,
#  "Arturo's Mexico to Go": 1,
#  'Artusi Restaurant': 1,
#  "Arvind's Curry & Cocktail": 1,
#  'Asa Sushi': 1,
#  'Asahi Japanese Restaurant': 1,
#  'Ash Street Bistro': 1,
#  'Ashiana Tandoori Restaurant': 1,
#  'Asia Market': 1,
#  'Asian Jazz': 1,
#  'Asian Spice': 1,
#  'Ask For Luigi': 1,
#  'Assembli': 1,
#  "Astro's Kitchen": 1,
#  'Asylum Restaurant': 1,
#  'Atlas Steak + Fish': 1,
#  'Au Comptoir': 1,
#  'Aussie Pie Guy': 1,
#  'Austin Fish House': 1,
#  'Austin Heights Pizza': 1,
#  'Autostrada': 1,
#  'Autostrada Osteria': 1,
#  'Avalon Dairy': 1,
#  'Avery Cafe Restaurant': 1,
#  'Avi Pizza & Pasta': 1,
#  'Axum Restaurant': 1,
#  'Aya Beauty Shop': 1,
#  "Ayoub's Dried Fruits and Nuts": 1,
#  'Azure Play Cafe': 1,
#  'BANSHAN BBQ RESTAURANT': 1,
#  'BBQ Chicken': 1,
#  'BBQ Chicken & Pub': 1,
#  'BBQ King Delight': 1,
#  'BBT Cafe': 1,
#  'BC Ferries': 1,
#  'BC Kitchen': 1,
#  'BC Liquor Distribution Branch Cafeteria': 1,
#  'BC TACO': 1,
#  'BG Urban Cafe': 1,
#  'BLOCK 18 Cart Noodle': 1,
#  'BOGO Korean Kitchen': 1,
#  'BT Cafe': 1,
#  'Ba Le Banh Mi': 1,
#  'Ba Le Sandwich Shop': 2,
#  'Ba Shu Szechuan Food': 1,
#  'Baba Sweets & Restaurant': 2,
#  'Babylon Café': 3,
#  'Bacchus Restaurant & Lounge': 1,
#  'Baci Restaurant': 1,
#  'Backstage Café': 1,
#  'Backstage Lounge': 1,
#  'Badminton Vancouver': 1,
#  'Baggio Gelateria & Pizzaeria': 1,
#  'Baghdad Cafe': 1,
#  'Baguette': 1,
#  'Bahn Shop': 1,
#  'Bai Bua Thai Cuisine': 1,
#  'Baiyulan Shanghai Cuisine': 1,
#  'Baker & Table Cafe Bakery': 1,
#  'Baker One Cafe': 1,
#  'Bali Thai': 1,
#  'Balila': 1,
#  'Balkan House': 1,
#  'Ball Breakers Billiards & Bistro': 1,
#  'Ballyhoo': 1,
#  'Bambo Café': 1,
#  'Bamboo Express': 1,
#  'Bamboo Garden': 1,
#  'Bamboo Grove': 1,
#  'Banana Leaf': 5,
#  'Bandidas Taqueria': 1,
#  'Bangkok City Cafe': 1,
#  'Banh Mi Bar Restaurant': 1,
#  'Banh Mi Saigon': 1,
#  'Banh Mi Timon': 1,
#  'Banter Room': 1,
#  'Banzai Sushi House': 1,
#  'Bao Bakery': 1,
#  'Bao Bei Chinese Brasserie': 1,
#  'Bao Chau Vietnamese Restaurant': 1,
#  'Bao Down Gastropub + Raw bar': 1,
#  'Bao Down UBC': 1,
#  'Baoguette Vietnamese Bistro': 2,
#  'Barcelona Tapas & Wine Bar': 1,
#  'Barcelos Flame Grilled Chicken': 3,
#  "Barney's Pizza & Chicken": 1,
#  'Barra 41': 1,
#  'Bartholomew Bar': 1,
#  'Basak': 1,
#  'Basil Box': 1,
#  'Basil Garden': 1,
#  'Basil Pasta Bar': 1,
#  'Batard Boulangerie & Cafe Moderne': 1,
#  "Bawan's Greek Restaurant": 1,
#  'Bay Sushi': 1,
#  'Bay Sushi Express Cafe': 1,
#  'Bbong': 1,
#  'Be Fresh Local Market': 1,
#  'Beach Ave Bar And Grill': 1,
#  'Bean Around the World Coffees': 2,
#  'Bean Banh Mi': 1,
#  'Beanery Coffeehouse & Eatery': 1,
#  'Beehive Restaurant': 1,
#  'Beeryani Indian Bistro & Bar': 1,
#  'BeetBox': 1,
#  'Beijiang Restaurant': 2,
#  'Beijing Hot Pot': 1,
#  'Bel Café': 1,
#  'Bel Café - Kits': 1,
#  'Belgian Fries': 1,
#  'Bella Pizza': 2,
#  'Bella Roma': 1,
#  'Bellaggio Cafe': 1,
#  'Bellagio Cafe': 1,
#  'Bells and Whistles': 1,
#  'Belmondo Cafe': 1,
#  'Belmont Cafe': 1,
#  'Bene Sushi': 1,
#  'Benkei Noodle Shop': 1,
#  'Bentoya': 1,
#  'Berry Good': 1,
#  'Best Bite Donair': 1,
#  'Best Bite Indian Cuisine': 1,
#  'Best Burrito': 1,
#  'Best Falafel': 2,
#  'Best Neighbours Restaurant & Pizza House': 1,
#  'Best Quality Sweets & Restaurant': 1,
#  'Beyond Bread Artisan Bakery': 1,
#  'Beyond Coffee': 1,
#  'Bharat Sweets & Restaurant': 1,
#  'Bian Fu Chang Noodle Shop': 1,
#  'Bibiko': 1,
#  'Bibis Kitchen': 1,
#  'Bibo Pizzeria': 1,
#  'Bibo Pizzeria con Cucina': 1,
#  'Bier Craft Bistro': 1,
#  'BierCraft Wesbrook': 1,
#  'Biercraft Tap & Tapas': 1,
#  'Big Bang Sushi': 2,
#  'Big Bowl Rice': 1,
#  'Big Chef Restaurant': 1,
#  'Big Chicken Town': 1,
#  'Big Flat Pancake Co': 1,
#  'Big G Fried Chicken Steaks': 1,
#  'Big Rock-Vancouver': 1,
#  'Big Shots Cafe': 1,
#  'Big Star Sandwich': 2,
#  'Big Star Sandwich Co.': 1,
#  'Big Star Sandwiches': 1,
#  'Bigsby the Bakehouse': 1,
#  "Bimini's Public House": 1,
#  'Bin 4 Burger Lounge': 1,
#  'Bing and Noodles World': 1,
#  'Birds & the Beets': 1,
#  "Bishop's Restaurant": 1,
#  'Bistro Sakana': 1,
#  'Bistro Verde': 1,
#  'BjornBar Bakery': 1,
#  'Black & Blue': 1,
#  'Black Bear Neighbourhood Pub': 1,
#  'Black Dog Video': 1,
#  'Black Frog Eatery': 1,
#  'Black Rice Izakaya': 1,
#  'Blackball Taiwanese Dessert': 1,
#  'Blaze Pizza': 1,
#  'Blazing Sushi': 1,
#  'Blend Bubble Tea': 1,
#  'Blenz Coffee': 34,
#  'Bliss Cafe': 1,
#  'Blowfish Sushi & Japanese Food': 1,
#  'Blue Canoe Waterfront Restaurant': 1,
#  'Blue Chip': 1,
#  'Blue Edge Cafe': 1,
#  'Blue Hat Bistro': 1,
#  'Blue Sky Japanese Bistro': 1,
#  'Blue Water Cafe': 1,
#  'Bluefin Sushi': 1,
#  'Bluhouse Market & Cafe': 1,
#  'Blvd Bistro': 1,
#  'Bmo Bank of Montreal': 1,
#  'Bo Wah Fast Food': 1,
#  "Bob & Al's Pizza": 1,
#  'Bob Likes Thai Food': 1,
#  'Bob Pochana': 1,
#  'Boba Time Cafe': 1,
#  'Bobacabana': 1,
#  'Boca Grande Donut Shop': 1,
#  'Bodega On Main': 1,
#  "Bogart's Bar and Restaurant": 1,
#  'Boiling Point': 3,
#  'Bombay Kitchen and Bar': 1,
#  'Bon Cafe': 1,
#  'Bon Crepe': 1,
#  'Bon Ga Korean Restaurant': 1,
#  'Bon Macaron Patisserie': 1,
#  "Bon's Off Broadway": 1,
#  'Bonchaz Bakery Café': 1,
#  'Bonjour Banh Mi': 1,
#  'Bonjour Vietnam Bistro': 1,
#  'Bonus Bakery': 1,
#  'BookKyung Ban Jeoum Korean': 1,
#  'Boom Beer': 1,
#  'Booster Juice': 1,
#  'Bosa Foods': 1,
#  'Boston Pizza': 14,
#  'Botanist': 1,
#  'Boteco Brasil': 1,
#  'Boulevard Kitchen & Oyster Bar': 1,
#  'Bourbon Street Grill': 4,
#  'Bovine': 1,
#  'Bowen Island Pizza Company': 1,
#  'Bowen Island Pub': 1,
#  'Boy With a Knife Grill': 1,
#  'Bozzinis Restaurant': 1,
#  'Branas Mediterranean Grill': 1,
#  'Branch on Bowen': 1,
#  'Brandywine Bartending School': 1,
#  'Brass Fish Tavern & Kitchen': 1,
#  'Bravo Cucina': 1,
#  'Brazza Gelato & Coffee': 1,
#  'Breakfast Table': 1,
#  'Breka Bakery & Cafe': 1,
#  'Breka Bakery and Cafe': 1,
#  'Brewhall': 1,
#  'Bridges Restaurant': 1,
#  'Brioche Doreé': 1,
#  'Brioche Urban Baking & Catering': 1,
#  'Brisk Cafe': 1,
#  'Britannia Sushi': 1,
#  'Brix & Mortar': 1,
#  'Broadway Chinese Restaurant': 1,
#  'Broadway Station Sushi': 1,
#  'Brock House': 1,
#  'Brock House Restaurant': 1,
#  'Broken Rice Vietnamese Restaurant': 1,
#  'Browns Crafthouse': 1,
#  'Browns Crafthouse Seymour': 1,
#  'Browns Social House': 1,
#  'Browns Socialhouse Brentwood': 1,
#  'Browns Socialhouse Brewery District': 1,
#  'Browns Socialhouse Guildford': 1,
#  'Browns Socialhouse Ironwood': 1,
#  'Browns Socialhouse Kitsilano': 1,
#  'Browns Socialhouse Lower Lonsdale': 1,
#  'Browns Socialhouse Lynn Valley': 1,
#  'Browns Socialhouse Newport': 1,
#  'Browns Socialhouse Point Grey': 1,
#  'Browns Socialhouse QE Theatre': 1,
#  'Browns Socialhouse Sun:shine Hills': 1,
#  'Browns Socialhouse Surrey Centre': 1,
#  'Browns Socialhouse Town Centre': 1,
#  'Browns Socialhouse Upper Lonsdale': 1,
#  'Brunch': 1,
#  'Bruncheria Cafe': 1,
#  'Bubble 88': 1,
#  'Bubble Bear Cafe': 1,
#  'Bubble Queen': 1,
#  'Bubble Waffle': 1,
#  'Bubble Waffle - Crystal Mall': 1,
#  'Bubble Waffle Cafe': 10,
#  'Bubble Waffle Cafe - Harbour Centre Food Court': 1,
#  'Bubble Waffle Cafe - Ironwood': 1,
#  'Bubble World': 7,
#  'Buckstop': 1,
#  'Buddha-Full': 1,
#  'Buddha-Full Northwoods': 1,
#  'Budgies Burritos': 1,
#  'Bufala': 1,
#  'Bukjang Korean Restaurant': 1,
#  'Bull King BBQ': 1,
#  'Bun Cha Ca Hoang Yen': 1,
#  'Burdock': 1,
#  'Burger Heaven': 1,
#  'Burger King': 15,
#  'Burgoo Bistro': 3,
#  'Burgoo Bistros': 1,
#  'Burnaby Mountain Clubhouse': 1,
#  'Burnaby Palace Restaurant': 1,
#  'Burrata Pizzeria': 1,
#  'Busan Daeji Gukbap Korean Restaurant': 1,
#  'Busan Daeji Gukbap North Van': 1,
#  'Busters Towing': 1,
#  'Busy Bee One Hour Cleaners': 1,
#  'Butchers Block BBQ': 1,
#  'Butter Baked Goods & Cafe': 1,
#  'Butter Lane Bake Shop & Tea House': 1,
#  'Bánh Mì Très Bon': 1,
#  'Bánh Shop': 1,
#  'C Market Coffee': 1,
#  'C Prime': 1,
#  "C'est si bon": 1,
#  'C-Lovers Fish & Chips': 3,
#  'CC Violin Patisserie & Cafe': 1,
#  'CHAU Veggie Express': 2,
#  'CRAFT Beer Market': 1,
#  'Cabizerra Bistro': 1,
#  'Cactus Club Cafe': 14,
#  'Cactus Club Cafe Station Square': 1,
#  'Cafe 106': 1,
#  'Cafe Ami': 1,
#  'Cafe Crepe': 2,
#  "Cafe D'Lite Express": 1,
#  'Cafe Du Soleil': 1,
#  'Cafe Eggstatic': 1,
#  'Cafe Eve': 1,
#  'Cafe FortyOne': 1,
#  'Cafe Hashtag': 1,
#  'Cafe Il Nido': 1,
#  'Cafe Lokal': 1,
#  'Cafe Loyal': 1,
#  'Cafe Mai-Mai': 1,
#  'Cafe One': 1,
#  'Cafe Orso': 1,
#  'Cafe Perugia': 1,
#  'Cafe Phin and Pho': 1,
#  'Cafe Savoureux': 1,
#  'Cafe SoBahn': 1,
#  'Cafe Sweets & Beans': 1,
#  'Cafe Tica': 1,
#  'Cafe Villaggio': 1,
#  'Cafe Xu Hue': 1,
#  "Cafe de l'Orangerie": 1,
#  'Cafeoca': 1,
#  'Caffe Artigiano': 2,
#  'Caffe Barney': 2,
#  'Caffe Cittadella': 1,
#  'Caffe Di Beppe': 1,
#  'Caffe Divano': 1,
#  'Caffe La Tana': 1,
#  'Caffe Mira': 1,
#  'Caffe W': 1,
#  'Caffè Artigiano': 6,
#  'Caffé Divano': 1,
#  'Café At Mandeville': 1,
#  'Café By Tao': 1,
#  'Café Calabria': 1,
#  'Café Deux Soleils': 1,
#  'Café Gloucester': 1,
#  'Café Portrait': 1,
#  'Café Veneti': 1,
#  'Café Zen On Yew': 1,
#  'Cake Ya': 1,
#  'Calabash Bistro': 1,
#  'Calgary Sweets': 1,
#  'Cambie Bar & Grill': 1,
#  'Cambie Vietnam Restaurant': 1,
#  "Camy's Pizza": 2,
#  'Canadian 2 for 1 Pizza': 1,
#  'Canadian Pizza Plus': 1,
#  'Canan 2 For 1 Pizza': 1,
#  'Cannery Cafe': 1,
#  'Cantonese BBQ Restaurant': 1,
#  'Capilano Sushi': 1,
#  'Captain Wa': 1,
#  "Captain's Oven Pizza": 1,
#  'Caravan Authentic Cafe': 1,
#  'Cardero Cafe': 2,
#  "Cardero's Restaurant & Marine Pub": 1,
#  'Caritas 9 Coffee Roasters': 1,
#  "Carl's Jr": 2,
#  "Carlos O'Bryans Neighbourhood Pub": 1,
#  'Carls Jr': 1,
#  "Carmelo's": 1,
#  'Carnegie Centre': 1,
#  'Carp': 1,
#  'Cartel Taco': 1,
#  'Cartems Donuts': 1,
#  'Casa Dolce Coal Harbour': 1,
#  'Casa Dolce Gelato & Chocolate': 1,
#  'Casa Verde Restaurant': 1,
#  'Casa di Amici Restaurant': 1,
#  'Castaway Bar and Kitchen': 1,
#  'Cat & Fiddle Pub': 1,
#  'Catch 122': 1,
#  'Catch Kitchen + Bar': 1,
#  'Catfe': 1,
#  'Cathay Pacific VIP YVR Lounge': 1,
#  'Cattle Cafe': 1,
#  'Caveman Cafe': 1,
#  'Cavo Bar and Kitchen': 1,
#  'Cavu Kitchen Bar': 1,
#  'Cayenne Bistro & Grill': 1,
#  'Cazba': 2,
#  'Cazba Express': 1,
#  'Cazba Food Cart': 1,
#  'Celeshmet': 1,
#  "Celine's Fish and Chips": 1,
#  'Central City Shopping Centre': 1,
#  'Central City Taphouse': 1,
#  'Cha Ca Hoang Yen Deli': 1,
#  'Cha Dian Tea': 1,
#  "Chachi's Coquitlam Centre": 1,
#  "Chachi's Pacific": 1,
#  'Chad Thai': 1,
#  'Chada Thai Fine Cuisine': 1,
#  'Chaise Lounge Restaurant': 1,
#  'Chakra Indian Restaurant': 1,
#  'Cham Mani': 1,
#  'Chambar': 1,
#  "Chan's Garden": 1,
#  'Chance Cafe': 1,
#  'Chancho Tortilleria': 1,
#  'Chands': 1,
#  "Chang'An": 1,
#  'Chao Shou Wang': 1,
#  'Charisma Cafe & Dessert House': 1,
#  'Charlie Hamiltons Pub': 1,
#  "Charlie's Mexican Restaurant": 1,
#  'Charqui': 1,
#  'Chatime': 4,
#  'Chatime Richmond': 1,
#  'Chef Hung Taiwanese Beef Noodle': 5,
#  'Chef Liu Kitchen': 1,
#  'Chef Pin': 2,
#  'Chef Rong Noodle House': 1,
#  'Chef Tony': 2,
#  'Chef of Dumplings': 1,
#  "Chef's Playground Eatery": 1,
#  'Chengdu Noodle House': 1,
#  'Chengdu Spicy Restaurant': 1,
#  "Cherry's Food House": 1,
#  "Cherry's Tea & Icy Bar": 1,
#  'Chettinad Dosa King': 1,
#  'Chettinad Dosa Palace': 1,
#  "Cheung's Chiu Chow Restaurant": 1,
#  'Chew Restaurant': 1,
#  "Chewie's Chicken & Biscuits": 1,
#  'Chewies Steam & Oyster Bar - Coal Harbour': 1,
#  'Chewies Steam & Oyster Bar - Kits': 1,
#  'Chez Meme Baguette Bistro': 1,
#  'Chez Michel Restaurant': 1,
#  'Chi House': 1,
#  'Chi Noodle Bar': 1,
#  'Chi Vegan': 1,
#  'ChiMec Fried Chicken & Burger': 1,
#  'Chicago Subs': 1,
#  'Chicken World': 1,
#  'Chicko Chicken': 1,
#  'Chicko Chicken Korean Style': 1,
#  'Chickpea': 1,
#  'Chickpea Food Truck': 1,
#  'Chili Pepper House': 1,
#  'Chilli Lee': 1,
#  'China Lan Beef Noodle': 1,
#  'China Village Restaurant': 1,
#  'Chinatown': 1,
#  'Chinatown BBQ': 1,
#  'Chinese Sauerkraut Fish': 1,
#  'Chipotle Mexican Grill': 5,
#  'Chirpyhut Chicken': 1,
#  'Chit Chat Burger Bar': 1,
#  'Cho Sun BBQ Korean Restaurant': 1,
#  'Choices Markets': 1,
#  'ChongQing': 1,
#  'ChongQing Restaurant': 1,
#  'Chongqing': 1,
#  'Chongqing Noodle House': 1,
#  'Chongqing Qinma Hotpot': 1,
#  'Chongqing Restaurant': 1,
#  'Chop Steakhouse & Bar': 1,
#  'Chop n Toss': 2,
#  'Chopped Leaf Ironwood': 1,
#  'Chouchou Breton Crepes': 1,
#  'Chow Lucky Noodle Bar': 1,
#  "Christine's Cafe": 1,
#  'Chronic Tacos': 3,
#  'Chu Kiang Chinese Restaurant': 1,
#  'Chuan BBQ Restaurant': 1,
#  'Chuan Yue': 1,
#  'Chun Hing': 1,
#  'Chuncheon Dakgalbi': 1,
#  'Chung Chun': 1,
#  "Church's Chicken": 14,
#  'Chào Street Food': 1,
#  'Cibo Trattoria': 1,
#  'Cilantro and Jalapeño': 1,
#  'Cimona Cafe': 1,
#  'CinCin Ristorante + Bar': 1,
#  'Cinco De Mayo Mexican Grill': 1,
#  "Cindy's": 1,
#  'Cindys Palace': 1,
#  'Cinema Public House': 1,
#  "Cioffi's Meat Market & Deli": 1,
#  "Cioppino's Mediterranean Grill": 1,
#  'Circus Play Cafe': 1,
#  'City 1 Cafe': 1,
#  'Claypot Hot Pot & BBQ': 1,
#  'Clough Club': 1,
#  'Club Ilia': 1,
#  'Clubone Cafe': 1,
#  'Co Chau': 1,
#  'CoCo Fresh Tea & Juice': 2,
#  'CoM Vietnamese': 1,
#  'Coast Restaurant': 1,
#  'Cockney Kings Fish & Chips': 2,
#  'Coco Rico Cafe': 1,
#  'Coco et Olive Fine Foods & Cafe': 1,
#  'Cocoa West Chocolatier': 1,
#  'Cocoru': 1,
#  'Coffee + Vanilla': 1,
#  'Coffeebar': 1,
#  'Cold Tea Restaurant': 1,
#  'Colony Bar': 2,
#  'Colosseum Pizza': 1,
#  'Colour See See': 1,
#  'ColourSeeSee': 1,
#  'Columbia Street Sandwich': 1,
#  'Come Along Seafood Restaurant': 1,
#  'Come Arepa': 1,
#  'Comebuy': 1,
#  'Coming Home Cafe': 1,
#  'Commercial Street Cafe': 1,
#  'Commercial Sushi': 1,
#  'Como': 1,
#  'Congee Noodle Delight': 1,
#  'Congee Noodle House': 1,
#  'Congee Noodle King': 1,
#  'Connected Minds Cafe and Roastery': 1,
#  "Connie's Cook House": 1,
#  'Conte Food Importers': 1,
#  'Continental Coffee House': 1,
#  'Continental Seafood Restaurant': 1,
#  'Convivial Cafe and Bakery': 1,
#  'Cool Chinese Restaurant': 1,
#  'Copa Cafe': 2,
#  'Copper Branch': 1,
#  'Copper Chimney Indian Grill & Bar': 1,
#  'Coppertank Grill': 1,
#  'Cora': 2,
#  'Cora Breakfast & Lunch': 2,
#  'Cora Breakfast and Lunch': 1,
#  'Coral Court Szechuan Cuisine': 1,
#  'Corduroy': 1,
#  'Corduroy Pie Company': 1,
#  'Corner 23': 1,
#  'Corner Stone': 1,
#  'Cosy Inn Cafe': 1,
#  'Cottage Deli Soup and Sandwich': 1,
#  'Cotto Enoteca Pizzeria': 1,
#  'Country Meadows Golf Course': 1,
#  'Cove Sushi': 1,
#  'Covert Neighbourhood Cafe': 1,
#  'Cozmos Cafe + Bistro': 1,
#  'Crabtree & Evelyn': 1,
#  'Crackle Creme': 1,
#  'Craffles': 1,
#  'Craft & Cork Kitchen + Taphouse': 1,
#  'Crave India': 1,
#  'Cravings': 1,
#  'Creme De La Crumb': 1,
#  'Creme de la Crumb': 1,
#  'Creme de la Crumb Bakeshop & Catering': 2,
#  'Crepe & Cafe': 1,
#  'Crepe De Licious': 1,
#  'Crepe Delicious': 2,
#  'Crepe Escape': 1,
#  'Crispy': 1,
#  'Crispy Falafel': 1,
#  'Crystal Palace': 1,
#  'Crêpe Delicious': 1,
#  'Cuatro Coffee': 1,
#  'Cuchillo': 1,
#  'Cultured Coffee & Tea': 1,
#  'Cultures': 1,
#  'Culver City Salads': 1,
#  'Cup Full Dessert Cafe': 1,
#  'CuppaJoe Coffee Roasters': 1,
#  'Curry Bistro': 1,
#  'Curry Express': 3,
#  'Curry Fusion': 1,
#  'Curry House': 1,
#  'Curry Point': 1,
#  'Curry Way': 1,
#  'Curry and Kabab': 1,
#  'Curve Lounge': 1,
#  'Cypress Mountain Crazy Raven Bar and Grill': 1,
#  'D Original Sausage Haus': 1,
#  'D Roti Shak': 1,
#  "D'oro Gelato e Caffè": 1,
#  'D-Plus Pizza': 1,
#  'D/6 Bar & Lounge': 1,
#  'DD Mau': 1,
#  'DD Mau Chinatown': 1,
#  'DDDN Pizza': 1,
#  'DICED Discovery Cafe': 1,
#  'DQ / Orange Julius': 1,
#  'Daan Korean Cuisine': 1,
#  'Dachi': 1,
#  "Daddy's Grill": 1,
#  "Daddy's Kitchen": 1,
#  'Dae Bak Bon Ga': 1,
#  'Dae-Ji Cutlet House': 5,
#  'Dai Jang Kum Korean BBQ': 1,
#  'Dai Jang Kum Restaurant': 1,
#  'Dai Tung Chinese Restaurant': 1,
#  'Daikichi Sushi': 2,
#  'Dairy Queen': 9,
#  'Dairy Queen / Orange Julius': 2,
#  'Dairy Queen Grill & Chill': 15,
#  'Dairy Queen/Orange Julius Treat Ctr': 1,
#  'Daisy Sandwiches & Such': 1,
#  'Dalina': 2,
#  'Dallas Pizza & Souvlaki': 1,
#  "Damien's Belgian Waffle": 1,
#  'Damso': 2,
#  'Dang Anh Cafe': 1,
#  'Daniel Le Chocolat Belge': 1,
#  'Daniel le Chocolat Belge': 1,
#  "Danny's Wun Tun Restaurant": 1,
#  'Danoo Cafe': 1,
#  'Daon Korean Cuisine': 1,
#  "Darby's Gastown": 1,
#  "Darby's Pub": 1,
#  'Dark Table': 1,
#  'Datang BBQ Express': 1,
#  "Dave's Fish & Chips": 1,
#  'Davie Dosa Company': 1,
#  "Davood's Bistro": 1,
#  'Days Inn Downtown': 1,
#  'Days Thai Restaurant': 1,
#  'De Dutch': 8,
#  "Deacon's Corner": 2,
#  'Deep Cove Ice Cream Cafe': 1,
#  'Deep Cove Osaka Sushi': 1,
#  'Deep Cove Pizza': 1,
#  'Deepwater Micro Eatery': 1,
#  'Deer Garden Restaurant': 1,
#  'Deer Garden Signatures': 4,
#  'Deer Island Bakery': 1,
#  'Deer Lake Wonton House': 1,
#  'Deja Brew': 1,
#  "Delany's Coffee": 2,
#  'Delhi 6 Indian Bistro': 1,
#  'Delicious BBQ': 1,
#  'Delicious Pho': 2,
#  'Dell Lanes': 1,
#  'Delta Hotels by Marriott Vancouver Downtown Suites': 1,
#  'Delta Pizza': 1,
#  "Denny's": 8,
#  'Desi Bites': 1,
#  'Desi Dosa Madras': 1,
#  'Desi Turka Indian Cuisine': 1,
#  'Deutsches Haus': 1,
#  "Devil's Elbow Ale & Smoke House": 1,
#  'Dewan-E-Khass': 1,
#  'Dex Gourmet Burger Bar': 1,
#  'Dhaliwal Sweet & Restaurant': 1,
#  'Dharma Garden': 1,
#  'Dharma Garden Veggie Deli': 1,
#  'Dhoom Restaurant & Bar': 1,
#  'Di Beppe': 1,
#  'Di Reggae Cafe': 1,
#  'Diamond Resturant': 1,
#  "Did's Pizza": 1,
#  "Dijo's Pizza & Panzerotto": 1,
#  'Dijon Kitchen': 1,
#  'Dinakis Mediterranean Grill': 1,
#  'Dinesty Dumpling House': 3,
#  'Ding Hao Noodle House': 1,
#  'Dipped Doughnut': 1,
#  'Disco Cheetah': 2,
#  'Diva At the Met': 1,
#  'Dive In Dessert Cafe': 1,
#  "Dixie's BBQ": 1,
#  'Djjs Wedge Pizza & Pasta': 1,
#  'Do Chay': 1,
#  'Do Chay Saigon Vegetarian': 1,
#  "Doc Morgan's Pub & Restaurant": 1,
#  "Doc's Pizza": 1,
#  'Dock Lunch': 1,
#  'Dockside Restaurant': 1,
#  'Dodo sushi': 1,
#  'Dollar Meat Store': 1,
#  'Dolpan Seoul BBQ': 1,
#  'Dominion Bar + Kitchen': 1,
#  "Domino's": 1,
#  "Domino's Pizza": 19,
#  'Domo Sushi': 1,
#  "Don Chepe's Restaurant": 1,
#  'Don Francesco Ristorante': 1,
#  'Don Oso': 1,
#  'Donair Affair': 4,
#  'Donair Bite': 1,
#  'Donair Delight': 1,
#  'Donair Dude': 4,
#  'Donair Dude - Kitsilano': 1,
#  'Donair Dude Granville': 1,
#  'Donair King Restaurant': 1,
#  'Donair Land': 1,
#  'Donair Spot': 3,
#  'Donair Star': 1,
#  'Donair Town': 4,
#  'Donair Town Robson': 1,
#  'Donairville & Cafe': 1,
#  "Donegal's Irish House": 1,
#  'Dong Tai Xiang Shanghai Dim Sum': 1,
#  'DooBoo': 1,
#  'DooGauBee': 1,
#  'Doon Express Indian Cuisine': 1,
#  'Doppio Zero Pizza': 1,
#  'Dosa Corner': 1,
#  'Dosa Factory': 1,
#  'Dosa and Curry': 1,
#  'Dosanko': 1,
#  'Double DD Pizza': 1,
#  'Double Double Chinese Restaurant': 1,
#  'Double East Cuisine': 1,
#  'Double One Chinese Restaurant': 1,
#  'Douce Diner': 1,
#  'Doughgirls': 1,
#  'Downlow Chicken Shack': 1,
#  'Downtown Sushi Bar Japanese Restaurant': 1,
#  'Dragon Crepe': 1,
#  'Dragon Group Seafood Restaurant': 1,
#  'Dragon wok': 1,
#  'Dragonview Chinese Cuisine': 1,
#  'Dream Sushi': 1,
#  'Dublin Calling': 1,
#  'Dublin Crossing': 1,
#  "Duffin's Donuts": 1,
#  'Dumpling House': 1,
#  'Dunbar Pizza & Grill': 1,
#  'Dunbar Sushi': 1,
#  'Dundarave Sushi': 1,
#  'Dundas Eat + Drink': 1,
#  'Duotian Fish Soup Noodles Restaurant': 1,
#  "Duso's Italian Foods": 1,
#  "Dussa's Ham & Cheese": 1,
#  'Dutch Wooden Shoe Cafe': 1,
#  "Dylan's": 1,
#  'Dynasty Seafood Restaurant': 1,
#  'Döner Kebab': 1,
#  'Döner Stop': 1,
#  'E-Mo Restaurant': 1,
#  'EStEA Cafe 生活小品': 1,
#  'Earls Kitchen + Bar': 9,
#  'Earls Kitchen + Bar - Station Square': 1,
#  'East Is East': 1,
#  'East One Chinese Seafood Restaurant': 1,
#  'East Side Craft House': 1,
#  'East is East': 1,
#  'Eastern Pearl Seafood Restaurant': 1,
#  'Eat Chicken Wraps': 1,
#  'Eat! Vancouver': 1,
#  'Ebi-Ten': 1,
#  'Ebisu In Richmond': 1,
#  'Ebisu On Robson': 1,
#  'Ebisu on Broadway': 1,
#  'Echo Cafe': 1,
#  'Edge Catering': 1,
#  'Edible Flours': 1,
#  'Edo Japan': 1,
#  'Egg & Co': 1,
#  'Eggspectation': 1,
#  'Eh! Restaurant': 1,
#  'Eight 1/2 Restaurant Lounge': 1,
#  'Eighties Restaurant': 1,
#  'Einstein Wrap House': 1,
#  "El Camino's": 1,
#  'El Caracol Café': 1,
#  'El Comal': 1,
#  'El Furniture Warehouse - Granville': 1,
#  'El Furniture Warehouse - Hastings': 1,
#  'El Guapo': 1,
#  'El Inka Latin Deli': 1,
#  'El Santo': 1,
#  'Elephant Garden Creamery': 1,
#  'Elisa': 1,
#  'Elvis Pizza': 1,
#  'Elwoods': 1,
#  'Elysian Coffee': 2,
#  'Ember Indian Kitchen': 1,
#  "Emelle's Catering": 1,
#  'Empire Seafood Restaurant': 1,
#  'Encore Coffee & Tea': 1,
#  'Enigma Restaurant': 1,
#  'Enjoy Cafe 1 Plus1': 1,
#  "Enzo's Cafe": 1,
#  'Epic Grill Silogs': 1,
#  'España Restaurant': 1,
#  'Estea Cafe Metro Place': 1,
#  'Eternal Abundance': 1,
#  'Ethno Restaurant Vayat': 1,
#  'Euro Bagel Cafe': 1,
#  'Euro Café': 1,
#  'Euro Food Plus': 1,
#  'Europe Old Fashion Bakery & Deli': 1,
#  'European Breads': 1,
#  "Evelyn's Coffee Shop": 1,
#  'Everyday Sushi': 1,
#  'Excellent Dim Sum King Restaurant': 1,
#  'Excellent Tofu & Snacks': 1,
#  'Express Pho': 1,
#  'FRESH Sushi': 1,
#  'Fable': 1,
#  'Fable Diner': 1,
#  'Fairways Grill & Patio': 1,
#  'Falafel Cafe': 1,
#  'Falafel King': 1,
#  'Falafel King Restaurant': 1,
#  'Fami Pho': 1,
#  'Famoso Neapolitan Pizzeria': 2,
#  'Famous Famiglia Pizzeria': 1,
#  'Famous Wok': 1,
#  'Fanny Bay Oyster Bar & Shellfish Market': 1,
#  'Fantastico Pizza 2001': 1,
#  'Farina a Legna': 1,
#  'Fassil Ethiopian Restaurant': 1,
#  'Fat Mao Noodles': 1,
#  'Fat Tuna Sushi': 1,
#  'Fatburger': 9,
#  'Fatty Cow Seafood Hot Pot': 1,
#  'Faubourg': 1,
#  'Fayuca': 1,
#  'Feast': 1,
#  'Feastro': 2,
#  'Festal Paleo Cafe': 1,
#  'Fets Whisky Kitchen': 1,
#  'Field & Social': 1,
#  'Fife Bakery': 1,
#  'Figaro Cafe and Bakery': 1,
#  'Finch & Barley': 1,
#  "Finch's Market": 1,
#  "Finch's Tea & Coffee House": 1,
#  'Finest At Sea Seafood Boutique': 1,
#  'Fior di Latte': 1,
#  'Fiore Famiglia': 1,
#  'Fiore Restaurants': 1,
#  'Fire Pizza': 1,
#  'Firebird Cafe': 1,
#  'Firecrust': 1,
#  'Firefighters Public House': 1,
#  'First Choice': 1,
#  'Fish Café': 1,
#  "Fisherman's Terrace Seafood Restaurant": 1,
#  'Fishworks': 1,
#  'Fit For Life': 1,
#  'Fit for Life Restaurant': 1,
#  'Five Guys': 2,
#  'Five Guys Burgers & Fries': 1,
#  'Five Loaves Two Fish': 1,
#  'Five Sails Restaurant': 1,
#  'Flaming Wok': 1,
#  'Flamingo Chinese Restaurant': 1,
#  'Flavor Balance Espresso Bar': 1,
#  'Floata Seafood Restaurant': 1,
#  'Flourist': 1,
#  'Flower And Horse In Spring': 1,
#  'Flying Beaver Bar': 1,
#  'Flying Wedge Pizza': 2,
#  'Flying Wedge Pizza Company': 3,
#  "Fogg 'n' Suds Restaurant & Beer Bar": 1,
#  'Fok Po Tong': 1,
#  'Fondway': 1,
#  'Food Shanghai Ting': 1,
#  'Foodies On Board': 1,
#  'Footo Croissant': 1,
#  'Forage': 1,
#  'Fortuna Bakery': 1,
#  'Fortune City Seafood Restaurant': 1,
#  'Fortune Express': 1,
#  'Fortune Lamb Dining': 1,
#  'Fortune Terrace Chinese Cuisine': 1,
#  'Fortune Wok': 1,
#  'Four Bistro': 1,
#  'Four Olives': 1,
#  'Four Winds Brewing': 1,
#  ...}

# %%
import pprint
pp = pprint.PrettyPrinter(depth=4)
pp.pprint(results)

# %%
rest2=df_1[df_1['name']=='De Dutch']

# %%
rest2
# Out:
#                  business_id      name                        address  \
# 505   _OfAq8W9clDTta_YesbcbQ  De Dutch               657 W 3rd Street
# 809   BJ-mZ93qfDZJE45gPksFAA  De Dutch           60-1055 Canada Place
# 2538  HbJStt8kJ6r8QCvoNlEdQg  De Dutch             1634 Capilano Road
# 3385  3ZTbk0l9ZHH6VdVilhFrqw  De Dutch   2748 Lougheed Hwy, Suite 200
# 3592  YO6nR3SuN3MxhKXttgG2xA  De Dutch      15235 Fraser Hwy, Ste 101
# 3889  wUDhTxF_oZMRr6X1-LQCHg  De Dutch                3192 Oak Street
# 4024  n_jcZ9i-HIqFXHGd5he9jw  De Dutch               410 W 2nd Avenue
# 4529  Mpl5bUYWf_hUE9TeeDyXwQ  De Dutch  1035 Columbia Street, Ste 102
#
#                  city state postal_code   latitude   longitude  stars  \
# 505       N Vancouver    BC     V7M 1H1  49.319227 -123.090558    3.5
# 809         Vancouver    BC     V6C 3T4  49.290030 -123.116896    3.5
# 2538  North Vancouver    BC     V7P 3B4  49.324860 -123.121427    3.5
# 3385   Port Coquitlam    BC     V3B 6P2  49.272474 -122.789011    3.0
# 3592           Surrey    BC     V3R 3P3  49.166082 -122.800249    3.0
# 3889        Vancouver    BC     V6H 2L1  49.257264 -123.127002    3.5
# 4024        Vancouver    BC     V5Y 1E2  49.267136 -123.113174    2.5
# 4529  New Westminster    BC     V3M 1C4  49.200446 -122.917667    3.0
#
#       review_count  is_open  \
# 505             34        1
# 809            179        1
# 2538            32        1
# 3385            30        1
# 3592            25        1
# 3889            42        1
# 4024            29        1
# 4529            34        1
#
#                                              attributes  \
# 505   {'RestaurantsReservations': 'False', 'WiFi': "...
# 809   {'RestaurantsDelivery': 'False', 'RestaurantsT...
# 2538  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 3385  {'GoodForKids': 'True', 'NoiseLevel': "u'loud'...
# 3592  {'WiFi': "'free'", 'Alcohol': "'none'", 'Resta...
# 3889  {'RestaurantsDelivery': 'False', 'RestaurantsG...
# 4024  {'WiFi': "u'free'", 'RestaurantsPriceRange2': ...
# 4529  {'RestaurantsPriceRange2': '2', 'Ambience': "{...
#
#                                              categories  \
# 505   Gluten-Free, Breakfast & Brunch, Canadian (New...
# 809   Restaurants, Modern European, Gluten-Free, Bre...
# 2538  Food, Restaurants, Gluten-Free, Canadian (New)...
# 3385                    Restaurants, Breakfast & Brunch
# 3592  Restaurants, Gluten-Free, Canadian (New), Brea...
# 3889  Modern European, Gluten-Free, Restaurants, Can...
# 4024  Food, Restaurants, Breakfast & Brunch, Gluten-...
# 4529  Breakfast & Brunch, Gluten-Free, Restaurants, ...
#
#                                                   hours
# 505   {'Monday': '0:0-0:0', 'Tuesday': '7:30-14:30',...
# 809   {'Monday': '0:0-0:0', 'Tuesday': '8:0-15:0', '...
# 2538  {'Monday': '0:0-0:0', 'Tuesday': '7:0-15:0', '...
# 3385  {'Monday': '0:0-0:0', 'Tuesday': '7:30-15:0', ...
# 3592  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:30', ...
# 3889  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...
# 4024  {'Monday': '0:0-0:0', 'Tuesday': '7:30-15:0', ...
# 4529  {'Monday': '6:30-15:0', 'Tuesday': '6:30-15:0'...

# %%
rest2_cat=rest2['categories']
rest2_cat
# Out:
# 505     Gluten-Free, Breakfast & Brunch, Canadian (New...
# 809     Restaurants, Modern European, Gluten-Free, Bre...
# 2538    Food, Restaurants, Gluten-Free, Canadian (New)...
# 3385                      Restaurants, Breakfast & Brunch
# 3592    Restaurants, Gluten-Free, Canadian (New), Brea...
# 3889    Modern European, Gluten-Free, Restaurants, Can...
# 4024    Food, Restaurants, Breakfast & Brunch, Gluten-...
# 4529    Breakfast & Brunch, Gluten-Free, Restaurants, ...
# Name: categories, dtype: object

# %%
rest2_comp=df_1[df_1.categories.isin(rest2.categories)]

# %%
rest2_comp
# Out:
#                  business_id                     name  \
# 505   _OfAq8W9clDTta_YesbcbQ                 De Dutch
# 628   4O3lfnrszTf8SdJLvV3hHA                     Cora
# 734   RqtEy936GDBb0ddesDqKQg          Breakfast Table
# 809   BJ-mZ93qfDZJE45gPksFAA                 De Dutch
# 1006  qteZ9HUas8ijJInMmKQiVg      Morning Tide Eatery
# 1143  PpPVbWqcPaUbtnWIYTcMsQ          Café Zen On Yew
# 1163  QmkGDL-8zexdKV3Xcn8ZYg        OEB Breakfast Co.
# 1587  SpMcJgpiooetjxJI0_KFMA        Jimmy’s Lunch Box
# 2532  5FsEDcLp7E3P3YM0AcK59A              Only U Cafe
# 2538  HbJStt8kJ6r8QCvoNlEdQg                 De Dutch
# 2604  GvuQgsZpzrbY_PuaiYnAsQ              Joe's Grill
# 2706  R_LM4VdyhZ6aDxlLfCdgRw      Big Flat Pancake Co
# 2993  BFsG4V17HD-6OXIqlS2NcA  Twin Bridges Restaurant
# 3173  kD-V4HCkdeI3QVIezQeuUQ             Pür & Simple
# 3273  YH_jjPE1ieLSGC-YqJk0Lw                  Tractor
# 3385  3ZTbk0l9ZHH6VdVilhFrqw                 De Dutch
# 3554  NKlvGvErXTX5JkZOPJ3iLg                KC's Cafe
# 3592  YO6nR3SuN3MxhKXttgG2xA                 De Dutch
# 3889  wUDhTxF_oZMRr6X1-LQCHg                 De Dutch
# 4024  n_jcZ9i-HIqFXHGd5he9jw                 De Dutch
# 4529  Mpl5bUYWf_hUE9TeeDyXwQ                 De Dutch
#
#                                 address             city state postal_code  \
# 505                    657 W 3rd Street      N Vancouver    BC     V7M 1H1
# 628   11380 Steveston Highway, Unit 170         Richmond    BC     V7A 5J5
# 734               3014 Granville Street        Vancouver    BC     V6H 1H6
# 809                60-1055 Canada Place        Vancouver    BC     V6C 3T4
# 1006         8 - 228 Schoolhouse Street        Coquitlam    BC     V3K 6V7
# 1143                    1631 Yew Street        Vancouver    BC     V6K 3E6
# 1163           1137 Marinaside Crescent        Vancouver    BC     V6Z 2Y3
# 1587            2652 Shaughnessy Street   Port Coquitlam    BC     V3C 3G8
# 2532     5737 Dalhousie Road, Suite 116        Vancouver    BC     V6T 2H9
# 2538                 1634 Capilano Road  North Vancouver    BC     V7P 3B4
# 2604                  1031 Davie Street        Vancouver    BC     V6E 1M5
# 2706          203 2020 Oxford Connector   Port Coquitlam    BC     V3C 0A4
# 2993      1080 Cliveden Avenue, Suite 1            Delta    BC     V3M 6G6
# 3173                     299 E 10th Ave        Vancouver    BC     V5T 3J2
# 3273                     601 W Broadway        Vancouver    BC     V5Z 4C2
# 3385       2748 Lougheed Hwy, Suite 200   Port Coquitlam    BC     V3B 6P2
# 3554       1449 Prairie Avenue, Suite 8   Port Coquitlam    BC     V3B 1S9
# 3592          15235 Fraser Hwy, Ste 101           Surrey    BC     V3R 3P3
# 3889                    3192 Oak Street        Vancouver    BC     V6H 2L1
# 4024                   410 W 2nd Avenue        Vancouver    BC     V5Y 1E2
# 4529      1035 Columbia Street, Ste 102  New Westminster    BC     V3M 1C4
#
#        latitude   longitude  stars  review_count  is_open  \
# 505   49.319227 -123.090558    3.5            34        1
# 628   49.132159 -123.099182    3.0           103        1
# 734   49.258568 -123.138517    4.5           210        1
# 809   49.290030 -123.116896    3.5           179        1
# 1006  49.237012 -122.852789    5.0             6        1
# 1143  49.271149 -123.155189    3.5           155        1
# 1163  49.273457 -123.119265    4.0           371        1
# 1587  49.263665 -122.780050    4.5             9        1
# 2532  49.265984 -123.242392    3.5            24        1
# 2538  49.324860 -123.121427    3.5            32        1
# 2604  49.279750 -123.129945    4.0           170        1
# 2706  49.264730 -122.771435    4.5            75        1
# 2993  49.171784 -122.946208    4.5             7        1
# 3173  49.262108 -123.099292    3.0             5        1
# 3273  49.263467 -123.118252    4.0            21        1
# 3385  49.272474 -122.789011    3.0            30        1
# 3554  49.271547 -122.753704    3.5            15        1
# 3592  49.166082 -122.800249    3.0            25        1
# 3889  49.257264 -123.127002    3.5            42        1
# 4024  49.267136 -123.113174    2.5            29        1
# 4529  49.200446 -122.917667    3.0            34        1
#
#                                              attributes  \
# 505   {'RestaurantsReservations': 'False', 'WiFi': "...
# 628   {'Caters': 'False', 'RestaurantsDelivery': 'Fa...
# 734   {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 809   {'RestaurantsDelivery': 'False', 'RestaurantsT...
# 1006  {'WiFi': "u'free'", 'OutdoorSeating': 'False',...
# 1143  {'RestaurantsReservations': 'False', 'OutdoorS...
# 1163  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 1587  {'BusinessParking': "{'garage': False, 'street...
# 2532  {'GoodForKids': 'True', 'WiFi': "u'free'", 'Re...
# 2538  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 2604  {'NoiseLevel': "u'average'", 'RestaurantsReser...
# 2706  {'OutdoorSeating': 'False', 'RestaurantsTableS...
# 2993  {'RestaurantsAttire': "'casual'", 'Ambience': ...
# 3173                                                NaN
# 3273  {'BikeParking': 'True', 'Alcohol': "u'beer_and...
# 3385  {'GoodForKids': 'True', 'NoiseLevel': "u'loud'...
# 3554  {'RestaurantsPriceRange2': '1', 'WiFi': "u'no'...
# 3592  {'WiFi': "'free'", 'Alcohol': "'none'", 'Resta...
# 3889  {'RestaurantsDelivery': 'False', 'RestaurantsG...
# 4024  {'WiFi': "u'free'", 'RestaurantsPriceRange2': ...
# 4529  {'RestaurantsPriceRange2': '2', 'Ambience': "{...
#
#                                              categories  \
# 505   Gluten-Free, Breakfast & Brunch, Canadian (New...
# 628                     Restaurants, Breakfast & Brunch
# 734                     Restaurants, Breakfast & Brunch
# 809   Restaurants, Modern European, Gluten-Free, Bre...
# 1006                    Restaurants, Breakfast & Brunch
# 1143                    Restaurants, Breakfast & Brunch
# 1163                    Restaurants, Breakfast & Brunch
# 1587                    Restaurants, Breakfast & Brunch
# 2532                    Restaurants, Breakfast & Brunch
# 2538  Food, Restaurants, Gluten-Free, Canadian (New)...
# 2604                    Restaurants, Breakfast & Brunch
# 2706                    Restaurants, Breakfast & Brunch
# 2993                    Restaurants, Breakfast & Brunch
# 3173                    Restaurants, Breakfast & Brunch
# 3273                    Restaurants, Breakfast & Brunch
# 3385                    Restaurants, Breakfast & Brunch
# 3554                    Restaurants, Breakfast & Brunch
# 3592  Restaurants, Gluten-Free, Canadian (New), Brea...
# 3889  Modern European, Gluten-Free, Restaurants, Can...
# 4024  Food, Restaurants, Breakfast & Brunch, Gluten-...
# 4529  Breakfast & Brunch, Gluten-Free, Restaurants, ...
#
#                                                   hours
# 505   {'Monday': '0:0-0:0', 'Tuesday': '7:30-14:30',...
# 628   {'Monday': '6:0-15:0', 'Tuesday': '6:0-15:0', ...
# 734   {'Monday': '0:0-0:0', 'Wednesday': '9:0-14:0',...
# 809   {'Monday': '0:0-0:0', 'Tuesday': '8:0-15:0', '...
# 1006  {'Tuesday': '10:0-15:0', 'Wednesday': '10:0-15...
# 1143  {'Monday': '9:0-14:0', 'Tuesday': '9:0-14:0', ...
# 1163  {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...
# 1587  {'Monday': '9:0-15:0', 'Tuesday': '9:0-15:0', ...
# 2532  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 2538  {'Monday': '0:0-0:0', 'Tuesday': '7:0-15:0', '...
# 2604  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 2706  {'Monday': '8:0-14:30', 'Tuesday': '8:0-14:30'...
# 2993  {'Monday': '6:0-14:30', 'Tuesday': '6:0-14:30'...
# 3173                                                NaN
# 3273  {'Monday': '7:0-21:30', 'Tuesday': '7:0-21:30'...
# 3385  {'Monday': '0:0-0:0', 'Tuesday': '7:30-15:0', ...
# 3554  {'Tuesday': '8:0-16:0', 'Wednesday': '8:0-16:0...
# 3592  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:30', ...
# 3889  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...
# 4024  {'Monday': '0:0-0:0', 'Tuesday': '7:30-15:0', ...
# 4529  {'Monday': '6:30-15:0', 'Tuesday': '6:30-15:0'...

# %%
rest2_comp.sort_values('stars',ascending=False)
# Out:
#                  business_id                     name  \
# 1006  qteZ9HUas8ijJInMmKQiVg      Morning Tide Eatery
# 2706  R_LM4VdyhZ6aDxlLfCdgRw      Big Flat Pancake Co
# 734   RqtEy936GDBb0ddesDqKQg          Breakfast Table
# 1587  SpMcJgpiooetjxJI0_KFMA        Jimmy’s Lunch Box
# 2993  BFsG4V17HD-6OXIqlS2NcA  Twin Bridges Restaurant
# 2604  GvuQgsZpzrbY_PuaiYnAsQ              Joe's Grill
# 1163  QmkGDL-8zexdKV3Xcn8ZYg        OEB Breakfast Co.
# 3273  YH_jjPE1ieLSGC-YqJk0Lw                  Tractor
# 3889  wUDhTxF_oZMRr6X1-LQCHg                 De Dutch
# 3554  NKlvGvErXTX5JkZOPJ3iLg                KC's Cafe
# 505   _OfAq8W9clDTta_YesbcbQ                 De Dutch
# 2538  HbJStt8kJ6r8QCvoNlEdQg                 De Dutch
# 2532  5FsEDcLp7E3P3YM0AcK59A              Only U Cafe
# 1143  PpPVbWqcPaUbtnWIYTcMsQ          Café Zen On Yew
# 809   BJ-mZ93qfDZJE45gPksFAA                 De Dutch
# 628   4O3lfnrszTf8SdJLvV3hHA                     Cora
# 3173  kD-V4HCkdeI3QVIezQeuUQ             Pür & Simple
# 3385  3ZTbk0l9ZHH6VdVilhFrqw                 De Dutch
# 3592  YO6nR3SuN3MxhKXttgG2xA                 De Dutch
# 4529  Mpl5bUYWf_hUE9TeeDyXwQ                 De Dutch
# 4024  n_jcZ9i-HIqFXHGd5he9jw                 De Dutch
#
#                                 address             city state postal_code  \
# 1006         8 - 228 Schoolhouse Street        Coquitlam    BC     V3K 6V7
# 2706          203 2020 Oxford Connector   Port Coquitlam    BC     V3C 0A4
# 734               3014 Granville Street        Vancouver    BC     V6H 1H6
# 1587            2652 Shaughnessy Street   Port Coquitlam    BC     V3C 3G8
# 2993      1080 Cliveden Avenue, Suite 1            Delta    BC     V3M 6G6
# 2604                  1031 Davie Street        Vancouver    BC     V6E 1M5
# 1163           1137 Marinaside Crescent        Vancouver    BC     V6Z 2Y3
# 3273                     601 W Broadway        Vancouver    BC     V5Z 4C2
# 3889                    3192 Oak Street        Vancouver    BC     V6H 2L1
# 3554       1449 Prairie Avenue, Suite 8   Port Coquitlam    BC     V3B 1S9
# 505                    657 W 3rd Street      N Vancouver    BC     V7M 1H1
# 2538                 1634 Capilano Road  North Vancouver    BC     V7P 3B4
# 2532     5737 Dalhousie Road, Suite 116        Vancouver    BC     V6T 2H9
# 1143                    1631 Yew Street        Vancouver    BC     V6K 3E6
# 809                60-1055 Canada Place        Vancouver    BC     V6C 3T4
# 628   11380 Steveston Highway, Unit 170         Richmond    BC     V7A 5J5
# 3173                     299 E 10th Ave        Vancouver    BC     V5T 3J2
# 3385       2748 Lougheed Hwy, Suite 200   Port Coquitlam    BC     V3B 6P2
# 3592          15235 Fraser Hwy, Ste 101           Surrey    BC     V3R 3P3
# 4529      1035 Columbia Street, Ste 102  New Westminster    BC     V3M 1C4
# 4024                   410 W 2nd Avenue        Vancouver    BC     V5Y 1E2
#
#        latitude   longitude  stars  review_count  is_open  \
# 1006  49.237012 -122.852789    5.0             6        1
# 2706  49.264730 -122.771435    4.5            75        1
# 734   49.258568 -123.138517    4.5           210        1
# 1587  49.263665 -122.780050    4.5             9        1
# 2993  49.171784 -122.946208    4.5             7        1
# 2604  49.279750 -123.129945    4.0           170        1
# 1163  49.273457 -123.119265    4.0           371        1
# 3273  49.263467 -123.118252    4.0            21        1
# 3889  49.257264 -123.127002    3.5            42        1
# 3554  49.271547 -122.753704    3.5            15        1
# 505   49.319227 -123.090558    3.5            34        1
# 2538  49.324860 -123.121427    3.5            32        1
# 2532  49.265984 -123.242392    3.5            24        1
# 1143  49.271149 -123.155189    3.5           155        1
# 809   49.290030 -123.116896    3.5           179        1
# 628   49.132159 -123.099182    3.0           103        1
# 3173  49.262108 -123.099292    3.0             5        1
# 3385  49.272474 -122.789011    3.0            30        1
# 3592  49.166082 -122.800249    3.0            25        1
# 4529  49.200446 -122.917667    3.0            34        1
# 4024  49.267136 -123.113174    2.5            29        1
#
#                                              attributes  \
# 1006  {'WiFi': "u'free'", 'OutdoorSeating': 'False',...
# 2706  {'OutdoorSeating': 'False', 'RestaurantsTableS...
# 734   {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 1587  {'BusinessParking': "{'garage': False, 'street...
# 2993  {'RestaurantsAttire': "'casual'", 'Ambience': ...
# 2604  {'NoiseLevel': "u'average'", 'RestaurantsReser...
# 1163  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 3273  {'BikeParking': 'True', 'Alcohol': "u'beer_and...
# 3889  {'RestaurantsDelivery': 'False', 'RestaurantsG...
# 3554  {'RestaurantsPriceRange2': '1', 'WiFi': "u'no'...
# 505   {'RestaurantsReservations': 'False', 'WiFi': "...
# 2538  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 2532  {'GoodForKids': 'True', 'WiFi': "u'free'", 'Re...
# 1143  {'RestaurantsReservations': 'False', 'OutdoorS...
# 809   {'RestaurantsDelivery': 'False', 'RestaurantsT...
# 628   {'Caters': 'False', 'RestaurantsDelivery': 'Fa...
# 3173                                                NaN
# 3385  {'GoodForKids': 'True', 'NoiseLevel': "u'loud'...
# 3592  {'WiFi': "'free'", 'Alcohol': "'none'", 'Resta...
# 4529  {'RestaurantsPriceRange2': '2', 'Ambience': "{...
# 4024  {'WiFi': "u'free'", 'RestaurantsPriceRange2': ...
#
#                                              categories  \
# 1006                    Restaurants, Breakfast & Brunch
# 2706                    Restaurants, Breakfast & Brunch
# 734                     Restaurants, Breakfast & Brunch
# 1587                    Restaurants, Breakfast & Brunch
# 2993                    Restaurants, Breakfast & Brunch
# 2604                    Restaurants, Breakfast & Brunch
# 1163                    Restaurants, Breakfast & Brunch
# 3273                    Restaurants, Breakfast & Brunch
# 3889  Modern European, Gluten-Free, Restaurants, Can...
# 3554                    Restaurants, Breakfast & Brunch
# 505   Gluten-Free, Breakfast & Brunch, Canadian (New...
# 2538  Food, Restaurants, Gluten-Free, Canadian (New)...
# 2532                    Restaurants, Breakfast & Brunch
# 1143                    Restaurants, Breakfast & Brunch
# 809   Restaurants, Modern European, Gluten-Free, Bre...
# 628                     Restaurants, Breakfast & Brunch
# 3173                    Restaurants, Breakfast & Brunch
# 3385                    Restaurants, Breakfast & Brunch
# 3592  Restaurants, Gluten-Free, Canadian (New), Brea...
# 4529  Breakfast & Brunch, Gluten-Free, Restaurants, ...
# 4024  Food, Restaurants, Breakfast & Brunch, Gluten-...
#
#                                                   hours
# 1006  {'Tuesday': '10:0-15:0', 'Wednesday': '10:0-15...
# 2706  {'Monday': '8:0-14:30', 'Tuesday': '8:0-14:30'...
# 734   {'Monday': '0:0-0:0', 'Wednesday': '9:0-14:0',...
# 1587  {'Monday': '9:0-15:0', 'Tuesday': '9:0-15:0', ...
# 2993  {'Monday': '6:0-14:30', 'Tuesday': '6:0-14:30'...
# 2604  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 1163  {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...
# 3273  {'Monday': '7:0-21:30', 'Tuesday': '7:0-21:30'...
# 3889  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...
# 3554  {'Tuesday': '8:0-16:0', 'Wednesday': '8:0-16:0...
# 505   {'Monday': '0:0-0:0', 'Tuesday': '7:30-14:30',...
# 2538  {'Monday': '0:0-0:0', 'Tuesday': '7:0-15:0', '...
# 2532  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 1143  {'Monday': '9:0-14:0', 'Tuesday': '9:0-14:0', ...
# 809   {'Monday': '0:0-0:0', 'Tuesday': '8:0-15:0', '...
# 628   {'Monday': '6:0-15:0', 'Tuesday': '6:0-15:0', ...
# 3173                                                NaN
# 3385  {'Monday': '0:0-0:0', 'Tuesday': '7:30-15:0', ...
# 3592  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:30', ...
# 4529  {'Monday': '6:30-15:0', 'Tuesday': '6:30-15:0'...
# 4024  {'Monday': '0:0-0:0', 'Tuesday': '7:30-15:0', ...

# %%
rest2_comp_filter=rest2_comp[rest2_comp['stars'] >= 4.0] #and rest2_comp['review_count'>= 50]]

# %%
rest2_comp_filter=rest2_comp_filter[rest2_comp_filter['review_count'] >= 100]

# %%
rest2_comp_filter
# Out:
#                  business_id               name                   address  \
# 734   RqtEy936GDBb0ddesDqKQg    Breakfast Table     3014 Granville Street
# 1163  QmkGDL-8zexdKV3Xcn8ZYg  OEB Breakfast Co.  1137 Marinaside Crescent
# 2604  GvuQgsZpzrbY_PuaiYnAsQ        Joe's Grill         1031 Davie Street
#
#            city state postal_code   latitude   longitude  stars  review_count  \
# 734   Vancouver    BC     V6H 1H6  49.258568 -123.138517    4.5           210
# 1163  Vancouver    BC     V6Z 2Y3  49.273457 -123.119265    4.0           371
# 2604  Vancouver    BC     V6E 1M5  49.279750 -123.129945    4.0           170
#
#       is_open                                         attributes  \
# 734         1  {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 1163        1  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 2604        1  {'NoiseLevel': "u'average'", 'RestaurantsReser...
#
#                            categories  \
# 734   Restaurants, Breakfast & Brunch
# 1163  Restaurants, Breakfast & Brunch
# 2604  Restaurants, Breakfast & Brunch
#
#                                                   hours
# 734   {'Monday': '0:0-0:0', 'Wednesday': '9:0-14:0',...
# 1163  {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...
# 2604  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...

# %%
# rest2_coords=rest2_comp_filter[['name','stars','latitude','longitude']]

# %%
rest2_comp_filter = rest2_comp_filter[rest2_comp_filter['name'].str.contains("De Dutch")== False]
rest2_coords=rest2_comp_filter[['name','stars','latitude','longitude']]

# %%
rest2_coords
# Out:
#                    name  stars   latitude   longitude
# 734     Breakfast Table    4.5  49.258568 -123.138517
# 1163  OEB Breakfast Co.    4.0  49.273457 -123.119265
# 2604        Joe's Grill    4.0  49.279750 -123.129945

# %%
rest2_og_coords=rest2[['name','stars','latitude','longitude']]

# %%
rest2_og_coords
# Out:
#           name  stars   latitude   longitude
# 505   De Dutch    3.5  49.319227 -123.090558
# 809   De Dutch    3.5  49.290030 -123.116896
# 2538  De Dutch    3.5  49.324860 -123.121427
# 3385  De Dutch    3.0  49.272474 -122.789011
# 3592  De Dutch    3.0  49.166082 -122.800249
# 3889  De Dutch    3.5  49.257264 -123.127002
# 4024  De Dutch    2.5  49.267136 -123.113174
# 4529  De Dutch    3.0  49.200446 -122.917667

# %%
rest2_og_coords.to_csv('rest2og.csv')

# %%
rest2_coords.to_csv('rest2.csv')

# %%
rest1=df_1[df_1.name=='Mucho Burrito']

rest1
# Out:
#                  business_id           name                     address  \
# 509   oAv2XW5i-w3A-pESAu1Abw  Mucho Burrito            988 Davie Street
# 1451  LiEz1GBLKwYBW7n4H9YxzQ  Mucho Burrito        7515 Market Crossing
# 2755  aqchZyKeC32rmPX5I2DYYw  Mucho Burrito           7113 120th Street
# 3725  9v0Iz8rR1-CK3GumfuSwgw  Mucho Burrito  9666 King George Boulevard
#
#            city state postal_code   latitude   longitude  stars  review_count  \
# 509   Vancouver    BC     V6Z 1B7  49.278722 -123.128947    3.0            77
# 1451    Burnaby    BC     V5J 3J4  49.198046 -122.979105    3.0            54
# 2755      Delta    BC     V4E 2A9  49.131666 -122.892143    4.0             6
# 3725     Surrey    BC     V3T 2V4  49.178843 -122.844991    3.5            19
#
#       is_open                                         attributes  \
# 509         1  {'RestaurantsAttire': "u'casual'", 'WiFi': "'f...
# 1451        1  {'HasTV': 'True', 'RestaurantsAttire': "u'casu...
# 2755        1  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 3725        1  {'Ambience': "{'touristy': False, 'hipster': F...
#
#                                            categories  \
# 509                   Fast Food, Mexican, Restaurants
# 1451         Mexican, Fast Food, Tex-Mex, Restaurants
# 2755  Fast Food, Restaurants, Food, Desserts, Mexican
# 3725                             Restaurants, Mexican
#
#                                                   hours
# 509   {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 1451  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 2755  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 3725  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...

# %%
# burioto_cus=['Mexican','mexican','Restaurants']

# %%
# df1_name

# %%
rest1_comp=df_1[df_1.categories.isin(rest1.categories)]

rest1_comp
# Out:
#                  business_id                             name  \
# 116   bWmgiuAxZC60YoE1IgMiHg                   Tacofino Oasis
# 509   oAv2XW5i-w3A-pESAu1Abw                    Mucho Burrito
# 693   fm6crzNySAjkHGGbsOz_fg                          Quesada
# 1185  wtyCB3iRPHSXNxmtZsg89A                    Tacofino Ocho
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria
# 1437  FTcqO7j-A6Z3NVEs_Or6-g     Charlie's Mexican Restaurant
# 1451  LiEz1GBLKwYBW7n4H9YxzQ                    Mucho Burrito
# 1955  VCzzjdi1FU7gPOQsSReSXw                          Don Oso
# 2083  Nrmsdtg10pyX2Qm2nZcVSg                     Best Burrito
# 2514  w-WIdtND5jGIiiYoFjhtmg                        La Casita
# 2535  rr3fgRYPxcXt0pACSaAjew                         Tacofino
# 2755  aqchZyKeC32rmPX5I2DYYw                    Mucho Burrito
# 2816  jEhTKvmL7RM-7j_ipovizg     La Taqueria Pinche Taco Shop
# 3400  P3XAouZt4PXHRurzfirJxw                 Rosarito Burrito
# 3407  IeWSMJJ90F4YMNb8YUqF8g                      Red Burrito
# 3725  9v0Iz8rR1-CK3GumfuSwgw                    Mucho Burrito
# 3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina
# 4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón
# 4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos
# 4149  bUyJ7AHN-dXCewS0NVw7jQ                       Lucky Taco
# 4296  XDWS4Rayi52jrN0z0ibG4Q                 Mi Casa Mexicana
# 4446  t2ssQUXsQILshsn6IJa00Q             Ole Ole Mexican Deli
# 4453  k7AMSxc3qWaSychj1EpLTg                       La Cantina
# 4573  bn6HPzhF36_jXWJOx2RQ6g                         El Santo
#
#                           address             city state postal_code  \
# 116             122-1050 W Pender        Vancouver    BC         V6E
# 509              988 Davie Street        Vancouver    BC     V6Z 1B7
# 693          4297 Hastings Street          Burnaby    BC     V5C 2J5
# 1185               8 East 5th Ave        Vancouver    BC     V5T 2W7
# 1299        1622 Commercial Drive        Vancouver    BC     V5L 3Y4
# 1437        2517 St. Johns Street       Port Moody    BC     V3H 2B3
# 1451         7515 Market Crossing          Burnaby    BC     V5J 3J4
# 1955             4421 Hastings St          Burnaby    BC     V5C 2K1
# 2083                15 W Broadway        Vancouver    BC     V5Y 1P1
# 2514         101 W Cordova Street        Vancouver    BC     V6B 1E1
# 2535               1909 W 4th Ave        Vancouver    BC     V6J 3L9
# 2755            7113 120th Street            Delta    BC     V4E 2A9
# 2816            586 Hornby Street        Vancouver    BC     V6C 3B6
# 3400                1230 Davie St        Vancouver    BC     V6E 1N3
# 3407            1455 Lonsdale Ave  North Vancouver    BC     V7M 2H9
# 3725   9666 King George Boulevard           Surrey    BC     V3T 2V4
# 3746        1049 Granville Street        Vancouver    BC     V6Z 1L4
# 4085  701 Kingsway Street, Unit 5        Vancouver    BC     V5T 3K6
# 4089           1187 Denman Street        Vancouver    BC     V6G 2N1
# 4149              1685 Yew Street        Vancouver    BC     V6K 3E6
# 4296          2015 Burrard Street        Vancouver    BC     V6J 1M3
# 4446                831 12 Street  New Westminster    BC     V3M 4K4
# 4453                722 Nelson St        Vancouver    BC     V6Z 2A8
# 4573          680 Columbia Street  New Westminster    BC     V3M 1A9
#
#        latitude   longitude  stars  review_count  is_open  \
# 116   49.286801 -123.119575    4.0            29        1
# 509   49.278722 -123.128947    3.0            77        1
# 693   49.281196 -123.008958    2.5             6        1
# 1185  49.266368 -123.104530    3.0            58        1
# 1299  49.270090 -123.069500    4.0           242        1
# 1437  49.276516 -122.855229    2.5            61        1
# 1451  49.198046 -122.979105    3.0            54        1
# 1955  49.281166 -123.005217    3.5             6        1
# 2083  49.263173 -123.105380    3.0            38        1
# 2514  49.283048 -123.106905    3.0           242        1
# 2535  49.268262 -123.148323    3.5            13        1
# 2755  49.131666 -122.892143    4.0             6        1
# 2816  49.285006 -123.118050    3.5            93        1
# 3400  49.282116 -123.134145    3.0             7        1
# 3407  49.321836 -123.072600    3.0            28        1
# 3725  49.178843 -122.844991    3.5            19        1
# 3746  49.278828 -123.124044    4.5           356        1
# 4085  49.256904 -123.089246    4.0           581        1
# 4089  49.287774 -123.141263    4.5           101        1
# 4149  49.271069 -123.155104    3.5            43        1
# 4296  49.267771 -123.145790    4.5             6        1
# 4446  49.211660 -122.935206    3.5            38        1
# 4453  49.279434 -123.123527    4.0            50        1
# 4573  49.201967 -122.909371    3.5           210        1
#
#                                              attributes  \
# 116   {'GoodForKids': 'True', 'RestaurantsTakeOut': ...
# 509   {'RestaurantsAttire': "u'casual'", 'WiFi': "'f...
# 693   {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 1185  {'Ambience': "{'touristy': None, 'hipster': Tr...
# 1299  {'Caters': 'True', 'GoodForKids': 'False', 'Re...
# 1437  {'Alcohol': "u'beer_and_wine'", 'BusinessParki...
# 1451  {'HasTV': 'True', 'RestaurantsAttire': "u'casu...
# 1955                                                NaN
# 2083  {'OutdoorSeating': 'True', 'Ambience': "{'roma...
# 2514  {'BikeParking': 'True', 'OutdoorSeating': 'Fal...
# 2535  {'GoodForMeal': "{'dessert': False, 'latenight...
# 2755  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 2816  {'RestaurantsGoodForGroups': 'True', 'BikePark...
# 3400  {'BusinessParking': "{'garage': False, 'street...
# 3407  {'RestaurantsTakeOut': 'True', 'NoiseLevel': "...
# 3725  {'Ambience': "{'touristy': False, 'hipster': F...
# 3746  {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 4085  {'GoodForKids': 'True', 'WiFi': "u'no'", 'Outd...
# 4089  {'WiFi': "'no'", 'RestaurantsAttire': "'casual...
# 4149  {'HappyHour': 'True', 'RestaurantsDelivery': '...
# 4296  {'BikeParking': 'True', 'HasTV': 'True', 'Outd...
# 4446  {'RestaurantsPriceRange2': '2', 'GoodForKids':...
# 4453  {'GoodForKids': 'False', 'RestaurantsReservati...
# 4573  {'HasTV': 'False', 'RestaurantsTableService': ...
#
#                                            categories  \
# 116                              Restaurants, Mexican
# 509                   Fast Food, Mexican, Restaurants
# 693                              Restaurants, Mexican
# 1185                             Restaurants, Mexican
# 1299                             Restaurants, Mexican
# 1437                             Restaurants, Mexican
# 1451         Mexican, Fast Food, Tex-Mex, Restaurants
# 1955                             Restaurants, Mexican
# 2083                             Restaurants, Mexican
# 2514                             Restaurants, Mexican
# 2535                             Restaurants, Mexican
# 2755  Fast Food, Restaurants, Food, Desserts, Mexican
# 2816                  Fast Food, Mexican, Restaurants
# 3400                             Restaurants, Mexican
# 3407                             Restaurants, Mexican
# 3725                             Restaurants, Mexican
# 3746                             Restaurants, Mexican
# 4085                             Restaurants, Mexican
# 4089                             Restaurants, Mexican
# 4149                             Restaurants, Mexican
# 4296                             Restaurants, Mexican
# 4446                             Restaurants, Mexican
# 4453                             Restaurants, Mexican
# 4573                             Restaurants, Mexican
#
#                                                   hours
# 116   {'Monday': '0:0-0:0', 'Tuesday': '11:0-19:0', ...
# 509   {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 693   {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 1185  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 1299  {'Tuesday': '17:0-23:0', 'Wednesday': '11:0-23...
# 1437                                                NaN
# 1451  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 1955                                                NaN
# 2083  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 2514  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 2535  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 2755  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 2816  {'Monday': '11:30-17:30', 'Tuesday': '11:30-17...
# 3400  {'Monday': '10:0-21:30', 'Tuesday': '10:0-21:3...
# 3407  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 3725  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 3746  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 4085  {'Monday': '0:0-0:0', 'Tuesday': '10:30-20:0',...
# 4089  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 4149  {'Monday': '11:30-2:0', 'Tuesday': '11:30-2:0'...
# 4296  {'Monday': '0:0-0:0', 'Wednesday': '17:0-21:0'...
# 4446                                                NaN
# 4453  {'Monday': '11:30-20:0', 'Tuesday': '11:30-20:...
# 4573  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...

# %%
rest1_comp.sort_values('stars',ascending=False)
# Out:
#                  business_id                             name  \
# 4296  XDWS4Rayi52jrN0z0ibG4Q                 Mi Casa Mexicana
# 4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos
# 3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina
# 116   bWmgiuAxZC60YoE1IgMiHg                   Tacofino Oasis
# 2755  aqchZyKeC32rmPX5I2DYYw                    Mucho Burrito
# 4453  k7AMSxc3qWaSychj1EpLTg                       La Cantina
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria
# 4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón
# 4446  t2ssQUXsQILshsn6IJa00Q             Ole Ole Mexican Deli
# 4149  bUyJ7AHN-dXCewS0NVw7jQ                       Lucky Taco
# 3725  9v0Iz8rR1-CK3GumfuSwgw                    Mucho Burrito
# 2816  jEhTKvmL7RM-7j_ipovizg     La Taqueria Pinche Taco Shop
# 2535  rr3fgRYPxcXt0pACSaAjew                         Tacofino
# 1955  VCzzjdi1FU7gPOQsSReSXw                          Don Oso
# 4573  bn6HPzhF36_jXWJOx2RQ6g                         El Santo
# 509   oAv2XW5i-w3A-pESAu1Abw                    Mucho Burrito
# 3400  P3XAouZt4PXHRurzfirJxw                 Rosarito Burrito
# 3407  IeWSMJJ90F4YMNb8YUqF8g                      Red Burrito
# 2514  w-WIdtND5jGIiiYoFjhtmg                        La Casita
# 2083  Nrmsdtg10pyX2Qm2nZcVSg                     Best Burrito
# 1451  LiEz1GBLKwYBW7n4H9YxzQ                    Mucho Burrito
# 1185  wtyCB3iRPHSXNxmtZsg89A                    Tacofino Ocho
# 1437  FTcqO7j-A6Z3NVEs_Or6-g     Charlie's Mexican Restaurant
# 693   fm6crzNySAjkHGGbsOz_fg                          Quesada
#
#                           address             city state postal_code  \
# 4296          2015 Burrard Street        Vancouver    BC     V6J 1M3
# 4089           1187 Denman Street        Vancouver    BC     V6G 2N1
# 3746        1049 Granville Street        Vancouver    BC     V6Z 1L4
# 116             122-1050 W Pender        Vancouver    BC         V6E
# 2755            7113 120th Street            Delta    BC     V4E 2A9
# 4453                722 Nelson St        Vancouver    BC     V6Z 2A8
# 1299        1622 Commercial Drive        Vancouver    BC     V5L 3Y4
# 4085  701 Kingsway Street, Unit 5        Vancouver    BC     V5T 3K6
# 4446                831 12 Street  New Westminster    BC     V3M 4K4
# 4149              1685 Yew Street        Vancouver    BC     V6K 3E6
# 3725   9666 King George Boulevard           Surrey    BC     V3T 2V4
# 2816            586 Hornby Street        Vancouver    BC     V6C 3B6
# 2535               1909 W 4th Ave        Vancouver    BC     V6J 3L9
# 1955             4421 Hastings St          Burnaby    BC     V5C 2K1
# 4573          680 Columbia Street  New Westminster    BC     V3M 1A9
# 509              988 Davie Street        Vancouver    BC     V6Z 1B7
# 3400                1230 Davie St        Vancouver    BC     V6E 1N3
# 3407            1455 Lonsdale Ave  North Vancouver    BC     V7M 2H9
# 2514         101 W Cordova Street        Vancouver    BC     V6B 1E1
# 2083                15 W Broadway        Vancouver    BC     V5Y 1P1
# 1451         7515 Market Crossing          Burnaby    BC     V5J 3J4
# 1185               8 East 5th Ave        Vancouver    BC     V5T 2W7
# 1437        2517 St. Johns Street       Port Moody    BC     V3H 2B3
# 693          4297 Hastings Street          Burnaby    BC     V5C 2J5
#
#        latitude   longitude  stars  review_count  is_open  \
# 4296  49.267771 -123.145790    4.5             6        1
# 4089  49.287774 -123.141263    4.5           101        1
# 3746  49.278828 -123.124044    4.5           356        1
# 116   49.286801 -123.119575    4.0            29        1
# 2755  49.131666 -122.892143    4.0             6        1
# 4453  49.279434 -123.123527    4.0            50        1
# 1299  49.270090 -123.069500    4.0           242        1
# 4085  49.256904 -123.089246    4.0           581        1
# 4446  49.211660 -122.935206    3.5            38        1
# 4149  49.271069 -123.155104    3.5            43        1
# 3725  49.178843 -122.844991    3.5            19        1
# 2816  49.285006 -123.118050    3.5            93        1
# 2535  49.268262 -123.148323    3.5            13        1
# 1955  49.281166 -123.005217    3.5             6        1
# 4573  49.201967 -122.909371    3.5           210        1
# 509   49.278722 -123.128947    3.0            77        1
# 3400  49.282116 -123.134145    3.0             7        1
# 3407  49.321836 -123.072600    3.0            28        1
# 2514  49.283048 -123.106905    3.0           242        1
# 2083  49.263173 -123.105380    3.0            38        1
# 1451  49.198046 -122.979105    3.0            54        1
# 1185  49.266368 -123.104530    3.0            58        1
# 1437  49.276516 -122.855229    2.5            61        1
# 693   49.281196 -123.008958    2.5             6        1
#
#                                              attributes  \
# 4296  {'BikeParking': 'True', 'HasTV': 'True', 'Outd...
# 4089  {'WiFi': "'no'", 'RestaurantsAttire': "'casual...
# 3746  {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 116   {'GoodForKids': 'True', 'RestaurantsTakeOut': ...
# 2755  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 4453  {'GoodForKids': 'False', 'RestaurantsReservati...
# 1299  {'Caters': 'True', 'GoodForKids': 'False', 'Re...
# 4085  {'GoodForKids': 'True', 'WiFi': "u'no'", 'Outd...
# 4446  {'RestaurantsPriceRange2': '2', 'GoodForKids':...
# 4149  {'HappyHour': 'True', 'RestaurantsDelivery': '...
# 3725  {'Ambience': "{'touristy': False, 'hipster': F...
# 2816  {'RestaurantsGoodForGroups': 'True', 'BikePark...
# 2535  {'GoodForMeal': "{'dessert': False, 'latenight...
# 1955                                                NaN
# 4573  {'HasTV': 'False', 'RestaurantsTableService': ...
# 509   {'RestaurantsAttire': "u'casual'", 'WiFi': "'f...
# 3400  {'BusinessParking': "{'garage': False, 'street...
# 3407  {'RestaurantsTakeOut': 'True', 'NoiseLevel': "...
# 2514  {'BikeParking': 'True', 'OutdoorSeating': 'Fal...
# 2083  {'OutdoorSeating': 'True', 'Ambience': "{'roma...
# 1451  {'HasTV': 'True', 'RestaurantsAttire': "u'casu...
# 1185  {'Ambience': "{'touristy': None, 'hipster': Tr...
# 1437  {'Alcohol': "u'beer_and_wine'", 'BusinessParki...
# 693   {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
#
#                                            categories  \
# 4296                             Restaurants, Mexican
# 4089                             Restaurants, Mexican
# 3746                             Restaurants, Mexican
# 116                              Restaurants, Mexican
# 2755  Fast Food, Restaurants, Food, Desserts, Mexican
# 4453                             Restaurants, Mexican
# 1299                             Restaurants, Mexican
# 4085                             Restaurants, Mexican
# 4446                             Restaurants, Mexican
# 4149                             Restaurants, Mexican
# 3725                             Restaurants, Mexican
# 2816                  Fast Food, Mexican, Restaurants
# 2535                             Restaurants, Mexican
# 1955                             Restaurants, Mexican
# 4573                             Restaurants, Mexican
# 509                   Fast Food, Mexican, Restaurants
# 3400                             Restaurants, Mexican
# 3407                             Restaurants, Mexican
# 2514                             Restaurants, Mexican
# 2083                             Restaurants, Mexican
# 1451         Mexican, Fast Food, Tex-Mex, Restaurants
# 1185                             Restaurants, Mexican
# 1437                             Restaurants, Mexican
# 693                              Restaurants, Mexican
#
#                                                   hours
# 4296  {'Monday': '0:0-0:0', 'Wednesday': '17:0-21:0'...
# 4089  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 3746  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 116   {'Monday': '0:0-0:0', 'Tuesday': '11:0-19:0', ...
# 2755  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 4453  {'Monday': '11:30-20:0', 'Tuesday': '11:30-20:...
# 1299  {'Tuesday': '17:0-23:0', 'Wednesday': '11:0-23...
# 4085  {'Monday': '0:0-0:0', 'Tuesday': '10:30-20:0',...
# 4446                                                NaN
# 4149  {'Monday': '11:30-2:0', 'Tuesday': '11:30-2:0'...
# 3725  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 2816  {'Monday': '11:30-17:30', 'Tuesday': '11:30-17...
# 2535  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 1955                                                NaN
# 4573  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 509   {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 3400  {'Monday': '10:0-21:30', 'Tuesday': '10:0-21:3...
# 3407  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2514  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 2083  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 1451  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 1185  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 1437                                                NaN
# 693   {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...

# %%
rest1_comp_filter=rest1_comp[rest1_comp['stars'] >= 4.0]
rest1_comp_filter
# Out:
#                  business_id                             name  \
# 116   bWmgiuAxZC60YoE1IgMiHg                   Tacofino Oasis
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria
# 2755  aqchZyKeC32rmPX5I2DYYw                    Mucho Burrito
# 3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina
# 4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón
# 4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos
# 4296  XDWS4Rayi52jrN0z0ibG4Q                 Mi Casa Mexicana
# 4453  k7AMSxc3qWaSychj1EpLTg                       La Cantina
#
#                           address       city state postal_code   latitude  \
# 116             122-1050 W Pender  Vancouver    BC         V6E  49.286801
# 1299        1622 Commercial Drive  Vancouver    BC     V5L 3Y4  49.270090
# 2755            7113 120th Street      Delta    BC     V4E 2A9  49.131666
# 3746        1049 Granville Street  Vancouver    BC     V6Z 1L4  49.278828
# 4085  701 Kingsway Street, Unit 5  Vancouver    BC     V5T 3K6  49.256904
# 4089           1187 Denman Street  Vancouver    BC     V6G 2N1  49.287774
# 4296          2015 Burrard Street  Vancouver    BC     V6J 1M3  49.267771
# 4453                722 Nelson St  Vancouver    BC     V6Z 2A8  49.279434
#
#        longitude  stars  review_count  is_open  \
# 116  -123.119575    4.0            29        1
# 1299 -123.069500    4.0           242        1
# 2755 -122.892143    4.0             6        1
# 3746 -123.124044    4.5           356        1
# 4085 -123.089246    4.0           581        1
# 4089 -123.141263    4.5           101        1
# 4296 -123.145790    4.5             6        1
# 4453 -123.123527    4.0            50        1
#
#                                              attributes  \
# 116   {'GoodForKids': 'True', 'RestaurantsTakeOut': ...
# 1299  {'Caters': 'True', 'GoodForKids': 'False', 'Re...
# 2755  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 3746  {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 4085  {'GoodForKids': 'True', 'WiFi': "u'no'", 'Outd...
# 4089  {'WiFi': "'no'", 'RestaurantsAttire': "'casual...
# 4296  {'BikeParking': 'True', 'HasTV': 'True', 'Outd...
# 4453  {'GoodForKids': 'False', 'RestaurantsReservati...
#
#                                            categories  \
# 116                              Restaurants, Mexican
# 1299                             Restaurants, Mexican
# 2755  Fast Food, Restaurants, Food, Desserts, Mexican
# 3746                             Restaurants, Mexican
# 4085                             Restaurants, Mexican
# 4089                             Restaurants, Mexican
# 4296                             Restaurants, Mexican
# 4453                             Restaurants, Mexican
#
#                                                   hours
# 116   {'Monday': '0:0-0:0', 'Tuesday': '11:0-19:0', ...
# 1299  {'Tuesday': '17:0-23:0', 'Wednesday': '11:0-23...
# 2755  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 3746  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 4085  {'Monday': '0:0-0:0', 'Tuesday': '10:30-20:0',...
# 4089  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 4296  {'Monday': '0:0-0:0', 'Wednesday': '17:0-21:0'...
# 4453  {'Monday': '11:30-20:0', 'Tuesday': '11:30-20:...

# %%
rest1_comp_filter=rest1_comp_filter[rest1_comp_filter['review_count'] >= 100]
rest1_comp_filter
# Out:
#                  business_id                             name  \
# 1299  ieuUpA1eswgXDAfxp8B42A                    La Mezcaleria
# 3746  AEyYLMPjnFWybOmD81pufg  The Mexican Antojitos Y Cantina
# 4085  bExSibVFQPQdq3-xGyIEqw                      Sal y Limón
# 4089  rhkj-58IoZ9p_CvYS3NbOQ                 La Catrina Tacos
#
#                           address       city state postal_code   latitude  \
# 1299        1622 Commercial Drive  Vancouver    BC     V5L 3Y4  49.270090
# 3746        1049 Granville Street  Vancouver    BC     V6Z 1L4  49.278828
# 4085  701 Kingsway Street, Unit 5  Vancouver    BC     V5T 3K6  49.256904
# 4089           1187 Denman Street  Vancouver    BC     V6G 2N1  49.287774
#
#        longitude  stars  review_count  is_open  \
# 1299 -123.069500    4.0           242        1
# 3746 -123.124044    4.5           356        1
# 4085 -123.089246    4.0           581        1
# 4089 -123.141263    4.5           101        1
#
#                                              attributes            categories  \
# 1299  {'Caters': 'True', 'GoodForKids': 'False', 'Re...  Restaurants, Mexican
# 3746  {'GoodForKids': 'True', 'RestaurantsPriceRange...  Restaurants, Mexican
# 4085  {'GoodForKids': 'True', 'WiFi': "u'no'", 'Outd...  Restaurants, Mexican
# 4089  {'WiFi': "'no'", 'RestaurantsAttire': "'casual...  Restaurants, Mexican
#
#                                                   hours
# 1299  {'Tuesday': '17:0-23:0', 'Wednesday': '11:0-23...
# 3746  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 4085  {'Monday': '0:0-0:0', 'Tuesday': '10:30-20:0',...
# 4089  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...

# %%
rest1_comp_filter = rest1_comp_filter[rest1_comp_filter['name'].str.contains("Mucho Burrito")== False]
rest1_coords=rest1_comp_filter[['name','stars','latitude','longitude']]

# %%
rest1_coords
# Out:
#                                  name  stars   latitude   longitude
# 1299                    La Mezcaleria    4.0  49.270090 -123.069500
# 3746  The Mexican Antojitos Y Cantina    4.5  49.278828 -123.124044
# 4085                      Sal y Limón    4.0  49.256904 -123.089246
# 4089                 La Catrina Tacos    4.5  49.287774 -123.141263

# %%
rest1_og_coords=rest1[['name','stars','latitude','longitude']]

# %%
rest1_og_coords
# Out:
#                name  stars   latitude   longitude
# 509   Mucho Burrito    3.0  49.278722 -123.128947
# 1451  Mucho Burrito    3.0  49.198046 -122.979105
# 2755  Mucho Burrito    4.0  49.131666 -122.892143
# 3725  Mucho Burrito    3.5  49.178843 -122.844991

# %%
rest1_og_coords.to_csv('rest1og.csv')

# %%
rest1_coords.to_csv('rest1.csv')

# %%
results
# Out:
# {'0755 Lounge': 1,
#  '131 Water Kitchen & Bar': 1,
#  '1931 Gallery Bistro': 1,
#  '24 Train Express': 1,
#  '3 Quarters Full': 1,
#  "4 Brothers' Pizza": 1,
#  '4 Stones Vegetarian Cuisine': 1,
#  '41 Noodle & Rice Pot House': 1,
#  '49th Parallel Coffee': 2,
#  '5 Spice Vietnamese Cuisine': 1,
#  "50's Burgers": 1,
#  '54th Ave Cafe Restaurant': 1,
#  '6 Degrees Eatery': 1,
#  '604 Dental At Main 41': 1,
#  '6th Ave Bread & Deli': 1,
#  '7 Days Coffee': 1,
#  '7-Eleven': 1,
#  '75 West Coast Grill': 1,
#  '777 Pizza & Donair': 1,
#  '8 at Doneras': 1,
#  '88 PalPal Noodle House': 1,
#  '888 Caffe Express': 1,
#  '99 BBQ House': 1,
#  'A & W Restaurants': 1,
#  'A Bread Affair': 1,
#  'A La Mode': 1,
#  'A Taste of India Restaurant': 1,
#  'A Taste of Punjab': 1,
#  'A Taste of Vietnam': 1,
#  'A&W': 42,
#  'AAA Restaurant': 1,
#  'ABODE Restaurant & Coffee Bar': 1,
#  'AFURI ramen + dumpling': 1,
#  'AKD Kitchen': 1,
#  'ARC Restaurant': 1,
#  'ARGO': 1,
#  'ARISU Authentic Korean BBQ': 1,
#  'ASA Sushi': 1,
#  'Abc Country Restaurant': 1,
#  'Abdul BBQ & Shawarma': 1,
#  'Aberdeen Square Food Court': 1,
#  'Absinthe Bistro': 1,
#  'Abyssinia Ethiopian Restaurant': 1,
#  'Acqua Restaurant + Bar': 1,
#  'Active Body Burnaby': 1,
#  "Adam's Crepes": 1,
#  'Addis Cafe Ethiopian Restaurant': 1,
#  'Adelitas': 1,
#  'Adonia Tea House': 1,
#  'Aero Inn Sushi Cafe': 1,
#  'Afghan Bakery & Fast Food': 1,
#  'Afghan Chopan Bakery & Diner': 1,
#  'Afghan Chopan Restaurant': 2,
#  'Afghan Horsemen Restaurant': 1,
#  'Afghan Turkish Cuisine': 1,
#  'Afra Bakery & Market': 1,
#  'Aggarwal Sweets': 1,
#  'Agora Cafe': 1,
#  'Agra Indian Sweets And Restaurant': 1,
#  'Agra Tandoori Restaurant': 2,
#  'Agro Roasters': 1,
#  'Aji Hana': 1,
#  'Ajisai Sushi Bar': 1,
#  'Ajishou Japanese Cuisine': 1,
#  'Ajiya Sushi Bar': 1,
#  'Ajs Brooklyn Pizza Joint': 1,
#  'Ajuker Fried Chicken': 1,
#  'Akari Japanese Restaurant': 1,
#  'Akasaka Japanese Restaurant': 1,
#  'Akash Chat House & Restaurant': 1,
#  "Akbar's Own Dining Lounge": 1,
#  'Akebono Japanese Food & Sushi': 1,
#  'Akira Sushi': 1,
#  'Al Basha': 2,
#  'Al Basha Restaurant': 1,
#  'Al Porto': 1,
#  'Al-Salam Halal Meat': 1,
#  'Al-Watan Tandoori': 1,
#  'Aladdin Cafe': 1,
#  'Alberello Pizzeria': 1,
#  'Alenka European Foods': 1,
#  'Aleph Eatery': 1,
#  'AliBaba Capilano Cafe': 1,
#  'Alibi Room': 1,
#  'Aling Ening Restaurant': 1,
#  'All About Pho': 1,
#  'All Day Café': 1,
#  'All India Sweets & Restaurant': 1,
#  'Alley BBQ Restaurant': 1,
#  'Alma Mater Society of UBC': 1,
#  'Altitudes Bistro': 1,
#  'Altmaerker German Sausage House And Deli': 1,
#  'Alvin Garden': 1,
#  'Amato Gelato Cafe': 1,
#  "Amay's House": 1,
#  'Amelia Restaurant': 1,
#  'Amigo Pancake House Restaurant': 1,
#  'Amorosa Pasta House': 1,
#  'An Pho': 1,
#  'Ananda Bhavan': 1,
#  'Anar Persian Cuisine': 1,
#  'Anatoli Souvlaki': 1,
#  'Anatolia Express': 1,
#  "Anatolia's Gate Restaurant": 1,
#  'Ancora Waterfront Dining and Patio': 1,
#  'Ancora Waterfront Dining and Patio - Ambleside': 1,
#  'Andamiro Korean Bistro': 1,
#  'Andreas Restaurant': 1,
#  'Angel Cafe': 1,
#  "Angelina's": 1,
#  'Angus T': 1,
#  'Anh and Chi': 1,
#  "Anita's Kitchen": 1,
#  'AnnaLena': 1,
#  "Anny's Dairy Bar": 1,
#  "Anton's Pasta Bar": 1,
#  'Aperture Coffee Bar': 2,
#  "Aphrodite's Organic  Pie Shop": 1,
#  "Aphrodite's Organic Cafe": 1,
#  'Apna Bhaia Sweet Shop': 1,
#  'Apna Chaat House': 1,
#  'Apollo Pizza': 1,
#  'Apollonia Greek Restaurant': 1,
#  'Applause Japanese Restaurant': 1,
#  'Argo Café': 1,
#  'Aria Kabab': 1,
#  'Arike Restaurant': 1,
#  'Arirang Korean Restaurant': 1,
#  'Arms Reach Bistro': 1,
#  'Aroma Restaurant & Bar': 1,
#  'Aroy Thai': 1,
#  'Arriva Ristorante': 1,
#  'Artisan Eats Cafe & Fine Foods': 1,
#  'Artisan Sake Maker': 1,
#  "Arturo's Mexico to Go": 1,
#  'Artusi Restaurant': 1,
#  "Arvind's Curry & Cocktail": 1,
#  'Asa Sushi': 1,
#  'Asahi Japanese Restaurant': 1,
#  'Ash Street Bistro': 1,
#  'Ashiana Tandoori Restaurant': 1,
#  'Asia Market': 1,
#  'Asian Jazz': 1,
#  'Asian Spice': 1,
#  'Ask For Luigi': 1,
#  'Assembli': 1,
#  "Astro's Kitchen": 1,
#  'Asylum Restaurant': 1,
#  'Atlas Steak + Fish': 1,
#  'Au Comptoir': 1,
#  'Aussie Pie Guy': 1,
#  'Austin Fish House': 1,
#  'Austin Heights Pizza': 1,
#  'Autostrada': 1,
#  'Autostrada Osteria': 1,
#  'Avalon Dairy': 1,
#  'Avery Cafe Restaurant': 1,
#  'Avi Pizza & Pasta': 1,
#  'Axum Restaurant': 1,
#  'Aya Beauty Shop': 1,
#  "Ayoub's Dried Fruits and Nuts": 1,
#  'Azure Play Cafe': 1,
#  'BANSHAN BBQ RESTAURANT': 1,
#  'BBQ Chicken': 1,
#  'BBQ Chicken & Pub': 1,
#  'BBQ King Delight': 1,
#  'BBT Cafe': 1,
#  'BC Ferries': 1,
#  'BC Kitchen': 1,
#  'BC Liquor Distribution Branch Cafeteria': 1,
#  'BC TACO': 1,
#  'BG Urban Cafe': 1,
#  'BLOCK 18 Cart Noodle': 1,
#  'BOGO Korean Kitchen': 1,
#  'BT Cafe': 1,
#  'Ba Le Banh Mi': 1,
#  'Ba Le Sandwich Shop': 2,
#  'Ba Shu Szechuan Food': 1,
#  'Baba Sweets & Restaurant': 2,
#  'Babylon Café': 3,
#  'Bacchus Restaurant & Lounge': 1,
#  'Baci Restaurant': 1,
#  'Backstage Café': 1,
#  'Backstage Lounge': 1,
#  'Badminton Vancouver': 1,
#  'Baggio Gelateria & Pizzaeria': 1,
#  'Baghdad Cafe': 1,
#  'Baguette': 1,
#  'Bahn Shop': 1,
#  'Bai Bua Thai Cuisine': 1,
#  'Baiyulan Shanghai Cuisine': 1,
#  'Baker & Table Cafe Bakery': 1,
#  'Baker One Cafe': 1,
#  'Bali Thai': 1,
#  'Balila': 1,
#  'Balkan House': 1,
#  'Ball Breakers Billiards & Bistro': 1,
#  'Ballyhoo': 1,
#  'Bambo Café': 1,
#  'Bamboo Express': 1,
#  'Bamboo Garden': 1,
#  'Bamboo Grove': 1,
#  'Banana Leaf': 5,
#  'Bandidas Taqueria': 1,
#  'Bangkok City Cafe': 1,
#  'Banh Mi Bar Restaurant': 1,
#  'Banh Mi Saigon': 1,
#  'Banh Mi Timon': 1,
#  'Banter Room': 1,
#  'Banzai Sushi House': 1,
#  'Bao Bakery': 1,
#  'Bao Bei Chinese Brasserie': 1,
#  'Bao Chau Vietnamese Restaurant': 1,
#  'Bao Down Gastropub + Raw bar': 1,
#  'Bao Down UBC': 1,
#  'Baoguette Vietnamese Bistro': 2,
#  'Barcelona Tapas & Wine Bar': 1,
#  'Barcelos Flame Grilled Chicken': 3,
#  "Barney's Pizza & Chicken": 1,
#  'Barra 41': 1,
#  'Bartholomew Bar': 1,
#  'Basak': 1,
#  'Basil Box': 1,
#  'Basil Garden': 1,
#  'Basil Pasta Bar': 1,
#  'Batard Boulangerie & Cafe Moderne': 1,
#  "Bawan's Greek Restaurant": 1,
#  'Bay Sushi': 1,
#  'Bay Sushi Express Cafe': 1,
#  'Bbong': 1,
#  'Be Fresh Local Market': 1,
#  'Beach Ave Bar And Grill': 1,
#  'Bean Around the World Coffees': 2,
#  'Bean Banh Mi': 1,
#  'Beanery Coffeehouse & Eatery': 1,
#  'Beehive Restaurant': 1,
#  'Beeryani Indian Bistro & Bar': 1,
#  'BeetBox': 1,
#  'Beijiang Restaurant': 2,
#  'Beijing Hot Pot': 1,
#  'Bel Café': 1,
#  'Bel Café - Kits': 1,
#  'Belgian Fries': 1,
#  'Bella Pizza': 2,
#  'Bella Roma': 1,
#  'Bellaggio Cafe': 1,
#  'Bellagio Cafe': 1,
#  'Bells and Whistles': 1,
#  'Belmondo Cafe': 1,
#  'Belmont Cafe': 1,
#  'Bene Sushi': 1,
#  'Benkei Noodle Shop': 1,
#  'Bentoya': 1,
#  'Berry Good': 1,
#  'Best Bite Donair': 1,
#  'Best Bite Indian Cuisine': 1,
#  'Best Burrito': 1,
#  'Best Falafel': 2,
#  'Best Neighbours Restaurant & Pizza House': 1,
#  'Best Quality Sweets & Restaurant': 1,
#  'Beyond Bread Artisan Bakery': 1,
#  'Beyond Coffee': 1,
#  'Bharat Sweets & Restaurant': 1,
#  'Bian Fu Chang Noodle Shop': 1,
#  'Bibiko': 1,
#  'Bibis Kitchen': 1,
#  'Bibo Pizzeria': 1,
#  'Bibo Pizzeria con Cucina': 1,
#  'Bier Craft Bistro': 1,
#  'BierCraft Wesbrook': 1,
#  'Biercraft Tap & Tapas': 1,
#  'Big Bang Sushi': 2,
#  'Big Bowl Rice': 1,
#  'Big Chef Restaurant': 1,
#  'Big Chicken Town': 1,
#  'Big Flat Pancake Co': 1,
#  'Big G Fried Chicken Steaks': 1,
#  'Big Rock-Vancouver': 1,
#  'Big Shots Cafe': 1,
#  'Big Star Sandwich': 2,
#  'Big Star Sandwich Co.': 1,
#  'Big Star Sandwiches': 1,
#  'Bigsby the Bakehouse': 1,
#  "Bimini's Public House": 1,
#  'Bin 4 Burger Lounge': 1,
#  'Bing and Noodles World': 1,
#  'Birds & the Beets': 1,
#  "Bishop's Restaurant": 1,
#  'Bistro Sakana': 1,
#  'Bistro Verde': 1,
#  'BjornBar Bakery': 1,
#  'Black & Blue': 1,
#  'Black Bear Neighbourhood Pub': 1,
#  'Black Dog Video': 1,
#  'Black Frog Eatery': 1,
#  'Black Rice Izakaya': 1,
#  'Blackball Taiwanese Dessert': 1,
#  'Blaze Pizza': 1,
#  'Blazing Sushi': 1,
#  'Blend Bubble Tea': 1,
#  'Blenz Coffee': 34,
#  'Bliss Cafe': 1,
#  'Blowfish Sushi & Japanese Food': 1,
#  'Blue Canoe Waterfront Restaurant': 1,
#  'Blue Chip': 1,
#  'Blue Edge Cafe': 1,
#  'Blue Hat Bistro': 1,
#  'Blue Sky Japanese Bistro': 1,
#  'Blue Water Cafe': 1,
#  'Bluefin Sushi': 1,
#  'Bluhouse Market & Cafe': 1,
#  'Blvd Bistro': 1,
#  'Bmo Bank of Montreal': 1,
#  'Bo Wah Fast Food': 1,
#  "Bob & Al's Pizza": 1,
#  'Bob Likes Thai Food': 1,
#  'Bob Pochana': 1,
#  'Boba Time Cafe': 1,
#  'Bobacabana': 1,
#  'Boca Grande Donut Shop': 1,
#  'Bodega On Main': 1,
#  "Bogart's Bar and Restaurant": 1,
#  'Boiling Point': 3,
#  'Bombay Kitchen and Bar': 1,
#  'Bon Cafe': 1,
#  'Bon Crepe': 1,
#  'Bon Ga Korean Restaurant': 1,
#  'Bon Macaron Patisserie': 1,
#  "Bon's Off Broadway": 1,
#  'Bonchaz Bakery Café': 1,
#  'Bonjour Banh Mi': 1,
#  'Bonjour Vietnam Bistro': 1,
#  'Bonus Bakery': 1,
#  'BookKyung Ban Jeoum Korean': 1,
#  'Boom Beer': 1,
#  'Booster Juice': 1,
#  'Bosa Foods': 1,
#  'Boston Pizza': 14,
#  'Botanist': 1,
#  'Boteco Brasil': 1,
#  'Boulevard Kitchen & Oyster Bar': 1,
#  'Bourbon Street Grill': 4,
#  'Bovine': 1,
#  'Bowen Island Pizza Company': 1,
#  'Bowen Island Pub': 1,
#  'Boy With a Knife Grill': 1,
#  'Bozzinis Restaurant': 1,
#  'Branas Mediterranean Grill': 1,
#  'Branch on Bowen': 1,
#  'Brandywine Bartending School': 1,
#  'Brass Fish Tavern & Kitchen': 1,
#  'Bravo Cucina': 1,
#  'Brazza Gelato & Coffee': 1,
#  'Breakfast Table': 1,
#  'Breka Bakery & Cafe': 1,
#  'Breka Bakery and Cafe': 1,
#  'Brewhall': 1,
#  'Bridges Restaurant': 1,
#  'Brioche Doreé': 1,
#  'Brioche Urban Baking & Catering': 1,
#  'Brisk Cafe': 1,
#  'Britannia Sushi': 1,
#  'Brix & Mortar': 1,
#  'Broadway Chinese Restaurant': 1,
#  'Broadway Station Sushi': 1,
#  'Brock House': 1,
#  'Brock House Restaurant': 1,
#  'Broken Rice Vietnamese Restaurant': 1,
#  'Browns Crafthouse': 1,
#  'Browns Crafthouse Seymour': 1,
#  'Browns Social House': 1,
#  'Browns Socialhouse Brentwood': 1,
#  'Browns Socialhouse Brewery District': 1,
#  'Browns Socialhouse Guildford': 1,
#  'Browns Socialhouse Ironwood': 1,
#  'Browns Socialhouse Kitsilano': 1,
#  'Browns Socialhouse Lower Lonsdale': 1,
#  'Browns Socialhouse Lynn Valley': 1,
#  'Browns Socialhouse Newport': 1,
#  'Browns Socialhouse Point Grey': 1,
#  'Browns Socialhouse QE Theatre': 1,
#  'Browns Socialhouse Sun:shine Hills': 1,
#  'Browns Socialhouse Surrey Centre': 1,
#  'Browns Socialhouse Town Centre': 1,
#  'Browns Socialhouse Upper Lonsdale': 1,
#  'Brunch': 1,
#  'Bruncheria Cafe': 1,
#  'Bubble 88': 1,
#  'Bubble Bear Cafe': 1,
#  'Bubble Queen': 1,
#  'Bubble Waffle': 1,
#  'Bubble Waffle - Crystal Mall': 1,
#  'Bubble Waffle Cafe': 10,
#  'Bubble Waffle Cafe - Harbour Centre Food Court': 1,
#  'Bubble Waffle Cafe - Ironwood': 1,
#  'Bubble World': 7,
#  'Buckstop': 1,
#  'Buddha-Full': 1,
#  'Buddha-Full Northwoods': 1,
#  'Budgies Burritos': 1,
#  'Bufala': 1,
#  'Bukjang Korean Restaurant': 1,
#  'Bull King BBQ': 1,
#  'Bun Cha Ca Hoang Yen': 1,
#  'Burdock': 1,
#  'Burger Heaven': 1,
#  'Burger King': 15,
#  'Burgoo Bistro': 3,
#  'Burgoo Bistros': 1,
#  'Burnaby Mountain Clubhouse': 1,
#  'Burnaby Palace Restaurant': 1,
#  'Burrata Pizzeria': 1,
#  'Busan Daeji Gukbap Korean Restaurant': 1,
#  'Busan Daeji Gukbap North Van': 1,
#  'Busters Towing': 1,
#  'Busy Bee One Hour Cleaners': 1,
#  'Butchers Block BBQ': 1,
#  'Butter Baked Goods & Cafe': 1,
#  'Butter Lane Bake Shop & Tea House': 1,
#  'Bánh Mì Très Bon': 1,
#  'Bánh Shop': 1,
#  'C Market Coffee': 1,
#  'C Prime': 1,
#  "C'est si bon": 1,
#  'C-Lovers Fish & Chips': 3,
#  'CC Violin Patisserie & Cafe': 1,
#  'CHAU Veggie Express': 2,
#  'CRAFT Beer Market': 1,
#  'Cabizerra Bistro': 1,
#  'Cactus Club Cafe': 14,
#  'Cactus Club Cafe Station Square': 1,
#  'Cafe 106': 1,
#  'Cafe Ami': 1,
#  'Cafe Crepe': 2,
#  "Cafe D'Lite Express": 1,
#  'Cafe Du Soleil': 1,
#  'Cafe Eggstatic': 1,
#  'Cafe Eve': 1,
#  'Cafe FortyOne': 1,
#  'Cafe Hashtag': 1,
#  'Cafe Il Nido': 1,
#  'Cafe Lokal': 1,
#  'Cafe Loyal': 1,
#  'Cafe Mai-Mai': 1,
#  'Cafe One': 1,
#  'Cafe Orso': 1,
#  'Cafe Perugia': 1,
#  'Cafe Phin and Pho': 1,
#  'Cafe Savoureux': 1,
#  'Cafe SoBahn': 1,
#  'Cafe Sweets & Beans': 1,
#  'Cafe Tica': 1,
#  'Cafe Villaggio': 1,
#  'Cafe Xu Hue': 1,
#  "Cafe de l'Orangerie": 1,
#  'Cafeoca': 1,
#  'Caffe Artigiano': 2,
#  'Caffe Barney': 2,
#  'Caffe Cittadella': 1,
#  'Caffe Di Beppe': 1,
#  'Caffe Divano': 1,
#  'Caffe La Tana': 1,
#  'Caffe Mira': 1,
#  'Caffe W': 1,
#  'Caffè Artigiano': 6,
#  'Caffé Divano': 1,
#  'Café At Mandeville': 1,
#  'Café By Tao': 1,
#  'Café Calabria': 1,
#  'Café Deux Soleils': 1,
#  'Café Gloucester': 1,
#  'Café Portrait': 1,
#  'Café Veneti': 1,
#  'Café Zen On Yew': 1,
#  'Cake Ya': 1,
#  'Calabash Bistro': 1,
#  'Calgary Sweets': 1,
#  'Cambie Bar & Grill': 1,
#  'Cambie Vietnam Restaurant': 1,
#  "Camy's Pizza": 2,
#  'Canadian 2 for 1 Pizza': 1,
#  'Canadian Pizza Plus': 1,
#  'Canan 2 For 1 Pizza': 1,
#  'Cannery Cafe': 1,
#  'Cantonese BBQ Restaurant': 1,
#  'Capilano Sushi': 1,
#  'Captain Wa': 1,
#  "Captain's Oven Pizza": 1,
#  'Caravan Authentic Cafe': 1,
#  'Cardero Cafe': 2,
#  "Cardero's Restaurant & Marine Pub": 1,
#  'Caritas 9 Coffee Roasters': 1,
#  "Carl's Jr": 2,
#  "Carlos O'Bryans Neighbourhood Pub": 1,
#  'Carls Jr': 1,
#  "Carmelo's": 1,
#  'Carnegie Centre': 1,
#  'Carp': 1,
#  'Cartel Taco': 1,
#  'Cartems Donuts': 1,
#  'Casa Dolce Coal Harbour': 1,
#  'Casa Dolce Gelato & Chocolate': 1,
#  'Casa Verde Restaurant': 1,
#  'Casa di Amici Restaurant': 1,
#  'Castaway Bar and Kitchen': 1,
#  'Cat & Fiddle Pub': 1,
#  'Catch 122': 1,
#  'Catch Kitchen + Bar': 1,
#  'Catfe': 1,
#  'Cathay Pacific VIP YVR Lounge': 1,
#  'Cattle Cafe': 1,
#  'Caveman Cafe': 1,
#  'Cavo Bar and Kitchen': 1,
#  'Cavu Kitchen Bar': 1,
#  'Cayenne Bistro & Grill': 1,
#  'Cazba': 2,
#  'Cazba Express': 1,
#  'Cazba Food Cart': 1,
#  'Celeshmet': 1,
#  "Celine's Fish and Chips": 1,
#  'Central City Shopping Centre': 1,
#  'Central City Taphouse': 1,
#  'Cha Ca Hoang Yen Deli': 1,
#  'Cha Dian Tea': 1,
#  "Chachi's Coquitlam Centre": 1,
#  "Chachi's Pacific": 1,
#  'Chad Thai': 1,
#  'Chada Thai Fine Cuisine': 1,
#  'Chaise Lounge Restaurant': 1,
#  'Chakra Indian Restaurant': 1,
#  'Cham Mani': 1,
#  'Chambar': 1,
#  "Chan's Garden": 1,
#  'Chance Cafe': 1,
#  'Chancho Tortilleria': 1,
#  'Chands': 1,
#  "Chang'An": 1,
#  'Chao Shou Wang': 1,
#  'Charisma Cafe & Dessert House': 1,
#  'Charlie Hamiltons Pub': 1,
#  "Charlie's Mexican Restaurant": 1,
#  'Charqui': 1,
#  'Chatime': 4,
#  'Chatime Richmond': 1,
#  'Chef Hung Taiwanese Beef Noodle': 5,
#  'Chef Liu Kitchen': 1,
#  'Chef Pin': 2,
#  'Chef Rong Noodle House': 1,
#  'Chef Tony': 2,
#  'Chef of Dumplings': 1,
#  "Chef's Playground Eatery": 1,
#  'Chengdu Noodle House': 1,
#  'Chengdu Spicy Restaurant': 1,
#  "Cherry's Food House": 1,
#  "Cherry's Tea & Icy Bar": 1,
#  'Chettinad Dosa King': 1,
#  'Chettinad Dosa Palace': 1,
#  "Cheung's Chiu Chow Restaurant": 1,
#  'Chew Restaurant': 1,
#  "Chewie's Chicken & Biscuits": 1,
#  'Chewies Steam & Oyster Bar - Coal Harbour': 1,
#  'Chewies Steam & Oyster Bar - Kits': 1,
#  'Chez Meme Baguette Bistro': 1,
#  'Chez Michel Restaurant': 1,
#  'Chi House': 1,
#  'Chi Noodle Bar': 1,
#  'Chi Vegan': 1,
#  'ChiMec Fried Chicken & Burger': 1,
#  'Chicago Subs': 1,
#  'Chicken World': 1,
#  'Chicko Chicken': 1,
#  'Chicko Chicken Korean Style': 1,
#  'Chickpea': 1,
#  'Chickpea Food Truck': 1,
#  'Chili Pepper House': 1,
#  'Chilli Lee': 1,
#  'China Lan Beef Noodle': 1,
#  'China Village Restaurant': 1,
#  'Chinatown': 1,
#  'Chinatown BBQ': 1,
#  'Chinese Sauerkraut Fish': 1,
#  'Chipotle Mexican Grill': 5,
#  'Chirpyhut Chicken': 1,
#  'Chit Chat Burger Bar': 1,
#  'Cho Sun BBQ Korean Restaurant': 1,
#  'Choices Markets': 1,
#  'ChongQing': 1,
#  'ChongQing Restaurant': 1,
#  'Chongqing': 1,
#  'Chongqing Noodle House': 1,
#  'Chongqing Qinma Hotpot': 1,
#  'Chongqing Restaurant': 1,
#  'Chop Steakhouse & Bar': 1,
#  'Chop n Toss': 2,
#  'Chopped Leaf Ironwood': 1,
#  'Chouchou Breton Crepes': 1,
#  'Chow Lucky Noodle Bar': 1,
#  "Christine's Cafe": 1,
#  'Chronic Tacos': 3,
#  'Chu Kiang Chinese Restaurant': 1,
#  'Chuan BBQ Restaurant': 1,
#  'Chuan Yue': 1,
#  'Chun Hing': 1,
#  'Chuncheon Dakgalbi': 1,
#  'Chung Chun': 1,
#  "Church's Chicken": 14,
#  'Chào Street Food': 1,
#  'Cibo Trattoria': 1,
#  'Cilantro and Jalapeño': 1,
#  'Cimona Cafe': 1,
#  'CinCin Ristorante + Bar': 1,
#  'Cinco De Mayo Mexican Grill': 1,
#  "Cindy's": 1,
#  'Cindys Palace': 1,
#  'Cinema Public House': 1,
#  "Cioffi's Meat Market & Deli": 1,
#  "Cioppino's Mediterranean Grill": 1,
#  'Circus Play Cafe': 1,
#  'City 1 Cafe': 1,
#  'Claypot Hot Pot & BBQ': 1,
#  'Clough Club': 1,
#  'Club Ilia': 1,
#  'Clubone Cafe': 1,
#  'Co Chau': 1,
#  'CoCo Fresh Tea & Juice': 2,
#  'CoM Vietnamese': 1,
#  'Coast Restaurant': 1,
#  'Cockney Kings Fish & Chips': 2,
#  'Coco Rico Cafe': 1,
#  'Coco et Olive Fine Foods & Cafe': 1,
#  'Cocoa West Chocolatier': 1,
#  'Cocoru': 1,
#  'Coffee + Vanilla': 1,
#  'Coffeebar': 1,
#  'Cold Tea Restaurant': 1,
#  'Colony Bar': 2,
#  'Colosseum Pizza': 1,
#  'Colour See See': 1,
#  'ColourSeeSee': 1,
#  'Columbia Street Sandwich': 1,
#  'Come Along Seafood Restaurant': 1,
#  'Come Arepa': 1,
#  'Comebuy': 1,
#  'Coming Home Cafe': 1,
#  'Commercial Street Cafe': 1,
#  'Commercial Sushi': 1,
#  'Como': 1,
#  'Congee Noodle Delight': 1,
#  'Congee Noodle House': 1,
#  'Congee Noodle King': 1,
#  'Connected Minds Cafe and Roastery': 1,
#  "Connie's Cook House": 1,
#  'Conte Food Importers': 1,
#  'Continental Coffee House': 1,
#  'Continental Seafood Restaurant': 1,
#  'Convivial Cafe and Bakery': 1,
#  'Cool Chinese Restaurant': 1,
#  'Copa Cafe': 2,
#  'Copper Branch': 1,
#  'Copper Chimney Indian Grill & Bar': 1,
#  'Coppertank Grill': 1,
#  'Cora': 2,
#  'Cora Breakfast & Lunch': 2,
#  'Cora Breakfast and Lunch': 1,
#  'Coral Court Szechuan Cuisine': 1,
#  'Corduroy': 1,
#  'Corduroy Pie Company': 1,
#  'Corner 23': 1,
#  'Corner Stone': 1,
#  'Cosy Inn Cafe': 1,
#  'Cottage Deli Soup and Sandwich': 1,
#  'Cotto Enoteca Pizzeria': 1,
#  'Country Meadows Golf Course': 1,
#  'Cove Sushi': 1,
#  'Covert Neighbourhood Cafe': 1,
#  'Cozmos Cafe + Bistro': 1,
#  'Crabtree & Evelyn': 1,
#  'Crackle Creme': 1,
#  'Craffles': 1,
#  'Craft & Cork Kitchen + Taphouse': 1,
#  'Crave India': 1,
#  'Cravings': 1,
#  'Creme De La Crumb': 1,
#  'Creme de la Crumb': 1,
#  'Creme de la Crumb Bakeshop & Catering': 2,
#  'Crepe & Cafe': 1,
#  'Crepe De Licious': 1,
#  'Crepe Delicious': 2,
#  'Crepe Escape': 1,
#  'Crispy': 1,
#  'Crispy Falafel': 1,
#  'Crystal Palace': 1,
#  'Crêpe Delicious': 1,
#  'Cuatro Coffee': 1,
#  'Cuchillo': 1,
#  'Cultured Coffee & Tea': 1,
#  'Cultures': 1,
#  'Culver City Salads': 1,
#  'Cup Full Dessert Cafe': 1,
#  'CuppaJoe Coffee Roasters': 1,
#  'Curry Bistro': 1,
#  'Curry Express': 3,
#  'Curry Fusion': 1,
#  'Curry House': 1,
#  'Curry Point': 1,
#  'Curry Way': 1,
#  'Curry and Kabab': 1,
#  'Curve Lounge': 1,
#  'Cypress Mountain Crazy Raven Bar and Grill': 1,
#  'D Original Sausage Haus': 1,
#  'D Roti Shak': 1,
#  "D'oro Gelato e Caffè": 1,
#  'D-Plus Pizza': 1,
#  'D/6 Bar & Lounge': 1,
#  'DD Mau': 1,
#  'DD Mau Chinatown': 1,
#  'DDDN Pizza': 1,
#  'DICED Discovery Cafe': 1,
#  'DQ / Orange Julius': 1,
#  'Daan Korean Cuisine': 1,
#  'Dachi': 1,
#  "Daddy's Grill": 1,
#  "Daddy's Kitchen": 1,
#  'Dae Bak Bon Ga': 1,
#  'Dae-Ji Cutlet House': 5,
#  'Dai Jang Kum Korean BBQ': 1,
#  'Dai Jang Kum Restaurant': 1,
#  'Dai Tung Chinese Restaurant': 1,
#  'Daikichi Sushi': 2,
#  'Dairy Queen': 9,
#  'Dairy Queen / Orange Julius': 2,
#  'Dairy Queen Grill & Chill': 15,
#  'Dairy Queen/Orange Julius Treat Ctr': 1,
#  'Daisy Sandwiches & Such': 1,
#  'Dalina': 2,
#  'Dallas Pizza & Souvlaki': 1,
#  "Damien's Belgian Waffle": 1,
#  'Damso': 2,
#  'Dang Anh Cafe': 1,
#  'Daniel Le Chocolat Belge': 1,
#  'Daniel le Chocolat Belge': 1,
#  "Danny's Wun Tun Restaurant": 1,
#  'Danoo Cafe': 1,
#  'Daon Korean Cuisine': 1,
#  "Darby's Gastown": 1,
#  "Darby's Pub": 1,
#  'Dark Table': 1,
#  'Datang BBQ Express': 1,
#  "Dave's Fish & Chips": 1,
#  'Davie Dosa Company': 1,
#  "Davood's Bistro": 1,
#  'Days Inn Downtown': 1,
#  'Days Thai Restaurant': 1,
#  'De Dutch': 8,
#  "Deacon's Corner": 2,
#  'Deep Cove Ice Cream Cafe': 1,
#  'Deep Cove Osaka Sushi': 1,
#  'Deep Cove Pizza': 1,
#  'Deepwater Micro Eatery': 1,
#  'Deer Garden Restaurant': 1,
#  'Deer Garden Signatures': 4,
#  'Deer Island Bakery': 1,
#  'Deer Lake Wonton House': 1,
#  'Deja Brew': 1,
#  "Delany's Coffee": 2,
#  'Delhi 6 Indian Bistro': 1,
#  'Delicious BBQ': 1,
#  'Delicious Pho': 2,
#  'Dell Lanes': 1,
#  'Delta Hotels by Marriott Vancouver Downtown Suites': 1,
#  'Delta Pizza': 1,
#  "Denny's": 8,
#  'Desi Bites': 1,
#  'Desi Dosa Madras': 1,
#  'Desi Turka Indian Cuisine': 1,
#  'Deutsches Haus': 1,
#  "Devil's Elbow Ale & Smoke House": 1,
#  'Dewan-E-Khass': 1,
#  'Dex Gourmet Burger Bar': 1,
#  'Dhaliwal Sweet & Restaurant': 1,
#  'Dharma Garden': 1,
#  'Dharma Garden Veggie Deli': 1,
#  'Dhoom Restaurant & Bar': 1,
#  'Di Beppe': 1,
#  'Di Reggae Cafe': 1,
#  'Diamond Resturant': 1,
#  "Did's Pizza": 1,
#  "Dijo's Pizza & Panzerotto": 1,
#  'Dijon Kitchen': 1,
#  'Dinakis Mediterranean Grill': 1,
#  'Dinesty Dumpling House': 3,
#  'Ding Hao Noodle House': 1,
#  'Dipped Doughnut': 1,
#  'Disco Cheetah': 2,
#  'Diva At the Met': 1,
#  'Dive In Dessert Cafe': 1,
#  "Dixie's BBQ": 1,
#  'Djjs Wedge Pizza & Pasta': 1,
#  'Do Chay': 1,
#  'Do Chay Saigon Vegetarian': 1,
#  "Doc Morgan's Pub & Restaurant": 1,
#  "Doc's Pizza": 1,
#  'Dock Lunch': 1,
#  'Dockside Restaurant': 1,
#  'Dodo sushi': 1,
#  'Dollar Meat Store': 1,
#  'Dolpan Seoul BBQ': 1,
#  'Dominion Bar + Kitchen': 1,
#  "Domino's": 1,
#  "Domino's Pizza": 19,
#  'Domo Sushi': 1,
#  "Don Chepe's Restaurant": 1,
#  'Don Francesco Ristorante': 1,
#  'Don Oso': 1,
#  'Donair Affair': 4,
#  'Donair Bite': 1,
#  'Donair Delight': 1,
#  'Donair Dude': 4,
#  'Donair Dude - Kitsilano': 1,
#  'Donair Dude Granville': 1,
#  'Donair King Restaurant': 1,
#  'Donair Land': 1,
#  'Donair Spot': 3,
#  'Donair Star': 1,
#  'Donair Town': 4,
#  'Donair Town Robson': 1,
#  'Donairville & Cafe': 1,
#  "Donegal's Irish House": 1,
#  'Dong Tai Xiang Shanghai Dim Sum': 1,
#  'DooBoo': 1,
#  'DooGauBee': 1,
#  'Doon Express Indian Cuisine': 1,
#  'Doppio Zero Pizza': 1,
#  'Dosa Corner': 1,
#  'Dosa Factory': 1,
#  'Dosa and Curry': 1,
#  'Dosanko': 1,
#  'Double DD Pizza': 1,
#  'Double Double Chinese Restaurant': 1,
#  'Double East Cuisine': 1,
#  'Double One Chinese Restaurant': 1,
#  'Douce Diner': 1,
#  'Doughgirls': 1,
#  'Downlow Chicken Shack': 1,
#  'Downtown Sushi Bar Japanese Restaurant': 1,
#  'Dragon Crepe': 1,
#  'Dragon Group Seafood Restaurant': 1,
#  'Dragon wok': 1,
#  'Dragonview Chinese Cuisine': 1,
#  'Dream Sushi': 1,
#  'Dublin Calling': 1,
#  'Dublin Crossing': 1,
#  "Duffin's Donuts": 1,
#  'Dumpling House': 1,
#  'Dunbar Pizza & Grill': 1,
#  'Dunbar Sushi': 1,
#  'Dundarave Sushi': 1,
#  'Dundas Eat + Drink': 1,
#  'Duotian Fish Soup Noodles Restaurant': 1,
#  "Duso's Italian Foods": 1,
#  "Dussa's Ham & Cheese": 1,
#  'Dutch Wooden Shoe Cafe': 1,
#  "Dylan's": 1,
#  'Dynasty Seafood Restaurant': 1,
#  'Döner Kebab': 1,
#  'Döner Stop': 1,
#  'E-Mo Restaurant': 1,
#  'EStEA Cafe 生活小品': 1,
#  'Earls Kitchen + Bar': 9,
#  'Earls Kitchen + Bar - Station Square': 1,
#  'East Is East': 1,
#  'East One Chinese Seafood Restaurant': 1,
#  'East Side Craft House': 1,
#  'East is East': 1,
#  'Eastern Pearl Seafood Restaurant': 1,
#  'Eat Chicken Wraps': 1,
#  'Eat! Vancouver': 1,
#  'Ebi-Ten': 1,
#  'Ebisu In Richmond': 1,
#  'Ebisu On Robson': 1,
#  'Ebisu on Broadway': 1,
#  'Echo Cafe': 1,
#  'Edge Catering': 1,
#  'Edible Flours': 1,
#  'Edo Japan': 1,
#  'Egg & Co': 1,
#  'Eggspectation': 1,
#  'Eh! Restaurant': 1,
#  'Eight 1/2 Restaurant Lounge': 1,
#  'Eighties Restaurant': 1,
#  'Einstein Wrap House': 1,
#  "El Camino's": 1,
#  'El Caracol Café': 1,
#  'El Comal': 1,
#  'El Furniture Warehouse - Granville': 1,
#  'El Furniture Warehouse - Hastings': 1,
#  'El Guapo': 1,
#  'El Inka Latin Deli': 1,
#  'El Santo': 1,
#  'Elephant Garden Creamery': 1,
#  'Elisa': 1,
#  'Elvis Pizza': 1,
#  'Elwoods': 1,
#  'Elysian Coffee': 2,
#  'Ember Indian Kitchen': 1,
#  "Emelle's Catering": 1,
#  'Empire Seafood Restaurant': 1,
#  'Encore Coffee & Tea': 1,
#  'Enigma Restaurant': 1,
#  'Enjoy Cafe 1 Plus1': 1,
#  "Enzo's Cafe": 1,
#  'Epic Grill Silogs': 1,
#  'España Restaurant': 1,
#  'Estea Cafe Metro Place': 1,
#  'Eternal Abundance': 1,
#  'Ethno Restaurant Vayat': 1,
#  'Euro Bagel Cafe': 1,
#  'Euro Café': 1,
#  'Euro Food Plus': 1,
#  'Europe Old Fashion Bakery & Deli': 1,
#  'European Breads': 1,
#  "Evelyn's Coffee Shop": 1,
#  'Everyday Sushi': 1,
#  'Excellent Dim Sum King Restaurant': 1,
#  'Excellent Tofu & Snacks': 1,
#  'Express Pho': 1,
#  'FRESH Sushi': 1,
#  'Fable': 1,
#  'Fable Diner': 1,
#  'Fairways Grill & Patio': 1,
#  'Falafel Cafe': 1,
#  'Falafel King': 1,
#  'Falafel King Restaurant': 1,
#  'Fami Pho': 1,
#  'Famoso Neapolitan Pizzeria': 2,
#  'Famous Famiglia Pizzeria': 1,
#  'Famous Wok': 1,
#  'Fanny Bay Oyster Bar & Shellfish Market': 1,
#  'Fantastico Pizza 2001': 1,
#  'Farina a Legna': 1,
#  'Fassil Ethiopian Restaurant': 1,
#  'Fat Mao Noodles': 1,
#  'Fat Tuna Sushi': 1,
#  'Fatburger': 9,
#  'Fatty Cow Seafood Hot Pot': 1,
#  'Faubourg': 1,
#  'Fayuca': 1,
#  'Feast': 1,
#  'Feastro': 2,
#  'Festal Paleo Cafe': 1,
#  'Fets Whisky Kitchen': 1,
#  'Field & Social': 1,
#  'Fife Bakery': 1,
#  'Figaro Cafe and Bakery': 1,
#  'Finch & Barley': 1,
#  "Finch's Market": 1,
#  "Finch's Tea & Coffee House": 1,
#  'Finest At Sea Seafood Boutique': 1,
#  'Fior di Latte': 1,
#  'Fiore Famiglia': 1,
#  'Fiore Restaurants': 1,
#  'Fire Pizza': 1,
#  'Firebird Cafe': 1,
#  'Firecrust': 1,
#  'Firefighters Public House': 1,
#  'First Choice': 1,
#  'Fish Café': 1,
#  "Fisherman's Terrace Seafood Restaurant": 1,
#  'Fishworks': 1,
#  'Fit For Life': 1,
#  'Fit for Life Restaurant': 1,
#  'Five Guys': 2,
#  'Five Guys Burgers & Fries': 1,
#  'Five Loaves Two Fish': 1,
#  'Five Sails Restaurant': 1,
#  'Flaming Wok': 1,
#  'Flamingo Chinese Restaurant': 1,
#  'Flavor Balance Espresso Bar': 1,
#  'Floata Seafood Restaurant': 1,
#  'Flourist': 1,
#  'Flower And Horse In Spring': 1,
#  'Flying Beaver Bar': 1,
#  'Flying Wedge Pizza': 2,
#  'Flying Wedge Pizza Company': 3,
#  "Fogg 'n' Suds Restaurant & Beer Bar": 1,
#  'Fok Po Tong': 1,
#  'Fondway': 1,
#  'Food Shanghai Ting': 1,
#  'Foodies On Board': 1,
#  'Footo Croissant': 1,
#  'Forage': 1,
#  'Fortuna Bakery': 1,
#  'Fortune City Seafood Restaurant': 1,
#  'Fortune Express': 1,
#  'Fortune Lamb Dining': 1,
#  'Fortune Terrace Chinese Cuisine': 1,
#  'Fortune Wok': 1,
#  'Four Bistro': 1,
#  'Four Olives': 1,
#  'Four Winds Brewing': 1,
#  ...}

# %%
#rest4 is here

# %%
rest4=df_1[df_1['name']=='Akari Japanese Restaurant']
rest4
# Out:
#                business_id                       name          address   city  \
# 22  rDLPdfI6TOsQlTf6AQaCTA  Akari Japanese Restaurant  7261 120 Street  Delta
#
#    state postal_code   latitude  longitude  stars  review_count  is_open  \
# 22    BC     V4C 6P5  49.134883 -122.89192    4.0            53        1
#
#                                            attributes  \
# 22  {'GoodForKids': 'True', 'HasTV': 'False', 'Cat...
#
#                                          categories  \
# 22  Asian Fusion, Japanese, Sushi Bars, Restaurants
#
#                                                 hours
# 22  {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...

# %%
rest4.categories
# Out:
# 22    Asian Fusion, Japanese, Sushi Bars, Restaurants
# Name: categories, dtype: object

# %%
# rest4_cat=['Japanese','Sushi Bars']

# %%
# rest4_cat_df=pd.DataFrame(rest4_cat)
# rest4_cat_df

# %%
# df_1['categories']

# %%
rest4_comp = df_1[df_1['categories'].str.contains('Sushi')]

rest4_comp
# Out:
#                  business_id                         name  \
# 7     XqaO85CV9Km7m_aQ3iIpRA             Cactus Club Cafe
# 16    7lRIEq5_tBBR1T9d_vTDvQ                  Yoko Sushi
# 17    mvCO6pRpfMB0_1GLlwgZRw             Sushi California
# 22    rDLPdfI6TOsQlTf6AQaCTA    Akari Japanese Restaurant
# 32    _aGG6e3dWYrKyFNpdK_vpA  Sushi Maki Japanese Cuisine
# ...                      ...                          ...
# 4671  vnOhpYbHv7PZXD1iwKytXg               Everyday Sushi
# 4682  tm7wfsNwucLsDhXnknmyCw          Aero Inn Sushi Cafe
# 4686  wF5gy4a0pBAA5QTQ_ceOWQ               Hanamori Sushi
# 4718  HRmLSZKvoER_UhqObL5zng                     Tomokazu
# 4725  jrW5mnMLDp2BeGZh8A6VFg                  Sushi Ninja
#
#                        address       city state postal_code   latitude  \
# 7      1666-6551 Number 3 Road   Richmond    BC     V6Y 2B6  49.166831
# 16          1001 Austin Avenue  Coquitlam    BC     V3K 3N9  49.249298
# 17              388 W Broadway  Vancouver    BC     V5Y 4A8  49.263045
# 22             7261 120 Street      Delta    BC     V4C 6P5  49.134883
# 32           989 Hornby Street  Vancouver    BC     V6Z 1V3  49.280754
# ...                        ...        ...   ...         ...        ...
# 4671         4572W 10 Avenue W  Vancouver    BC     V6R 2J1  49.263702
# 4682       5455 Airport Road S   Richmond    BC     V7B 1B5  49.180640
# 4686  102-511 Rochester Avenue  Coquitlam    BC     V3K 0A2  49.246166
# 4718           1128 W Broadway  Vancouver    BC     V6H 1G5  49.263243
# 4725        1861 Commercial Dr  Vancouver    BC     V5N 4A6  49.267992
#
#        longitude  stars  review_count  is_open  \
# 7    -123.137747    3.5           123        1
# 16   -122.867573    4.0            17        1
# 17   -123.112614    3.5           280        1
# 22   -122.891920    4.0            53        1
# 32   -123.124907    3.0            37        1
# ...          ...    ...           ...      ...
# 4671 -123.211343    3.0            25        1
# 4682 -123.158027    3.0             8        1
# 4686 -122.890755    4.0            87        1
# 4718 -123.129745    3.0           175        1
# 4725 -123.069849    3.5            10        1
#
#                                              attributes  \
# 7     {'HappyHour': 'True', 'Caters': 'False', 'HasT...
# 16    {'RestaurantsDelivery': 'True', 'RestaurantsRe...
# 17    {'RestaurantsTakeOut': 'True', 'Alcohol': "u'b...
# 22    {'GoodForKids': 'True', 'HasTV': 'False', 'Cat...
# 32    {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# ...                                                 ...
# 4671  {'RestaurantsTakeOut': 'True', 'WiFi': "u'no'"...
# 4682  {'RestaurantsPriceRange2': '1', 'RestaurantsTa...
# 4686  {'WiFi': "'free'", 'NoiseLevel': "u'average'",...
# 4718  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 4725  {'RestaurantsDelivery': 'True', 'HasTV': 'True...
#
#                                              categories  \
# 7     Canadian (New), Cocktail Bars, Bars, Nightlife...
# 16                    Sushi Bars, Japanese, Restaurants
# 17                    Japanese, Restaurants, Sushi Bars
# 22      Asian Fusion, Japanese, Sushi Bars, Restaurants
# 32                    Restaurants, Japanese, Sushi Bars
# ...                                                 ...
# 4671                            Restaurants, Sushi Bars
# 4682                            Sushi Bars, Restaurants
# 4686    Sushi Bars, Asian Fusion, Japanese, Restaurants
# 4718                  Japanese, Restaurants, Sushi Bars
# 4725                            Restaurants, Sushi Bars
#
#                                                   hours
# 7     {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 16    {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 17    {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...
# 22    {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...
# 32    {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# ...                                                 ...
# 4671  {'Monday': '10:30-21:30', 'Tuesday': '11:0-21:...
# 4682  {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...
# 4686  {'Monday': '0:0-0:0', 'Tuesday': '11:30-21:30'...
# 4718  {'Monday': '17:0-0:0', 'Tuesday': '17:0-0:0', ...
# 4725  {'Wednesday': '11:30-21:30', 'Thursday': '11:3...
#
# [401 rows x 14 columns]

# %%
rest4_comp_filter=rest4_comp[rest4_comp['stars'] >= 4]
rest4_comp_filter
# Out:
#                  business_id                       name  \
# 16    7lRIEq5_tBBR1T9d_vTDvQ                Yoko Sushi
# 22    rDLPdfI6TOsQlTf6AQaCTA  Akari Japanese Restaurant
# 84    t6eEIUaZK97tEejpDNa4cw                Sushi Karis
# 160   jrVEB7FPeD7zeLdYfmnwVg   Kuma Japanese Restaurant
# 166   szPJyzsly0a5ZkehLAV1fA                  Pokérrito
# ...                      ...                        ...
# 4625  uZGQy70xpYkUzQxTpKoXaA        Yui Japanese Bistro
# 4631  S6QRnCQVpEqQRyszrF51bw           Ajisai Sushi Bar
# 4641  CjQMcgDgX_RdpSNby266oA            Tsuki Sushi Bar
# 4652  6k1omPa3O3Kl7lSjXfCxvA             Octopus Garden
# 4686  wF5gy4a0pBAA5QTQ_ceOWQ             Hanamori Sushi
#
#                         address       city state postal_code   latitude  \
# 16           1001 Austin Avenue  Coquitlam    BC     V3K 3N9  49.249298
# 22              7261 120 Street      Delta    BC     V4C 6P5  49.134883
# 84            504 Nelson Street  Coquitlam    BC     V3J 7R4  49.249346
# 160          3446 Dunbar Street  Vancouver    BC     V6S 2C3  49.255975
# 166         558 Dunsmuir Street  Vancouver    BC     V6B 1Y1  49.282642
# ...                         ...        ...   ...         ...        ...
# 4625  102-1185 W Georgia Street  Vancouver    BC     V6E 4E6  49.287111
# 4631         2081 W 42nd Avenue  Vancouver    BC     V6M 2B4  49.233934
# 4641          509 Abbott Street  Vancouver    BC     V6B 6N7  49.280983
# 4652       1995 Cornwall Avenue  Vancouver    BC     V6J 1C9  49.272630
# 4686   102-511 Rochester Avenue  Coquitlam    BC     V3K 0A2  49.246166
#
#        longitude  stars  review_count  is_open  \
# 16   -122.867573    4.0            17        1
# 22   -122.891920    4.0            53        1
# 84   -122.865829    4.5            39        1
# 160  -123.184964    4.0            55        1
# 166  -123.115118    4.0           182        1
# ...          ...    ...           ...      ...
# 4625 -123.124702    4.0           123        1
# 4631 -123.153690    4.0           380        1
# 4641 -123.107658    4.0           173        1
# 4652 -123.149817    4.0           139        1
# 4686 -122.890755    4.0            87        1
#
#                                              attributes  \
# 16    {'RestaurantsDelivery': 'True', 'RestaurantsRe...
# 22    {'GoodForKids': 'True', 'HasTV': 'False', 'Cat...
# 84    {'Ambience': "{'romantic': False, 'intimate': ...
# 160   {'Alcohol': "u'beer_and_wine'", 'RestaurantsPr...
# 166   {'RestaurantsTableService': 'False', 'WiFi': "...
# ...                                                 ...
# 4625  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 4631  {'RestaurantsGoodForGroups': 'False', 'Restaur...
# 4641  {'BusinessParking': "{'garage': False, 'street...
# 4652  {'RestaurantsPriceRange2': '3', 'BikeParking':...
# 4686  {'WiFi': "'free'", 'NoiseLevel': "u'average'",...
#
#                                              categories  \
# 16                    Sushi Bars, Japanese, Restaurants
# 22      Asian Fusion, Japanese, Sushi Bars, Restaurants
# 84                    Restaurants, Japanese, Sushi Bars
# 160                   Sushi Bars, Restaurants, Japanese
# 166   Food, Sushi Bars, Poke, Japanese, Restaurants,...
# ...                                                 ...
# 4625         Bistros, Sushi Bars, Restaurants, Japanese
# 4631   Sushi Bars, Japanese, Food, Restaurants, Butcher
# 4641                  Restaurants, Japanese, Sushi Bars
# 4652                  Restaurants, Japanese, Sushi Bars
# 4686    Sushi Bars, Asian Fusion, Japanese, Restaurants
#
#                                                   hours
# 16    {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 22    {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...
# 84    {'Monday': '11:30-21:0', 'Tuesday': '11:30-21:...
# 160   {'Monday': '16:0-21:0', 'Wednesday': '16:0-21:...
# 166   {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:0', ...
# ...                                                 ...
# 4625  {'Monday': '11:0-18:0', 'Tuesday': '11:0-18:0'...
# 4631  {'Monday': '0:0-0:0', 'Tuesday': '11:0-19:30',...
# 4641  {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...
# 4652  {'Monday': '17:0-21:0', 'Thursday': '17:0-21:0...
# 4686  {'Monday': '0:0-0:0', 'Tuesday': '11:30-21:30'...
#
# [142 rows x 14 columns]

# %%
rest4_comp_filter=rest4_comp_filter[rest4_comp_filter['review_count'] >= 100]
rest4_comp_filter
# Out:
#                  business_id                             name  \
# 166   szPJyzsly0a5ZkehLAV1fA                        Pokérrito
# 307   G3jAGk0OUS_hkrsD4ERevA            Sushimoto Enterprises
# 369   9UThLJTuOQPLcDCLx5BVqw                    Sushi By Yuji
# 376   j7VmHg9M-eWZuDw-p4AIaA         Seto Japanese Restaurant
# 455   irdrKokOvuxP_atEjtzkQA                 Green Leaf Sushi
# 500   NBiBIk83cYjWnFS8QTJWyg                      Kaide Sushi
# 665   gpTJqlxw4_bI_7K_R_Fw4w            Fujiya Japanese Foods
# 991   iMtUsHOqitE6Aau59K_XRg                        Sushi Jin
# 1136  e30bAA7PQfbbvZOc5LLuvA                  Kimbap Cheonguk
# 1355  UqqkI-YNmfpng4BKj8kxcg  Sushi Hachi Japanese Restaurant
# 1450  FmD4x9ClmSzSLKOTV7jfXw  Hitoe Sushi Japanese Restaurant
# 1531  o5YLdmUogknjtDzUBv5Smw                        Tom Sushi
# 1541  pJNRkDPA_2wLv_0Bj6fzww                 Sushi K Kamizato
# 1724  Cw-_dU8r4A_Z9nsCIigibA            Tatsu Japanese Bistro
# 1871  OULhS4WGI_mh5gRGLZBySg                     Temaki Sushi
# 1900  HIJlNqu7VKYAxFApilHg6w                            Shiro
# 1939  z7aqQzhbnuoAXtFQslDsWQ   Sushi Uomo Japanese Restaurant
# 1956  gt1BSfVFvzI-qHdJ3LUZug                  Blue Water Cafe
# 2038  4EV_ZcQmjAmP3pmO-_nb2A                             Miku
# 2290  7_qZrRi_zs2GbnxmEAAVmQ                  Sushi Bar Maumi
# 2301  umv8zQBbJ5GgRT0qVHIpCg                            Suika
# 2578  p8lxRgWWIFhWuecUwWFVOg                      FRESH Sushi
# 2622  as2xQt48ltKKDUQbMCBrMw                        Shizen Ya
# 2720  cD-yIXTipTTN336R5c_MMg                      Toshi Sushi
# 2728  i7nUiW7bxJXV0XS7R-RahQ                  Green Leaf Cafe
# 2883  34Fq-2nCOFN3gHPZLCqqJQ            Kimu Japanese Cuisine
# 3152  gV9lrbWr1CE1Jl0E58UO2g                           Minami
# 3461  I0r8kMimYW2BY6lINcZRFA       Kishimoto Japanese Kitchen
# 3527  Ad3_MdkP35Ku17OC1ovnTg                      Sushi Mania
# 3602  qebPYEXBp8Zo_d7GY50i2w                   Westcoast Poke
# 3641  EGp24Ifh3dltG5tEcJrJqA              Bishop's Restaurant
# 4123  sz2eLUlDS6H0ict-qeyLHg                        Sushi Hub
# 4303  Rr6dOSMzTg6SQHEimeQt6Q                   Victoria Sushi
# 4330  TQj4HSCmm5GnriKMiSpqpQ                            Raisu
# 4409  VcaNoLa56gpBWPxufnTw4w             Shizenya on Broadway
# 4421  u3D-3lorbz_vUifEqQdJOg                      Isami Sushi
# 4555  8HH7xRjmjwzkhADZWir_Cw               Black Rice Izakaya
# 4625  uZGQy70xpYkUzQxTpKoXaA              Yui Japanese Bistro
# 4631  S6QRnCQVpEqQRyszrF51bw                 Ajisai Sushi Bar
# 4641  CjQMcgDgX_RdpSNby266oA                  Tsuki Sushi Bar
# 4652  6k1omPa3O3Kl7lSjXfCxvA                   Octopus Garden
#
#                                            address             city state  \
# 166                            558 Dunsmuir Street        Vancouver    BC
# 307                    2201 Holdom Avenue, Ste 102          Burnaby    BC
# 369                                  2252 Kingsway        Vancouver    BC
# 376                 8460 Alexandra Road, Suite 155         Richmond    BC
# 455                                3416 W Broadway        Vancouver    BC
# 500                           1375 Richards Street        Vancouver    BC
# 665                                912 Clark Drive        Vancouver    BC
# 991                              750 Nelson Street        Vancouver    BC
# 1136                              341 North Road A        Coquitlam    BC
# 1355               8888 Odlin Crescent, Suite 1278         Richmond    BC
# 1450                             3347 W 4th Avenue        Vancouver    BC
# 1531                                 1175 Davie St        Vancouver    BC
# 1541                2105 - 2850 Shaughnessy Street   Port Coquitlam    BC
# 1724                         1441 Commercial Drive        Vancouver    BC
# 1871                      2156 W Broadway, Suite 2        Vancouver    BC
# 1900                            3096 Cambie Street        Vancouver    BC
# 1939                          4280 Hastings Street          Burnaby    BC
# 1956                              1095 Hamilton St        Vancouver    BC
# 2038                200 Granville Street, Suite 70        Vancouver    BC
# 2290                                  1226 Bute St        Vancouver    BC
# 2301                               1626 W Broadway        Vancouver    BC
# 2578                            909 Expo Boulevard        Vancouver    BC
# 2622                             965 Hornby Street        Vancouver    BC
# 2720                          181 East 16th Avenue        Vancouver    BC
# 2728                           9604 Cameron Street          Burnaby    BC
# 2883                            4441 Boundary Road        Vancouver    BC
# 3152                          1118 Mainland Street        Vancouver    BC
# 3461                         2054 Commercial Drive        Vancouver    BC
# 3527                      3851 Main Street, Unit 1        Vancouver    BC
# 3602                              463 W 8th Avenue        Vancouver    BC
# 3641                             2183 W 4th Avenue        Vancouver    BC
# 4123                              4855 Main Street        Vancouver    BC
# 4303                   15 Royal Avenue E, Suite 10  New Westminster    BC
# 4330                             2340 W 4th Avenue        Vancouver    BC
# 4409                      1333 W Broadway, Ste 160        Vancouver    BC
# 4421  6-4603 Kingsway Street, Metropointe Building          Burnaby    BC
# 4555                             782 Cambie Street        Vancouver    BC
# 4625                     102-1185 W Georgia Street        Vancouver    BC
# 4631                            2081 W 42nd Avenue        Vancouver    BC
# 4641                             509 Abbott Street        Vancouver    BC
# 4652                          1995 Cornwall Avenue        Vancouver    BC
#
#      postal_code   latitude   longitude  stars  review_count  is_open  \
# 166      V6B 1Y1  49.282642 -123.115118    4.0           182        1
# 307      V5B 0A2  49.264259 -122.981803    4.0           116        1
# 369      V5N 2T7  49.242483 -123.059835    4.0           127        1
# 376      V6X 3L4  49.177587 -123.129710    4.0           101        1
# 455      V6R 2B3  49.264268 -123.180100    4.0           355        1
# 500      V6B 3G7  49.274238 -123.127095    4.5           225        1
# 665      V5L 3J8  49.276554 -123.076880    4.0           116        1
# 991      V6Z 1A8  49.279579 -123.123818    4.5           124        1
# 1136     V3K 3V8  49.244698 -122.891831    4.5           103        1
# 1355     V6X 3Z8  49.183988 -123.126650    4.5           108        1
# 1450     V6R 1N6  49.268654 -123.178708    4.0           162        1
# 1531     V6E 1N2  49.281650 -123.132662    5.0           103        1
# 1541     V3C 6K5  49.254224 -122.783238    4.0           106        1
# 1724     V5L 3X8  49.271623 -123.069889    4.0           160        1
# 1871     V6K 2C8  49.263919 -123.154395    4.0           131        1
# 1900     V5Z 2V9  49.257930 -123.114617    4.0           238        1
# 1939     V5C 2J6  49.280950 -123.009199    4.0           137        1
# 1956     V6B 5T4  49.276155 -123.121129    4.5           911        1
# 2038     V6C 1S4  49.287008 -123.113051    4.5          1805        1
# 2290     V6E 1Z8  49.281408 -123.133696    4.0           155        1
# 2301     V6J 1X6  49.263410 -123.141690    4.0           437        1
# 2578     V6Z 3G8  49.275706 -123.115138    4.0           114        1
# 2622     V6Z 1V3  49.280884 -123.124628    4.0           550        1
# 2720     V5T 4R2  49.256699 -123.101936    4.0           410        1
# 2728     V3J 1M2  49.253277 -122.898401    4.0           183        1
# 2883     V5R 2N3  49.244919 -123.024194    4.0           125        1
# 3152     V6B 2T9  49.275266 -123.120816    4.0           647        1
# 3461     V5N 4A9  49.266736 -123.069411    4.5           469        1
# 3527     V5V 3P1  49.250538 -123.101180    4.0           160        1
# 3602     V5Y 3Z5  49.264087 -123.113864    4.0           152        1
# 3641     V6K 1N7  49.268324 -123.154703    4.5           111        1
# 4123     V5V 3R9  49.241181 -123.101670    4.0           117        1
# 4303     V3L 0A9  49.213378 -122.898880    4.0           137        1
# 4330     V6K 1P1  49.267999 -123.158381    4.0           303        1
# 4409     V6H 1G5  49.263875 -123.134264    4.0           134        1
# 4421     V5H 4M4  49.229657 -123.002154    4.0           100        1
# 4555     V6B 2R5  49.278444 -123.114329    4.0           238        1
# 4625     V6E 4E6  49.287111 -123.124702    4.0           123        1
# 4631     V6M 2B4  49.233934 -123.153690    4.0           380        1
# 4641     V6B 6N7  49.280983 -123.107658    4.0           173        1
# 4652     V6J 1C9  49.272630 -123.149817    4.0           139        1
#
#                                              attributes  \
# 166   {'RestaurantsTableService': 'False', 'WiFi': "...
# 307   {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 369   {'Ambience': "{'romantic': False, 'intimate': ...
# 376   {'RestaurantsDelivery': 'False', 'RestaurantsT...
# 455   {'BikeParking': 'True', 'RestaurantsReservatio...
# 500   {'WiFi': "'no'", 'Caters': 'False', 'Restauran...
# 665   {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 991   {'BusinessParking': "{'garage': False, 'street...
# 1136  {'RestaurantsReservations': 'False', 'GoodForK...
# 1355  {'BikeParking': 'True', 'RestaurantsReservatio...
# 1450  {'RestaurantsPriceRange2': '2', 'GoodForKids':...
# 1531  {'RestaurantsPriceRange2': '2', 'RestaurantsTa...
# 1541  {'RestaurantsDelivery': 'False', 'WiFi': "u'no...
# 1724  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 1871  {'RestaurantsTakeOut': 'True', 'Caters': 'True...
# 1900  {'RestaurantsAttire': "u'casual'", 'BikeParkin...
# 1939  {'WheelchairAccessible': 'True', 'BikeParking'...
# 1956  {'Ambience': "{'touristy': False, 'hipster': F...
# 2038  {'RestaurantsAttire': "'casual'", 'BikeParking...
# 2290  {'DogsAllowed': 'False', 'BikeParking': 'False...
# 2301  {'BusinessParking': "{'garage': False, 'street...
# 2578  {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 2622  {'RestaurantsReservations': 'True', 'Restauran...
# 2720  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 2728  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# 2883  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 3152  {'RestaurantsGoodForGroups': 'True', 'BikePark...
# 3461  {'HasTV': 'False', 'WiFi': "u'no'", 'Alcohol':...
# 3527  {'Alcohol': "u'none'", 'GoodForKids': 'True', ...
# 3602  {'BikeParking': 'True', 'NoiseLevel': "u'avera...
# 3641  {'BusinessParking': "{'garage': False, 'street...
# 4123  {'Alcohol': "u'none'", 'NoiseLevel': "u'quiet'...
# 4303  {'RestaurantsReservations': 'True', 'GoodForKi...
# 4330  {'BikeParking': 'True', 'RestaurantsPriceRange...
# 4409  {'Alcohol': "u'beer_and_wine'", 'WiFi': "u'no'...
# 4421  {'NoiseLevel': "u'average'", 'RestaurantsPrice...
# 4555  {'WiFi': "u'free'", 'RestaurantsPriceRange2': ...
# 4625  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 4631  {'RestaurantsGoodForGroups': 'False', 'Restaur...
# 4641  {'BusinessParking': "{'garage': False, 'street...
# 4652  {'RestaurantsPriceRange2': '3', 'BikeParking':...
#
#                                              categories  \
# 166   Food, Sushi Bars, Poke, Japanese, Restaurants,...
# 307                   Japanese, Sushi Bars, Restaurants
# 369                   Restaurants, Sushi Bars, Japanese
# 376                   Japanese, Sushi Bars, Restaurants
# 455                   Restaurants, Japanese, Sushi Bars
# 500                             Sushi Bars, Restaurants
# 665   Seafood Markets, Restaurants, Sushi Bars, Inte...
# 991                   Sushi Bars, Japanese, Restaurants
# 1136           Noodles, Sushi Bars, Korean, Restaurants
# 1355                  Sushi Bars, Restaurants, Japanese
# 1450     Restaurants, Japanese, Sushi Bars, Gluten-Free
# 1531                  Japanese, Restaurants, Sushi Bars
# 1541  Restaurants, Sushi Bars, Canadian (New), Japanese
# 1724                  Sushi Bars, Japanese, Restaurants
# 1871                  Japanese, Sushi Bars, Restaurants
# 1900                  Japanese, Restaurants, Sushi Bars
# 1939                  Japanese, Sushi Bars, Restaurants
# 1956  Live/Raw Food, Restaurants, Steakhouses, Sushi...
# 2038                  Japanese, Sushi Bars, Restaurants
# 2290                  Sushi Bars, Japanese, Restaurants
# 2301  Restaurants, Tapas/Small Plates, Sushi Bars, J...
# 2578  Sushi Bars, Asian Fusion, Japanese, Restaurant...
# 2622  Bars, Vegetarian, Restaurants, Nightlife, Japa...
# 2720                  Sushi Bars, Restaurants, Japanese
# 2728  Restaurants, Asian Fusion, Japanese, Sushi Bar...
# 2883                  Japanese, Sushi Bars, Restaurants
# 3152                  Japanese, Sushi Bars, Restaurants
# 3461                  Restaurants, Sushi Bars, Japanese
# 3527                  Restaurants, Japanese, Sushi Bars
# 3602  Food, Poke, Hawaiian, Restaurants, Sushi Bars,...
# 3641  American (New), Sushi Bars, Seafood, Vegetaria...
# 4123                  Sushi Bars, Restaurants, Japanese
# 4303                  Restaurants, Japanese, Sushi Bars
# 4330           Vegan, Sushi Bars, Japanese, Restaurants
# 4409      Japanese, Sushi Bars, Vegetarian, Restaurants
# 4421                  Sushi Bars, Restaurants, Japanese
# 4555  Tapas Bars, Restaurants, Tapas/Small Plates, J...
# 4625         Bistros, Sushi Bars, Restaurants, Japanese
# 4631   Sushi Bars, Japanese, Food, Restaurants, Butcher
# 4641                  Restaurants, Japanese, Sushi Bars
# 4652                  Restaurants, Japanese, Sushi Bars
#
#                                                   hours
# 166   {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:0', ...
# 307   {'Monday': '16:30-21:30', 'Tuesday': '16:30-21...
# 369   {'Tuesday': '17:30-21:30', 'Wednesday': '17:0-...
# 376   {'Monday': '17:30-21:15', 'Wednesday': '17:30-...
# 455   {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 500   {'Monday': '0:0-0:0', 'Tuesday': '12:0-20:0', ...
# 665   {'Monday': '0:0-0:0', 'Tuesday': '9:30-20:0', ...
# 991   {'Monday': '0:0-0:0', 'Wednesday': '17:0-23:0'...
# 1136  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 1355   {'Friday': '16:0-19:0', 'Saturday': '16:0-19:0'}
# 1450  {'Monday': '17:0-21:0', 'Tuesday': '17:0-20:30...
# 1531  {'Monday': '11:30-17:30', 'Tuesday': '12:0-21:...
# 1541  {'Wednesday': '17:0-21:30', 'Thursday': '17:0-...
# 1724  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 1871  {'Monday': '0:0-0:0', 'Tuesday': '17:0-22:0', ...
# 1900  {'Monday': '16:0-21:30', 'Tuesday': '16:0-21:3...
# 1939  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 1956  {'Monday': '0:0-0:0', 'Tuesday': '16:30-22:30'...
# 2038  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 2290  {'Monday': '0:0-0:0', 'Tuesday': '18:0-18:30',...
# 2301  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 2578  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 2622  {'Monday': '11:30-21:0', 'Tuesday': '11:30-21:...
# 2720  {'Tuesday': '16:0-20:0', 'Wednesday': '16:0-20...
# 2728  {'Monday': '11:30-22:0', 'Wednesday': '11:30-2...
# 2883  {'Monday': '11:30-21:0', 'Tuesday': '11:30-21:...
# 3152  {'Monday': '0:0-0:0', 'Tuesday': '11:30-21:0',...
# 3461  {'Monday': '0:0-0:0', 'Tuesday': '17:0-21:45',...
# 3527  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-2...
# 3602  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 3641  {'Tuesday': '17:30-23:0', 'Wednesday': '17:30-...
# 4123  {'Monday': '0:0-0:0', 'Wednesday': '11:30-20:3...
# 4303  {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...
# 4330  {'Monday': '11:30-21:0', 'Tuesday': '11:30-21:...
# 4409  {'Monday': '11:30-21:0', 'Tuesday': '11:30-21:...
# 4421  {'Tuesday': '17:30-22:0', 'Wednesday': '17:30-...
# 4555  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 4625  {'Monday': '11:0-18:0', 'Tuesday': '11:0-18:0'...
# 4631  {'Monday': '0:0-0:0', 'Tuesday': '11:0-19:30',...
# 4641  {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...
# 4652  {'Monday': '17:0-21:0', 'Thursday': '17:0-21:0...

# %%
rest4
# Out:
#                business_id                       name          address   city  \
# 22  rDLPdfI6TOsQlTf6AQaCTA  Akari Japanese Restaurant  7261 120 Street  Delta
#
#    state postal_code   latitude  longitude  stars  review_count  is_open  \
# 22    BC     V4C 6P5  49.134883 -122.89192    4.0            53        1
#
#                                            attributes  \
# 22  {'GoodForKids': 'True', 'HasTV': 'False', 'Cat...
#
#                                          categories  \
# 22  Asian Fusion, Japanese, Sushi Bars, Restaurants
#
#                                                 hours
# 22  {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...

# %%
rest4_comp_filter = rest4_comp_filter[rest4_comp_filter['name'].str.contains("Akari Japanese Restaurant")== False]
rest4_coords=rest4_comp_filter[['name','stars','latitude','longitude']]

# %%
rest4_coords
# Out:
#                                  name  stars   latitude   longitude
# 166                         Pokérrito    4.0  49.282642 -123.115118
# 307             Sushimoto Enterprises    4.0  49.264259 -122.981803
# 369                     Sushi By Yuji    4.0  49.242483 -123.059835
# 376          Seto Japanese Restaurant    4.0  49.177587 -123.129710
# 455                  Green Leaf Sushi    4.0  49.264268 -123.180100
# 500                       Kaide Sushi    4.5  49.274238 -123.127095
# 665             Fujiya Japanese Foods    4.0  49.276554 -123.076880
# 991                         Sushi Jin    4.5  49.279579 -123.123818
# 1136                  Kimbap Cheonguk    4.5  49.244698 -122.891831
# 1355  Sushi Hachi Japanese Restaurant    4.5  49.183988 -123.126650
# 1450  Hitoe Sushi Japanese Restaurant    4.0  49.268654 -123.178708
# 1531                        Tom Sushi    5.0  49.281650 -123.132662
# 1541                 Sushi K Kamizato    4.0  49.254224 -122.783238
# 1724            Tatsu Japanese Bistro    4.0  49.271623 -123.069889
# 1871                     Temaki Sushi    4.0  49.263919 -123.154395
# 1900                            Shiro    4.0  49.257930 -123.114617
# 1939   Sushi Uomo Japanese Restaurant    4.0  49.280950 -123.009199
# 1956                  Blue Water Cafe    4.5  49.276155 -123.121129
# 2038                             Miku    4.5  49.287008 -123.113051
# 2290                  Sushi Bar Maumi    4.0  49.281408 -123.133696
# 2301                            Suika    4.0  49.263410 -123.141690
# 2578                      FRESH Sushi    4.0  49.275706 -123.115138
# 2622                        Shizen Ya    4.0  49.280884 -123.124628
# 2720                      Toshi Sushi    4.0  49.256699 -123.101936
# 2728                  Green Leaf Cafe    4.0  49.253277 -122.898401
# 2883            Kimu Japanese Cuisine    4.0  49.244919 -123.024194
# 3152                           Minami    4.0  49.275266 -123.120816
# 3461       Kishimoto Japanese Kitchen    4.5  49.266736 -123.069411
# 3527                      Sushi Mania    4.0  49.250538 -123.101180
# 3602                   Westcoast Poke    4.0  49.264087 -123.113864
# 3641              Bishop's Restaurant    4.5  49.268324 -123.154703
# 4123                        Sushi Hub    4.0  49.241181 -123.101670
# 4303                   Victoria Sushi    4.0  49.213378 -122.898880
# 4330                            Raisu    4.0  49.267999 -123.158381
# 4409             Shizenya on Broadway    4.0  49.263875 -123.134264
# 4421                      Isami Sushi    4.0  49.229657 -123.002154
# 4555               Black Rice Izakaya    4.0  49.278444 -123.114329
# 4625              Yui Japanese Bistro    4.0  49.287111 -123.124702
# 4631                 Ajisai Sushi Bar    4.0  49.233934 -123.153690
# 4641                  Tsuki Sushi Bar    4.0  49.280983 -123.107658
# 4652                   Octopus Garden    4.0  49.272630 -123.149817

# %%
rest4_coords.to_csv('rest4.csv')

# %%
rest4_og_coords=rest4[['name','stars','latitude','longitude']]

# %%
rest4_og_coords.to_csv('rest4og.csv')

# %%
#rest3 starts here

# %%
rest3=df_1[df_1['name']=='Cactus Club Cafe']

# %%
rest3
# Out:
#                  business_id              name                  address  \
# 7     XqaO85CV9Km7m_aQ3iIpRA  Cactus Club Cafe  1666-6551 Number 3 Road
# 40    u-tcnG8zdDG8QWYTctxyfg  Cactus Club Cafe           575 Broadway W
# 365   YA2nxYti0P5RRtZpN3S4MQ  Cactus Club Cafe       1136 Robson Street
# 557   jKO4Og6ucdX2-YCTKQVYjg  Cactus Club Cafe        1085 Canada Place
# 724   sMGcNtd1iNi5IZk2sNhXLQ  Cactus Club Cafe    1598 Pemberton Avenue
# 1140  f7Sr6NKUtQYCZZSvYiNvtA  Cactus Club Cafe         357 Davie Street
# 2633  TLBh17U7A4zmVxSJc4Ci7A  Cactus Club Cafe          855 Main Street
# 2733  wzbOW1qG47ut4les3La0Ag  Cactus Club Cafe     7320 Market Crossing
# 2997  7MTK1nzefMtcsz8eM2XYdg  Cactus Club Cafe        1790 Beach Avenue
# 3005  TfPQNp3P-ElvHLds1t9zYA  Cactus Club Cafe       1530 West Broadway
# 4205  aB_wfxQvgso67lzgrrfTuA  Cactus Club Cafe       588 Burrard Street
# 4329  B_JRhoUwjpIqzaFUKQ3S7g  Cactus Club Cafe   101 Schoolhouse Street
# 4618  c7GPtFk8fwAHJ2M0NxUi9g  Cactus Club Cafe    4219 Lougheed Highway
# 4716  jN5cdG9G37WNETLeBLR-9g  Cactus Club Cafe        7907 120th Street
#
#                  city state postal_code   latitude   longitude  stars  \
# 7            Richmond    BC     V6Y 2B6  49.166831 -123.137747    3.5
# 40          Vancouver    BC     V5Z 1E6  49.263373 -123.117130    3.5
# 365         Vancouver    BC     V6E 1B2  49.285027 -123.126059    4.0
# 557         Vancouver    BC     V6C 3E1  49.289402 -123.118043    4.0
# 724   North Vancouver    BC     V7P 2S2  49.322767 -123.107459    4.5
# 1140        Vancouver    BC     V6B 1R2  49.275073 -123.122761    3.5
# 2633   West Vancouver    BC     V7T 2Z3  49.325892 -123.142124    4.0
# 2733          Burnaby    BC     V5J 0A2  49.202009 -122.981730    3.5
# 2997        Vancouver    BC     V6E 1V3  49.286741 -123.142718    3.5
# 3005        Vancouver    BC     V6J 5K9  49.263439 -123.139548    3.5
# 4205        Vancouver    BC     V6C 1A8  49.285459 -123.118732    4.0
# 4329        Coquitlam    BC     V3K 4X8  49.232728 -122.850155    4.0
# 4618          Burnaby    BC     V5C 3Y6  49.266657 -123.011379    3.5
# 4716            Delta    BC     V4C 6P6  49.146889 -122.891112    4.0
#
#       review_count  is_open  \
# 7              123        1
# 40             123        1
# 365            165        1
# 557            683        1
# 724             80        1
# 1140           195        1
# 2633            80        1
# 2733           120        1
# 2997           263        1
# 3005           136        1
# 4205           408        1
# 4329           111        1
# 4618           126        1
# 4716            64        1
#
#                                              attributes  \
# 7     {'HappyHour': 'True', 'Caters': 'False', 'HasT...
# 40    {'Alcohol': "u'full_bar'", 'RestaurantsGoodFor...
# 365   {'BikeParking': 'True', 'RestaurantsAttire': "...
# 557   {'Alcohol': "u'full_bar'", 'RestaurantsGoodFor...
# 724   {'RestaurantsReservations': 'True', 'Caters': ...
# 1140  {'WiFi': "u'free'", 'GoodForKids': 'False', 'A...
# 2633  {'NoiseLevel': "u'average'", 'Alcohol': "u'ful...
# 2733  {'OutdoorSeating': 'True', 'RestaurantsPriceRa...
# 2997  {'WiFi': "'free'", 'NoiseLevel': "u'average'",...
# 3005  {'RestaurantsPriceRange2': '2', 'GoodForKids':...
# 4205  {'NoiseLevel': "u'average'", 'HasTV': 'True', ...
# 4329  {'RestaurantsGoodForGroups': 'True', 'Caters':...
# 4618  {'RestaurantsAttire': "u'casual'", 'NoiseLevel...
# 4716  {'RestaurantsGoodForGroups': 'True', 'Restaura...
#
#                                              categories  \
# 7     Canadian (New), Cocktail Bars, Bars, Nightlife...
# 40    Restaurants, Nightlife, Gluten-Free, Bars, Can...
# 365   Cocktail Bars, Canadian (New), Restaurants, Sa...
# 557   Canadian (New), Cafes, Gastropubs, Lounges, Ni...
# 724   American (New), Restaurants, Bars, Cocktail Ba...
# 1140  Canadian (New), Nightlife, Cocktail Bars, Amer...
# 2633  Nightlife, Cocktail Bars, American (New), Rest...
# 2733  Restaurants, Canadian (New), Cocktail Bars, Fo...
# 2997  Bars, Restaurants, Cocktail Bars, Cafes, Ameri...
# 3005  American (New), Canadian (New), Bars, Cocktail...
# 4205  American (New), Restaurants, Bars, Cafes, Cock...
# 4329  Bars, Restaurants, Canadian (New), Nightlife, ...
# 4618  Canadian (New), Cocktail Bars, Restaurants, Am...
# 4716  Chicken Wings, Canadian (New), Restaurants, Ba...
#
#                                                   hours
# 7     {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 40    {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 365   {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 557   {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 724   {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 1140  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 2633  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 2733  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 2997  {'Monday': '0:0-0:0', 'Tuesday': '11:30-1:0', ...
# 3005  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 4205  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 4329  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 4618  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 4716  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...

# %%
rest3_comp = df_1[df_1['categories'].str.contains('Nightlife','Cocktail')]

rest3_comp
# Out:
#                  business_id                                name  \
# 7     XqaO85CV9Km7m_aQ3iIpRA                    Cactus Club Cafe
# 8     tcreyfoiR2NFMuEz0UClrg                           The Roost
# 10    MYainrGOUR9OGC0eXqpkuA                    Living Room Cafe
# 15    9JRIp0cJUtCV_-riFGmDnQ                           Vino Volo
# 40    u-tcnG8zdDG8QWYTctxyfg                    Cactus Club Cafe
# ...                      ...                                 ...
# 4704  a9P_JDakVrbunkghXHM9ug                      Coco Rico Cafe
# 4707  vXTo69v2bGEyuBdT0X1hrw        La Taqueria Pinche Taco Shop
# 4708  zZuLCpvgrhHb-6Oh03fFOw  Browns Socialhouse Sun:shine Hills
# 4716  jN5cdG9G37WNETLeBLR-9g                    Cactus Club Cafe
# 4724  W95cWsAZvNvRzqBAHvHAfQ                          Triple O's
#
#                                                 address       city state  \
# 7                               1666-6551 Number 3 Road   Richmond    BC
# 8                                    1037 Denman Street  Vancouver    BC
# 10                            3787 Canada Way, Unit 116    Burnaby    BC
# 15    Vancouver International Airport - Concourse E ...   Richmond    BC
# 40                                       575 Broadway W  Vancouver    BC
# ...                                                 ...        ...   ...
# 4704                                 1290 Robson Street  Vancouver    BC
# 4707                              322 W Hastings Street  Vancouver    BC
# 4708                                  6485 120th Street      Delta    BC
# 4716                                  7907 120th Street      Delta    BC
# 4724                                     2015 Main Mall  Vancouver    BC
#
#      postal_code   latitude   longitude  stars  review_count  is_open  \
# 7        V6Y 2B6  49.166831 -123.137747    3.5           123        1
# 8        V6G 2M4  49.289052 -123.139457    3.5             6        1
# 10       V5G 4V4  49.254865 -123.020418    4.0             7        1
# 15       V7B 1Y7  49.197256 -123.174398    4.0            59        1
# 40       V5Z 1E6  49.263373 -123.117130    3.5           123        1
# ...          ...        ...         ...    ...           ...      ...
# 4704     V6E 1C1  49.286774 -123.128585    3.5            69        1
# 4707     V8B 1K6  49.282912 -123.110593    4.5           473        1
# 4708     V4E 3G3  49.120713 -122.890675    3.5            32        1
# 4716     V4C 6P6  49.146889 -122.891112    4.0            64        1
# 4724     V6T 1Z1  49.265920 -123.254532    2.5            17        1
#
#                                              attributes  \
# 7     {'HappyHour': 'True', 'Caters': 'False', 'HasT...
# 8                            {'OutdoorSeating': 'True'}
# 10    {'Ambience': "{'touristy': False, 'hipster': F...
# 15    {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 40    {'Alcohol': "u'full_bar'", 'RestaurantsGoodFor...
# ...                                                 ...
# 4704  {'RestaurantsPriceRange2': '2', 'OutdoorSeatin...
# 4707  {'HasTV': 'False', 'RestaurantsReservations': ...
# 4708  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 4716  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 4724  {'Caters': 'False', 'BusinessParking': "{'gara...
#
#                                              categories  \
# 7     Canadian (New), Cocktail Bars, Bars, Nightlife...
# 8     Bars, Restaurants, Sandwiches, American (Tradi...
# 10    Bars, Lounges, Nightlife, Cafes, Restaurants, ...
# 15    Canadian (New), Tapas/Small Plates, Restaurant...
# 40    Restaurants, Nightlife, Gluten-Free, Bars, Can...
# ...                                                 ...
# 4704  Canadian (New), Breakfast & Brunch, Tapas Bars...
# 4707  Event Planning & Services, Restaurants, Catere...
# 4708  Restaurants, Canadian (New), Breakfast & Brunc...
# 4716  Chicken Wings, Canadian (New), Restaurants, Ba...
# 4724  Burgers, Nightlife, Sports Bars, Restaurants, ...
#
#                                                   hours
# 7     {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 8     {'Monday': '12:0-22:0', 'Tuesday': '12:0-22:0'...
# 10    {'Monday': '14:0-2:0', 'Tuesday': '14:0-2:0', ...
# 15    {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 40    {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# ...                                                 ...
# 4704  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
# 4707  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 4708  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 4716  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
# 4724                                                NaN
#
# [487 rows x 14 columns]

# %%
rest3_comp_filter=rest3_comp[rest3_comp['stars'] >= 4]
rest3_comp_filter
# Out:
#                  business_id                          name  \
# 10    MYainrGOUR9OGC0eXqpkuA              Living Room Cafe
# 15    9JRIp0cJUtCV_-riFGmDnQ                     Vino Volo
# 50    WPrY9K874pABkAqSxO17nw     Showcase Restaurant & Bar
# 101   oHWRtfmqtUXgBuD5XJk3Pg                Kennedy's  Pub
# 118   ulsLlVcGvuLOSN0n3bR2zg          Harbour Oyster + Bar
# ...                      ...                           ...
# 4667  iHgpWa4sNnjGjPsZIi-VNw                     The Ellis
# 4679  0BvstbA_zaIfe6fwtMm-Ow       CinCin Ristorante + Bar
# 4698  YvksVmCj9LMlY92BEqBR8A        Spencer's Resto Lounge
# 4707  vXTo69v2bGEyuBdT0X1hrw  La Taqueria Pinche Taco Shop
# 4716  jN5cdG9G37WNETLeBLR-9g              Cactus Club Cafe
#
#                                                 address       city state  \
# 10                            3787 Canada Way, Unit 116    Burnaby    BC
# 15    Vancouver International Airport - Concourse E ...   Richmond    BC
# 50                            1122 West Hastings Street  Vancouver    BC
# 101                                   11906 88th Avenue      Delta    BC
# 118                               1408 Commercial Drive  Vancouver    BC
# ...                                                 ...        ...   ...
# 4667                                   2204 York Avenue  Vancouver    BC
# 4679                                 1154 Robson Street  Vancouver    BC
# 4698    Delta Hotels and Resorts, 550 W Hastings Street  Vancouver    BC
# 4707                              322 W Hastings Street  Vancouver    BC
# 4716                                  7907 120th Street      Delta    BC
#
#      postal_code   latitude   longitude  stars  review_count  is_open  \
# 10       V5G 4V4  49.254865 -123.020418    4.0             7        1
# 15       V7B 1Y7  49.197256 -123.174398    4.0            59        1
# 50       V6E 4R5  49.287882 -123.120442    4.0           109        1
# 101      V4C 3C8  49.162936 -122.892940    4.0             9        1
# 118      V5L 3X9  49.271895 -123.069182    4.0            39        1
# ...          ...        ...         ...    ...           ...      ...
# 4667         V6K  49.271566 -123.155289    4.5            56        1
# 4679     V6E 1B2  49.285261 -123.126139    4.0           369        1
# 4698     V6B 1L6  49.284143 -123.112606    4.5            11        1
# 4707     V8B 1K6  49.282912 -123.110593    4.5           473        1
# 4716     V4C 6P6  49.146889 -122.891112    4.0            64        1
#
#                                              attributes  \
# 10    {'Ambience': "{'touristy': False, 'hipster': F...
# 15    {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 50    {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 101   {'RestaurantsPriceRange2': '2', 'HasTV': 'True...
# 118   {'BusinessParking': "{'garage': None, 'street'...
# ...                                                 ...
# 4667  {'CoatCheck': 'False', 'RestaurantsPriceRange2...
# 4679  {'HasTV': 'False', 'RestaurantsAttire': "u'dre...
# 4698  {'GoodForKids': 'False', 'RestaurantsPriceRang...
# 4707  {'HasTV': 'False', 'RestaurantsReservations': ...
# 4716  {'RestaurantsGoodForGroups': 'True', 'Restaura...
#
#                                              categories  \
# 10    Bars, Lounges, Nightlife, Cafes, Restaurants, ...
# 15    Canadian (New), Tapas/Small Plates, Restaurant...
# 50    Restaurants, Seafood, Nightlife, American (Tra...
# 101   Restaurants, Bars, Nightlife, British, Sports ...
# 118   Fish & Chips, Nightlife, Seafood, Bars, Restau...
# ...                                                 ...
# 4667  Pubs, Gastropubs, Bars, Nightlife, Restaurants...
# 4679  Italian, Bars, Seafood, Restaurants, Food Deli...
# 4698  American (New), Nightlife, Lounges, Restaurant...
# 4707  Event Planning & Services, Restaurants, Catere...
# 4716  Chicken Wings, Canadian (New), Restaurants, Ba...
#
#                                                   hours
# 10    {'Monday': '14:0-2:0', 'Tuesday': '14:0-2:0', ...
# 15    {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 50    {'Monday': '6:30-0:0', 'Tuesday': '6:30-0:0', ...
# 101   {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...
# 118   {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...
# ...                                                 ...
# 4667  {'Monday': '15:0-22:0', 'Tuesday': '15:0-22:0'...
# 4679  {'Monday': '0:0-0:0', 'Wednesday': '17:0-22:0'...
# 4698  {'Monday': '16:0-22:0', 'Tuesday': '15:0-22:30...
# 4707  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 4716  {'Monday': '0:0-0:0', 'Tuesday': '11:0-1:0', '...
#
# [172 rows x 14 columns]

# %%
rest3_comp_filter=rest3_comp_filter[rest3_comp_filter['review_count'] >= 100]
rest3_comp_filter
# Out:
#                  business_id                          name  \
# 50    WPrY9K874pABkAqSxO17nw     Showcase Restaurant & Bar
# 148   VPqWLp9kMiZEbctCebIZUA                   Medina Cafe
# 168   O9KCg8IfPtbNSlk7M0OdSQ      Johnnie Fox's Irish Snug
# 174   3J_E0XfGLFAHKnQqIO9rXA                JOEY Coquitlam
# 212   B1bE80mdyebL15IVtHrJRA         X-Site Grill & Bistro
# ...                      ...                           ...
# 4493  pdQ4pZ7x9p9lUPY4JgItMw            Zakkushi on Denman
# 4607  htvl5L_V-zKN0UvUgP60PQ                Robba da Matti
# 4635  WAKwis2gWtNjRqFGkgwORw                      AnnaLena
# 4679  0BvstbA_zaIfe6fwtMm-Ow       CinCin Ristorante + Bar
# 4707  vXTo69v2bGEyuBdT0X1hrw  La Taqueria Pinche Taco Shop
#
#                         address       city state postal_code   latitude  \
# 50    1122 West Hastings Street  Vancouver    BC     V6E 4R5  49.287882
# 148         780 Richards Street  Vancouver    BC     V6B 3A4  49.280443
# 168       1033 Granville Street  Vancouver    BC     V6Z 1L4  49.278962
# 174        550 Lougheed Highway  Coquitlam    BC     V3K 3S3  49.242901
# 212        4625 Hastings Street    Burnaby    BC     V5C 2K6  49.281310
# ...                         ...        ...   ...         ...        ...
# 4493          823 Denman Street  Vancouver    BC     V6G 2L7  49.291205
# 4607       1127 Mainland Street  Vancouver    BC     V6B 5P2  49.275340
# 4635          1809 W 1st Avenue  Vancouver    BC     V6J 5B8  49.270826
# 4679         1154 Robson Street  Vancouver    BC     V6E 1B2  49.285261
# 4707      322 W Hastings Street  Vancouver    BC     V8B 1K6  49.282912
#
#        longitude  stars  review_count  is_open  \
# 50   -123.120442    4.0           109        1
# 148  -123.117036    4.0          2302        1
# 168  -123.123755    4.0           111        1
# 174  -122.889260    4.0           139        1
# 212  -122.999140    4.0           128        1
# ...          ...    ...           ...      ...
# 4493 -123.136249    4.0           197        1
# 4607 -123.120897    4.0           435        1
# 4635 -123.146771    4.5           301        1
# 4679 -123.126139    4.0           369        1
# 4707 -123.110593    4.5           473        1
#
#                                              attributes  \
# 50    {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 148   {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 168   {'HasTV': 'True', 'RestaurantsTakeOut': 'True'...
# 174   {'RestaurantsGoodForGroups': 'True', 'Caters':...
# 212   {'RestaurantsPriceRange2': '1', 'RestaurantsTa...
# ...                                                 ...
# 4493  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'Tru...
# 4607  {'NoiseLevel': "u'average'", 'GoodForKids': 'T...
# 4635  {'Alcohol': "u'full_bar'", 'BikeParking': 'Tru...
# 4679  {'HasTV': 'False', 'RestaurantsAttire': "u'dre...
# 4707  {'HasTV': 'False', 'RestaurantsReservations': ...
#
#                                              categories  \
# 50    Restaurants, Seafood, Nightlife, American (Tra...
# 148   Bars, Moroccan, Wine Bars, Breakfast & Brunch,...
# 168           Restaurants, Nightlife, Pubs, Bars, Irish
# 174   Restaurants, Greek, Canadian (New), American (...
# 212   Restaurants, Canadian (New), Nightlife, Bars, ...
# ...                                                 ...
# 4493  Japanese, Restaurants, Bars, Barbeque, Wine Ba...
# 4607  Tapas Bars, Restaurants, Tapas/Small Plates, I...
# 4635  Nightlife, Restaurants, Diners, Breakfast & Br...
# 4679  Italian, Bars, Seafood, Restaurants, Food Deli...
# 4707  Event Planning & Services, Restaurants, Catere...
#
#                                                   hours
# 50    {'Monday': '6:30-0:0', 'Tuesday': '6:30-0:0', ...
# 148   {'Monday': '0:0-0:0', 'Tuesday': '9:0-15:0', '...
# 168   {'Monday': '11:30-1:0', 'Tuesday': '11:30-1:0'...
# 174   {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 212   {'Monday': '11:0-22:30', 'Tuesday': '11:0-22:3...
# ...                                                 ...
# 4493  {'Monday': '0:0-0:0', 'Tuesday': '16:0-23:0', ...
# 4607  {'Monday': '17:0-22:15', 'Tuesday': '17:0-21:0...
# 4635  {'Wednesday': '17:0-22:0', 'Thursday': '17:0-2...
# 4679  {'Monday': '0:0-0:0', 'Wednesday': '17:0-22:0'...
# 4707  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
#
# [71 rows x 14 columns]

# %%
rest3_comp_filter = rest3_comp_filter[rest3_comp_filter['name'].str.contains("Cactus Club Cafe")== False]
rest3_coords=rest3_comp_filter[['name','stars','latitude','longitude']]

# %%
rest3_coords
# Out:
#                               name  stars   latitude   longitude
# 50       Showcase Restaurant & Bar    4.0  49.287882 -123.120442
# 148                    Medina Cafe    4.0  49.280443 -123.117036
# 168       Johnnie Fox's Irish Snug    4.0  49.278962 -123.123755
# 174                 JOEY Coquitlam    4.0  49.242901 -122.889260
# 212          X-Site Grill & Bistro    4.0  49.281310 -122.999140
# ...                            ...    ...        ...         ...
# 4493            Zakkushi on Denman    4.0  49.291205 -123.136249
# 4607                Robba da Matti    4.0  49.275340 -123.120897
# 4635                      AnnaLena    4.5  49.270826 -123.146771
# 4679       CinCin Ristorante + Bar    4.0  49.285261 -123.126139
# 4707  La Taqueria Pinche Taco Shop    4.5  49.282912 -123.110593
#
# [67 rows x 4 columns]

# %%
rest3_coords.to_csv('rest3.csv')

# %%
rest3_og_coords=rest3[['name','stars','latitude','longitude']]

# %%
rest3_og_coords.to_csv('rest3og.csv')

# %%
#rest 5 starts here

# %%
rest5=df_1[df_1['name']=='Sula Indian Restaurant']

# %%
rest5
# Out:
#                  business_id                    name                address  \
# 1619  l0cLT4c59zu0H8MVwp7vqA  Sula Indian Restaurant  1128 Commercial Drive
#
#            city state postal_code   latitude   longitude  stars  review_count  \
# 1619  Vancouver    BC     V5L 2N1  49.274434 -123.069188    4.0           179
#
#       is_open                                         attributes  \
# 1619        1  {'NoiseLevel': "u'average'", 'Alcohol': "u'ful...
#
#                                         categories  \
# 1619  Restaurants, Indian, Vegetarian, Gluten-Free
#
#                                                   hours
# 1619  {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...

# %%
rest5_comp=df_1[df_1['categories'].str.contains('Indian')]

# %%
rest5_comp
# Out:
#                  business_id                                   name  \
# 2     Xi2GGNzOiUS8r6WCFvu-fw                         Kerala Kitchen
# 6     AaNj_9KNy9t1H1cu1NCNLQ               Mumbai Masala Restaurant
# 42    mKgqjVBcEJD3JwEx1k27jQ             Navraj Sweets & Restaurant
# 93    VCiopspKLHelqobEsSeNxw                         House of Dosas
# 108   _Ief3C6t-930SBuwvVuDAQ                    Tasty Indian Bistro
# ...                      ...                                    ...
# 4505  RMy907_r36OEjHm-sCMM9w                          Rice 'N Spice
# 4568  nbkyXYzUozfOBzir2F7ePA                         Main Kabab Hut
# 4616  tcridEGsBziueOjzuPr1fQ                             Indian Wok
# 4639  MpLoj5dtljg6ksh5LYRfwQ  Fraserview Tandoori House & Meat Shop
# 4670  r6xLifuHkUSxWLBEGu4M7w            Mirch Masala Indian Cuisine
#
#                                address             city state postal_code  \
# 2                 103- 9386 120 Street           Surrey    BC     V3V 4B9
# 6      333 Brooksbank Avenue, Unit 770  North Vancouver    BC     V7J 3V8
# 42           8148 128 Street, Unit 386           Surrey    BC         V3W
# 93                       1391 Kingsway        Vancouver    BC     V5V 3E3
# 108                    8295 Scott Road            Delta    BC     V4C 6R1
# ...                                ...              ...   ...         ...
# 4505  1055 W Georgia Street, Suite 218        Vancouver    BC     V6E 3P1
# 4568                 215 E 49th Avenue        Vancouver    BC     V5W 2V4
# 4616                     5212 Kingsway          Burnaby    BC     V5H 2G1
# 4639                      7271 Main St        Vancouver    BC     V5X 3J3
# 4670                 9545-120th Street            Delta    BC     V4C 6S3
#
#        latitude   longitude  stars  review_count  is_open  \
# 2     49.173723 -122.889641    4.0             9        1
# 6     49.310091 -123.041686    3.5            54        1
# 42    49.150180 -122.866438    4.5            14        1
# 93    49.250466 -123.076325    4.0           411        1
# 108   49.154520 -122.890501    4.5           526        1
# ...         ...         ...    ...           ...      ...
# 4505  49.285298 -123.121724    3.0            30        1
# 4568  49.225753 -123.101232    4.0            61        1
# 4616  49.224841 -122.988467    4.0            86        1
# 4639  49.218788 -123.102185    4.0            19        1
# 4670  49.175928 -122.890811    4.0            73        1
#
#                                              attributes  \
# 2     {'BusinessParking': "{'garage': False, 'street...
# 6     {'OutdoorSeating': 'False', 'RestaurantsReserv...
# 42    {'BusinessParking': "{'garage': False, 'street...
# 93    {'RestaurantsReservations': 'True', 'Alcohol':...
# 108   {'RestaurantsReservations': 'True', 'HasTV': '...
# ...                                                 ...
# 4505  {'RestaurantsPriceRange2': '1', 'RestaurantsRe...
# 4568  {'RestaurantsGoodForGroups': 'False', 'Restaur...
# 4616  {'WiFi': "u'free'", 'BusinessParking': "{'gara...
# 4639  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 4670  {'HasTV': 'True', 'RestaurantsPriceRange2': '2...
#
#                                              categories  \
# 2                                   Indian, Restaurants
# 6                                   Restaurants, Indian
# 42                                  Restaurants, Indian
# 93    Indian, Pakistani, Restaurants, Ethnic Food, F...
# 108                                 Restaurants, Indian
# ...                                                 ...
# 4505  Turkish, Restaurants, Mediterranean, Indian, A...
# 4568  Pakistani, Mediterranean, Restaurants, Indian,...
# 4616                       Chinese, Restaurants, Indian
# 4639                                Restaurants, Indian
# 4670     Indian, Restaurants, Pakistani, Middle Eastern
#
#                                                   hours
# 2     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 6     {'Monday': '11:0-21:30', 'Tuesday': '11:0-21:3...
# 42    {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...
# 93    {'Monday': '11:0-3:0', 'Tuesday': '11:0-3:0', ...
# 108   {'Monday': '11:30-0:0', 'Tuesday': '11:30-0:0'...
# ...                                                 ...
# 4505  {'Monday': '10:0-16:0', 'Tuesday': '10:0-16:0'...
# 4568  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 4616  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 4639                                                NaN
# 4670  {'Monday': '11:30-22:30', 'Tuesday': '11:30-22...
#
# [184 rows x 14 columns]

# %%
rest5_comp_filter=rest5_comp[rest5_comp['stars'] >= 4.0]

# %%
rest5_comp_filter=rest5_comp_filter[rest5_comp_filter['review_count'] >= 100]

# %%
len(rest5_comp_filter)
# Out:
# 24

# %%
rest5_comp_filter = rest5_comp_filter[rest5_comp_filter['name'].str.contains("Sula Indian Restaurant")== False]
rest5_coords=rest5_comp_filter[['name','stars','latitude','longitude']]

# %%
rest5_coords=rest5_coords.sort_values('stars',ascending=False)

# %%
rest5_coords
# Out:
#                                                name  stars   latitude  \
# 2130                            Indian Roti Kitchen    4.5  49.259024
# 510                           Delhi 6 Indian Bistro    4.5  49.265235
# 3521                              Mirchi Restaurant    4.5  49.213541
# 681                        Indian Fusion Restaurant    4.5  49.327987
# 1338                                    Dosa Corner    4.5  49.209751
# 1649                  Lazzez's Grill Indian Cuisine    4.5  49.277355
# 108                             Tasty Indian Bistro    4.5  49.154520
# 2807                                   East Is East    4.0  49.264389
# 3983                                   Salam Bombay    4.0  49.284023
# 3588  Green Lettuce Indian Style Chinese Restaurant    4.0  49.245795
# 3511                           Indian Bombay Bistro    4.0  49.223157
# 3434                               Apna Chaat House    4.0  49.139607
# 3421                             Davie Dosa Company    4.0  49.282163
# 2907                       Agra Tandoori Restaurant    4.0  49.254436
# 93                                   House of Dosas    4.0  49.250466
# 2597                            Tasty Indian Bistro    4.0  49.274317
# 2391                             Chili Pepper House    4.0  49.236280
# 2129                                   East is East    4.0  49.245353
# 1164                    Spicy 6 Fine Indian Cuisine    4.0  49.284819
# 630                                    Dosa Factory    4.0  49.251000
# 437                                Vij's Restaurant    4.0  49.257537
# 119                                 Tandoori Fusion    4.0  49.263968
# 4148                                Raga Restaurant    4.0  49.263478
#
#        longitude
# 2130 -123.115355
# 510  -123.144968
# 3521 -123.140140
# 681  -123.072428
# 1338 -123.090829
# 1649 -122.804792
# 108  -122.890501
# 2807 -123.172693
# 3983 -123.121840
# 3588 -123.065938
# 3511 -122.932603
# 3434 -122.890066
# 3421 -123.133735
# 2907 -123.020050
# 93   -123.076325
# 2597 -123.123969
# 2391 -123.041712
# 2129 -123.101476
# 1164 -123.125714
# 630  -123.076990
# 437  -123.114788
# 119  -123.169557
# 4148 -123.130517

# %%
rest5_coords.to_csv('rest5.csv')

# %%
rest5_og_coords=rest5[['name','stars','latitude','longitude']]

# %%
rest5_og_coords.to_csv('rest5og.csv')

# %%
##3folium part starts here

# %%
import pandas as pd
# !pip3 install folium
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: folium in /usr/local/lib/python3.9/site-packages (0.12.1.post1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.9/site-packages (from folium) (3.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from folium) (1.21.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from folium) (2.27.1)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.9/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->folium) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->folium) (1.26.8)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
mb1 = pd.read_csv("rest1og.csv")
mb1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 mb1 = pd.read_csv("rest1og.csv")
#       2 mb1
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
mbc1 = pd.read_csv("rest1.csv")
mbc1
# Out:
#    Unnamed: 0                             name  stars   latitude   longitude
# 0        1299                    La Mezcaleria    4.0  49.270090 -123.069500
# 1        3746  The Mexican Antojitos Y Cantina    4.5  49.278828 -123.124044
# 2        4085                      Sal y Limón    4.0  49.256904 -123.089246
# 3        4089                 La Catrina Tacos    4.5  49.287774 -123.141263

# %%
mb2 = pd.read_csv("rest2og.csv")
mb2
# Out:
#    Unnamed: 0      name  stars   latitude   longitude
# 0         505  De Dutch    3.5  49.319227 -123.090558
# 1         809  De Dutch    3.5  49.290030 -123.116896
# 2        2538  De Dutch    3.5  49.324860 -123.121427
# 3        3385  De Dutch    3.0  49.272474 -122.789011
# 4        3592  De Dutch    3.0  49.166082 -122.800249
# 5        3889  De Dutch    3.5  49.257264 -123.127002
# 6        4024  De Dutch    2.5  49.267136 -123.113174
# 7        4529  De Dutch    3.0  49.200446 -122.917667

# %%
mbc2 = pd.read_csv("rest2.csv")
mbc2
# Out:
#    Unnamed: 0               name  stars   latitude   longitude
# 0         734    Breakfast Table    4.5  49.258568 -123.138517
# 1        1163  OEB Breakfast Co.    4.0  49.273457 -123.119265
# 2        2604        Joe's Grill    4.0  49.279750 -123.129945

# %%
mb3 = pd.read_csv("rest3og.csv")
mb3
# Out:
#     Unnamed: 0              name  stars   latitude   longitude
# 0            7  Cactus Club Cafe    3.5  49.166831 -123.137747
# 1           40  Cactus Club Cafe    3.5  49.263373 -123.117130
# 2          365  Cactus Club Cafe    4.0  49.285027 -123.126059
# 3          557  Cactus Club Cafe    4.0  49.289402 -123.118043
# 4          724  Cactus Club Cafe    4.5  49.322767 -123.107459
# 5         1140  Cactus Club Cafe    3.5  49.275073 -123.122761
# 6         2633  Cactus Club Cafe    4.0  49.325892 -123.142124
# 7         2733  Cactus Club Cafe    3.5  49.202009 -122.981730
# 8         2997  Cactus Club Cafe    3.5  49.286741 -123.142718
# 9         3005  Cactus Club Cafe    3.5  49.263439 -123.139548
# 10        4205  Cactus Club Cafe    4.0  49.285459 -123.118732
# 11        4329  Cactus Club Cafe    4.0  49.232728 -122.850155
# 12        4618  Cactus Club Cafe    3.5  49.266657 -123.011379
# 13        4716  Cactus Club Cafe    4.0  49.146889 -122.891112

# %%
mbc3 = pd.read_csv("rest3.csv")
mbc3
# Out:
#     Unnamed: 0                          name  stars   latitude   longitude
# 0           50     Showcase Restaurant & Bar    4.0  49.287882 -123.120442
# 1          148                   Medina Cafe    4.0  49.280443 -123.117036
# 2          168      Johnnie Fox's Irish Snug    4.0  49.278962 -123.123755
# 3          174                JOEY Coquitlam    4.0  49.242901 -122.889260
# 4          212         X-Site Grill & Bistro    4.0  49.281310 -122.999140
# ..         ...                           ...    ...        ...         ...
# 62        4493            Zakkushi on Denman    4.0  49.291205 -123.136249
# 63        4607                Robba da Matti    4.0  49.275340 -123.120897
# 64        4635                      AnnaLena    4.5  49.270826 -123.146771
# 65        4679       CinCin Ristorante + Bar    4.0  49.285261 -123.126139
# 66        4707  La Taqueria Pinche Taco Shop    4.5  49.282912 -123.110593
#
# [67 rows x 5 columns]

# %%
mb4 = pd.read_csv("rest4og.csv")
mb4
# Out:
#    Unnamed: 0                       name  stars   latitude  longitude
# 0          22  Akari Japanese Restaurant    4.0  49.134883 -122.89192

# %%
mbc4 = pd.read_csv("rest4.csv")
mbc4
# Out:
#     Unnamed: 0                             name  stars   latitude   longitude
# 0          166                        Pokérrito    4.0  49.282642 -123.115118
# 1          307            Sushimoto Enterprises    4.0  49.264259 -122.981803
# 2          369                    Sushi By Yuji    4.0  49.242483 -123.059835
# 3          376         Seto Japanese Restaurant    4.0  49.177587 -123.129710
# 4          455                 Green Leaf Sushi    4.0  49.264268 -123.180100
# 5          500                      Kaide Sushi    4.5  49.274238 -123.127095
# 6          665            Fujiya Japanese Foods    4.0  49.276554 -123.076880
# 7          991                        Sushi Jin    4.5  49.279579 -123.123818
# 8         1136                  Kimbap Cheonguk    4.5  49.244698 -122.891831
# 9         1355  Sushi Hachi Japanese Restaurant    4.5  49.183988 -123.126650
# 10        1450  Hitoe Sushi Japanese Restaurant    4.0  49.268654 -123.178708
# 11        1531                        Tom Sushi    5.0  49.281650 -123.132662
# 12        1541                 Sushi K Kamizato    4.0  49.254224 -122.783238
# 13        1724            Tatsu Japanese Bistro    4.0  49.271623 -123.069889
# 14        1871                     Temaki Sushi    4.0  49.263919 -123.154395
# 15        1900                            Shiro    4.0  49.257930 -123.114617
# 16        1939   Sushi Uomo Japanese Restaurant    4.0  49.280950 -123.009199
# 17        1956                  Blue Water Cafe    4.5  49.276155 -123.121129
# 18        2038                             Miku    4.5  49.287008 -123.113051
# 19        2290                  Sushi Bar Maumi    4.0  49.281408 -123.133696
# 20        2301                            Suika    4.0  49.263410 -123.141690
# 21        2578                      FRESH Sushi    4.0  49.275706 -123.115138
# 22        2622                        Shizen Ya    4.0  49.280884 -123.124628
# 23        2720                      Toshi Sushi    4.0  49.256699 -123.101936
# 24        2728                  Green Leaf Cafe    4.0  49.253277 -122.898401
# 25        2883            Kimu Japanese Cuisine    4.0  49.244919 -123.024194
# 26        3152                           Minami    4.0  49.275266 -123.120816
# 27        3461       Kishimoto Japanese Kitchen    4.5  49.266736 -123.069411
# 28        3527                      Sushi Mania    4.0  49.250538 -123.101180
# 29        3602                   Westcoast Poke    4.0  49.264087 -123.113864
# 30        3641              Bishop's Restaurant    4.5  49.268324 -123.154703
# 31        4123                        Sushi Hub    4.0  49.241181 -123.101670
# 32        4303                   Victoria Sushi    4.0  49.213378 -122.898880
# 33        4330                            Raisu    4.0  49.267999 -123.158381
# 34        4409             Shizenya on Broadway    4.0  49.263875 -123.134264
# 35        4421                      Isami Sushi    4.0  49.229657 -123.002154
# 36        4555               Black Rice Izakaya    4.0  49.278444 -123.114329
# 37        4625              Yui Japanese Bistro    4.0  49.287111 -123.124702
# 38        4631                 Ajisai Sushi Bar    4.0  49.233934 -123.153690
# 39        4641                  Tsuki Sushi Bar    4.0  49.280983 -123.107658
# 40        4652                   Octopus Garden    4.0  49.272630 -123.149817

# %%
mb5 = pd.read_csv("rest5og.csv")
mb5
# Out:
#    Unnamed: 0                    name  stars   latitude   longitude
# 0        1619  Sula Indian Restaurant    4.0  49.274434 -123.069188

# %%
mbc5 = pd.read_csv("rest5.csv")
mbc5
# Out:
#     Unnamed: 0                                           name  stars  \
# 0         2130                            Indian Roti Kitchen    4.5
# 1          510                          Delhi 6 Indian Bistro    4.5
# 2         3521                              Mirchi Restaurant    4.5
# 3          681                       Indian Fusion Restaurant    4.5
# 4         1338                                    Dosa Corner    4.5
# 5         1649                  Lazzez's Grill Indian Cuisine    4.5
# 6          108                            Tasty Indian Bistro    4.5
# 7         2807                                   East Is East    4.0
# 8         3983                                   Salam Bombay    4.0
# 9         3588  Green Lettuce Indian Style Chinese Restaurant    4.0
# 10        3511                           Indian Bombay Bistro    4.0
# 11        3434                               Apna Chaat House    4.0
# 12        3421                             Davie Dosa Company    4.0
# 13        2907                       Agra Tandoori Restaurant    4.0
# 14          93                                 House of Dosas    4.0
# 15        2597                            Tasty Indian Bistro    4.0
# 16        2391                             Chili Pepper House    4.0
# 17        2129                                   East is East    4.0
# 18        1164                    Spicy 6 Fine Indian Cuisine    4.0
# 19         630                                   Dosa Factory    4.0
# 20         437                               Vij's Restaurant    4.0
# 21         119                                Tandoori Fusion    4.0
# 22        4148                                Raga Restaurant    4.0
#
#      latitude   longitude
# 0   49.259024 -123.115355
# 1   49.265235 -123.144968
# 2   49.213541 -123.140140
# 3   49.327987 -123.072428
# 4   49.209751 -123.090829
# 5   49.277355 -122.804792
# 6   49.154520 -122.890501
# 7   49.264389 -123.172693
# 8   49.284023 -123.121840
# 9   49.245795 -123.065938
# 10  49.223157 -122.932603
# 11  49.139607 -122.890066
# 12  49.282163 -123.133735
# 13  49.254436 -123.020050
# 14  49.250466 -123.076325
# 15  49.274317 -123.123969
# 16  49.236280 -123.041712
# 17  49.245353 -123.101476
# 18  49.284819 -123.125714
# 19  49.251000 -123.076990
# 20  49.257537 -123.114788
# 21  49.263968 -123.169557
# 22  49.263478 -123.130517

# %%
# !pip3 install folium
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: folium in /usr/local/lib/python3.9/site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.9/site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.9/site-packages (from folium) (3.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->folium) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import folium

# %%
m = folium.Map(location=[49.285006, -123.118050	],
               zoom_start=14)

for index, row in mb1.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'green',icon='glass')
                 ).add_to(m)


a = mbc1['latitude'].to_list()
b = mbc1['longitude'].to_list()
points = []

c = mb1['latitude'].to_list()
d = mb1['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc1.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'red', icon = 'star')
                 ).add_to(m)

for index, row in mbc1.iterrows():
    folium.PolyLine(pointsc, color='blue', weight=3).add_to(m)
    
for index, row in mb1.iterrows():
    folium.PolyLine(points, color='red', weight=3).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_02436197808b4b6aa19f99908367eac6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_02436197808b4b6aa19f99908367eac6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_02436197808b4b6aa19f99908367eac6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_02436197808b4b6aa19f99908367eac6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
m = folium.Map(location=[49.285006, -123.118050	],
               zoom_start=14)

for index, row in mb2.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'green',icon='glass')
                 ).add_to(m)


a = mbc2['latitude'].to_list()
b = mbc2['longitude'].to_list()
points = []

c = mb2['latitude'].to_list()
d = mb2['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc2.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'red', icon = 'star')
                 ).add_to(m)

for index, row in mbc2.iterrows():
    folium.PolyLine(pointsc, color='blue', weight=3).add_to(m)
    
for index, row in mb2.iterrows():
    folium.PolyLine(points, color='red', weight=3).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_adc9d2579e60423d9cf60e148ae8c62b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_adc9d2579e60423d9cf60e148ae8c62b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_adc9d2579e60423d9cf60e148ae8c62b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_adc9d2579e60423d9cf60e148ae8c62b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
m = folium.Map(location=[49.285006, -123.118050	],
               zoom_start=14)

for index, row in mb3.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'green',icon='glass')
                 ).add_to(m)


a = mbc3['latitude'].to_list()
b = mbc3['longitude'].to_list()
points = []

c = mb3['latitude'].to_list()
d = mb3['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc3.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'red', icon = 'star')
                 ).add_to(m)

for index, row in mbc3.iterrows():
    folium.PolyLine(pointsc, color='blue', weight=3).add_to(m)
    
for index, row in mb3.iterrows():
    folium.PolyLine(points, color='red', weight=3).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2d04f9f2d73e46518a0dea75a7c10ee8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2d04f9f2d73e46518a0dea75a7c10ee8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2d04f9f2d73e46518a0dea75a7c10ee8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2d04f9f2d73e46518a0dea75a7c10ee8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
m = folium.Map(location=[49.285006, -123.118050	],
               zoom_start=14)

for index, row in mb4.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'green',icon='glass')
                 ).add_to(m)


a = mbc4['latitude'].to_list()
b = mbc4['longitude'].to_list()
points = []

c = mb4['latitude'].to_list()
d = mb4['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc4.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'red', icon = 'star')
                 ).add_to(m)

for index, row in mbc4.iterrows():
    folium.PolyLine(pointsc, color='blue', weight=3).add_to(m)
    
for index, row in mb4.iterrows():
    folium.PolyLine(points, color='red', weight=3).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_459ba67603194617ae93aaeca59d52ae%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_459ba67603194617ae93aaeca59d52ae%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_459ba67603194617ae93aaeca59d52ae%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_459ba67603194617ae93aaeca59d52ae%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# !pip3 install ipywidgets
import ipywidgets as widgets
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/site-packages (7.7.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets) (3.6.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets) (1.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/site-packages (from ipywidgets) (6.9.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets) (8.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.9/site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.4)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: appnope in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (57.4.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.28)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.4.8)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.4.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.3)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.11)
# Requirement already satisfied: testpath in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.7)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in /usr/local/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
m5 = folium.Map(location=[49.285006, -123.118050	],
               zoom_start=14)

for index, row in mb5.iterrows():
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'green',icon='glass')
                 ).add_to(m)


a = mbc5['latitude'].to_list()
b = mbc5['longitude'].to_list()
points = []

c = mb5['latitude'].to_list()
d = mb5['longitude'].to_list()
pointsc = []

for i in range(len(a)):
    points.append([a[i], b[i]])
    
for i in range(len(c)):
    pointsc.append([c[i], d[i]])

for index, row in mbc5.iterrows():
        
    iframe = folium.IFrame(width=200, height=200)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker([row['latitude'], row['longitude']], 
                  popup=row[['name','stars']],
                  icon=folium.Icon(color = 'red', icon = 'star')
                 ).add_to(m)

for index, row in mbc5.iterrows():
    folium.PolyLine(pointsc, color='blue', weight=3).add_to(m)
    
for index, row in mb5.iterrows():
    folium.PolyLine(points, color='red', weight=3).add_to(m)
    
widgets.Dropdown(options=['Mucho Burito', 'De Dutch', 'Cactus Club Cafe'], value=  'Mucho Burito', description='Restaurant:')
# Out:
# Dropdown(description='Restaurant:', options=('Mucho Burito', 'De Dutch', 'Cactus Club Cafe'), value='Mucho Bur…

# %%
from folium.plugins import Draw

# %%
#m = folium.Map()
Draw(
    export=True,
    Dropdown=True,
    filename='my_data.geojson',
    position='topleft',
    draw_options={'polyline': {'allowIntersection': False}},
    edit_options={'poly': {'allowIntersection': False}}


).add_to(m5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [184], in <cell line: 2>()
#       1 #m = folium.Map()
# ----> 2 Draw(
#       3     export=True,
#       4     Dropdown=True,
#       5     filename='my_data.geojson',
#       6     position='topleft',
#       7     draw_options={'polyline': {'allowIntersection': False}},
#       8     edit_options={'poly': {'allowIntersection': False}}
#       9
#      10
#      11 ).add_to(m5)
#
# TypeError: __init__() got an unexpected keyword argument 'Dropdown'

# %%
folium.LayerControl().add_to(m5)

# %%
m5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_18a1264844274eada1f28be896b2b037%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23export%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20absolute%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%205px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20right%3A%2010px%3B%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
from branca.element import Figure
fig=Figure(width=550,height=350)

# %%
m1=folium.Map()
fig.add_child(m1)
m1
# Out:
# <iframe src="about:blank" width="550" height="350"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c3ec8c776b124d8fb3c1051e77a22c90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c3ec8c776b124d8fb3c1051e77a22c90%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c3ec8c776b124d8fb3c1051e77a22c90%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c3ec8c776b124d8fb3c1051e77a22c90%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%201%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
fig2=Figure(width=550,height=350)
# m2=folium.Map(location=[28.644800, 77.216721])
fig2.add_child(m5)
folium.TileLayer('Stamen Terrain').add_to(m5)
# folium.TileLayer('Stamen Toner').add_to(m3)
# folium.TileLayer('Stamen Water Color').add_to(m4)
# folium.TileLayer('cartodbpositron').add_to(m2)
folium.TileLayer('cartodbdark_matter').add_to(m1)
folium.LayerControl().add_to(m1)
m1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [197], in <cell line: 4>()
#       2 # m2=folium.Map(location=[28.644800, 77.216721])
#       3 fig2.add_child(m5)
# ----> 4 folium.TileLayer('Sula Indian Restaurant').add_to(m5)
#       5 # folium.TileLayer('Stamen Toner').add_to(m3)
#       6 # folium.TileLayer('Stamen Water Color').add_to(m4)
#       7 # folium.TileLayer('cartodbpositron').add_to(m2)
#       8 folium.TileLayer('cartodbdark_matter').add_to(m1)
#
# File /usr/local/lib/python3.9/site-packages/folium/raster_layers.py:111, in TileLayer.__init__(self, tiles, min_zoom, max_zoom, max_native_zoom, attr, detect_retina, name, overlay, control, show, no_wrap, subdomains, tms, opacity, **kwargs)
#     109     self.tiles = tiles
#     110     if not attr:
# --> 111         raise ValueError('Custom tiles must have an attribution.')
#     113 self.options = parse_options(
#     114     min_zoom=min_zoom,
#     115     max_zoom=max_zoom,
#    (...)
#     123     **kwargs
#     124 )
#
# ValueError: Custom tiles must have an attribution.

# %%
# !pip3 install geopandas
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: geopandas in /usr/local/lib/python3.9/site-packages (0.10.2)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.9/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.9/site-packages (from geopandas) (1.4.1)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.9/site-packages (from geopandas) (1.8.1.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.9/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import geopandas as gpd

# %%
p = folium.Map(location=[49.285006, -123.118050], zoom_start=10, control_scale=True)
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_812ab593459446e485f23dd897330be7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_812ab593459446e485f23dd897330be7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_812ab593459446e485f23dd897330be7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_812ab593459446e485f23dd897330be7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
outfp = "base_map.html"
p.save(outfp)

# %%
# Create a Map instance
m = folium.Map(location=[60.20, 24.96],
    zoom_start=12, control_scale=True)

# Add marker
# Run: help(folium.Icon) for more info about icons
folium.Marker(
    location=[60.20426, 24.96179],
    popup='Kumpula Campus',
    icon=folium.Icon(color='green', icon='ok-sign'),
).add_to(m)

#Show map
m

# %%
mbc1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 mbc1
#
# NameError: name 'mbc1' is not defined

# %%
points=[mbc1['latitude'],mbc1['longitude']]
points
# Out:
# [0    49.270090
#  1    49.278828
#  2    49.256904
#  3    49.287774
#  Name: latitude, dtype: float64,
#  0   -123.069500
#  1   -123.124044
#  2   -123.089246
#  3   -123.141263
#  Name: longitude, dtype: float64]

# %%
# Read the data
points = gpd.read_file(points_fp)

#Check input data
points.head()

# %%
from geopandas import GeoSeries
import geopandas as gpd

# %%
gdf = gpd.GeoDataFrame(
    mbc1, geometry=gpd.points_from_xy(mbc1.longitude, mbc1.latitude))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
#       1 gdf = gpd.GeoDataFrame(
# ----> 2     mbc1, geometry=gpd.points_from_xy(mbc1.longitude, mbc1.latitude))
#
# NameError: name 'mbc1' is not defined

# %%
gdf.crs = "EPSG:4326"

# %%
points_gjson = folium.features.GeoJson(gdf, name="Compettitors for Mucho Buritto")
points_gjson.add_to(p)

folium.LayerControl().add_to(p)

# %%
widgets.Dropdown(options=['Mucho Burito', 'De Dutch', 'Cactus Club Cafe'], value=  'Mucho Burito', description='Restaurant:')


folium.LayerControl().add_to(p)

# %%
widgets.Dropdown(options=['Mucho Burito', 'De Dutch', 'Cactus Club Cafe'], value=  'Mucho Burito', description='Restaurant:')
# Out:
# Dropdown(description='Restaurant:', options=('Mucho Burito', 'De Dutch', 'Cactus Club Cafe'), value='Mucho Bur…

# %%
folium.LayerControl().add_to(p)

# %%
gdf2 = gpd.GeoDataFrame(
    mb1, geometry=gpd.points_from_xy(mb1.longitude, mb1.latitude))

# %%
gdf2.crs = "EPSG:4326"

# %%
points_gjson2 = folium.features.GeoJson(gdf2, name="Mucho Buritto")
points_gjson2.add_to(p)


folium.LayerControl().add_to(p)

# %%
folium.LayerControl().add_to(p)

# %%
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6d59f4fd68544e4abebbb0ce6c329cee%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6d59f4fd68544e4abebbb0ce6c329cee%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6d59f4fd68544e4abebbb0ce6c329cee%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6d59f4fd68544e4abebbb0ce6c329cee%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# Create a Map instance

# Add points to the map instance
points_gjson.add_to(p)

# Alternative syntax for adding points to the map instance
#m.add_child(points_gjson)


#Show map
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2828e8075d184841b6577fb19e02f1bf%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2828e8075d184841b6577fb19e02f1bf%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2828e8075d184841b6577fb19e02f1bf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2828e8075d184841b6577fb19e02f1bf%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
folium.LayerControl().add_to(p)
p.add_child(points_gjson)

#Show map
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2828e8075d184841b6577fb19e02f1bf%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2828e8075d184841b6577fb19e02f1bf%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2828e8075d184841b6577fb19e02f1bf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2828e8075d184841b6577fb19e02f1bf%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2828e8075d184841b6577fb19e02f1bf%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2828e8075d184841b6577fb19e02f1bf%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2828e8075d184841b6577fb19e02f1bf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2828e8075d184841b6577fb19e02f1bf%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.285006%2C%20-123.11805%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
df_1['name'].max()

# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import numpy as np

# %%
coords = burioto_comp[['latitude', 'longitude']].values

# %%
kms_per_radian = 6371.0088
epsilon = 1 / kms_per_radian
db = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree', metric='haversine')

# %%
labels = db.fit_predict(np.radians(coords))

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True

# %%
# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = labels == k

    xy = coords[class_member_mask & core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=14,
    )

    xy = coords[class_member_mask & ~core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=6,
    )

plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [162], in <cell line: 2>()
#       1 # Black removed and is used for noise instead.
# ----> 2 unique_labels = set(labels)
#       3 colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
#       4 for k, col in zip(unique_labels, colors):
#
# NameError: name 'labels' is not defined

# %%
df1_name

# %%
locations_A2=df1_name[['latitude','longitude','name','stars']]
locations_A2

# %%
locations_A2.to_csv('locationwithmeta.csv')

# %%
locations_B2=burioto_comp[['latitude','longitude','name','stars']]

locations_B2

# %%
locations_B2.to_csv('compwithmeta.csv')

# %%
locations_A=df1_name[['latitude','longitude','name']]
locations_B=pd.DataFrame(coords)

# %%
locations_A=locations_A.reset_index()

# %%
df_1.loc[509:,].head(1)

# %%
df_1.loc[1451:,].head(1)

# %%
df_1.loc[2755:,].head(1)

# %%
df_1.loc[3725:,].head(1)

# %%
locations_A

# %%
locations_A.drop(columns='index')

# %%
locations_B

# %%
import pandas as pd
import numpy as np
import sklearn.neighbors
# Create two dataframes with city names and lat-long in degrees

# %%
locations_A

# %%
locations_B.iloc[:, 0]

# %%
locations_A[['lat_radians_A','long_radians_A']] = (
    np.radians(locations_A.loc[:,['latitude','longitude']])
)

# %%
# add columns with radians for latitude and longitude

locations_B[['lat_radians_B','long_radians_B']] = (
    np.radians(locations_B.iloc[:,[0,1]])
)

# %%
locations_B

# %%
dist = sklearn.neighbors.DistanceMetric.get_metric('haversine')
dist_matrix = (dist.pairwise
    (locations_A[['lat_radians_A','long_radians_A']],
     locations_B[['lat_radians_B','long_radians_B']])*3959
)
# Note that 3959 is the radius of the earth in miles
df_dist_matrix = (
    pd.DataFrame(dist_matrix)
)

# %%
# Unpivot this dataframe from wide format to long format.
# When you unpivot, the data in the pivot table becomes a
# column named 'value'. Rename this column to 'miles' for clarity.
df_dist_long = (
    pd.melt(df_dist_matrix.reset_index())
)
df_dist_long = df_dist_long.rename(columns={'value':'miles'})

# %%
df_dist_long

# %%
locations_A

# %%
locations_A.to_csv('mucho_burrito.csv', encoding='utf-8')

# %%
locations_B.to_csv('mucho_burrito_comp.csv', encoding='utf-8')

# %%
pip install folium

# %%
listb1=locations_B.iloc[:,0]
listb2=locations_B.iloc[:,1]

# %%
listb3=pd.concat(listb1,listb2)
listb3

# %%
import folium
m=folium.Map(listb1,listb2)
m

# %%
category_list_client_exploded['categories']=df_1['categories'].str.split(',')

# %%
category_list_client_exploded

# %%
# # initializing the data and an empty list
# flat_list = []

# # iterating over the data
# for item in category_list_client_exploded:
#     # appending elements to the flat_list
#     flat_list += item

# # printing the resultantn flat_list
# print(flat_list)

# %%
competitor_common_categories_df = pd.DataFrame(columns = ['index', 'nr_common_categories', 'list_common_categories'])

competitor_common_categories_df

# %%
cuisines_list = ['Mexican', 'American', 'Italian', 'Indian', 
            'Chinese', 'Mediterranean', 'Pizza', 'Bars']
cusines['cuisines']=pd.DataFrame(cuisines_list)

# %%
cusines

# %%
common_cuisnes=category_list_client_exploded[category_list_client_exploded.isin(cusines)]
common_cuisnes

# %%
cusines

# %%
common_cuisnes2=df_1[df_1['categories'].isin(cusines['cuisines'])]
common_cuisnes2

# %%
pd.Series(list(set(s1).intersection(set(s2))))

# %%
common_cuisnes = (list(set(category_list_client_exploded["categories"])).intersection(set(cusines["cuisines"])))
df_subset = category_list_client_exploded[category_list_client_exploded["categories"].isin(common_users) & cusines["cuisines"].isin(common_users)]

# %%
category_list_client_exploded

# %%
def get_cuisine(x,y):
    for cuisine in y:
        if cuisine in x:
            print (cuisine)
            return cuisine
    else:
        return 'other'
get_cuisine(category_list_client_exploded,cuisines)

# %%
for index, row in category_list_client_exploded.iteritems():
         print(index,row)

# %%
category_list_client

# %%
cuisines = ['mexican', 'american', 'italian', 'indian', 
            'chinese', 'mediterranean', 'pizza', 'bar']
